# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
import os, sys
import glob
import numpy as np
import torch
import pandas as pd
import random
import torch.nn as nn
import pickle
import torch.nn.functional as F

# %%
from mstcn_model import *
from utility.adaptive_data_loader import Breakfast, collate_fn_override
from utils import calculate_mof, dotdict

# %%
os.environ["WANDB_API_KEY"] = "992b3b1371ba79f48484cfca522b3786d7fa52c2"
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dipika_singhania (use `wandb login --relogin` to force relogin)
# True

# %%
seed = 42

# Ensure deterministic behavior
def set_seed():
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
set_seed()

# Device configuration
os.environ['CUDA_VISIBLE_DEVICES']='5'
# os.environ['CUDA_LAUNCH_BLOCKING']='6'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config = dotdict(
    epochs=500,
    num_class=48,
    batch_size=8,
    learning_rate=5e-4,
    weight_decay=0,
    dataset="Breakfast",
    architecture="unet-ensemble",
    features_file_name="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/",
    chunk_size=1,
    max_frames_per_video=1200,
    feature_size=2048,
    ground_truth_files_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/",
    label_id_csv="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv",
    gamma=0.1,
    step_size=500,
    split=3,
#     output_dir="/mnt/data/ar-datasets/dipika/breakfast/ms_tcn/data/breakfast/results/unsuper-finetune-split2-0.05-data-llr/",
    output_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcn-lenpsuedo-full-supervised-split3/",
    project_name="breakfast-split-3",
    train_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split{}.bundle",
    test_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split{}.bundle",
    all_files="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt",
    cutoff=8,
    data_per = 0.2,
    budget=40,
    semi_supervised_split="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split{}_amt{}.bundle")

config.train_split_file = config.train_split_file.format(config.split)
config.semi_supervised_split = config.semi_supervised_split.format(config.split, config.data_per)
config.test_split_file = config.test_split_file.format(config.split)

if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)

print(config)
# Out:
# {'epochs': 500, 'num_class': 48, 'batch_size': 8, 'learning_rate': 0.0005, 'weight_decay': 0, 'dataset': 'Breakfast', 'architecture': 'unet-ensemble', 'features_file_name': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/', 'chunk_size': 1, 'max_frames_per_video': 1200, 'feature_size': 2048, 'ground_truth_files_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/', 'label_id_csv': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv', 'gamma': 0.1, 'step_size': 500, 'split': 3, 'output_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcn-lenpsuedo-full-supervised-split3/', 'project_name': 'breakfast-split-3', 'train_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split3.bundle', 'test_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split3.bundle', 'all_files': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt', 'cutoff': 8, 'data_per': 0.2, 'budget': 40, 'semi_supervised_split': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split3_amt0.2.bundle'}

# %%
df=pd.read_csv(config.label_id_csv)
label_id_to_label_name = {}
label_name_to_label_id_dict = {}
for i, ele in df.iterrows():
    label_id_to_label_name[ele.label_id] = ele.label_name
    label_name_to_label_id_dict[ele.label_name] = ele.label_id

# %%
traindataset = Breakfast(config, fold='train', fold_file_name=config.train_split_file)
testdataset = Breakfast(config, fold='test', fold_file_name=config.test_split_file)
# Out:
# Number of videos logged in train fold is 1279
# Number of videos not found in train fold is 0
# Number of videos logged in test fold is 433
# Number of videos not found in test fold is 0

# %%
def _init_fn(worker_id):
    np.random.seed(int(seed))
trainloader = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=config.batch_size, 
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)
testloader = torch.utils.data.DataLoader(dataset=testdataset,
                                          batch_size=config.batch_size, 
                                          shuffle=False,
                                          pin_memory=True, num_workers=4,
                                          collate_fn=lambda x: collate_fn_override(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

# %%
set_seed()
model = MultiStageModel(num_stages=4, num_layers=10, num_f_maps=64, dim=2048, num_classes=48).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

# Requires loaded_vidid_selected_frames, boundaries_dict
ce_criterion = nn.CrossEntropyLoss(ignore_index=-100)
mse_criterion = nn.MSELoss(reduction='none')

# %%
pseudo_labels_dir = "/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/length_segmentation_output/"
def get_single_random(output_p, video_ids):
    # Generate target for only timestamps. Do not generate pseudo labels at first 30 epochs.
    boundary_target_tensor = torch.ones((output_p.shape[0], output_p.shape[2]), dtype=torch.long, 
                                        device=output_p.device) * (-100)
    for iter_num, cur_vidid in enumerate(video_ids):
        pseudo_l = open(pseudo_labels_dir + cur_vidid + ".txt").read().split("\n")[0:-1]
        pseudo_l = [label_name_to_label_id_dict[ele] for ele in pseudo_l]
        abc = torch.tensor(pseudo_l).to(torch.long).to(boundary_target_tensor.device)
        frame_idx_tensor = torch.arange(0, len(pseudo_l), 1).to(device)
        boundary_target_tensor[iter_num, frame_idx_tensor] = abc

    return boundary_target_tensor

# %%
best_val_acc = 0
best_epoch = -1
for epoch in range(100):
    print("Starting Training")
    model.train()
    for i, item in enumerate(trainloader):
        item_0 = item[0].to(device)
        item_1 = item[1].to(device)
        item_2 = item[2].to(device)
        src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
        src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
        optimizer.zero_grad()
        
        middle_pred, predictions = model(item_0, src_mask_mse)
        psuedo_l = get_single_random(predictions[-1], item[4])
        loss = 0
        for p in predictions:
            loss += ce_criterion(p, psuedo_l)
            loss += 0.15 * torch.mean(torch.clamp(mse_criterion(F.log_softmax(p[:, :, 1:], dim=1), 
                                                                F.log_softmax(p.detach()[:, :, :-1], dim=1)), min=0,
                                        max=16) * src_mask_mse[:, :, 1:])
            

        loss.backward()
        optimizer.step()
        
        if i % 10 == 0:
            with torch.no_grad():
                pred = torch.argmax(predictions[-1], dim=1)
                correct = float(torch.sum((pred == item_2) * src_mask).item())
                total = float(torch.sum(src_mask).item())
                print(f"Training:: Epoch {epoch}, Iteration {i}, Current loss {loss.item()}" +
                      f" Accuracy {correct * 100.0 / total}")
    # Calculating Expectation Step
    model.eval()

    print("Calculating Validation Data Accuracy")
    correct = 0.0
    total = 0.0
    for i, item in enumerate(testloader):
        with torch.no_grad():
            item_0 = item[0].to(device)
            item_1 = item[1].to(device)
            item_2 = item[2].to(device)
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)

            middle_pred, predictions = model(item_0, src_mask_mse)

            pred = torch.argmax(predictions[-1], dim=1)
            correct += float(torch.sum((pred == item_2) * src_mask).item())
            total += float(torch.sum(src_mask).item())
    val_acc = correct * 100.0 / total
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_epoch = epoch
        torch.save(model.state_dict(), config.output_dir + "ms-tcn-best-model.wt")
    torch.save(model.state_dict(), config.output_dir + "ms-tcn-last-model.wt")
    print(f"Validation:: Epoch {epoch}, Probability Accuracy {val_acc}")
# Out:
# Starting Training
# Training:: Epoch 0, Iteration 0, Current loss 15.790573120117188 Accuracy 4.178496481915813
# Training:: Epoch 0, Iteration 10, Current loss 15.370514869689941 Accuracy 3.826644122096645
# Training:: Epoch 0, Iteration 20, Current loss 14.129740715026855 Accuracy 1.939795375243953
# Training:: Epoch 0, Iteration 30, Current loss 12.482433319091797 Accuracy 11.194074428050893
# Training:: Epoch 0, Iteration 40, Current loss 12.917685508728027 Accuracy 12.976514635806671
# Training:: Epoch 0, Iteration 50, Current loss 12.395744323730469 Accuracy 16.094906133431174
# Training:: Epoch 0, Iteration 60, Current loss 14.231739044189453 Accuracy 11.620149004781497
# Training:: Epoch 0, Iteration 70, Current loss 11.462493896484375 Accuracy 8.897485493230175
# Training:: Epoch 0, Iteration 80, Current loss 11.71151351928711 Accuracy 10.336245697643632
# Training:: Epoch 0, Iteration 90, Current loss 11.299846649169922 Accuracy 9.973498804214337
# Training:: Epoch 0, Iteration 100, Current loss 11.706720352172852 Accuracy 16.502409110819098
# Training:: Epoch 0, Iteration 110, Current loss 9.909093856811523 Accuracy 21.859504132231404
# Training:: Epoch 0, Iteration 120, Current loss 10.621853828430176 Accuracy 20.632755148444097
# Training:: Epoch 0, Iteration 130, Current loss 10.964588165283203 Accuracy 12.945013135247757
# Training:: Epoch 0, Iteration 140, Current loss 9.309575080871582 Accuracy 21.885775862068964
# Training:: Epoch 0, Iteration 150, Current loss 8.994714736938477 Accuracy 22.731253168640826
# Calculating Validation Data Accuracy
# Validation:: Epoch 0, Probability Accuracy 19.825559009157313
# Starting Training
# Training:: Epoch 1, Iteration 0, Current loss 9.926614761352539 Accuracy 22.459893048128343
# Training:: Epoch 1, Iteration 10, Current loss 9.956401824951172 Accuracy 16.54575707154742
# Training:: Epoch 1, Iteration 20, Current loss 9.910243034362793 Accuracy 16.82991396426208
# Training:: Epoch 1, Iteration 30, Current loss 8.228724479675293 Accuracy 25.77281873056521
# Training:: Epoch 1, Iteration 40, Current loss 9.216893196105957 Accuracy 19.34282869388285
# Training:: Epoch 1, Iteration 50, Current loss 8.546883583068848 Accuracy 22.849462365591396
# Training:: Epoch 1, Iteration 60, Current loss 8.97719955444336 Accuracy 14.843209021663863
# Training:: Epoch 1, Iteration 70, Current loss 9.83655071258545 Accuracy 17.426062846580407
# Training:: Epoch 1, Iteration 80, Current loss 7.917385578155518 Accuracy 21.444891741921445
# Training:: Epoch 1, Iteration 90, Current loss 8.895462036132812 Accuracy 33.89315419065899
# Training:: Epoch 1, Iteration 100, Current loss 8.015950202941895 Accuracy 18.431785291409025
# Training:: Epoch 1, Iteration 110, Current loss 8.270453453063965 Accuracy 29.679012345679013
# Training:: Epoch 1, Iteration 120, Current loss 7.566263198852539 Accuracy 24.24490825398827
# Training:: Epoch 1, Iteration 130, Current loss 8.955362319946289 Accuracy 25.706422018348626
# Training:: Epoch 1, Iteration 140, Current loss 9.091983795166016 Accuracy 20.04305190145898
# Training:: Epoch 1, Iteration 150, Current loss 8.145029067993164 Accuracy 29.89817200343516
# Calculating Validation Data Accuracy
# Validation:: Epoch 1, Probability Accuracy 35.0206751078398
# Starting Training
# Training:: Epoch 2, Iteration 0, Current loss 7.1966233253479 Accuracy 33.11517046009573
# Training:: Epoch 2, Iteration 10, Current loss 8.41518497467041 Accuracy 17.39598872865904
# Training:: Epoch 2, Iteration 20, Current loss 6.913686275482178 Accuracy 35.333670739642834
# Training:: Epoch 2, Iteration 30, Current loss 9.533015251159668 Accuracy 17.00236542183356
# Training:: Epoch 2, Iteration 40, Current loss 8.326080322265625 Accuracy 33.340822287126485
# Training:: Epoch 2, Iteration 50, Current loss 7.653830051422119 Accuracy 19.8228812686644
# Training:: Epoch 2, Iteration 60, Current loss 6.764346599578857 Accuracy 32.001593534801664
# Training:: Epoch 2, Iteration 70, Current loss 7.9906415939331055 Accuracy 30.639530565252915
# Training:: Epoch 2, Iteration 80, Current loss 9.176003456115723 Accuracy 23.445980542754736
# Training:: Epoch 2, Iteration 90, Current loss 10.60008716583252 Accuracy 17.529002320185615
# Training:: Epoch 2, Iteration 100, Current loss 8.150875091552734 Accuracy 25.2752267412013
# Training:: Epoch 2, Iteration 110, Current loss 7.003841876983643 Accuracy 33.63649384130622
# Training:: Epoch 2, Iteration 120, Current loss 8.4956636428833 Accuracy 49.663024275338614
# Training:: Epoch 2, Iteration 130, Current loss 7.050069332122803 Accuracy 47.64567769477055
# Training:: Epoch 2, Iteration 140, Current loss 8.92564582824707 Accuracy 18.683034130419358
# Training:: Epoch 2, Iteration 150, Current loss 7.006897926330566 Accuracy 28.075253256150507
# Calculating Validation Data Accuracy
# Validation:: Epoch 2, Probability Accuracy 34.18697440304462
# Starting Training
# Training:: Epoch 3, Iteration 0, Current loss 7.303325176239014 Accuracy 30.549888504056554
# Training:: Epoch 3, Iteration 10, Current loss 6.602120399475098 Accuracy 31.648422408242112
# Training:: Epoch 3, Iteration 20, Current loss 8.937738418579102 Accuracy 19.644238205723124
# Training:: Epoch 3, Iteration 30, Current loss 7.523517608642578 Accuracy 37.75982532751092
# Training:: Epoch 3, Iteration 40, Current loss 9.133842468261719 Accuracy 21.848227875625135
# Training:: Epoch 3, Iteration 50, Current loss 7.916407108306885 Accuracy 20.555767034640272
# Training:: Epoch 3, Iteration 60, Current loss 11.373598098754883 Accuracy 27.89927104042412
# Training:: Epoch 3, Iteration 70, Current loss 7.620577812194824 Accuracy 20.70112589559877
# Training:: Epoch 3, Iteration 80, Current loss 6.533278942108154 Accuracy 35.04773784963777
# Training:: Epoch 3, Iteration 90, Current loss 8.287160873413086 Accuracy 29.35719415848695
# Training:: Epoch 3, Iteration 100, Current loss 9.356263160705566 Accuracy 26.76719253900462
# Training:: Epoch 3, Iteration 110, Current loss 6.474776744842529 Accuracy 37.910289303724674
# Training:: Epoch 3, Iteration 120, Current loss 6.812935829162598 Accuracy 35.58860979280009
# Training:: Epoch 3, Iteration 130, Current loss 6.730884552001953 Accuracy 30.36140610850416
# Training:: Epoch 3, Iteration 140, Current loss 7.70185661315918 Accuracy 29.46101517530089
# Training:: Epoch 3, Iteration 150, Current loss 8.06264877319336 Accuracy 36.802235787306024
# Calculating Validation Data Accuracy
# Validation:: Epoch 3, Probability Accuracy 37.95246678310947
# Starting Training
# Training:: Epoch 4, Iteration 0, Current loss 6.686804294586182 Accuracy 29.461797917583223
# Training:: Epoch 4, Iteration 10, Current loss 6.676654815673828 Accuracy 37.79451525685593
# Training:: Epoch 4, Iteration 20, Current loss 6.894930839538574 Accuracy 36.72800808897877
# Training:: Epoch 4, Iteration 30, Current loss 6.265796184539795 Accuracy 35.60864618885097
# Training:: Epoch 4, Iteration 40, Current loss 5.956193923950195 Accuracy 43.20733104238259
# Training:: Epoch 4, Iteration 50, Current loss 6.308755874633789 Accuracy 31.52414144848691
# Training:: Epoch 4, Iteration 60, Current loss 6.554183006286621 Accuracy 45.27753916635988
# Training:: Epoch 4, Iteration 70, Current loss 5.247427940368652 Accuracy 40.55530776092775
# Training:: Epoch 4, Iteration 80, Current loss 6.808213710784912 Accuracy 44.537181627268325
# Training:: Epoch 4, Iteration 90, Current loss 7.263601779937744 Accuracy 29.413170218866483
# Training:: Epoch 4, Iteration 100, Current loss 6.093990325927734 Accuracy 42.21119382409705
# Training:: Epoch 4, Iteration 110, Current loss 7.694523334503174 Accuracy 32.570883964736716
# Training:: Epoch 4, Iteration 120, Current loss 8.537774085998535 Accuracy 25.15112476464176
# Training:: Epoch 4, Iteration 130, Current loss 5.855587005615234 Accuracy 36.09051676441297
# Training:: Epoch 4, Iteration 140, Current loss 4.435948371887207 Accuracy 50.51806469051266
# Training:: Epoch 4, Iteration 150, Current loss 4.853629112243652 Accuracy 38.10476536922517
# Calculating Validation Data Accuracy
# Validation:: Epoch 4, Probability Accuracy 38.795207616028925
# Starting Training
# Training:: Epoch 5, Iteration 0, Current loss 8.2605562210083 Accuracy 29.47374652222814
# Training:: Epoch 5, Iteration 10, Current loss 9.969806671142578 Accuracy 35.06643167028199
# Training:: Epoch 5, Iteration 20, Current loss 7.353093147277832 Accuracy 38.530827768287004
# Training:: Epoch 5, Iteration 30, Current loss 8.147224426269531 Accuracy 33.62985366721523
# Training:: Epoch 5, Iteration 40, Current loss 6.804376602172852 Accuracy 35.63823071419553
# Training:: Epoch 5, Iteration 50, Current loss 5.116456031799316 Accuracy 53.302702210899824
# Training:: Epoch 5, Iteration 60, Current loss 6.010030269622803 Accuracy 50.816286388670335
# Training:: Epoch 5, Iteration 70, Current loss 6.13594913482666 Accuracy 34.466871434839845
# Training:: Epoch 5, Iteration 80, Current loss 10.460982322692871 Accuracy 15.978131475684494
# Training:: Epoch 5, Iteration 90, Current loss 8.309371948242188 Accuracy 24.25101373961655
# Training:: Epoch 5, Iteration 100, Current loss 5.860569000244141 Accuracy 54.52690061794886
# Training:: Epoch 5, Iteration 110, Current loss 10.958028793334961 Accuracy 23.074071786001113
# Training:: Epoch 5, Iteration 120, Current loss 9.959272384643555 Accuracy 26.625860749808723
# Training:: Epoch 5, Iteration 130, Current loss 10.672765731811523 Accuracy 22.615328732292046
# Training:: Epoch 5, Iteration 140, Current loss 6.89401388168335 Accuracy 52.32226467897314
# Training:: Epoch 5, Iteration 150, Current loss 5.642049312591553 Accuracy 45.72986069049061
# Calculating Validation Data Accuracy
# Validation:: Epoch 5, Probability Accuracy 47.10989335997009
# Starting Training
# Training:: Epoch 6, Iteration 0, Current loss 5.017128944396973 Accuracy 53.63589809243375
# Training:: Epoch 6, Iteration 10, Current loss 6.180642604827881 Accuracy 39.93705979319646
# Training:: Epoch 6, Iteration 20, Current loss 6.863143444061279 Accuracy 39.284585729634074
# Training:: Epoch 6, Iteration 30, Current loss 6.847145080566406 Accuracy 35.68741450068399
# Training:: Epoch 6, Iteration 40, Current loss 5.738131523132324 Accuracy 43.74827300359215
# Training:: Epoch 6, Iteration 50, Current loss 7.069589614868164 Accuracy 42.597765363128495
# Training:: Epoch 6, Iteration 60, Current loss 6.806276321411133 Accuracy 46.421267893660534
# Training:: Epoch 6, Iteration 70, Current loss 5.3722920417785645 Accuracy 54.430629563844484
# Training:: Epoch 6, Iteration 80, Current loss 7.531330585479736 Accuracy 44.48426659652122
# Training:: Epoch 6, Iteration 90, Current loss 6.022895336151123 Accuracy 40.61115747576555
# Training:: Epoch 6, Iteration 100, Current loss 4.529558181762695 Accuracy 67.81876790830945
# Training:: Epoch 6, Iteration 110, Current loss 4.849847793579102 Accuracy 58.729546581455566
# Training:: Epoch 6, Iteration 120, Current loss 5.086103439331055 Accuracy 58.913474585116376
# Training:: Epoch 6, Iteration 130, Current loss 5.229424953460693 Accuracy 57.72196394148997
# Training:: Epoch 6, Iteration 140, Current loss 7.303027153015137 Accuracy 40.447607614474364
# Training:: Epoch 6, Iteration 150, Current loss 8.097336769104004 Accuracy 31.55870028165144
# Calculating Validation Data Accuracy
# Validation:: Epoch 6, Probability Accuracy 49.84961021422872
# Starting Training
# Training:: Epoch 7, Iteration 0, Current loss 6.721088886260986 Accuracy 45.511650381187586
# Training:: Epoch 7, Iteration 10, Current loss 4.49537992477417 Accuracy 52.106918238993714
# Training:: Epoch 7, Iteration 20, Current loss 4.314157009124756 Accuracy 55.30927835051546
# Training:: Epoch 7, Iteration 30, Current loss 4.734573841094971 Accuracy 48.26933591285696
# Training:: Epoch 7, Iteration 40, Current loss 5.192688941955566 Accuracy 57.64204876910512
# Training:: Epoch 7, Iteration 50, Current loss 5.055296421051025 Accuracy 47.6342294036664
# Training:: Epoch 7, Iteration 60, Current loss 6.6224565505981445 Accuracy 34.94077123414265
# Training:: Epoch 7, Iteration 70, Current loss 7.127902030944824 Accuracy 49.78494156493027
# Training:: Epoch 7, Iteration 80, Current loss 5.136288166046143 Accuracy 50.84439083232811
# Training:: Epoch 7, Iteration 90, Current loss 9.165787696838379 Accuracy 42.572207084468666
# Training:: Epoch 7, Iteration 100, Current loss 5.518003463745117 Accuracy 52.372735116479724
# Training:: Epoch 7, Iteration 110, Current loss 9.058515548706055 Accuracy 35.59222156747201
# Training:: Epoch 7, Iteration 120, Current loss 5.958914279937744 Accuracy 50.11463738385423
# Training:: Epoch 7, Iteration 130, Current loss 6.266061782836914 Accuracy 36.12091898428053
# Training:: Epoch 7, Iteration 140, Current loss 8.72712230682373 Accuracy 52.0946960714568
# Training:: Epoch 7, Iteration 150, Current loss 8.372903823852539 Accuracy 36.41575538804544
# Calculating Validation Data Accuracy
# Validation:: Epoch 7, Probability Accuracy 47.12830843577882
# Starting Training
# Training:: Epoch 8, Iteration 0, Current loss 6.054271697998047 Accuracy 56.86140140483125
# Training:: Epoch 8, Iteration 10, Current loss 6.0332932472229 Accuracy 47.45969116859077
# Training:: Epoch 8, Iteration 20, Current loss 5.669862270355225 Accuracy 47.31188629089134
# Training:: Epoch 8, Iteration 30, Current loss 7.018407821655273 Accuracy 40.38140434133052
# Training:: Epoch 8, Iteration 40, Current loss 5.962369918823242 Accuracy 60.7911172796669
# Training:: Epoch 8, Iteration 50, Current loss 4.336029529571533 Accuracy 63.218608169440245
# Training:: Epoch 8, Iteration 60, Current loss 4.4915289878845215 Accuracy 69.08031216042676
# Training:: Epoch 8, Iteration 70, Current loss 7.251575469970703 Accuracy 39.042027636571916
# Training:: Epoch 8, Iteration 80, Current loss 7.071511745452881 Accuracy 41.62824557146324
# Training:: Epoch 8, Iteration 90, Current loss 4.7193756103515625 Accuracy 47.937603119844006
# Training:: Epoch 8, Iteration 100, Current loss 5.218645095825195 Accuracy 48.02733083535376
# Training:: Epoch 8, Iteration 110, Current loss 5.56230354309082 Accuracy 64.37593237195425
# Training:: Epoch 8, Iteration 120, Current loss 4.5908331871032715 Accuracy 48.757100422116835
# Training:: Epoch 8, Iteration 130, Current loss 5.036098003387451 Accuracy 55.232611278676536
# Training:: Epoch 8, Iteration 140, Current loss 5.8057966232299805 Accuracy 42.43563971208093
# Training:: Epoch 8, Iteration 150, Current loss 5.020814895629883 Accuracy 45.56478778351673
# Calculating Validation Data Accuracy
# Validation:: Epoch 8, Probability Accuracy 50.94000591514556
# Starting Training
# Training:: Epoch 9, Iteration 0, Current loss 4.609263896942139 Accuracy 63.070888203978704
# Training:: Epoch 9, Iteration 10, Current loss 4.954829216003418 Accuracy 46.83361629881154
# Training:: Epoch 9, Iteration 20, Current loss 5.570481777191162 Accuracy 46.36490074598559
# Training:: Epoch 9, Iteration 30, Current loss 6.454682350158691 Accuracy 53.85284931647125
# Training:: Epoch 9, Iteration 40, Current loss 5.351769924163818 Accuracy 51.11729797054729
# Training:: Epoch 9, Iteration 50, Current loss 5.869587421417236 Accuracy 41.12600235518421
# Training:: Epoch 9, Iteration 60, Current loss 4.76985502243042 Accuracy 52.55602836879433
# Training:: Epoch 9, Iteration 70, Current loss 6.577881813049316 Accuracy 41.71695677957233
# Training:: Epoch 9, Iteration 80, Current loss 5.197782039642334 Accuracy 59.80174582038763
# Training:: Epoch 9, Iteration 90, Current loss 4.280400276184082 Accuracy 43.80467279371055
# Training:: Epoch 9, Iteration 100, Current loss 4.897947311401367 Accuracy 48.289421942587495
# Training:: Epoch 9, Iteration 110, Current loss 6.147531509399414 Accuracy 60.55908594903396
# Training:: Epoch 9, Iteration 120, Current loss 4.1652116775512695 Accuracy 48.98517050502289
# Training:: Epoch 9, Iteration 130, Current loss 4.29063606262207 Accuracy 58.540709039995775
# Training:: Epoch 9, Iteration 140, Current loss 5.851524829864502 Accuracy 53.257173219978746
# Training:: Epoch 9, Iteration 150, Current loss 4.924506187438965 Accuracy 47.86030822144322
# Calculating Validation Data Accuracy
# Validation:: Epoch 9, Probability Accuracy 50.74223916161182
# Starting Training
# Training:: Epoch 10, Iteration 0, Current loss 3.134575843811035 Accuracy 68.46653761061947
# Training:: Epoch 10, Iteration 10, Current loss 4.275312900543213 Accuracy 60.58733596636514
# Training:: Epoch 10, Iteration 20, Current loss 5.128239154815674 Accuracy 42.61108566193312
# Training:: Epoch 10, Iteration 30, Current loss 3.6843483448028564 Accuracy 60.69860279441118
# Training:: Epoch 10, Iteration 40, Current loss 4.356657981872559 Accuracy 51.60193184137133
# Training:: Epoch 10, Iteration 50, Current loss 4.701625823974609 Accuracy 59.192935720980714
# Training:: Epoch 10, Iteration 60, Current loss 4.9347004890441895 Accuracy 50.88930034225439
# Training:: Epoch 10, Iteration 70, Current loss 5.10862398147583 Accuracy 63.822047065064986
# Training:: Epoch 10, Iteration 80, Current loss 4.778704643249512 Accuracy 54.361636723819935
# Training:: Epoch 10, Iteration 90, Current loss 4.647982597351074 Accuracy 51.502018522916174
# Training:: Epoch 10, Iteration 100, Current loss 3.4182682037353516 Accuracy 64.79775730877053
# Training:: Epoch 10, Iteration 110, Current loss 4.693260192871094 Accuracy 61.22673368412786
# Training:: Epoch 10, Iteration 120, Current loss 4.50994348526001 Accuracy 54.75123263110713
# Training:: Epoch 10, Iteration 130, Current loss 4.696784496307373 Accuracy 54.08753096614368
# Training:: Epoch 10, Iteration 140, Current loss 5.332844257354736 Accuracy 54.73626574192371
# Training:: Epoch 10, Iteration 150, Current loss 4.281459331512451 Accuracy 53.039573887397104
# Calculating Validation Data Accuracy
# Validation:: Epoch 10, Probability Accuracy 49.82572641893739
# Starting Training
# Training:: Epoch 11, Iteration 0, Current loss 4.881819725036621 Accuracy 53.82287673996369
# Training:: Epoch 11, Iteration 10, Current loss 4.548576354980469 Accuracy 51.741834208778606
# Training:: Epoch 11, Iteration 20, Current loss 4.4717583656311035 Accuracy 60.4995766299746
# Training:: Epoch 11, Iteration 30, Current loss 3.860682249069214 Accuracy 62.76259397175578
# Training:: Epoch 11, Iteration 40, Current loss 4.975954055786133 Accuracy 55.137910604963466
# Training:: Epoch 11, Iteration 50, Current loss 4.810736656188965 Accuracy 53.822756809069546
# Training:: Epoch 11, Iteration 60, Current loss 3.916778326034546 Accuracy 56.78047033544228
# Training:: Epoch 11, Iteration 70, Current loss 3.7815537452697754 Accuracy 60.29930928626247
# Training:: Epoch 11, Iteration 80, Current loss 5.651627063751221 Accuracy 49.054024890295665
# Training:: Epoch 11, Iteration 90, Current loss 4.4853668212890625 Accuracy 63.705362018128206
# Training:: Epoch 11, Iteration 100, Current loss 4.906787872314453 Accuracy 48.260188087774296
# Training:: Epoch 11, Iteration 110, Current loss 4.967016220092773 Accuracy 56.94571515706008
# Training:: Epoch 11, Iteration 120, Current loss 5.145660400390625 Accuracy 55.213831735430354
# Training:: Epoch 11, Iteration 130, Current loss 6.038818836212158 Accuracy 46.6226081610697
# Training:: Epoch 11, Iteration 140, Current loss 5.296379566192627 Accuracy 65.63677841698076
# Training:: Epoch 11, Iteration 150, Current loss 4.522647857666016 Accuracy 56.71656686626746
# Calculating Validation Data Accuracy
# Validation:: Epoch 11, Probability Accuracy 54.15204156226807
# Starting Training
# Training:: Epoch 12, Iteration 0, Current loss 3.7143726348876953 Accuracy 65.70984162895928
# Training:: Epoch 12, Iteration 10, Current loss 4.794955730438232 Accuracy 51.003495320780246
# Training:: Epoch 12, Iteration 20, Current loss 5.338016986846924 Accuracy 41.8869546529121
# Training:: Epoch 12, Iteration 30, Current loss 3.29107928276062 Accuracy 62.77847458639432
# Training:: Epoch 12, Iteration 40, Current loss 5.000814437866211 Accuracy 53.69791460567449
# Training:: Epoch 12, Iteration 50, Current loss 4.081735134124756 Accuracy 55.08357745993452
# Training:: Epoch 12, Iteration 60, Current loss 4.715226650238037 Accuracy 64.57358294331773
# Training:: Epoch 12, Iteration 70, Current loss 4.956497669219971 Accuracy 52.70793036750484
# Training:: Epoch 12, Iteration 80, Current loss 3.9205729961395264 Accuracy 64.23632504963373
# Training:: Epoch 12, Iteration 90, Current loss 5.870418071746826 Accuracy 51.21872303710095
# Training:: Epoch 12, Iteration 100, Current loss 3.865041732788086 Accuracy 54.60778935820077
# Training:: Epoch 12, Iteration 110, Current loss 3.2406928539276123 Accuracy 64.70443197928867
# Training:: Epoch 12, Iteration 120, Current loss 5.348015785217285 Accuracy 44.839506172839506
# Training:: Epoch 12, Iteration 130, Current loss 4.796782970428467 Accuracy 59.93418031532221
# Training:: Epoch 12, Iteration 140, Current loss 6.592910289764404 Accuracy 26.978129768219137
# Training:: Epoch 12, Iteration 150, Current loss 5.593042373657227 Accuracy 40.07686700682526
# Calculating Validation Data Accuracy
# Validation:: Epoch 12, Probability Accuracy 52.69702736033839
# Starting Training
# Training:: Epoch 13, Iteration 0, Current loss 5.267740249633789 Accuracy 50.82438226583565
# Training:: Epoch 13, Iteration 10, Current loss 3.7960140705108643 Accuracy 62.428599566673235
# Training:: Epoch 13, Iteration 20, Current loss 4.127996921539307 Accuracy 57.71877389309793
# Training:: Epoch 13, Iteration 30, Current loss 3.499048948287964 Accuracy 67.8377065111759
# Training:: Epoch 13, Iteration 40, Current loss 3.682941198348999 Accuracy 56.093411691927
# Training:: Epoch 13, Iteration 50, Current loss 5.77447509765625 Accuracy 46.389409466087166
# Training:: Epoch 13, Iteration 60, Current loss 5.074182987213135 Accuracy 60.59971442170395
# Training:: Epoch 13, Iteration 70, Current loss 4.698006629943848 Accuracy 51.221292977565376
# Training:: Epoch 13, Iteration 80, Current loss 4.534186363220215 Accuracy 56.791818244217176
# Training:: Epoch 13, Iteration 90, Current loss 4.497654914855957 Accuracy 64.37737741922
# Training:: Epoch 13, Iteration 100, Current loss 5.300447463989258 Accuracy 41.19581661514175
# Training:: Epoch 13, Iteration 110, Current loss 6.370304107666016 Accuracy 48.26080174699735
# Training:: Epoch 13, Iteration 120, Current loss 4.626991271972656 Accuracy 57.17950007544133
# Training:: Epoch 13, Iteration 130, Current loss 3.960097312927246 Accuracy 62.67292369360121
# Training:: Epoch 13, Iteration 140, Current loss 4.709726333618164 Accuracy 65.25379923498397
# Training:: Epoch 13, Iteration 150, Current loss 3.5770487785339355 Accuracy 63.556429088652116
# Calculating Validation Data Accuracy
# Validation:: Epoch 13, Probability Accuracy 52.21968627407213
# Starting Training
# Training:: Epoch 14, Iteration 0, Current loss 3.200117826461792 Accuracy 65.10425949028694
# Training:: Epoch 14, Iteration 10, Current loss 3.690377712249756 Accuracy 64.25374804206757
# Training:: Epoch 14, Iteration 20, Current loss 4.589362144470215 Accuracy 59.96567974592767
# Training:: Epoch 14, Iteration 30, Current loss 3.262667417526245 Accuracy 64.58063038998702
# Training:: Epoch 14, Iteration 40, Current loss 5.2920756340026855 Accuracy 42.39713774597495
# Training:: Epoch 14, Iteration 50, Current loss 4.558761119842529 Accuracy 46.956634472029556
# Training:: Epoch 14, Iteration 60, Current loss 4.414689540863037 Accuracy 52.3664662186063
# Training:: Epoch 14, Iteration 70, Current loss 3.8316397666931152 Accuracy 57.77901254167328
# Training:: Epoch 14, Iteration 80, Current loss 3.8641438484191895 Accuracy 58.84510869565217
# Training:: Epoch 14, Iteration 90, Current loss 4.018795013427734 Accuracy 55.65687267814928
# Training:: Epoch 14, Iteration 100, Current loss 5.678399562835693 Accuracy 42.69930993980326
# Training:: Epoch 14, Iteration 110, Current loss 4.105257034301758 Accuracy 55.42469899335482
# Training:: Epoch 14, Iteration 120, Current loss 4.995882034301758 Accuracy 61.403600313070704
# Training:: Epoch 14, Iteration 130, Current loss 4.1572370529174805 Accuracy 58.892047037842055
# Training:: Epoch 14, Iteration 140, Current loss 3.4463791847229004 Accuracy 70.68905515921351
# Training:: Epoch 14, Iteration 150, Current loss 3.8865878582000732 Accuracy 57.37715715979449
# Calculating Validation Data Accuracy
# Validation:: Epoch 14, Probability Accuracy 53.613428496492766
# Starting Training
# Training:: Epoch 15, Iteration 0, Current loss 4.554633617401123 Accuracy 58.54724964739069
# Training:: Epoch 15, Iteration 10, Current loss 4.535492897033691 Accuracy 66.18365180467092
# Training:: Epoch 15, Iteration 20, Current loss 3.7792394161224365 Accuracy 47.92542641808806
# Training:: Epoch 15, Iteration 30, Current loss 3.508575916290283 Accuracy 61.90620272314675
# Training:: Epoch 15, Iteration 40, Current loss 3.9802350997924805 Accuracy 54.894871509622874
# Training:: Epoch 15, Iteration 50, Current loss 3.714111089706421 Accuracy 73.93120393120392
# Training:: Epoch 15, Iteration 60, Current loss 3.8604042530059814 Accuracy 58.207805546045876
# Training:: Epoch 15, Iteration 70, Current loss 4.606410026550293 Accuracy 61.505944517833555
# Training:: Epoch 15, Iteration 80, Current loss 4.158119201660156 Accuracy 57.05001969279244
# Training:: Epoch 15, Iteration 90, Current loss 4.054626941680908 Accuracy 54.39648151164685
# Training:: Epoch 15, Iteration 100, Current loss 5.626355171203613 Accuracy 60.22376983673935
# Training:: Epoch 15, Iteration 110, Current loss 5.021288871765137 Accuracy 47.6540043337903
# Training:: Epoch 15, Iteration 120, Current loss 4.291757106781006 Accuracy 67.80562436252367
# Training:: Epoch 15, Iteration 130, Current loss 3.416718006134033 Accuracy 66.74364896073904
# Training:: Epoch 15, Iteration 140, Current loss 3.8848893642425537 Accuracy 66.28718083706238
# Training:: Epoch 15, Iteration 150, Current loss 4.288409233093262 Accuracy 58.89736823336424
# Calculating Validation Data Accuracy
# Validation:: Epoch 15, Probability Accuracy 52.21042293290774
# Starting Training
# Training:: Epoch 16, Iteration 0, Current loss 3.6022961139678955 Accuracy 60.504742944138656
# Training:: Epoch 16, Iteration 10, Current loss 4.510164737701416 Accuracy 51.17738775836565
# Training:: Epoch 16, Iteration 20, Current loss 3.0892281532287598 Accuracy 67.1257318093114
# Training:: Epoch 16, Iteration 30, Current loss 4.488283634185791 Accuracy 61.14746053815327
# Training:: Epoch 16, Iteration 40, Current loss 3.9326281547546387 Accuracy 67.47321474342543
# Training:: Epoch 16, Iteration 50, Current loss 3.007444143295288 Accuracy 54.23702556158017
# Training:: Epoch 16, Iteration 60, Current loss 3.576788902282715 Accuracy 59.72181694387705
# Training:: Epoch 16, Iteration 70, Current loss 3.9484379291534424 Accuracy 60.025970475669766
# Training:: Epoch 16, Iteration 80, Current loss 4.234228134155273 Accuracy 52.37116429305535
# Training:: Epoch 16, Iteration 90, Current loss 3.7932000160217285 Accuracy 64.86437117544982
# Training:: Epoch 16, Iteration 100, Current loss 4.299350261688232 Accuracy 56.77472390006791
# Training:: Epoch 16, Iteration 110, Current loss 6.488748550415039 Accuracy 34.546549647220786
# Training:: Epoch 16, Iteration 120, Current loss 3.128095865249634 Accuracy 69.31360339901839
# Training:: Epoch 16, Iteration 130, Current loss 3.68166184425354 Accuracy 63.89248704663213
# Training:: Epoch 16, Iteration 140, Current loss 3.3044986724853516 Accuracy 65.60379049814317
# Training:: Epoch 16, Iteration 150, Current loss 4.050887107849121 Accuracy 63.607417925218364
# Calculating Validation Data Accuracy
# Validation:: Epoch 16, Probability Accuracy 55.498685833226375
# Starting Training
# Training:: Epoch 17, Iteration 0, Current loss 4.691694259643555 Accuracy 48.27165910974599
# Training:: Epoch 17, Iteration 10, Current loss 3.609717607498169 Accuracy 57.227693001578594
# Training:: Epoch 17, Iteration 20, Current loss 4.619058609008789 Accuracy 47.95280300146811
# Training:: Epoch 17, Iteration 30, Current loss 3.3664536476135254 Accuracy 63.58541977276233
# Training:: Epoch 17, Iteration 40, Current loss 3.6914865970611572 Accuracy 61.54937135847899
# Training:: Epoch 17, Iteration 50, Current loss 4.104769229888916 Accuracy 56.63952065487995
# Training:: Epoch 17, Iteration 60, Current loss 3.3706915378570557 Accuracy 67.5909111042211
# Training:: Epoch 17, Iteration 70, Current loss 2.6601357460021973 Accuracy 68.90291012104043
# Training:: Epoch 17, Iteration 80, Current loss 3.160149574279785 Accuracy 68.39852574010224
# Training:: Epoch 17, Iteration 90, Current loss 3.605543613433838 Accuracy 63.375398696436
# Training:: Epoch 17, Iteration 100, Current loss 4.092771530151367 Accuracy 56.54716622289844
# Training:: Epoch 17, Iteration 110, Current loss 5.859621524810791 Accuracy 51.002481056796086
# Training:: Epoch 17, Iteration 120, Current loss 4.395263195037842 Accuracy 69.50688152707656
# Training:: Epoch 17, Iteration 130, Current loss 4.409059047698975 Accuracy 59.58244111349036
# Training:: Epoch 17, Iteration 140, Current loss 4.160220146179199 Accuracy 61.752766501696044
# Training:: Epoch 17, Iteration 150, Current loss 2.9388315677642822 Accuracy 68.51978171896316
# Calculating Validation Data Accuracy
# Validation:: Epoch 17, Probability Accuracy 57.05001646196171
# Starting Training
# Training:: Epoch 18, Iteration 0, Current loss 3.385406255722046 Accuracy 61.67480092473671
# Training:: Epoch 18, Iteration 10, Current loss 4.821280479431152 Accuracy 51.44102899498583
# Training:: Epoch 18, Iteration 20, Current loss 6.500976085662842 Accuracy 57.91974656810982
# Training:: Epoch 18, Iteration 30, Current loss 4.212294578552246 Accuracy 61.472962066182404
# Training:: Epoch 18, Iteration 40, Current loss 3.7003378868103027 Accuracy 51.801146573115425
# Training:: Epoch 18, Iteration 50, Current loss 3.7588114738464355 Accuracy 65.3641975308642
# Training:: Epoch 18, Iteration 60, Current loss 3.747493267059326 Accuracy 61.48873046096622
# Training:: Epoch 18, Iteration 70, Current loss 4.311530590057373 Accuracy 45.89010989010989
# Training:: Epoch 18, Iteration 80, Current loss 3.9657065868377686 Accuracy 61.596256508271274
# Training:: Epoch 18, Iteration 90, Current loss 3.188791036605835 Accuracy 58.32875637504904
# Training:: Epoch 18, Iteration 100, Current loss 3.779071569442749 Accuracy 60.72367597345687
# Training:: Epoch 18, Iteration 110, Current loss 4.826618671417236 Accuracy 55.31799238992571
# Training:: Epoch 18, Iteration 120, Current loss 2.8398959636688232 Accuracy 61.57960420752362
# Training:: Epoch 18, Iteration 130, Current loss 3.136699914932251 Accuracy 64.15225447807289
# Training:: Epoch 18, Iteration 140, Current loss 4.962062358856201 Accuracy 52.15831787260359
# Training:: Epoch 18, Iteration 150, Current loss 3.2975471019744873 Accuracy 55.6662908680947
# Calculating Validation Data Accuracy
# Validation:: Epoch 18, Probability Accuracy 53.187761229011
# Starting Training
# Training:: Epoch 19, Iteration 0, Current loss 4.391432762145996 Accuracy 65.12166859791425
# Training:: Epoch 19, Iteration 10, Current loss 3.458538293838501 Accuracy 58.16283924843424
# Training:: Epoch 19, Iteration 20, Current loss 3.135246753692627 Accuracy 64.65128613099974
# Training:: Epoch 19, Iteration 30, Current loss 5.092178821563721 Accuracy 67.83332625408826
# Training:: Epoch 19, Iteration 40, Current loss 2.9949615001678467 Accuracy 68.93795719317258
# Training:: Epoch 19, Iteration 50, Current loss 2.7563819885253906 Accuracy 66.7909604519774
# Training:: Epoch 19, Iteration 60, Current loss 3.819049835205078 Accuracy 62.78763515386748
# Training:: Epoch 19, Iteration 70, Current loss 2.634350061416626 Accuracy 68.89004992453269
# Training:: Epoch 19, Iteration 80, Current loss 2.783320903778076 Accuracy 61.00738470112861
# Training:: Epoch 19, Iteration 90, Current loss 4.950123310089111 Accuracy 48.71051187583288
# Training:: Epoch 19, Iteration 100, Current loss 3.4265997409820557 Accuracy 69.64247484478699
# Training:: Epoch 19, Iteration 110, Current loss 5.8623833656311035 Accuracy 41.66739415102575
# Training:: Epoch 19, Iteration 120, Current loss 3.6338436603546143 Accuracy 50.80784002118924
# Training:: Epoch 19, Iteration 130, Current loss 3.3865280151367188 Accuracy 63.80698186748009
# Training:: Epoch 19, Iteration 140, Current loss 3.5431814193725586 Accuracy 61.8275674696613
# Training:: Epoch 19, Iteration 150, Current loss 3.261711359024048 Accuracy 66.21142058285837
# Calculating Validation Data Accuracy
# Validation:: Epoch 19, Probability Accuracy 53.75483395739979
# Starting Training
# Training:: Epoch 20, Iteration 0, Current loss 3.146266222000122 Accuracy 61.75200194127639
# Training:: Epoch 20, Iteration 10, Current loss 3.7840216159820557 Accuracy 61.861761052737585
# Training:: Epoch 20, Iteration 20, Current loss 3.21897554397583 Accuracy 64.5457905923667
# Training:: Epoch 20, Iteration 30, Current loss 3.1741936206817627 Accuracy 61.38453615831678
# Training:: Epoch 20, Iteration 40, Current loss 3.9061436653137207 Accuracy 60.85269734961408
# Training:: Epoch 20, Iteration 50, Current loss 3.2527098655700684 Accuracy 56.5793376173999
# Training:: Epoch 20, Iteration 60, Current loss 3.680213689804077 Accuracy 54.61754924533129
# Training:: Epoch 20, Iteration 70, Current loss 3.1150026321411133 Accuracy 68.43645186612432
# Training:: Epoch 20, Iteration 80, Current loss 3.639451742172241 Accuracy 49.86959189935563
# Training:: Epoch 20, Iteration 90, Current loss 2.972078323364258 Accuracy 65.28531134736386
# Training:: Epoch 20, Iteration 100, Current loss 3.507822036743164 Accuracy 58.968756827616346
# Training:: Epoch 20, Iteration 110, Current loss 5.561309337615967 Accuracy 49.16553411253058
# Training:: Epoch 20, Iteration 120, Current loss 4.10400390625 Accuracy 56.3040595997222
# Training:: Epoch 20, Iteration 130, Current loss 3.051084280014038 Accuracy 66.48866737866382
# Training:: Epoch 20, Iteration 140, Current loss 3.465397596359253 Accuracy 56.016060095842505
# Training:: Epoch 20, Iteration 150, Current loss 3.5183322429656982 Accuracy 70.77714285714286
# Calculating Validation Data Accuracy
# Validation:: Epoch 20, Probability Accuracy 55.739867523060695
# Starting Training
# Training:: Epoch 21, Iteration 0, Current loss 2.838994026184082 Accuracy 66.7671391008786
# Training:: Epoch 21, Iteration 10, Current loss 3.005891799926758 Accuracy 61.51301900070373
# Training:: Epoch 21, Iteration 20, Current loss 3.290249824523926 Accuracy 72.10109556351014
# Training:: Epoch 21, Iteration 30, Current loss 5.132955074310303 Accuracy 58.62325581395349
# Training:: Epoch 21, Iteration 40, Current loss 3.874429941177368 Accuracy 64.56048453101981
# Training:: Epoch 21, Iteration 50, Current loss 3.3904025554656982 Accuracy 59.766507657544565
# Training:: Epoch 21, Iteration 60, Current loss 3.6817679405212402 Accuracy 61.49584487534626
# Training:: Epoch 21, Iteration 70, Current loss 4.535572052001953 Accuracy 50.397035468501855
# Training:: Epoch 21, Iteration 80, Current loss 2.9147863388061523 Accuracy 51.103848946986204
# Training:: Epoch 21, Iteration 90, Current loss 2.4768145084381104 Accuracy 69.21831857564506
# Training:: Epoch 21, Iteration 100, Current loss 4.634900093078613 Accuracy 48.40840622844906
# Training:: Epoch 21, Iteration 110, Current loss 2.664783000946045 Accuracy 65.18036072144288
# Training:: Epoch 21, Iteration 120, Current loss 2.899162769317627 Accuracy 57.872907717375206
# Training:: Epoch 21, Iteration 130, Current loss 3.8379039764404297 Accuracy 58.88083784935761
# Training:: Epoch 21, Iteration 140, Current loss 3.434178352355957 Accuracy 67.24817107484525
# Training:: Epoch 21, Iteration 150, Current loss 3.594752073287964 Accuracy 59.64071164510166
# Calculating Validation Data Accuracy
# Validation:: Epoch 21, Probability Accuracy 54.58909269479523
# Starting Training
# Training:: Epoch 22, Iteration 0, Current loss 3.2238330841064453 Accuracy 49.82840993203688
# Training:: Epoch 22, Iteration 10, Current loss 2.6517317295074463 Accuracy 68.37729054125623
# Training:: Epoch 22, Iteration 20, Current loss 2.8254761695861816 Accuracy 63.62280150753769
# Training:: Epoch 22, Iteration 30, Current loss 3.2544069290161133 Accuracy 55.28253681995792
# Training:: Epoch 22, Iteration 40, Current loss 3.440370798110962 Accuracy 61.97556477639465
# Training:: Epoch 22, Iteration 50, Current loss 2.7947680950164795 Accuracy 57.39756931809912
# Training:: Epoch 22, Iteration 60, Current loss 3.8818328380584717 Accuracy 60.02564219973442
# Training:: Epoch 22, Iteration 70, Current loss 3.5809311866760254 Accuracy 56.1301275580435
# Training:: Epoch 22, Iteration 80, Current loss 4.20044469833374 Accuracy 55.71646988872845
# Training:: Epoch 22, Iteration 90, Current loss 2.8573224544525146 Accuracy 68.90450944182999
# Training:: Epoch 22, Iteration 100, Current loss 3.3829026222229004 Accuracy 63.270024772914944
# Training:: Epoch 22, Iteration 110, Current loss 3.0980868339538574 Accuracy 65.14128903063117
# Training:: Epoch 22, Iteration 120, Current loss 3.8827576637268066 Accuracy 54.488833526114426
# Training:: Epoch 22, Iteration 130, Current loss 2.791325569152832 Accuracy 65.46546546546547
# Training:: Epoch 22, Iteration 140, Current loss 3.6696512699127197 Accuracy 63.483706495233875
# Training:: Epoch 22, Iteration 150, Current loss 3.360323905944824 Accuracy 65.0832487915498
# Calculating Validation Data Accuracy
# Validation:: Epoch 22, Probability Accuracy 56.75280829906083
# Starting Training
# Training:: Epoch 23, Iteration 0, Current loss 3.728638172149658 Accuracy 57.154192012695056
# Training:: Epoch 23, Iteration 10, Current loss 2.848982334136963 Accuracy 62.91893998441154
# Training:: Epoch 23, Iteration 20, Current loss 3.3595070838928223 Accuracy 66.41104294478528
# Training:: Epoch 23, Iteration 30, Current loss 2.926251173019409 Accuracy 52.62848560047019
# Training:: Epoch 23, Iteration 40, Current loss 4.35041618347168 Accuracy 58.149149308316105
# Training:: Epoch 23, Iteration 50, Current loss 5.644746780395508 Accuracy 46.42443342447977
# Training:: Epoch 23, Iteration 60, Current loss 4.654444694519043 Accuracy 55.2101957548251
# Training:: Epoch 23, Iteration 70, Current loss 4.227102279663086 Accuracy 61.9330224671471
# Training:: Epoch 23, Iteration 80, Current loss 2.958509922027588 Accuracy 64.50663977139016
# Training:: Epoch 23, Iteration 90, Current loss 4.618046760559082 Accuracy 58.46181534585158
# Training:: Epoch 23, Iteration 100, Current loss 5.919243812561035 Accuracy 40.13666838576586
# Training:: Epoch 23, Iteration 110, Current loss 3.6864981651306152 Accuracy 61.714285714285715
# Training:: Epoch 23, Iteration 120, Current loss 3.7850897312164307 Accuracy 57.818222587637344
# Training:: Epoch 23, Iteration 130, Current loss 3.6774702072143555 Accuracy 69.55980400032131
# Training:: Epoch 23, Iteration 140, Current loss 4.023847579956055 Accuracy 55.10197015338804
# Training:: Epoch 23, Iteration 150, Current loss 3.460751533508301 Accuracy 62.83334668054777
# Calculating Validation Data Accuracy
# Validation:: Epoch 23, Probability Accuracy 56.41943962366281
# Starting Training
# Training:: Epoch 24, Iteration 0, Current loss 3.045391082763672 Accuracy 52.34261793592014
# Training:: Epoch 24, Iteration 10, Current loss 3.4652249813079834 Accuracy 70.84849301531689
# Training:: Epoch 24, Iteration 20, Current loss 3.3051795959472656 Accuracy 59.31107205623901
# Training:: Epoch 24, Iteration 30, Current loss 3.1796822547912598 Accuracy 51.840327533265096
# Training:: Epoch 24, Iteration 40, Current loss 2.697889566421509 Accuracy 65.63565800305774
# Training:: Epoch 24, Iteration 50, Current loss 3.3257148265838623 Accuracy 63.56204254590592
# Training:: Epoch 24, Iteration 60, Current loss 3.332460641860962 Accuracy 59.43189295898223
# Training:: Epoch 24, Iteration 70, Current loss 3.2843434810638428 Accuracy 69.62405223251895
# Training:: Epoch 24, Iteration 80, Current loss 2.9777238368988037 Accuracy 60.073493039361175
# Training:: Epoch 24, Iteration 90, Current loss 3.3255298137664795 Accuracy 66.14909014262629
# Training:: Epoch 24, Iteration 100, Current loss 3.26554012298584 Accuracy 60.5512929809605
# Training:: Epoch 24, Iteration 110, Current loss 3.092556953430176 Accuracy 59.737884791222186
# Training:: Epoch 24, Iteration 120, Current loss 5.280333995819092 Accuracy 57.974024261603375
# Training:: Epoch 24, Iteration 130, Current loss 2.940098762512207 Accuracy 56.310511756569845
# Training:: Epoch 24, Iteration 140, Current loss 3.879467010498047 Accuracy 68.85504201680672
# Training:: Epoch 24, Iteration 150, Current loss 2.1597683429718018 Accuracy 69.12556983008703
# Calculating Validation Data Accuracy
# Validation:: Epoch 24, Probability Accuracy 55.09254970675387
# Starting Training
# Training:: Epoch 25, Iteration 0, Current loss 2.3780202865600586 Accuracy 62.93376373455832
# Training:: Epoch 25, Iteration 10, Current loss 3.283296585083008 Accuracy 56.99116904962153
# Training:: Epoch 25, Iteration 20, Current loss 2.2568271160125732 Accuracy 69.07603662928285
# Training:: Epoch 25, Iteration 30, Current loss 2.879894495010376 Accuracy 65.74730354391372
# Training:: Epoch 25, Iteration 40, Current loss 2.571834087371826 Accuracy 65.20252498684903
# Training:: Epoch 25, Iteration 50, Current loss 3.6038637161254883 Accuracy 60.96939840521021
# Training:: Epoch 25, Iteration 60, Current loss 3.0579607486724854 Accuracy 60.092685238822476
# Training:: Epoch 25, Iteration 70, Current loss 2.7668845653533936 Accuracy 58.47225897503749
# Training:: Epoch 25, Iteration 80, Current loss 2.975069761276245 Accuracy 57.914627346508894
# Training:: Epoch 25, Iteration 90, Current loss 4.424899101257324 Accuracy 48.40977569467693
# Training:: Epoch 25, Iteration 100, Current loss 3.126537322998047 Accuracy 64.9005318101241
# Training:: Epoch 25, Iteration 110, Current loss 3.3176393508911133 Accuracy 64.81006025674614
# Training:: Epoch 25, Iteration 120, Current loss 3.2464802265167236 Accuracy 65.22645847815625
# Training:: Epoch 25, Iteration 130, Current loss 3.095716714859009 Accuracy 58.422350041084634
# Training:: Epoch 25, Iteration 140, Current loss 3.0975496768951416 Accuracy 55.65167243367935
# Training:: Epoch 25, Iteration 150, Current loss 3.310845375061035 Accuracy 73.32132564841498
# Calculating Validation Data Accuracy
# Validation:: Epoch 25, Probability Accuracy 54.321460259708374
# Starting Training
# Training:: Epoch 26, Iteration 0, Current loss 2.563094139099121 Accuracy 62.46279445531083
# Training:: Epoch 26, Iteration 10, Current loss 6.8735833168029785 Accuracy 65.13337893296854
# Training:: Epoch 26, Iteration 20, Current loss 3.7761824131011963 Accuracy 66.07632031598395
# Training:: Epoch 26, Iteration 30, Current loss 2.9738712310791016 Accuracy 64.16936488169365
# Training:: Epoch 26, Iteration 40, Current loss 2.8696389198303223 Accuracy 70.77495243037536
# Training:: Epoch 26, Iteration 50, Current loss 2.6264877319335938 Accuracy 67.18926459841892
# Training:: Epoch 26, Iteration 60, Current loss 3.907226085662842 Accuracy 64.43238486359637
# Training:: Epoch 26, Iteration 70, Current loss 3.7166683673858643 Accuracy 59.48033108627016
# Training:: Epoch 26, Iteration 80, Current loss 2.9791505336761475 Accuracy 67.34341252699784
# Training:: Epoch 26, Iteration 90, Current loss 2.8440823554992676 Accuracy 70.42750110180697
# Training:: Epoch 26, Iteration 100, Current loss 3.110323667526245 Accuracy 63.586497890295355
# Training:: Epoch 26, Iteration 110, Current loss 1.7173638343811035 Accuracy 71.632488942501
# Training:: Epoch 26, Iteration 120, Current loss 3.553208827972412 Accuracy 57.817293845094234
# Training:: Epoch 26, Iteration 130, Current loss 3.1336259841918945 Accuracy 58.614426569797615
# Training:: Epoch 26, Iteration 140, Current loss 2.8446273803710938 Accuracy 71.90617417093556
# Training:: Epoch 26, Iteration 150, Current loss 4.4785566329956055 Accuracy 43.15914612084561
# Calculating Validation Data Accuracy
# Validation:: Epoch 26, Probability Accuracy 56.725129882087714
# Starting Training
# Training:: Epoch 27, Iteration 0, Current loss 2.475236415863037 Accuracy 70.3204172876304
# Training:: Epoch 27, Iteration 10, Current loss 2.550548553466797 Accuracy 63.60424028268551
# Training:: Epoch 27, Iteration 20, Current loss 3.2489047050476074 Accuracy 62.889760611546976
# Training:: Epoch 27, Iteration 30, Current loss 3.5276036262512207 Accuracy 53.847334492990896
# Training:: Epoch 27, Iteration 40, Current loss 3.0204501152038574 Accuracy 65.99732262382865
# Training:: Epoch 27, Iteration 50, Current loss 3.009401321411133 Accuracy 58.938672223876154
# Training:: Epoch 27, Iteration 60, Current loss 3.2229504585266113 Accuracy 53.30292776224805
# Training:: Epoch 27, Iteration 70, Current loss 2.927286148071289 Accuracy 50.91711167866264
# Training:: Epoch 27, Iteration 80, Current loss 2.2977261543273926 Accuracy 65.25738135724224
# Training:: Epoch 27, Iteration 90, Current loss 2.8717076778411865 Accuracy 67.84635550236507
# Training:: Epoch 27, Iteration 100, Current loss 3.207185745239258 Accuracy 62.67510167193854
# Training:: Epoch 27, Iteration 110, Current loss 2.652020215988159 Accuracy 61.67659500992834
# Training:: Epoch 27, Iteration 120, Current loss 3.1571736335754395 Accuracy 67.13847114534006
# Training:: Epoch 27, Iteration 130, Current loss 2.4296720027923584 Accuracy 67.64514024787998
# Training:: Epoch 27, Iteration 140, Current loss 2.1563310623168945 Accuracy 63.52105530187722
# Training:: Epoch 27, Iteration 150, Current loss 2.8717455863952637 Accuracy 62.14067843608466
# Calculating Validation Data Accuracy
# Validation:: Epoch 27, Probability Accuracy 55.9189959877456
# Starting Training
# Training:: Epoch 28, Iteration 0, Current loss 2.3100216388702393 Accuracy 64.38464298528883
# Training:: Epoch 28, Iteration 10, Current loss 2.386472225189209 Accuracy 69.69736842105263
# Training:: Epoch 28, Iteration 20, Current loss 2.133478879928589 Accuracy 61.76155494337313
# Training:: Epoch 28, Iteration 30, Current loss 2.8020503520965576 Accuracy 65.4532967032967
# Training:: Epoch 28, Iteration 40, Current loss 3.0748744010925293 Accuracy 59.0895203177513
# Training:: Epoch 28, Iteration 50, Current loss 2.405195713043213 Accuracy 68.56763925729443
# Training:: Epoch 28, Iteration 60, Current loss 2.7063043117523193 Accuracy 60.77014002545918
# Training:: Epoch 28, Iteration 70, Current loss 2.0865790843963623 Accuracy 68.11384466956102
# Training:: Epoch 28, Iteration 80, Current loss 2.739961862564087 Accuracy 55.330882352941174
# Training:: Epoch 28, Iteration 90, Current loss 3.011183500289917 Accuracy 58.966766329346825
# Training:: Epoch 28, Iteration 100, Current loss 2.734326124191284 Accuracy 63.792194092827
# Training:: Epoch 28, Iteration 110, Current loss 2.7144594192504883 Accuracy 65.58452973923235
# Training:: Epoch 28, Iteration 120, Current loss 3.242654800415039 Accuracy 59.22438706068798
# Training:: Epoch 28, Iteration 130, Current loss 2.646827459335327 Accuracy 60.14843830532935
# Training:: Epoch 28, Iteration 140, Current loss 2.7285125255584717 Accuracy 60.04994912589029
# Training:: Epoch 28, Iteration 150, Current loss 2.7931809425354004 Accuracy 57.22263988830416
# Calculating Validation Data Accuracy
# Validation:: Epoch 28, Probability Accuracy 54.97301912377721
# Starting Training
# Training:: Epoch 29, Iteration 0, Current loss 2.391507625579834 Accuracy 62.241004390103804
# Training:: Epoch 29, Iteration 10, Current loss 2.7885124683380127 Accuracy 68.31393714510598
# Training:: Epoch 29, Iteration 20, Current loss 2.2197563648223877 Accuracy 54.52538631346578
# Training:: Epoch 29, Iteration 30, Current loss 2.7609946727752686 Accuracy 60.59262510974539
# Training:: Epoch 29, Iteration 40, Current loss 2.1797547340393066 Accuracy 66.00437211561817
# Training:: Epoch 29, Iteration 50, Current loss 2.7277774810791016 Accuracy 62.768764659890536
# Training:: Epoch 29, Iteration 60, Current loss 2.9472928047180176 Accuracy 66.71404206935759
# Training:: Epoch 29, Iteration 70, Current loss 3.016969919204712 Accuracy 63.38123338889139
# Training:: Epoch 29, Iteration 80, Current loss 1.9168643951416016 Accuracy 63.293079139336726
# Training:: Epoch 29, Iteration 90, Current loss 2.284846067428589 Accuracy 74.41800643086816
# Training:: Epoch 29, Iteration 100, Current loss 2.5136654376983643 Accuracy 64.81158788934873
# Training:: Epoch 29, Iteration 110, Current loss 2.797304153442383 Accuracy 67.7887405687754
# Training:: Epoch 29, Iteration 120, Current loss 2.8007659912109375 Accuracy 67.25531028738025
# Training:: Epoch 29, Iteration 130, Current loss 2.1217145919799805 Accuracy 62.897278314310796
# Training:: Epoch 29, Iteration 140, Current loss 2.6099395751953125 Accuracy 61.519733470015375
# Training:: Epoch 29, Iteration 150, Current loss 2.6074836254119873 Accuracy 71.20584079133302
# Calculating Validation Data Accuracy
# Validation:: Epoch 29, Probability Accuracy 55.838974112867675
# Starting Training
# Training:: Epoch 30, Iteration 0, Current loss 2.370784044265747 Accuracy 69.41052446630941
# Training:: Epoch 30, Iteration 10, Current loss 2.347555160522461 Accuracy 60.73740500985083
# Training:: Epoch 30, Iteration 20, Current loss 2.3671553134918213 Accuracy 65.10669414345543
# Training:: Epoch 30, Iteration 30, Current loss 2.4576501846313477 Accuracy 71.06811402055021
# Training:: Epoch 30, Iteration 40, Current loss 2.653542995452881 Accuracy 68.04556015186718
# Training:: Epoch 30, Iteration 50, Current loss 2.325338363647461 Accuracy 59.85342616342983
# Training:: Epoch 30, Iteration 60, Current loss 2.047990322113037 Accuracy 69.54461396208968
# Training:: Epoch 30, Iteration 70, Current loss 2.6892175674438477 Accuracy 68.23606989779097
# Training:: Epoch 30, Iteration 80, Current loss 2.364461898803711 Accuracy 74.45349988574911
# Training:: Epoch 30, Iteration 90, Current loss 2.126702308654785 Accuracy 66.13036613788437
# Training:: Epoch 30, Iteration 100, Current loss 2.4034645557403564 Accuracy 56.514060589593804
# Training:: Epoch 30, Iteration 110, Current loss 2.401421546936035 Accuracy 67.43941728533407
# Training:: Epoch 30, Iteration 120, Current loss 2.6697638034820557 Accuracy 68.34427885829756
# Training:: Epoch 30, Iteration 130, Current loss 2.6172778606414795 Accuracy 60.78732463181406
# Training:: Epoch 30, Iteration 140, Current loss 2.1673996448516846 Accuracy 60.907571667309426
# Training:: Epoch 30, Iteration 150, Current loss 2.7019455432891846 Accuracy 59.94409503843466
# Calculating Validation Data Accuracy
# Validation:: Epoch 30, Probability Accuracy 53.86565923181232
# Starting Training
# Training:: Epoch 31, Iteration 0, Current loss 2.1089377403259277 Accuracy 57.627923542680755
# Training:: Epoch 31, Iteration 10, Current loss 2.9002270698547363 Accuracy 51.24848668280872
# Training:: Epoch 31, Iteration 20, Current loss 1.988592267036438 Accuracy 63.960880195599024
# Training:: Epoch 31, Iteration 30, Current loss 2.537104606628418 Accuracy 58.05784194665587
# Training:: Epoch 31, Iteration 40, Current loss 1.9774408340454102 Accuracy 57.73097826086956
# Training:: Epoch 31, Iteration 50, Current loss 2.5100584030151367 Accuracy 67.9511994838407
# Training:: Epoch 31, Iteration 60, Current loss 2.237338066101074 Accuracy 69.4703569501195
# Training:: Epoch 31, Iteration 70, Current loss 2.990180015563965 Accuracy 59.787702017787126
# Training:: Epoch 31, Iteration 80, Current loss 2.888550043106079 Accuracy 53.11820320475831
# Training:: Epoch 31, Iteration 90, Current loss 2.054307222366333 Accuracy 60.086292261988966
# Training:: Epoch 31, Iteration 100, Current loss 2.440145254135132 Accuracy 55.504338394793926
# Training:: Epoch 31, Iteration 110, Current loss 2.679971218109131 Accuracy 64.67322557976107
# Training:: Epoch 31, Iteration 120, Current loss 3.286154270172119 Accuracy 54.34628975265018
# Training:: Epoch 31, Iteration 130, Current loss 2.189330816268921 Accuracy 69.82676565771939
# Training:: Epoch 31, Iteration 140, Current loss 2.217139959335327 Accuracy 63.85980883022303
# Training:: Epoch 31, Iteration 150, Current loss 2.9249348640441895 Accuracy 48.98029726927065
# Calculating Validation Data Accuracy
# Validation:: Epoch 31, Probability Accuracy 54.48094597686397
# Starting Training
# Training:: Epoch 32, Iteration 0, Current loss 3.552781581878662 Accuracy 63.47221246399213
# Training:: Epoch 32, Iteration 10, Current loss 1.944739580154419 Accuracy 64.91472005932518
# Training:: Epoch 32, Iteration 20, Current loss 2.1898183822631836 Accuracy 61.513536866359445
# Training:: Epoch 32, Iteration 30, Current loss 2.7811737060546875 Accuracy 60.751482533512736
# Training:: Epoch 32, Iteration 40, Current loss 2.1217870712280273 Accuracy 55.372980405637676
# Training:: Epoch 32, Iteration 50, Current loss 2.3202760219573975 Accuracy 59.60535411298938
# Training:: Epoch 32, Iteration 60, Current loss 2.5068767070770264 Accuracy 72.9683548629622
# Training:: Epoch 32, Iteration 70, Current loss 2.279416799545288 Accuracy 57.85578972294577
# Training:: Epoch 32, Iteration 80, Current loss 3.035411834716797 Accuracy 61.8846199036541
# Training:: Epoch 32, Iteration 90, Current loss 2.3708279132843018 Accuracy 64.38022071824889
# Training:: Epoch 32, Iteration 100, Current loss 2.6871001720428467 Accuracy 67.25108915099352
# Training:: Epoch 32, Iteration 110, Current loss 2.8039190769195557 Accuracy 63.17802011046594
# Training:: Epoch 32, Iteration 120, Current loss 2.9785919189453125 Accuracy 57.88395404990122
# Training:: Epoch 32, Iteration 130, Current loss 11.58200740814209 Accuracy 35.666521296700104
# Training:: Epoch 32, Iteration 140, Current loss 9.668376922607422 Accuracy 38.99590545319189
# Training:: Epoch 32, Iteration 150, Current loss 7.787054061889648 Accuracy 40.73547847889678
# Calculating Validation Data Accuracy
# Validation:: Epoch 32, Probability Accuracy 47.77964408680755
# Starting Training
# Training:: Epoch 33, Iteration 0, Current loss 5.086790084838867 Accuracy 44.022400779157536
# Training:: Epoch 33, Iteration 10, Current loss 6.3481597900390625 Accuracy 53.03056075296252
# Training:: Epoch 33, Iteration 20, Current loss 4.2992119789123535 Accuracy 58.54908306364617
# Training:: Epoch 33, Iteration 30, Current loss 4.362021446228027 Accuracy 56.270383466648354
# Training:: Epoch 33, Iteration 40, Current loss 3.1125869750976562 Accuracy 63.44135098128709
# Training:: Epoch 33, Iteration 50, Current loss 2.7624683380126953 Accuracy 66.64218836056546
# Training:: Epoch 33, Iteration 60, Current loss 3.529655694961548 Accuracy 58.91276281814829
# Training:: Epoch 33, Iteration 70, Current loss 3.063674211502075 Accuracy 69.3773918163085
# Training:: Epoch 33, Iteration 80, Current loss 2.6897053718566895 Accuracy 67.71278934953824
# Training:: Epoch 33, Iteration 90, Current loss 3.9741568565368652 Accuracy 46.84047724259832
# Training:: Epoch 33, Iteration 100, Current loss 3.3192667961120605 Accuracy 60.2130463430705
# Training:: Epoch 33, Iteration 110, Current loss 2.4968249797821045 Accuracy 73.24236817761332
# Training:: Epoch 33, Iteration 120, Current loss 2.414731502532959 Accuracy 68.97517753599583
# Training:: Epoch 33, Iteration 130, Current loss 3.9661505222320557 Accuracy 62.968173026200105
# Training:: Epoch 33, Iteration 140, Current loss 2.5314860343933105 Accuracy 64.41235922610453
# Training:: Epoch 33, Iteration 150, Current loss 2.489572525024414 Accuracy 63.601661143504344
# Calculating Validation Data Accuracy
# Validation:: Epoch 33, Probability Accuracy 54.096126695721566
# Starting Training
# Training:: Epoch 34, Iteration 0, Current loss 3.070666551589966 Accuracy 51.84834123222749
# Training:: Epoch 34, Iteration 10, Current loss 2.768324375152588 Accuracy 62.728816757878846
# Training:: Epoch 34, Iteration 20, Current loss 2.382396936416626 Accuracy 67.89989118607181
# Training:: Epoch 34, Iteration 30, Current loss 2.7732255458831787 Accuracy 59.49424046076314
# Training:: Epoch 34, Iteration 40, Current loss 2.0375120639801025 Accuracy 70.82124299885282
# Training:: Epoch 34, Iteration 50, Current loss 2.778078556060791 Accuracy 62.10093320235757
# Training:: Epoch 34, Iteration 60, Current loss 2.8587167263031006 Accuracy 62.29842362746874
# Training:: Epoch 34, Iteration 70, Current loss 2.2481579780578613 Accuracy 74.6661371195949
# Training:: Epoch 34, Iteration 80, Current loss 2.3115484714508057 Accuracy 69.5846994535519
# Training:: Epoch 34, Iteration 90, Current loss 2.2687089443206787 Accuracy 60.41799957346982
# Training:: Epoch 34, Iteration 100, Current loss 2.6532821655273438 Accuracy 65.70825211176088
# Training:: Epoch 34, Iteration 110, Current loss 2.947481870651245 Accuracy 56.152849740932645
# Training:: Epoch 34, Iteration 120, Current loss 2.1747052669525146 Accuracy 64.04727963886909
# Training:: Epoch 34, Iteration 130, Current loss 3.0048396587371826 Accuracy 64.7890719164323
# Training:: Epoch 34, Iteration 140, Current loss 1.7613657712936401 Accuracy 65.21331945889698
# Training:: Epoch 34, Iteration 150, Current loss 2.21085524559021 Accuracy 59.60184694572705
# Calculating Validation Data Accuracy
# Validation:: Epoch 34, Probability Accuracy 54.748131985870614
# Starting Training
# Training:: Epoch 35, Iteration 0, Current loss 1.9247143268585205 Accuracy 61.5483946704232
# Training:: Epoch 35, Iteration 10, Current loss 2.204866647720337 Accuracy 67.65614167769584
# Training:: Epoch 35, Iteration 20, Current loss 2.0809361934661865 Accuracy 66.04599279217436
# Training:: Epoch 35, Iteration 30, Current loss 1.8409050703048706 Accuracy 63.7213769397968
# Training:: Epoch 35, Iteration 40, Current loss 2.8765697479248047 Accuracy 61.55801706918467
# Training:: Epoch 35, Iteration 50, Current loss 2.3316562175750732 Accuracy 57.54315497537417
# Training:: Epoch 35, Iteration 60, Current loss 2.4338812828063965 Accuracy 63.22496211599394
# Training:: Epoch 35, Iteration 70, Current loss 2.3699052333831787 Accuracy 65.45270145675825
# Training:: Epoch 35, Iteration 80, Current loss 2.0923116207122803 Accuracy 55.55094934085068
# Training:: Epoch 35, Iteration 90, Current loss 2.2597570419311523 Accuracy 61.402543072604175
# Training:: Epoch 35, Iteration 100, Current loss 2.375473976135254 Accuracy 57.152361942781106
# Training:: Epoch 35, Iteration 110, Current loss 1.8254902362823486 Accuracy 72.30254510694229
# Training:: Epoch 35, Iteration 120, Current loss 2.6635689735412598 Accuracy 60.418963616317534
# Training:: Epoch 35, Iteration 130, Current loss 2.9510486125946045 Accuracy 58.249019202973365
# Training:: Epoch 35, Iteration 140, Current loss 2.717771053314209 Accuracy 71.09184502844758
# Training:: Epoch 35, Iteration 150, Current loss 1.8892467021942139 Accuracy 66.47031467989459
# Calculating Validation Data Accuracy
# Validation:: Epoch 35, Probability Accuracy 54.00539059491855
# Starting Training
# Training:: Epoch 36, Iteration 0, Current loss 1.5283524990081787 Accuracy 64.32868783794075
# Training:: Epoch 36, Iteration 10, Current loss 1.928717017173767 Accuracy 65.0532684466658
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-95645851addf> in <module>
#      23
#      24         loss.backward()
# ---> 25         optimizer.step()
#      26
#      27         if i % 10 == 0:
#
# ~/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# ~/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/optim/functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      92             denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      93         else:
# ---> 94             denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      95
#      96         step_size = lr / bias_correction1
#
# KeyboardInterrupt:

# %%
config.output_dir + "ms-tcn-best-model.wt"
# Out:
# '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcn-lenpsuedo-full-supervised-split1/ms-tcn-best-model.wt'

# %%
best_epoch
# Out:
# 10

# %%
torch.save(model.state_dict(),
"/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-speed/final-em-maximized.wt")

# %%
model.load_state_dict(torch.load(f"/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split3/ms-tcn-initial-15-epochs.wt"))
# Out:
# <All keys matched successfully>

# %%
print("Calculating Validation Data Accuracy")
correct = 0.0
total = 0.0
for i, item in enumerate(testloader):
    with torch.no_grad():
        item_0 = item[0].to(device)
        item_1 = item[1].to(device)
        item_2 = item[2].to(device)
        src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
        src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)

        middle_pred, predictions = model(item_0, src_mask_mse)

        pred = torch.argmax(predictions[-1], dim=1)
        correct += float(torch.sum((pred == item_2) * src_mask).item())
        total += float(torch.sum(src_mask).item())

print(f"Validation:: Epoch {epoch}, Probability Accuracy {correct * 100.0 / total}")
# Out:
# Calculating Validation Data Accuracy
# Validation:: Epoch 15, Probability Accuracy 57.770101729343025

# %%
import pickle
# pickle.dump(video_id_boundary_frames, open("dump_dir/video_id_boundary_frames_dict.pkl", "wb"))
# pickle.dump(loaded_vidid_selected_frames, open("dump_dir/loaded_vidid_selected_frames_dict.pkl", "wb"))
pickle.dump(boundary_dict, open("dump_dir/chunk_1_video_id_boundary_frames_dict.pkl", "wb"))
