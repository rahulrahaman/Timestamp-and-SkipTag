# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
import os, sys
import glob
import numpy as np
import torch
import pandas as pd
import random
import torch.nn as nn
import pickle
import torch.nn.functional as F
import matplotlib.pyplot as plt
import multiprocessing as mp
from time import time

# %%
from mstcn_model import *
from utility.adaptive_data_loader import Breakfast, collate_fn_override
from utility.adaptive_data_loader import BreakfastWithWeights, collate_fn_override_wtd
from utils import calculate_mof, dotdict

# %%
os.environ["WANDB_API_KEY"] = "992b3b1371ba79f48484cfca522b3786d7fa52c2"
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dipika_singhania (use `wandb login --relogin` to force relogin)
# True

# %%
seed = 42

# Ensure deterministic behavior
def set_seed():
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
set_seed()

# Device configuration
os.environ['CUDA_VISIBLE_DEVICES']='6'
# os.environ['CUDA_LAUNCH_BLOCKING']='6'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config = dotdict(
    epochs=500,
    num_class=48,
    batch_size=8,
    learning_rate=5e-4,
    weight_decay=0,
    dataset="Breakfast",
    architecture="unet-ensemble",
    features_file_name="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/",
    chunk_size=1,
    max_frames_per_video=1200,
    feature_size=2048,
    ground_truth_files_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/",
    label_id_csv="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv",
    gamma=0.1,
    step_size=500,
    split=2,
#     output_dir="/mnt/data/ar-datasets/dipika/breakfast/ms_tcn/data/breakfast/results/unsuper-finetune-split2-0.05-data-llr/",
    output_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select4/",
    train_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split{}.bundle",
    test_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split{}.bundle",
    all_files="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt",
    cutoff=8,
    data_per = 0.2,
    budget=40,
    semi_supervised_split="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split{}_amt{}.bundle")

config.train_split_file = config.train_split_file.format(config.split)
config.semi_supervised_split = config.semi_supervised_split.format(config.split, config.data_per)
config.test_split_file = config.test_split_file.format(config.split)

if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)

config.output_dir = config.output_dir + f"split{config.split}"
if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)
config.output_dir = config.output_dir + "/"
if not os.path.exists(os.path.join(config.output_dir, "posterior_weights")):
    os.mkdir(os.path.join(config.output_dir, "posterior_weights"))
print(config)
# Out:
# {'epochs': 500, 'num_class': 48, 'batch_size': 8, 'learning_rate': 0.0005, 'weight_decay': 0, 'dataset': 'Breakfast', 'architecture': 'unet-ensemble', 'features_file_name': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/', 'chunk_size': 1, 'max_frames_per_video': 1200, 'feature_size': 2048, 'ground_truth_files_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/', 'label_id_csv': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv', 'gamma': 0.1, 'step_size': 500, 'split': 2, 'output_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select4/split2/', 'train_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split2.bundle', 'test_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split2.bundle', 'all_files': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt', 'cutoff': 8, 'data_per': 0.2, 'budget': 40, 'semi_supervised_split': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split2_amt0.2.bundle'}

# %%
traindataset = BreakfastWithWeights(config, fold='train', fold_file_name=config.train_split_file)
testdataset = Breakfast(config, fold='test', fold_file_name=config.test_split_file)
# Out:
# Number of videos logged in train fold is 1261
# Number of videos not found in train fold is 0
# Number of videos logged in test fold is 451
# Number of videos not found in test fold is 0

# %%
def _init_fn(worker_id):
    np.random.seed(int(seed))
trainloader = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=config.batch_size, 
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)
testloader = torch.utils.data.DataLoader(dataset=testdataset,
                                          batch_size=config.batch_size, 
                                          shuffle=False,
                                          pin_memory=True, num_workers=4,
                                          collate_fn=lambda x: collate_fn_override(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

trainloder_expectation = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=20,
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

# %%
df = pd.read_csv(config.label_id_csv)
label_id_to_label_name = {}
label_name_to_label_id_dict = {}
for i, ele in df.iterrows():
    label_id_to_label_name[ele.label_id] = ele.label_name
    label_name_to_label_id_dict[ele.label_name] = ele.label_id

# %%
# selected_frames_dict = pickle.load(open("data/breakfast_len_assum_annotations.pkl", 'rb'))
# loaded_vidid_selected_frames
boundary_frames_dict = pickle.load(open("data/breakfast_boundary_annotations.pkl", "rb"))
num_boundary = 0
for key in boundary_frames_dict.keys():
    num_boundary += len(boundary_frames_dict[key])
# video_id_boundary_frames

# %%
selected_frames_dict = pickle.load(open("data/breakfast_random4frame_selection.pkl", "rb"))
# print(selected_frames_dict)

# %%
loaded_mean_var_actions = pickle.load(open("data/breakfast_meanvar_actions.pkl", "rb"))
mat_poisson = pickle.load(open("data/breakfast_possion_class_dict.pkl", "rb"))

def get_possion_prob(minlen, maxlen, cur_class):
    prob = mat_poisson[label_id_to_label_name[cur_class]][minlen:maxlen]
    return torch.tensor(prob)

def get_poisson_logcdf(minlen, cur_class):
    return np.log(np.sum(np.exp(mat_poisson[label_id_to_label_name[cur_class]][minlen:])) + 1e-20)

def get_possion_prob_for_all_class(minlen, maxlen):
    ele_list = []
    for i in range(config.num_class):
        prob = mat_poisson[label_id_to_label_name[i]][minlen:maxlen]
        ele_list.append(torch.tensor(prob))
    return torch.stack(ele_list, dim=-1)

# %%
def validate(model, dataloader, best_val_acc=None):
    model.eval()
    print("Calculating Validation Data Accuracy")
    correct = 0.0
    total = 0.0
    for i, item in enumerate(testloader):
        with torch.no_grad():
            item_0 = item[0].to(device)
            item_1 = item[1].to(device)
            item_2 = item[2].to(device)
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            pred = torch.argmax(predictions[-1], dim=1)
            correct += float(torch.sum((pred == item_2) * src_mask).item())
            total += float(torch.sum(src_mask).item())
    val_acc = correct * 100.0 / total
    if best_val_acc is not None and val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-best-model.wt")
    torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-last-model.wt")
    print(f"Validation:: Probability Accuracy {val_acc}")
    _ = model.train()
    return val_acc, best_val_acc

# %%
def prob_vals_per_segment(selected_frames, cur_vid_feat, labels, first_ele_flag, last_ele_flag, vidid, gt_labels):
    prob_each_segment = []
    LOW_VAL = -10000000
    num_frames = len(cur_vid_feat)
    log_probs = torch.log(cur_vid_feat + 1e-8)
    cumsum_feat = torch.cumsum(log_probs, dim=0)
    prev_boundary = 0
    per_frame_weights = torch.zeros((num_frames, config.num_class))
    start_time = time()
    boundary_error = 0
    current_boundary = 0
    labels = [config.num_class-1] + labels if selected_frames[0] != 0 else labels
    labels = labels + [config.num_class-1] if selected_frames[-1] != num_frames-1 else labels
    selected_frames = [0] + selected_frames if selected_frames[0] != 0 else selected_frames
    selected_frames = selected_frames + [num_frames-1] if selected_frames[-1] != num_frames-1 else selected_frames

    for i, cur_ele in enumerate(selected_frames[:-1]):
        next_ele = selected_frames[i + 1]
        label_cur_ele = labels[i]
        label_next_ele = labels[i + 1]
        if cur_ele == next_ele-1:
            per_frame_weights[cur_ele, label_cur_ele] = 1.0
            if label_cur_ele != label_next_ele:
                prev_boundary = cur_ele
            continue
        
        seg_len = next_ele - cur_ele
        mat_b1_b2_c_prob = LOW_VAL * torch.ones((seg_len, seg_len, config.num_class), dtype=cumsum_feat.dtype)
        b1_prior = get_possion_prob(cur_ele-prev_boundary, next_ele-prev_boundary, label_cur_ele)
        
        # find dummy label where we will keep the diagonal (b1=b2) probabilities, later we will distribute among
        # rest of the classes after the softmax by dividing by (num_class - 2)
        dummy_label = 0
        while True:
            if dummy_label != label_cur_ele and dummy_label != label_next_ele:
                break
            else:
                dummy_label += 1
        
        for b1 in range(cur_ele, next_ele - 1):

            cur_boundary_len = b1 - prev_boundary
            strt_index = cumsum_feat[cur_ele - 1, label_cur_ele] if cur_ele > 0 else 0
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            right_sum = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1+1:next_ele, label_next_ele] # mid_seg_len
            mid_sum = (cumsum_feat[b1+1:next_ele, :] - cumsum_feat[b1, :])  # mid_seg_len
            b2_prior = get_possion_prob_for_all_class(1, next_ele-b1)  # mid_seg_len x num_class
            
            mat_b1_b2_c_prob[b1-cur_ele, b1+1-cur_ele:next_ele-cur_ele] = (left_sum + right_sum[:,None] + mid_sum) \
                                                                            + b1_prior[b1-cur_ele] + b2_prior
            # when mid segment is absent but right and left is not the same
            # we assign the probability to a dummy label for now and then later 
            # re-distribute among other classes after the softmax
            if label_cur_ele != label_next_ele:
                rightsum_wo_midseg = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1, label_next_ele]
                mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + rightsum_wo_midseg + b1_prior[b1-cur_ele]
        
        # when mid segment is absent b1 can also be next_ele-1
        b1 = next_ele - 1
        if label_cur_ele != label_next_ele:
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior[b1-cur_ele]
        else:
            # returns prob that the left class length >= seg len
            b1_prior_ = get_poisson_logcdf(next_ele - prev_boundary, label_cur_ele) 
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior_
        
        mat_b1_b2_c_prob[:, :, label_cur_ele] = LOW_VAL
        mat_b1_b2_c_prob[:, :, label_next_ele] = LOW_VAL
        mat_b1_b2_c_prob = torch.softmax(mat_b1_b2_c_prob.flatten(), dim=0).reshape((seg_len, seg_len, config.num_class))
        
        # re-distribute the dummy class probability among the left-over classes
        left_over_classes = config.num_class - 2 + (label_cur_ele==label_next_ele)
        for b1 in range(cur_ele, next_ele):
            assigned_prob = mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label]
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, :] = assigned_prob/left_over_classes
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_cur_ele] = 0
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_next_ele] = 0
        
        marginal_b1 = torch.sum(mat_b1_b2_c_prob, axis=(1,2))
        mean_b1 = round(torch.sum(marginal_b1.squeeze() * torch.arange(cur_ele, next_ele, 1)).item())
        cumm_b1_prob = torch.cumsum(marginal_b1, dim=0)
        cumm_b1_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=1), dim=0)
        cumm_b2_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=0), dim=0)

        per_frame_weights[cur_ele, label_cur_ele] = 1.0
        per_frame_weights[cur_ele+1:next_ele, :] = cumm_b1_c_prob[:-1] - cumm_b2_c_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_cur_ele] = 1 - cumm_b1_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] = 0
        remaining_probability = 1 - torch.sum(per_frame_weights[cur_ele+1:next_ele, :], dim=-1)
        # we use "+=" in the next line because left and right label might be the same
        # in that case using "=" would just overwrite the previous probability
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] += remaining_probability
        
        expected_boundary = round(torch.sum(torch.sum(mat_b1_b2_c_prob, axis=(0,2)).squeeze() * \
                            torch.arange(cur_ele, next_ele, 1)).item())
        if not (label_cur_ele == label_next_ele and expected_boundary >= next_ele-2):
            prev_boundary = expected_boundary
        if expected_boundary == 0 and i > 0:
            print(f'Estimated boundary has become zero! for {vidid} and cur_ele, next_ele {cur_ele, next_ele}')
            import pdb
            pdb.set_trace()
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary] - mean_b1)**2
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary+1] - prev_boundary)**2
        # current_boundary += 2
        # prob_each_segment.append(mat_b1_b2_c_prob)
        
    posterior_prediction = torch.argmax(per_frame_weights, dim=1)
    correct = torch.sum(posterior_prediction == gt_labels[:num_frames]).item()
    
    return (vidid, per_frame_weights, [correct, num_frames, boundary_error]) #, prob_each_segment)

# %%
posterior_acc_correct, posterior_acc_total = 0, 0
posterior_boundary_total_mse = 0
results = []

# Step 2: Define callback function to collect the output in `results`
def collect_result(result):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    fname = os.path.join(config.output_dir, 'posterior_weights', result[0] + '.wt')
    torch.save(result[1], fname)
    correct, total, boundary_err = result[2]
    posterior_acc_correct += correct
    posterior_acc_total += total
    posterior_boundary_total_mse += boundary_err
    # print(f'Dumped in file {fname} at time {time()}')
    return

def calculate_element_probb(data_feat, data_count, video_ids, gt_labels): # loaded_vidid_selected_frames, boundaries_dict):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    pool = mp.Pool(20)
    for iter_num in range(len(data_count)):
        cur_vidid = video_ids[iter_num]
        cur_vid_count = data_count[iter_num]
        cur_vid_feat = data_feat[iter_num][:cur_vid_count].detach().cpu()
        cur_gt_labels = gt_labels[iter_num].detach().cpu()
        
        cur_video_select_frames = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices_and_labels = cur_video_select_frames
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]
        with torch.no_grad():
            # Multi-processing
            pool.apply_async(prob_vals_per_segment,
                             args=(selected_frames_indices, cur_vid_feat, selected_frames_labels,
                                   cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels),
                             callback=collect_result)
#             results.append(prob_vals_per_segment(selected_frames_indices, cur_vid_feat, selected_frames_labels,
#                                    cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels))
    # Step 4: Close Pool and let all the processes complete
    pool.close()
    pool.join()  # postpones the execution of next line of code until all processes in the queue are done.
    return

def perform_expectation(model, dataloader):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse = 0, 0, 0
    model.eval()
    correct = 0.0
    total = 0.0
    curtime = time()
    print(f'Calculating expectation')

    for i, item in enumerate(dataloader):
        with torch.no_grad():
            item_0 = item[0].to(device) # features
            item_1 = item[1].to(device) # count
            item_2 = item[2].to(device) # gt frame-wise labels
            item_4 = item[4] # video-ids
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            prob = torch.softmax(predictions[-1], dim=1)
            prob = prob.permute(0, 2, 1)
            
            calculate_element_probb(prob, item_1, item_4, item_2)
            if (i+1) % 10 == 0:
                print(f"iter {i+1} of Expectation completed in a total of {(time() - curtime)/60.: .1f} minutes")
    _ = model.train()
    print(f'Expectation step finished, '
          f'posterior frame-wise accuracy {100*posterior_acc_correct/posterior_acc_total: .2f}%, '
          f'boundary mse {(posterior_boundary_total_mse/num_boundary)**0.5: .2f}')
    return

# %%
set_seed()
model = MultiStageModel(num_stages=4, num_layers=10, num_f_maps=64, dim=2048, num_classes=48).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

# Requires loaded_vidid_selected_frames, boundaries_dict
ce_criterion = nn.CrossEntropyLoss(ignore_index=-100)
mse_criterion = nn.MSELoss(reduction='none')

# %%
loaded_file=torch.load(os.path.join(config.output_dir, "ms-tcn-initial-30-epochs.wt"))
model.load_state_dict(loaded_file)
# loaded_file=torch.load('/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcnnew-full-supervised-split1/ms-tcn-best-model.wt')
# model.load_state_dict(loaded_file)
_ = validate(model, testloader)
# Out:
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.130235737664165

# %%
# item = next(iter(trainloader))
    
# with torch.no_grad():
#     item_0 = item[0].to(device) # features
#     item_1 = item[1].to(device) # count
#     item_2 = item[2].to(device) # gt frame-wise labels
#     item_4 = item[4] # video-ids
#     src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
#     src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
#     middle_pred, predictions = model(item_0, src_mask_mse)
#     prob = torch.softmax(predictions[-1], dim=1)
#     prob = prob.permute(0, 2, 1)

#     res = calculate_element_probb(prob, item_1, item_4, item_2)

# %%
# idx = 2
# vidid = res[idx][0]
# mat = res[idx][1]
# mat.shape

# %%
# np.linspace(0, 5281, 4 + 1).astype(int)

# %%
# boundary_frames_dict[f'{vidid}.txt'], selected_frames_dict[f'{vidid}.txt'], weakly_labels[f'{vidid}.txt']

# %%
# fig = plt.figure(figsize=(20, 5))
# for i in range(48):
#     plt.plot(mat[:,i])
    
# for bd in boundary_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd, bd], [0, 2])
    
# for bd in selected_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd[0], bd[0]], [0, 2], '--')

# %%
# bd

# %%
# Calculating Expectation Step
# perform_expectation(model, trainloder_expectation)

# %%
def get_single_random(video_ids, len_frames, device):
    # Generate target for only timestamps. Do not generate pseudo labels at first 30 epochs.
    boundary_target_tensor = torch.ones((len(video_ids), len_frames), dtype=torch.long, device=device) * (-100)
    for iter_num, cur_vidid in enumerate(video_ids):
        selected_frames_indices_and_labels = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]

        frame_idx_tensor = torch.from_numpy(np.array(selected_frames_indices))
        frame_labels = torch.from_numpy(np.array(selected_frames_labels)).to(device)
        boundary_target_tensor[iter_num, frame_idx_tensor] = frame_labels

    return boundary_target_tensor

# %%
weakly_labels = pickle.load(open("data/breakfast_weaklysupervised_labels.pkl", "rb"))
prior_probs = pickle.load(open('data/breakfast_lengthmodel_multinomial_prior.pkl', 'rb'))

# %%
initialize_epoch = 30
expectation_cal_gap = 5
best_val_acc = 0
for epoch in range(30, 150):
    print("Starting Training")
    model.train()
    for i, item in enumerate(trainloader):
        item_0 = item[0].to(device)  # features
        item_1 = item[1].to(device)  # count
        item_2 = item[2].to(device)  # target
        weights = item[5].to(device)  # posterior weight
        src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
        src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
        optimizer.zero_grad()
        
        middle_pred, predictions = model(item_0, src_mask_mse)
        boundary_target_tensor = get_single_random(item[4], item_2.shape[1], item_2.device)
        
        loss = 0
        for p in predictions:
            if epoch <= initialize_epoch:
                loss += ce_criterion(p, boundary_target_tensor)
                loss += 0.15 * torch.mean(torch.clamp(mse_criterion(F.log_softmax(p[:, :, 1:], dim=1), 
                                                                    F.log_softmax(p.detach()[:, :, :-1], dim=1)), min=0,
                                            max=16) * src_mask_mse[:, :, 1:])
            else:
                prob = torch.softmax(p, dim=1)
                prob = prob.permute(0, 2, 1)
                total_count = torch.sum(src_mask)
                weighted_loss_sum = -torch.sum(torch.sum(torch.log(prob + 1e-8) * weights, dim=-1) * src_mask)
                loss += weighted_loss_sum/total_count

        loss.backward()
        optimizer.step()
        if (i+1)%20 == 0:
            print(f'Epoch {epoch+1}: Iteration {i+1} with loss {loss.item()}')

    if (epoch >= initialize_epoch) and ((epoch % (3 * expectation_cal_gap)) == 0):
        torch.save(model.state_dict(), config.output_dir + f"ms-tcn-initial-{epoch}-epochs.wt")

    if epoch >= initialize_epoch and (epoch % expectation_cal_gap == 0):
        perform_expectation(model, trainloder_expectation)
    
    print(f'Epoch {epoch+1} finished, starting validation')
    val_acc, best_val_acc = validate(model, testloader, best_val_acc)
# Out:
# Starting Training
# Epoch 31: Iteration 20 with loss 0.5504493713378906
# Epoch 31: Iteration 40 with loss 1.3216516971588135
# Epoch 31: Iteration 60 with loss 0.8120794892311096
# Epoch 31: Iteration 80 with loss 0.7270302176475525
# Epoch 31: Iteration 100 with loss 0.6850581765174866
# Epoch 31: Iteration 120 with loss 0.833518385887146
# Epoch 31: Iteration 140 with loss 1.0640850067138672
# Calculating expectation
# iter 10 of Expectation completed in a total of  5.0 minutes
# iter 20 of Expectation completed in a total of  10.8 minutes
# iter 30 of Expectation completed in a total of  17.8 minutes
# iter 40 of Expectation completed in a total of  24.5 minutes
# iter 50 of Expectation completed in a total of  29.2 minutes
# iter 60 of Expectation completed in a total of  33.6 minutes
# Expectation step finished, posterior frame-wise accuracy  75.03%, boundary mse  0.00
# Epoch 31 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.16236483407217
# Starting Training
# Epoch 32: Iteration 20 with loss 2.633448600769043
# Epoch 32: Iteration 40 with loss 2.292285680770874
# Epoch 32: Iteration 60 with loss 4.301058769226074
# Epoch 32: Iteration 80 with loss 3.6781272888183594
# Epoch 32: Iteration 100 with loss 4.323844909667969
# Epoch 32: Iteration 120 with loss 1.4388340711593628
# Epoch 32: Iteration 140 with loss 2.615229845046997
# Epoch 32 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.09178854041513
# Starting Training
# Epoch 33: Iteration 20 with loss 1.4804631471633911
# Epoch 33: Iteration 40 with loss 1.784061312675476
# Epoch 33: Iteration 60 with loss 1.9801793098449707
# Epoch 33: Iteration 80 with loss 3.735548973083496
# Epoch 33: Iteration 100 with loss 2.068079710006714
# Epoch 33: Iteration 120 with loss 2.245123863220215
# Epoch 33: Iteration 140 with loss 3.3294501304626465
# Epoch 33 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.66967725897999
# Starting Training
# Epoch 34: Iteration 20 with loss 1.225083351135254
# Epoch 34: Iteration 40 with loss 2.885145425796509
# Epoch 34: Iteration 60 with loss 3.3584790229797363
# Epoch 34: Iteration 80 with loss 3.492539167404175
# Epoch 34: Iteration 100 with loss 1.4760732650756836
# Epoch 34: Iteration 120 with loss 2.8914153575897217
# Epoch 34: Iteration 140 with loss 1.8624300956726074
# Epoch 34 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.10933421717695
# Starting Training
# Epoch 35: Iteration 20 with loss 1.5493251085281372
# Epoch 35: Iteration 40 with loss 1.688352108001709
# Epoch 35: Iteration 60 with loss 2.353393077850342
# Epoch 35: Iteration 80 with loss 1.3245000839233398
# Epoch 35: Iteration 100 with loss 2.638413906097412
# Epoch 35: Iteration 120 with loss 2.032182216644287
# Epoch 35: Iteration 140 with loss 3.0907528400421143
# Epoch 35 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.7696689729461
# Starting Training
# Epoch 36: Iteration 20 with loss 2.071638822555542
# Epoch 36: Iteration 40 with loss 1.8722046613693237
# Epoch 36: Iteration 60 with loss 0.906796932220459
# Epoch 36: Iteration 80 with loss 1.1045939922332764
# Epoch 36: Iteration 100 with loss 2.1220204830169678
# Epoch 36: Iteration 120 with loss 2.924379348754883
# Epoch 36: Iteration 140 with loss 1.603144884109497
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.1 minutes
# iter 20 of Expectation completed in a total of  6.8 minutes
# iter 30 of Expectation completed in a total of  10.5 minutes
# iter 40 of Expectation completed in a total of  13.9 minutes
# iter 50 of Expectation completed in a total of  17.5 minutes
# iter 60 of Expectation completed in a total of  20.9 minutes
# Expectation step finished, posterior frame-wise accuracy  75.02%, boundary mse  0.00
# Epoch 36 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.68154700252724
# Starting Training
# Epoch 37: Iteration 20 with loss 1.3428341150283813
# Epoch 37: Iteration 40 with loss 1.3353545665740967
# Epoch 37: Iteration 60 with loss 1.535544991493225
# Epoch 37: Iteration 80 with loss 1.5729951858520508
# Epoch 37: Iteration 100 with loss 2.821796178817749
# Epoch 37: Iteration 120 with loss 1.8597421646118164
# Epoch 37: Iteration 140 with loss 2.149606704711914
# Epoch 37 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.47847702697104
# Starting Training
# Epoch 38: Iteration 20 with loss 1.5168492794036865
# Epoch 38: Iteration 40 with loss 1.7371289730072021
# Epoch 38: Iteration 60 with loss 1.357895016670227
# Epoch 38: Iteration 80 with loss 0.7760287523269653
# Epoch 38: Iteration 100 with loss 2.097635507583618
# Epoch 38: Iteration 120 with loss 1.5728089809417725
# Epoch 38: Iteration 140 with loss 1.6782171726226807
# Epoch 38 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.23455690433774
# Starting Training
# Epoch 39: Iteration 20 with loss 1.58805513381958
# Epoch 39: Iteration 40 with loss 1.1609463691711426
# Epoch 39: Iteration 60 with loss 1.2402708530426025
# Epoch 39: Iteration 80 with loss 1.2595494985580444
# Epoch 39: Iteration 100 with loss 1.9626033306121826
# Epoch 39: Iteration 120 with loss 0.9128363728523254
# Epoch 39: Iteration 140 with loss 1.1281113624572754
# Epoch 39 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.84532046236069
# Starting Training
# Epoch 40: Iteration 20 with loss 0.8385536670684814
# Epoch 40: Iteration 40 with loss 1.1047145128250122
# Epoch 40: Iteration 60 with loss 2.258254289627075
# Epoch 40: Iteration 80 with loss 1.8309695720672607
# Epoch 40: Iteration 100 with loss 2.1142728328704834
# Epoch 40: Iteration 120 with loss 2.9778456687927246
# Epoch 40: Iteration 140 with loss 0.7994843125343323
# Epoch 40 finished, starting validation
# Calculating Validation Data Accuracy
# Calculating expectation
# iter 10 of Expectation completed in a total of  4.0 minutes
# iter 20 of Expectation completed in a total of  7.5 minutes
# iter 30 of Expectation completed in a total of  10.9 minutes
# iter 40 of Expectation completed in a total of  14.1 minutes
# iter 50 of Expectation completed in a total of  17.2 minutes
# iter 60 of Expectation completed in a total of  20.9 minutes
# Expectation step finished, posterior frame-wise accuracy  75.02%, boundary mse  0.00
# Epoch 41 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.66462277830716
# Starting Training
# Epoch 42: Iteration 20 with loss 0.8664419651031494
# Epoch 42: Iteration 40 with loss 1.4032397270202637
# Epoch 42: Iteration 60 with loss 1.7312923669815063
# Epoch 42: Iteration 80 with loss 1.2101165056228638
# Epoch 42: Iteration 100 with loss 1.5045137405395508
# Epoch 42: Iteration 120 with loss 1.711701512336731
# Epoch 42: Iteration 140 with loss 1.9429771900177002
# Epoch 42 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.59429506566682
# Starting Training
# Epoch 43: Iteration 20 with loss 1.0939326286315918
# Epoch 43: Iteration 40 with loss 0.67936110496521
# Epoch 43: Iteration 60 with loss 1.4737699031829834
# Epoch 43: Iteration 80 with loss 1.232555627822876
# Epoch 43: Iteration 100 with loss 1.7922121286392212
# Epoch 43: Iteration 120 with loss 0.5838337540626526
# Epoch 43: Iteration 140 with loss 2.2233173847198486
# Epoch 43 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.87241579318059
# Starting Training
# Epoch 44: Iteration 20 with loss 0.5097978711128235
# Epoch 44: Iteration 40 with loss 2.7239298820495605
# Epoch 44: Iteration 60 with loss 2.286159038543701
# Epoch 44: Iteration 80 with loss 0.810799241065979
# Epoch 44: Iteration 100 with loss 0.654005765914917
# Epoch 44: Iteration 120 with loss 1.2205463647842407
# Epoch 44: Iteration 140 with loss 1.4710628986358643
# Epoch 44 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.0358992418279
# Starting Training
# Epoch 45: Iteration 20 with loss 1.593314528465271
# Epoch 45: Iteration 40 with loss 0.9237377047538757
# Epoch 45: Iteration 60 with loss 1.0641595125198364
# Epoch 45: Iteration 80 with loss 0.7881408929824829
# Epoch 45: Iteration 100 with loss 1.0432318449020386
# Epoch 45: Iteration 120 with loss 1.593092441558838
# Epoch 45: Iteration 140 with loss 1.2809597253799438
# Epoch 45 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.507706011517584
# Starting Training
# Epoch 46: Iteration 20 with loss 1.3670021295547485
# Epoch 46: Iteration 40 with loss 1.3832145929336548
# Epoch 46: Iteration 60 with loss 0.9934844970703125
# Epoch 46: Iteration 80 with loss 1.2918455600738525
# Epoch 46: Iteration 100 with loss 1.0065866708755493
# Epoch 46: Iteration 120 with loss 0.9173724055290222
# Epoch 46: Iteration 140 with loss 0.6124089956283569
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  7.4 minutes
# iter 30 of Expectation completed in a total of  11.1 minutes
# iter 40 of Expectation completed in a total of  14.5 minutes
# iter 50 of Expectation completed in a total of  17.9 minutes
# iter 60 of Expectation completed in a total of  21.0 minutes
# Expectation step finished, posterior frame-wise accuracy  75.26%, boundary mse  0.00
# Epoch 46 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.130919335460085
# Starting Training
# Epoch 47: Iteration 20 with loss 0.7339627742767334
# Epoch 47: Iteration 40 with loss 0.6746801137924194
# Epoch 47: Iteration 60 with loss 0.7244361042976379
# Epoch 47: Iteration 80 with loss 0.7197525501251221
# Epoch 47: Iteration 100 with loss 0.6458986401557922
# Epoch 47: Iteration 120 with loss 0.9442324638366699
# Epoch 47: Iteration 140 with loss 0.731082022190094
# Epoch 47 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.55990802502382
# Starting Training
# Epoch 48: Iteration 20 with loss 0.7740412950515747
# Epoch 48: Iteration 40 with loss 0.8129401206970215
# Epoch 48: Iteration 60 with loss 1.5740967988967896
# Epoch 48: Iteration 80 with loss 1.390871286392212
# Epoch 48: Iteration 100 with loss 1.3359262943267822
# Epoch 48: Iteration 120 with loss 2.027796506881714
# Epoch 48: Iteration 140 with loss 3.984437942504883
# Epoch 48 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.414778141442596
# Starting Training
# Epoch 49: Iteration 20 with loss 0.9165235161781311
# Epoch 49: Iteration 40 with loss 1.110148310661316
# Epoch 49: Iteration 60 with loss 0.712933361530304
# Epoch 49: Iteration 80 with loss 0.5730948448181152
# Epoch 49: Iteration 100 with loss 1.5081281661987305
# Epoch 49: Iteration 120 with loss 1.1036934852600098
# Epoch 49: Iteration 140 with loss 0.9223182201385498
# Epoch 49 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.321912416621785
# Starting Training
# Epoch 50: Iteration 20 with loss 1.2680072784423828
# Epoch 50: Iteration 40 with loss 0.895195722579956
# Epoch 50: Iteration 60 with loss 0.47191232442855835
# Epoch 50: Iteration 80 with loss 0.4661881625652313
# Epoch 50: Iteration 100 with loss 2.2397396564483643
# Epoch 50: Iteration 120 with loss 0.7408313155174255
# Epoch 50: Iteration 140 with loss 1.4127984046936035
# Epoch 50 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.44444214276837
# Starting Training
# Epoch 51: Iteration 20 with loss 0.6674855351448059
# Epoch 51: Iteration 40 with loss 1.474895715713501
# Epoch 51: Iteration 60 with loss 1.1313753128051758
# Epoch 51: Iteration 80 with loss 0.6436672210693359
# Epoch 51: Iteration 100 with loss 0.612042248249054
# Epoch 51: Iteration 120 with loss 0.421247661113739
# Epoch 51: Iteration 140 with loss 0.7812010049819946
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  7.3 minutes
# iter 30 of Expectation completed in a total of  10.9 minutes
# iter 40 of Expectation completed in a total of  15.1 minutes
# iter 50 of Expectation completed in a total of  17.9 minutes
# iter 60 of Expectation completed in a total of  21.6 minutes
# Expectation step finished, posterior frame-wise accuracy  74.12%, boundary mse  0.00
# Epoch 51 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.1706922981315
# Starting Training
# Epoch 52: Iteration 20 with loss 1.328858733177185
# Epoch 52: Iteration 40 with loss 1.0369088649749756
# Epoch 52: Iteration 60 with loss 1.1705100536346436
# Epoch 52: Iteration 80 with loss 0.9426748752593994
# Epoch 52: Iteration 100 with loss 1.4816093444824219
# Epoch 52: Iteration 120 with loss 0.9930142164230347
# Epoch 52: Iteration 140 with loss 0.7709099054336548
# Epoch 52 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.486576625098394
# Starting Training
# Epoch 53: Iteration 20 with loss 0.587285578250885
# Epoch 53: Iteration 40 with loss 1.1924768686294556
# Epoch 53: Iteration 60 with loss 1.5781450271606445
# Epoch 53: Iteration 80 with loss 0.8896243572235107
# Epoch 53: Iteration 100 with loss 0.6409702301025391
# Epoch 53: Iteration 120 with loss 0.7061873078346252
# Epoch 53: Iteration 140 with loss 1.079869031906128
# Epoch 53 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.578178729751
# Starting Training
# Epoch 54: Iteration 20 with loss 3.2214303016662598
# Epoch 54: Iteration 40 with loss 1.5231297016143799
# Epoch 54: Iteration 60 with loss 1.0486491918563843
# Epoch 54: Iteration 80 with loss 1.165343999862671
# Epoch 54: Iteration 100 with loss 0.9450940489768982
# Epoch 54: Iteration 120 with loss 0.7895638942718506
# Epoch 54: Iteration 140 with loss 0.44875651597976685
# Epoch 54 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.46064133902308
# Starting Training
# Epoch 55: Iteration 20 with loss 0.7847086191177368
# Epoch 55: Iteration 40 with loss 0.9128372669219971
# Epoch 55: Iteration 60 with loss 1.1464505195617676
# Epoch 55: Iteration 80 with loss 0.40599772334098816
# Epoch 55: Iteration 100 with loss 1.209998607635498
# Epoch 55: Iteration 120 with loss 0.626541018486023
# Epoch 55: Iteration 140 with loss 0.5606657266616821
# Epoch 55 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.83001201474914
# Starting Training
# Epoch 56: Iteration 20 with loss 0.3364785313606262
# Epoch 56: Iteration 40 with loss 0.39899519085884094
# Epoch 56: Iteration 60 with loss 0.4865482449531555
# Epoch 56: Iteration 80 with loss 0.49188321828842163
# Epoch 56: Iteration 100 with loss 0.5049864649772644
# Epoch 56: Iteration 120 with loss 0.49301981925964355
# Epoch 56: Iteration 140 with loss 0.5290829539299011
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  7.8 minutes
# iter 30 of Expectation completed in a total of  11.9 minutes
# iter 40 of Expectation completed in a total of  14.8 minutes
# iter 50 of Expectation completed in a total of  18.0 minutes
# iter 60 of Expectation completed in a total of  21.1 minutes
# Expectation step finished, posterior frame-wise accuracy  74.07%, boundary mse  0.00
# Epoch 56 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.27412271616191
# Starting Training
# Epoch 57: Iteration 20 with loss 0.3540757894515991
# Epoch 57: Iteration 40 with loss 0.34195947647094727
# Epoch 57: Iteration 60 with loss 0.5953084826469421
# Epoch 57: Iteration 80 with loss 0.46953094005584717
# Epoch 57: Iteration 100 with loss 0.5954612493515015
# Epoch 57: Iteration 120 with loss 0.4040871262550354
# Epoch 57: Iteration 140 with loss 0.8775302171707153
# Epoch 57 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.80264738782782
# Starting Training
# Epoch 58: Iteration 20 with loss 0.569866418838501
# Epoch 58: Iteration 40 with loss 0.47852057218551636
# Epoch 58: Iteration 60 with loss 0.4472559094429016
# Epoch 58: Iteration 80 with loss 0.8306109309196472
# Epoch 58: Iteration 100 with loss 0.43616342544555664
# Epoch 58: Iteration 120 with loss 0.470406711101532
# Epoch 58: Iteration 140 with loss 0.39594021439552307
# Epoch 58 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.67630608609189
# Starting Training
# Epoch 59: Iteration 20 with loss 0.265825092792511
# Epoch 59: Iteration 40 with loss 0.9356696605682373
# Epoch 59: Iteration 60 with loss 0.7589644193649292
# Epoch 59: Iteration 80 with loss 0.5783658027648926
# Epoch 59: Iteration 100 with loss 0.44878634810447693
# Epoch 59: Iteration 120 with loss 0.5505452156066895
# Epoch 59: Iteration 140 with loss 0.9906851053237915
# Epoch 59 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.396403861291795
# Starting Training
# Epoch 60: Iteration 20 with loss 0.3712400197982788
# Epoch 60: Iteration 40 with loss 0.45768529176712036
# Epoch 60: Iteration 60 with loss 0.4826464056968689
# Epoch 60: Iteration 80 with loss 1.043832540512085
# Epoch 60: Iteration 100 with loss 0.5981861352920532
# Epoch 60: Iteration 120 with loss 0.3964102864265442
# Epoch 60: Iteration 140 with loss 0.682929515838623
# Epoch 60 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.987757384927704
# Starting Training
# Epoch 61: Iteration 20 with loss 0.3038448095321655
# Epoch 61: Iteration 40 with loss 0.662502646446228
# Epoch 61: Iteration 60 with loss 0.8000228404998779
# Epoch 61: Iteration 80 with loss 0.40276259183883667
# Epoch 61: Iteration 100 with loss 0.6323891878128052
# Epoch 61: Iteration 120 with loss 0.5257670879364014
# Epoch 61: Iteration 140 with loss 0.6516036987304688
# Calculating expectation
# iter 10 of Expectation completed in a total of  4.3 minutes
# iter 20 of Expectation completed in a total of  8.3 minutes
# iter 30 of Expectation completed in a total of  12.1 minutes
# iter 40 of Expectation completed in a total of  14.8 minutes
# iter 50 of Expectation completed in a total of  18.1 minutes
# iter 60 of Expectation completed in a total of  21.0 minutes
# Expectation step finished, posterior frame-wise accuracy  73.84%, boundary mse  0.00
# Epoch 61 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.90860504619464
# Starting Training
# Epoch 62: Iteration 20 with loss 0.8480901718139648
# Epoch 62: Iteration 40 with loss 0.4757227301597595
# Epoch 62: Iteration 60 with loss 0.9287757873535156
# Epoch 62: Iteration 80 with loss 8.288803100585938
# Epoch 62: Iteration 100 with loss 2.3813016414642334
# Epoch 62: Iteration 120 with loss 1.6798439025878906
# Epoch 62: Iteration 140 with loss 1.2152029275894165
# Epoch 62 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.75848282719476
# Starting Training
# Epoch 63: Iteration 20 with loss 1.187794804573059
# Epoch 63: Iteration 40 with loss 0.7512258887290955
# Epoch 63: Iteration 60 with loss 0.6490693092346191
# Epoch 63: Iteration 80 with loss 0.39865225553512573
# Epoch 63: Iteration 100 with loss 0.8366085290908813
# Epoch 63: Iteration 120 with loss 0.8277007341384888
# Epoch 63: Iteration 140 with loss 0.4083053171634674
# Epoch 63 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.822326718316276
# Starting Training
# Epoch 64: Iteration 20 with loss 0.7470876574516296
# Epoch 64: Iteration 40 with loss 0.5974456667900085
# Epoch 64: Iteration 60 with loss 0.5217688083648682
# Epoch 64: Iteration 80 with loss 0.3859671950340271
# Epoch 64: Iteration 100 with loss 0.4030994176864624
# Epoch 64: Iteration 120 with loss 1.3586063385009766
# Epoch 64: Iteration 140 with loss 0.3691423535346985
# Epoch 64 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.63485520155778
# Starting Training
# Epoch 65: Iteration 20 with loss 0.83439040184021
# Epoch 65: Iteration 40 with loss 0.5457069277763367
# Epoch 65: Iteration 60 with loss 0.5604016184806824
# Epoch 65: Iteration 80 with loss 0.4789881706237793
# Epoch 65: Iteration 100 with loss 0.43947622179985046
# Epoch 65: Iteration 120 with loss 0.41411060094833374
# Epoch 65: Iteration 140 with loss 0.7123907208442688
# Epoch 65 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.2662302688818
# Starting Training
# Epoch 66: Iteration 20 with loss 0.5574667453765869
# Epoch 66: Iteration 40 with loss 0.3099609613418579
# Epoch 66: Iteration 60 with loss 0.8236958980560303
# Epoch 66: Iteration 80 with loss 0.5100816488265991
# Epoch 66: Iteration 100 with loss 0.5078670382499695
# Epoch 66: Iteration 120 with loss 0.41256535053253174
# Epoch 66: Iteration 140 with loss 0.40304136276245117
# Calculating expectation
# iter 10 of Expectation completed in a total of  4.1 minutes
# iter 20 of Expectation completed in a total of  8.1 minutes
# iter 30 of Expectation completed in a total of  11.5 minutes
# iter 40 of Expectation completed in a total of  15.1 minutes
# iter 50 of Expectation completed in a total of  19.6 minutes
# iter 60 of Expectation completed in a total of  23.2 minutes
# Expectation step finished, posterior frame-wise accuracy  73.66%, boundary mse  0.00
# Epoch 66 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.61898744665866
# Starting Training
# Epoch 67: Iteration 20 with loss 0.36292529106140137
# Epoch 67: Iteration 40 with loss 0.3203403353691101
# Epoch 67: Iteration 60 with loss 0.28730106353759766
# Epoch 67: Iteration 80 with loss 0.3859838843345642
# Epoch 67: Iteration 100 with loss 0.8589677810668945
# Epoch 67: Iteration 120 with loss 0.6151662468910217
# Epoch 67: Iteration 140 with loss 0.6336678862571716
# Epoch 67 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.201309193354604
# Starting Training
# Epoch 68: Iteration 20 with loss 0.3181132972240448
# Epoch 68: Iteration 40 with loss 0.3869419991970062
# Epoch 68: Iteration 60 with loss 0.4516999125480652
# Epoch 68: Iteration 80 with loss 0.30380433797836304
# Epoch 68: Iteration 100 with loss 0.35525017976760864
# Epoch 68: Iteration 120 with loss 0.3813868463039398
# Epoch 68: Iteration 140 with loss 0.3718372881412506
# Epoch 68 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.885217715540456
# Starting Training
# Epoch 69: Iteration 20 with loss 0.23387199640274048
# Epoch 69: Iteration 40 with loss 0.30592983961105347
# Epoch 69: Iteration 60 with loss 0.31590238213539124
# Epoch 69: Iteration 80 with loss 0.27145078778266907
# Epoch 69: Iteration 100 with loss 0.2693382799625397
# Epoch 69: Iteration 120 with loss 0.3958977460861206
# Epoch 69: Iteration 140 with loss 0.6602470874786377
# Epoch 69 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.2645523470191
# Starting Training
# Epoch 70: Iteration 20 with loss 0.35732942819595337
# Epoch 70: Iteration 40 with loss 0.29651257395744324
# Epoch 70: Iteration 60 with loss 0.28771382570266724
# Epoch 70: Iteration 80 with loss 0.29600945115089417
# Epoch 70: Iteration 100 with loss 0.4299350380897522
# Epoch 70: Iteration 120 with loss 0.5308980345726013
# Epoch 70: Iteration 140 with loss 0.4131270945072174
# Epoch 70 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.059079421634834
# Starting Training
# Epoch 71: Iteration 20 with loss 0.40990912914276123
# Epoch 71: Iteration 40 with loss 0.640007495880127
# Epoch 71: Iteration 60 with loss 1.0211201906204224
# Epoch 71: Iteration 80 with loss 0.35741013288497925
# Epoch 71: Iteration 100 with loss 0.5590180158615112
# Epoch 71: Iteration 120 with loss 0.3279073238372803
# Epoch 71: Iteration 140 with loss 0.6853457689285278
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.7 minutes
# iter 20 of Expectation completed in a total of  7.2 minutes
# iter 30 of Expectation completed in a total of  10.9 minutes
# iter 40 of Expectation completed in a total of  14.7 minutes
# iter 50 of Expectation completed in a total of  17.4 minutes
# iter 60 of Expectation completed in a total of  21.6 minutes
# Expectation step finished, posterior frame-wise accuracy  68.31%, boundary mse  0.00
# Epoch 71 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 47.489021005095914
# Starting Training
# Epoch 72: Iteration 20 with loss 3.287480115890503
# Epoch 72: Iteration 40 with loss 2.4312572479248047
# Epoch 72: Iteration 60 with loss 3.892636775970459
# Epoch 72: Iteration 80 with loss 1.90945565700531
# Epoch 72: Iteration 100 with loss 2.142409563064575
# Epoch 72: Iteration 120 with loss 2.4746713638305664
# Epoch 72: Iteration 140 with loss 1.0045961141586304
# Epoch 72 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.36738202759249
# Starting Training
# Epoch 73: Iteration 20 with loss 1.3636481761932373
# Epoch 73: Iteration 40 with loss 1.1682263612747192
# Epoch 73: Iteration 60 with loss 0.9665166139602661
# Epoch 73: Iteration 80 with loss 1.2105196714401245
# Epoch 73: Iteration 100 with loss 10.715776443481445
# Epoch 73: Iteration 120 with loss 2.2729296684265137
# Epoch 73: Iteration 140 with loss 1.6505681276321411
# Epoch 73 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.22245929485852
# Starting Training
# Epoch 74: Iteration 20 with loss 0.8220359086990356
# Epoch 74: Iteration 40 with loss 1.3009567260742188
# Epoch 74: Iteration 60 with loss 7.468973159790039
# Epoch 74: Iteration 80 with loss 2.5368287563323975
# Epoch 74: Iteration 100 with loss 1.230735182762146
# Epoch 74: Iteration 120 with loss 0.9272405505180359
# Epoch 74: Iteration 140 with loss 0.5326640009880066
# Epoch 74 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.26096863736173
# Starting Training
# Epoch 75: Iteration 20 with loss 1.9144649505615234
# Epoch 75: Iteration 40 with loss 1.355521559715271
# Epoch 75: Iteration 60 with loss 0.9322173595428467
# Epoch 75: Iteration 80 with loss 0.8984737992286682
# Epoch 75: Iteration 100 with loss 0.5926210880279541
# Epoch 75: Iteration 120 with loss 0.9150547385215759
# Epoch 75: Iteration 140 with loss 0.7634528875350952
# Epoch 75 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.038219331317066
# Starting Training
# Epoch 76: Iteration 20 with loss 0.7258944511413574
# Epoch 76: Iteration 40 with loss 0.5962642431259155
# Epoch 76: Iteration 60 with loss 0.7558138966560364
# Epoch 76: Iteration 80 with loss 0.7694735527038574
# Epoch 76: Iteration 100 with loss 1.6962952613830566
# Epoch 76: Iteration 120 with loss 0.8531835079193115
# Epoch 76: Iteration 140 with loss 1.2530031204223633
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.1 minutes
# iter 20 of Expectation completed in a total of  7.3 minutes
# iter 30 of Expectation completed in a total of  10.7 minutes
# iter 40 of Expectation completed in a total of  14.4 minutes
# iter 50 of Expectation completed in a total of  18.8 minutes
# iter 60 of Expectation completed in a total of  22.6 minutes
# Expectation step finished, posterior frame-wise accuracy  68.95%, boundary mse  0.00
# Epoch 76 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.04366739859966
# Starting Training
# Epoch 77: Iteration 20 with loss 0.583191990852356
# Epoch 77: Iteration 40 with loss 0.701208233833313
# Epoch 77: Iteration 60 with loss 0.9037666320800781
# Epoch 77: Iteration 80 with loss 1.6239893436431885
# Epoch 77: Iteration 100 with loss 0.6990312337875366
# Epoch 77: Iteration 120 with loss 0.33563271164894104
# Epoch 77: Iteration 140 with loss 0.36796891689300537
# Epoch 77 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.2814972863239
# Starting Training
# Epoch 78: Iteration 20 with loss 0.9342215061187744
# Epoch 78: Iteration 40 with loss 1.2304718494415283
# Epoch 78: Iteration 60 with loss 0.6882416009902954
# Epoch 78: Iteration 80 with loss 0.6948310732841492
# Epoch 78: Iteration 100 with loss 0.9316260814666748
# Epoch 78: Iteration 120 with loss 0.5684464573860168
# Epoch 78: Iteration 140 with loss 1.2326102256774902
# Epoch 78 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.556510751128975
# Starting Training
# Epoch 79: Iteration 20 with loss 0.43611282110214233
# Epoch 79: Iteration 40 with loss 0.4114522337913513
# Epoch 79: Iteration 60 with loss 0.3052217960357666
# Epoch 79: Iteration 80 with loss 1.8815639019012451
# Epoch 79: Iteration 100 with loss 0.5367157459259033
# Epoch 79: Iteration 120 with loss 0.8031582236289978
# Epoch 79: Iteration 140 with loss 0.45683813095092773
# Epoch 79 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.11486514479844
# Starting Training
# Epoch 80: Iteration 20 with loss 0.4886016249656677
# Epoch 80: Iteration 40 with loss 0.8050369620323181
# Epoch 80: Iteration 60 with loss 0.5638792514801025
# Epoch 80: Iteration 80 with loss 0.3166022300720215
# Epoch 80: Iteration 100 with loss 0.37928569316864014
# Epoch 80: Iteration 120 with loss 0.39161837100982666
# Epoch 80: Iteration 140 with loss 0.35065513849258423
# Epoch 80 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.623876206653684
# Starting Training
# Epoch 81: Iteration 20 with loss 0.9336055517196655
# Epoch 81: Iteration 40 with loss 1.4944294691085815
# Epoch 81: Iteration 60 with loss 1.1556601524353027
# Epoch 81: Iteration 80 with loss 1.00780189037323
# Epoch 81: Iteration 100 with loss 1.549164891242981
# Epoch 81: Iteration 120 with loss 1.3250477313995361
# Epoch 81: Iteration 140 with loss 0.9500896334648132
# Calculating expectation
# iter 10 of Expectation completed in a total of  4.0 minutes
# iter 20 of Expectation completed in a total of  7.6 minutes
# iter 30 of Expectation completed in a total of  11.6 minutes
# iter 40 of Expectation completed in a total of  15.2 minutes
# iter 50 of Expectation completed in a total of  19.4 minutes
# iter 60 of Expectation completed in a total of  22.6 minutes
# Expectation step finished, posterior frame-wise accuracy  69.31%, boundary mse  0.00
# Epoch 81 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.94013340514563
# Starting Training
# Epoch 82: Iteration 20 with loss 0.609520435333252
# Epoch 82: Iteration 40 with loss 3.0242621898651123
# Epoch 82: Iteration 60 with loss 1.048229455947876
# Epoch 82: Iteration 80 with loss 0.8807718753814697
# Epoch 82: Iteration 100 with loss 0.3718976378440857
# Epoch 82: Iteration 120 with loss 0.5343125462532043
# Epoch 82: Iteration 140 with loss 0.7922804355621338
# Epoch 82 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.545883912665204
# Starting Training
# Epoch 83: Iteration 20 with loss 0.39479586482048035
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-547e90c7ceda> in <module>
#      14         optimizer.zero_grad()
#      15
# ---> 16         middle_pred, predictions = model(item_0, src_mask_mse)
#      17         boundary_target_tensor = get_single_random(item[4], item_2.shape[1], item_2.device)
#      18
#
# ~/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ar/em-less-frame-supervision/mstcn_model.py in forward(self, x, mask)
#      15
#      16     def forward(self, x, mask):
# ---> 17         middle_out, out = self.tower_stage(x, mask)
#      18         outputs = out.unsqueeze(0)
#      19         for s in self.single_stages:
#
# ~/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ar/em-less-frame-supervision/mstcn_model.py in forward(self, x, mask)
#      31     def forward(self, x, mask):
#      32         out1, final_out1 = self.stage1(x, mask)
# ---> 33         out2, final_out2 = self.stage2(x, mask)
#      34
#      35         return out1 + out2, final_out1 + final_out2
#
# ~/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ar/em-less-frame-supervision/mstcn_model.py in forward(self, x, mask)
#      47         out = self.conv_1x1(x)
#      48         for layer in self.layers:
# ---> 49             out = layer(out, mask)
#      50         final_out = self.conv_out(out) * mask[:, 0:1, :]
#      51         return out, final_out
#
# ~/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ar/em-less-frame-supervision/mstcn_model.py in forward(self, x, mask)
#      61
#      62     def forward(self, x, mask):
# ---> 63         out = F.relu(self.conv_dilated(x))
#      64         out = self.conv_1x1(out)
#      65         out = self.dropout(out)
#
# ~/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     257                             _single(0), self.dilation, self.groups)
#     258         return F.conv1d(input, self.weight, self.bias, self.stride,
# --> 259                         self.padding, self.dilation, self.groups)
#     260
#     261
#
# KeyboardInterrupt:

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {val_acc}")
# Out:
# Validation:: Epoch 105, Probability Accuracy 61.02425300046298

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {best_val_acc}")
# Out:
# Validation:: Epoch 105, Probability Accuracy 63.70656599831428

# %%
torch.save(model.state_dict(),
"/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-speed/final-em-maximized.wt")

# %%
config.output_dir
# Out:
# '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split1/'

# %%
model.load_state_dict(torch.load(config.output_dir + "ms-tcn-emmax-best-model.wt"))
# model.load_state_dict(torch.load(config.output_dir + "ms-tcn-initial-15-epochs.wt"))
# Out:
# <All keys matched successfully>
