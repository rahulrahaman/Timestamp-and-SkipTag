# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
import os, sys
import glob
import numpy as np
import torch
import pandas as pd
import random
import torch.nn as nn
import pickle
import torch.nn.functional as F
import matplotlib.pyplot as plt
import multiprocessing as mp
from time import time

# %%
from mstcn_model import *
from utility.adaptive_data_loader import Breakfast, collate_fn_override
from utility.adaptive_data_loader import BreakfastWithWeights, collate_fn_override_wtd
from utils import calculate_mof, dotdict

# %%
os.environ["WANDB_API_KEY"] = "992b3b1371ba79f48484cfca522b3786d7fa52c2"
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dipika_singhania (use `wandb login --relogin` to force relogin)
# True

# %%
seed = 42

# Ensure deterministic behavior
def set_seed():
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
set_seed()

# Device configuration
os.environ['CUDA_VISIBLE_DEVICES']='5'
# os.environ['CUDA_LAUNCH_BLOCKING']='6'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config = dotdict(
    epochs=500,
    num_class=48,
    batch_size=8,
    learning_rate=5e-4,
    weight_decay=0,
    dataset="Breakfast",
    architecture="unet-ensemble",
    features_file_name="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/",
    chunk_size=1,
    max_frames_per_video=1200,
    feature_size=2048,
    ground_truth_files_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/",
    label_id_csv="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv",
    gamma=0.1,
    step_size=500,
    split=3,
#     output_dir="/mnt/data/ar-datasets/dipika/breakfast/ms_tcn/data/breakfast/results/unsuper-finetune-split2-0.05-data-llr/",
    output_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select5/",
    train_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split{}.bundle",
    test_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split{}.bundle",
    all_files="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt",
    cutoff=8,
    data_per = 0.2,
    budget=40,
    semi_supervised_split="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split{}_amt{}.bundle")

config.train_split_file = config.train_split_file.format(config.split)
config.semi_supervised_split = config.semi_supervised_split.format(config.split, config.data_per)
config.test_split_file = config.test_split_file.format(config.split)

if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)

config.output_dir = config.output_dir + f"split{config.split}"
if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)
config.output_dir = config.output_dir + "/"
if not os.path.exists(os.path.join(config.output_dir, "posterior_weights")):
    os.mkdir(os.path.join(config.output_dir, "posterior_weights"))
print(config)
# Out:
# {'epochs': 500, 'num_class': 48, 'batch_size': 8, 'learning_rate': 0.0005, 'weight_decay': 0, 'dataset': 'Breakfast', 'architecture': 'unet-ensemble', 'features_file_name': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/', 'chunk_size': 1, 'max_frames_per_video': 1200, 'feature_size': 2048, 'ground_truth_files_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/', 'label_id_csv': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv', 'gamma': 0.1, 'step_size': 500, 'split': 3, 'output_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select5/split3/', 'train_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split3.bundle', 'test_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split3.bundle', 'all_files': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt', 'cutoff': 8, 'data_per': 0.2, 'budget': 40, 'semi_supervised_split': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split3_amt0.2.bundle'}

# %%
traindataset = BreakfastWithWeights(config, fold='train', fold_file_name=config.train_split_file)
testdataset = Breakfast(config, fold='test', fold_file_name=config.test_split_file)
# Out:
# Number of videos logged in train fold is 1279
# Number of videos not found in train fold is 0
# Number of videos logged in test fold is 433
# Number of videos not found in test fold is 0

# %%
def _init_fn(worker_id):
    np.random.seed(int(seed))
trainloader = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=config.batch_size, 
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)
testloader = torch.utils.data.DataLoader(dataset=testdataset,
                                          batch_size=config.batch_size, 
                                          shuffle=False,
                                          pin_memory=True, num_workers=4,
                                          collate_fn=lambda x: collate_fn_override(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

trainloder_expectation = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=20,
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

# %%
df = pd.read_csv(config.label_id_csv)
label_id_to_label_name = {}
label_name_to_label_id_dict = {}
for i, ele in df.iterrows():
    label_id_to_label_name[ele.label_id] = ele.label_name
    label_name_to_label_id_dict[ele.label_name] = ele.label_id

# %%
# selected_frames_dict = pickle.load(open("data/breakfast_len_assum_annotations.pkl", 'rb'))
# loaded_vidid_selected_frames
boundary_frames_dict = pickle.load(open("data/breakfast_boundary_annotations.pkl", "rb"))
num_boundary = 0
for key in boundary_frames_dict.keys():
    num_boundary += len(boundary_frames_dict[key])
# video_id_boundary_frames

# %%
selected_frames_dict = pickle.load(open("data/breakfast_random5frame_selection.pkl", "rb"))
# print(selected_frames_dict)

# %%
loaded_mean_var_actions = pickle.load(open("data/breakfast_meanvar_actions.pkl", "rb"))
mat_poisson = pickle.load(open("data/breakfast_possion_class_dict.pkl", "rb"))

def get_possion_prob(minlen, maxlen, cur_class):
    prob = mat_poisson[label_id_to_label_name[cur_class]][minlen:maxlen]
    return torch.tensor(prob)

def get_poisson_logcdf(minlen, cur_class):
    return np.log(np.sum(np.exp(mat_poisson[label_id_to_label_name[cur_class]][minlen:])) + 1e-20)

def get_possion_prob_for_all_class(minlen, maxlen):
    ele_list = []
    for i in range(config.num_class):
        prob = mat_poisson[label_id_to_label_name[i]][minlen:maxlen]
        ele_list.append(torch.tensor(prob))
    return torch.stack(ele_list, dim=-1)

# %%
def validate(model, dataloader, best_val_acc=None):
    model.eval()
    print("Calculating Validation Data Accuracy")
    correct = 0.0
    total = 0.0
    for i, item in enumerate(testloader):
        with torch.no_grad():
            item_0 = item[0].to(device)
            item_1 = item[1].to(device)
            item_2 = item[2].to(device)
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            pred = torch.argmax(predictions[-1], dim=1)
            correct += float(torch.sum((pred == item_2) * src_mask).item())
            total += float(torch.sum(src_mask).item())
    val_acc = correct * 100.0 / total
    if best_val_acc is not None and val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-best-model.wt")
    torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-last-model.wt")
    print(f"Validation:: Probability Accuracy {val_acc}")
    _ = model.train()
    return val_acc, best_val_acc

# %%
def prob_vals_per_segment(selected_frames, cur_vid_feat, labels, first_ele_flag, last_ele_flag, vidid, gt_labels):
    prob_each_segment = []
    LOW_VAL = -10000000
    num_frames = len(cur_vid_feat)
    log_probs = torch.log(cur_vid_feat + 1e-8)
    cumsum_feat = torch.cumsum(log_probs, dim=0)
    prev_boundary = 0
    per_frame_weights = torch.zeros((num_frames, config.num_class))
    start_time = time()
    boundary_error = 0
    current_boundary = 0
    labels = [config.num_class-1] + labels if selected_frames[0] != 0 else labels
    labels = labels + [config.num_class-1] if selected_frames[-1] != num_frames-1 else labels
    selected_frames = [0] + selected_frames if selected_frames[0] != 0 else selected_frames
    selected_frames = selected_frames + [num_frames-1] if selected_frames[-1] != num_frames-1 else selected_frames

    for i, cur_ele in enumerate(selected_frames[:-1]):
        next_ele = selected_frames[i + 1]
        label_cur_ele = labels[i]
        label_next_ele = labels[i + 1]
        if cur_ele == next_ele-1:
            per_frame_weights[cur_ele, label_cur_ele] = 1.0
            if label_cur_ele != label_next_ele:
                prev_boundary = cur_ele
            continue
        
        seg_len = next_ele - cur_ele
        mat_b1_b2_c_prob = LOW_VAL * torch.ones((seg_len, seg_len, config.num_class), dtype=cumsum_feat.dtype)
        b1_prior = get_possion_prob(cur_ele-prev_boundary, next_ele-prev_boundary, label_cur_ele)
        
        # find dummy label where we will keep the diagonal (b1=b2) probabilities, later we will distribute among
        # rest of the classes after the softmax by dividing by (num_class - 2)
        dummy_label = 0
        while True:
            if dummy_label != label_cur_ele and dummy_label != label_next_ele:
                break
            else:
                dummy_label += 1
        
        for b1 in range(cur_ele, next_ele - 1):

            cur_boundary_len = b1 - prev_boundary
            strt_index = cumsum_feat[cur_ele - 1, label_cur_ele] if cur_ele > 0 else 0
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            right_sum = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1+1:next_ele, label_next_ele] # mid_seg_len
            mid_sum = (cumsum_feat[b1+1:next_ele, :] - cumsum_feat[b1, :])  # mid_seg_len
            b2_prior = get_possion_prob_for_all_class(1, next_ele-b1)  # mid_seg_len x num_class
            
            mat_b1_b2_c_prob[b1-cur_ele, b1+1-cur_ele:next_ele-cur_ele] = (left_sum + right_sum[:,None] + mid_sum) \
                                                                            + b1_prior[b1-cur_ele] + b2_prior
            # when mid segment is absent but right and left is not the same
            # we assign the probability to a dummy label for now and then later 
            # re-distribute among other classes after the softmax
            if label_cur_ele != label_next_ele:
                rightsum_wo_midseg = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1, label_next_ele]
                mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + rightsum_wo_midseg + b1_prior[b1-cur_ele]
        
#         if vidid=='P39_cam02_P39_scrambledegg' and cur_ele==574:
#             import pdb
#             pdb.set_trace()
        # when mid segment is absent b1 can also be next_ele-1
        b1 = next_ele - 1
        if label_cur_ele != label_next_ele:
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior[b1-cur_ele]
        else:
            # returns prob that the left class length >= seg len
            b1_prior_ = get_poisson_logcdf(next_ele - prev_boundary, label_cur_ele) 
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior_
        
        mat_b1_b2_c_prob[:, :, label_cur_ele] = LOW_VAL
        mat_b1_b2_c_prob[:, :, label_next_ele] = LOW_VAL
        mat_b1_b2_c_prob = torch.softmax(mat_b1_b2_c_prob.flatten(), dim=0).reshape((seg_len, seg_len, config.num_class))
        
        # re-distribute the dummy class probability among the left-over classes
        left_over_classes = config.num_class - 2 + (label_cur_ele==label_next_ele)
        for b1 in range(cur_ele, next_ele):
            assigned_prob = mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label]
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, :] = assigned_prob/left_over_classes
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_cur_ele] = 0
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_next_ele] = 0
        
        marginal_b1 = torch.sum(mat_b1_b2_c_prob, axis=(1,2))
        mean_b1 = round(torch.sum(marginal_b1.squeeze() * torch.arange(cur_ele, next_ele, 1)).item())
        cumm_b1_prob = torch.cumsum(marginal_b1, dim=0)
        cumm_b1_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=1), dim=0)
        cumm_b2_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=0), dim=0)

        per_frame_weights[cur_ele, label_cur_ele] = 1.0
        per_frame_weights[cur_ele+1:next_ele, :] = cumm_b1_c_prob[:-1] - cumm_b2_c_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_cur_ele] = 1 - cumm_b1_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] = 0
        remaining_probability = 1 - torch.sum(per_frame_weights[cur_ele+1:next_ele, :], dim=-1)
        # we use "+=" in the next line because left and right label might be the same
        # in that case using "=" would just overwrite the previous probability
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] += remaining_probability
        
        expected_boundary = round(torch.sum(torch.sum(mat_b1_b2_c_prob, axis=(0,2)).squeeze() * \
                            torch.arange(cur_ele, next_ele, 1)).item())
        if not (label_cur_ele == label_next_ele and expected_boundary >= next_ele-2):
            prev_boundary = expected_boundary
        if expected_boundary == 0 and i > 0:
            print(f'Estimated boundary has become zero! for {vidid} and cur_ele, next_ele {cur_ele, next_ele}')
            import pdb
            pdb.set_trace()
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary] - mean_b1)**2
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary+1] - prev_boundary)**2
        # current_boundary += 2
        # prob_each_segment.append(mat_b1_b2_c_prob)
        
    posterior_prediction = torch.argmax(per_frame_weights, dim=1)
    correct = torch.sum(posterior_prediction == gt_labels[:num_frames]).item()
    
    return (vidid, per_frame_weights, [correct, num_frames, boundary_error]) #, prob_each_segment)

# %%
posterior_acc_correct, posterior_acc_total = 0, 0
posterior_boundary_total_mse = 0
results = []

# Step 2: Define callback function to collect the output in `results`
def collect_result(result):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    fname = os.path.join(config.output_dir, 'posterior_weights', result[0] + '.wt')
    torch.save(result[1], fname)
    correct, total, boundary_err = result[2]
    posterior_acc_correct += correct
    posterior_acc_total += total
    posterior_boundary_total_mse += boundary_err
    # print(f'Dumped in file {fname} at time {time()}')
    return

def calculate_element_probb(data_feat, data_count, video_ids, gt_labels): # loaded_vidid_selected_frames, boundaries_dict):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    pool = mp.Pool(20)
    for iter_num in range(len(data_count)):
        cur_vidid = video_ids[iter_num]
#         if cur_vidid!='P39_cam02_P39_scrambledegg':
#             continue
        cur_vid_count = data_count[iter_num]
        cur_vid_feat = data_feat[iter_num][:cur_vid_count].detach().cpu()
        cur_gt_labels = gt_labels[iter_num].detach().cpu()
        
        cur_video_select_frames = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices_and_labels = cur_video_select_frames
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]
        with torch.no_grad():
            # Multi-processing
            pool.apply_async(prob_vals_per_segment,
                             args=(selected_frames_indices, cur_vid_feat, selected_frames_labels,
                                   cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels),
                             callback=collect_result)
#             results.append(prob_vals_per_segment(selected_frames_indices, cur_vid_feat, selected_frames_labels,
#                                    cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels))
    # Step 4: Close Pool and let all the processes complete
    pool.close()
    pool.join()  # postpones the execution of next line of code until all processes in the queue are done.
    return results

def perform_expectation(model, dataloader):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse = 0, 0, 0
    model.eval()
    correct = 0.0
    total = 0.0
    curtime = time()
    print(f'Calculating expectation')

    for i, item in enumerate(dataloader):
        with torch.no_grad():
            item_0 = item[0].to(device) # features
            item_1 = item[1].to(device) # count
            item_2 = item[2].to(device) # gt frame-wise labels
            item_4 = item[4] # video-ids
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            prob = torch.softmax(predictions[-1], dim=1)
            prob = prob.permute(0, 2, 1)
            
            calculate_element_probb(prob, item_1, item_4, item_2)
            if (i+1) % 10 == 0:
                print(f"iter {i+1} of Expectation completed in a total of {(time() - curtime)/60.: .1f} minutes")
    _ = model.train()
    print(f'Expectation step finished, '
          f'posterior frame-wise accuracy {100*posterior_acc_correct/posterior_acc_total: .2f}%, '
          f'boundary mse {(posterior_boundary_total_mse/num_boundary)**0.5: .2f}')
    return

# %%
set_seed()
model = MultiStageModel(num_stages=4, num_layers=10, num_f_maps=64, dim=2048, num_classes=48).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

# Requires loaded_vidid_selected_frames, boundaries_dict
ce_criterion = nn.CrossEntropyLoss(ignore_index=-100)
mse_criterion = nn.MSELoss(reduction='none')

# %%
# loaded_file=torch.load(os.path.join(config.output_dir, "ms-tcn-initial-30-epochs.wt"))
# model.load_state_dict(loaded_file)
# # loaded_file=torch.load('/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcnnew-full-supervised-split1/ms-tcn-best-model.wt')
# # model.load_state_dict(loaded_file)
# _ = validate(model, testloader)

# %%
# item = next(iter(trainloader))
    
# with torch.no_grad():
#     item_0 = item[0].to(device) # features
#     item_1 = item[1].to(device) # count
#     item_2 = item[2].to(device) # gt frame-wise labels
#     item_4 = item[4] # video-ids
#     src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
#     src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
#     middle_pred, predictions = model(item_0, src_mask_mse)
#     prob = torch.softmax(predictions[-1], dim=1)
#     prob = prob.permute(0, 2, 1)

#     res = calculate_element_probb(prob, item_1, item_4, item_2)

# %%
# idx = 2
# vidid = res[idx][0]
# mat = res[idx][1]
# mat.shape

# %%
# np.linspace(0, 5281, 4 + 1).astype(int)

# %%
# boundary_frames_dict[f'{vidid}.txt'], selected_frames_dict[f'{vidid}.txt'], weakly_labels[f'{vidid}.txt']

# %%
# fig = plt.figure(figsize=(20, 5))
# for i in range(48):
#     plt.plot(mat[:,i])
    
# for bd in boundary_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd, bd], [0, 2])
    
# for bd in selected_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd[0], bd[0]], [0, 2], '--')

# %%
# bd

# %%
# Calculating Expectation Step
# perform_expectation(model, trainloder_expectation)

# %%
def get_single_random(video_ids, len_frames, device):
    # Generate target for only timestamps. Do not generate pseudo labels at first 30 epochs.
    boundary_target_tensor = torch.ones((len(video_ids), len_frames), dtype=torch.long, device=device) * (-100)
    for iter_num, cur_vidid in enumerate(video_ids):
        selected_frames_indices_and_labels = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]

        frame_idx_tensor = torch.from_numpy(np.array(selected_frames_indices))
        frame_labels = torch.from_numpy(np.array(selected_frames_labels)).to(device)
        boundary_target_tensor[iter_num, frame_idx_tensor] = frame_labels

    return boundary_target_tensor

# %%
weakly_labels = pickle.load(open("data/breakfast_weaklysupervised_labels.pkl", "rb"))
prior_probs = pickle.load(open('data/breakfast_lengthmodel_multinomial_prior.pkl', 'rb'))

# %%
initialize_epoch = 30
expectation_cal_gap = 5
best_val_acc = 0
for epoch in range(0, 150):
    print("Starting Training")
    model.train()
    for i, item in enumerate(trainloader):
        item_0 = item[0].to(device)  # features
        item_1 = item[1].to(device)  # count
        item_2 = item[2].to(device)  # target
        weights = item[5].to(device)  # posterior weight
        src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
        src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
        optimizer.zero_grad()
        
        middle_pred, predictions = model(item_0, src_mask_mse)
        boundary_target_tensor = get_single_random(item[4], item_2.shape[1], item_2.device)
        
        loss = 0
        for p in predictions:
            if epoch <= initialize_epoch:
                loss += ce_criterion(p, boundary_target_tensor)
                loss += 0.15 * torch.mean(torch.clamp(mse_criterion(F.log_softmax(p[:, :, 1:], dim=1), 
                                                                    F.log_softmax(p.detach()[:, :, :-1], dim=1)), min=0,
                                            max=16) * src_mask_mse[:, :, 1:])
            else:
                prob = torch.softmax(p, dim=1)
                prob = prob.permute(0, 2, 1)
                total_count = torch.sum(src_mask)
                weighted_loss_sum = -torch.sum(torch.sum(torch.log(prob + 1e-8) * weights, dim=-1) * src_mask)
                loss += weighted_loss_sum/total_count

        loss.backward()
        optimizer.step()
        if (i+1)%20 == 0:
            print(f'Epoch {epoch+1}: Iteration {i+1} with loss {loss.item()}')

    if (epoch >= initialize_epoch) and ((epoch % (3 * expectation_cal_gap)) == 0):
        torch.save(model.state_dict(), config.output_dir + f"ms-tcn-initial-{epoch}-epochs.wt")

    if epoch >= initialize_epoch and (epoch % expectation_cal_gap == 0):
        perform_expectation(model, trainloder_expectation)
    
    print(f'Epoch {epoch+1} finished, starting validation')
    val_acc, best_val_acc = validate(model, testloader, best_val_acc)
# Out:
# Starting Training
# Epoch 1: Iteration 20 with loss 14.365795135498047
# Epoch 1: Iteration 40 with loss 15.0377197265625
# Epoch 1: Iteration 60 with loss 12.144597053527832
# Epoch 1: Iteration 80 with loss 12.414261817932129
# Epoch 1: Iteration 100 with loss 11.690544128417969
# Epoch 1: Iteration 120 with loss 11.481892585754395
# Epoch 1: Iteration 140 with loss 12.400184631347656
# Epoch 1: Iteration 160 with loss 10.24402141571045
# Epoch 1 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 18.568199954241326
# Starting Training
# Epoch 2: Iteration 20 with loss 9.074760437011719
# Epoch 2: Iteration 40 with loss 9.470041275024414
# Epoch 2: Iteration 60 with loss 9.338632583618164
# Epoch 2: Iteration 80 with loss 10.043416976928711
# Epoch 2: Iteration 100 with loss 9.640118598937988
# Epoch 2: Iteration 120 with loss 9.783514022827148
# Epoch 2: Iteration 140 with loss 10.494584083557129
# Epoch 2: Iteration 160 with loss 8.914278984069824
# Epoch 2 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 24.36548903186924
# Starting Training
# Epoch 3: Iteration 20 with loss 8.656155586242676
# Epoch 3: Iteration 40 with loss 8.099365234375
# Epoch 3: Iteration 60 with loss 7.827939510345459
# Epoch 3: Iteration 80 with loss 7.476289749145508
# Epoch 3: Iteration 100 with loss 7.859058380126953
# Epoch 3: Iteration 120 with loss 7.470871448516846
# Epoch 3: Iteration 140 with loss 6.572747230529785
# Epoch 3: Iteration 160 with loss 6.842095375061035
# Epoch 3 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 26.72406962014721
# Starting Training
# Epoch 4: Iteration 20 with loss 7.720122337341309
# Epoch 4: Iteration 40 with loss 5.938582897186279
# Epoch 4: Iteration 60 with loss 6.784177303314209
# Epoch 4: Iteration 80 with loss 7.6454267501831055
# Epoch 4: Iteration 100 with loss 7.860010147094727
# Epoch 4: Iteration 120 with loss 5.215670108795166
# Epoch 4: Iteration 140 with loss 8.394079208374023
# Epoch 4: Iteration 160 with loss 5.984870910644531
# Epoch 4 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 43.33625370394138
# Starting Training
# Epoch 5: Iteration 20 with loss 7.048045635223389
# Epoch 5: Iteration 40 with loss 5.426567554473877
# Epoch 5: Iteration 60 with loss 6.824374675750732
# Epoch 5: Iteration 80 with loss 5.466929912567139
# Epoch 5: Iteration 100 with loss 4.613761901855469
# Epoch 5: Iteration 120 with loss 5.778598308563232
# Epoch 5: Iteration 140 with loss 5.657939910888672
# Epoch 5: Iteration 160 with loss 4.40479040145874
# Epoch 5 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 40.150110769471155
# Starting Training
# Epoch 6: Iteration 20 with loss 5.982985019683838
# Epoch 6: Iteration 40 with loss 5.824703216552734
# Epoch 6: Iteration 60 with loss 4.669900894165039
# Epoch 6: Iteration 80 with loss 5.405280590057373
# Epoch 6: Iteration 100 with loss 5.975564956665039
# Epoch 6: Iteration 120 with loss 7.930097579956055
# Epoch 6: Iteration 140 with loss 6.840968132019043
# Epoch 6: Iteration 160 with loss 5.680776596069336
# Epoch 6 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 42.63078889068699
# Starting Training
# Epoch 7: Iteration 20 with loss 5.088263034820557
# Epoch 7: Iteration 40 with loss 4.7060041427612305
# Epoch 7: Iteration 60 with loss 5.300219535827637
# Epoch 7: Iteration 80 with loss 5.46140193939209
# Epoch 7: Iteration 100 with loss 5.3968658447265625
# Epoch 7: Iteration 120 with loss 4.779552459716797
# Epoch 7: Iteration 140 with loss 4.363912582397461
# Epoch 7: Iteration 160 with loss 5.074469089508057
# Epoch 7 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 47.794487753974586
# Starting Training
# Epoch 8: Iteration 20 with loss 3.9247748851776123
# Epoch 8: Iteration 40 with loss 5.442153453826904
# Epoch 8: Iteration 60 with loss 4.324915885925293
# Epoch 8: Iteration 80 with loss 3.909954071044922
# Epoch 8: Iteration 100 with loss 5.091962814331055
# Epoch 8: Iteration 120 with loss 6.949393272399902
# Epoch 8: Iteration 140 with loss 4.3237690925598145
# Epoch 8: Iteration 160 with loss 3.781724691390991
# Epoch 8 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.41981350550499
# Starting Training
# Epoch 9: Iteration 20 with loss 4.545502662658691
# Epoch 9: Iteration 40 with loss 4.690090179443359
# Epoch 9: Iteration 60 with loss 3.244194269180298
# Epoch 9: Iteration 80 with loss 4.766983985900879
# Epoch 9: Iteration 100 with loss 5.664657115936279
# Epoch 9: Iteration 120 with loss 3.5359339714050293
# Epoch 9: Iteration 140 with loss 3.6858432292938232
# Epoch 9: Iteration 160 with loss 3.0441431999206543
# Epoch 9 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.83373418675119
# Starting Training
# Epoch 10: Iteration 20 with loss 2.790121078491211
# Epoch 10: Iteration 40 with loss 3.854870080947876
# Epoch 10: Iteration 60 with loss 4.4583282470703125
# Epoch 10: Iteration 80 with loss 5.715602874755859
# Epoch 10: Iteration 100 with loss 2.570223569869995
# Epoch 10: Iteration 120 with loss 2.682100772857666
# Epoch 10: Iteration 140 with loss 3.2820584774017334
# Epoch 10: Iteration 160 with loss 3.8411502838134766
# Epoch 10 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 46.41436152700041
# Starting Training
# Epoch 11: Iteration 20 with loss 4.6071977615356445
# Epoch 11: Iteration 40 with loss 2.8238868713378906
# Epoch 11: Iteration 60 with loss 3.1555967330932617
# Epoch 11: Iteration 80 with loss 4.034424304962158
# Epoch 11: Iteration 100 with loss 2.4926273822784424
# Epoch 11: Iteration 120 with loss 3.4541640281677246
# Epoch 11: Iteration 140 with loss 2.747222661972046
# Epoch 11: Iteration 160 with loss 2.0481903553009033
# Epoch 11 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.9647602412933
# Starting Training
# Epoch 12: Iteration 20 with loss 2.7490334510803223
# Epoch 12: Iteration 40 with loss 2.801938056945801
# Epoch 12: Iteration 60 with loss 3.036959171295166
# Epoch 12: Iteration 80 with loss 4.45220947265625
# Epoch 12: Iteration 100 with loss 1.8365455865859985
# Epoch 12: Iteration 120 with loss 3.5964951515197754
# Epoch 12: Iteration 140 with loss 2.597052574157715
# Epoch 12: Iteration 160 with loss 3.9834988117218018
# Epoch 12 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.692418011060205
# Starting Training
# Epoch 13: Iteration 20 with loss 3.4470133781433105
# Epoch 13: Iteration 40 with loss 1.6217702627182007
# Epoch 13: Iteration 60 with loss 2.624629497528076
# Epoch 13: Iteration 80 with loss 2.1217567920684814
# Epoch 13: Iteration 100 with loss 2.303955078125
# Epoch 13: Iteration 120 with loss 2.482889413833618
# Epoch 13: Iteration 140 with loss 3.218019723892212
# Epoch 13: Iteration 160 with loss 2.4911208152770996
# Epoch 13 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.03550203402883
# Starting Training
# Epoch 14: Iteration 20 with loss 2.010359525680542
# Epoch 14: Iteration 40 with loss 2.481815814971924
# Epoch 14: Iteration 60 with loss 2.852491855621338
# Epoch 14: Iteration 80 with loss 2.2846450805664062
# Epoch 14: Iteration 100 with loss 2.80182147026062
# Epoch 14: Iteration 120 with loss 2.3402187824249268
# Epoch 14: Iteration 140 with loss 2.590582847595215
# Epoch 14: Iteration 160 with loss 3.1593027114868164
# Epoch 14 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.01852110200278
# Starting Training
# Epoch 15: Iteration 20 with loss 2.2557499408721924
# Epoch 15: Iteration 40 with loss 2.283222198486328
# Epoch 15: Iteration 60 with loss 2.296520709991455
# Epoch 15: Iteration 80 with loss 4.010027885437012
# Epoch 15: Iteration 100 with loss 2.746061325073242
# Epoch 15: Iteration 120 with loss 3.968181610107422
# Epoch 15: Iteration 140 with loss 1.6113789081573486
# Epoch 15: Iteration 160 with loss 2.534322500228882
# Epoch 15 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.57635281053119
# Starting Training
# Epoch 16: Iteration 20 with loss 2.2989208698272705
# Epoch 16: Iteration 40 with loss 1.745731234550476
# Epoch 16: Iteration 60 with loss 2.057373523712158
# Epoch 16: Iteration 80 with loss 2.881068229675293
# Epoch 16: Iteration 100 with loss 2.1113486289978027
# Epoch 16: Iteration 120 with loss 2.6877219676971436
# Epoch 16: Iteration 140 with loss 3.0862722396850586
# Epoch 16: Iteration 160 with loss 2.510345935821533
# Epoch 16 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.06529539455695
# Starting Training
# Epoch 17: Iteration 20 with loss 1.8381211757659912
# Epoch 17: Iteration 40 with loss 2.064514398574829
# Epoch 17: Iteration 60 with loss 2.0689051151275635
# Epoch 17: Iteration 80 with loss 1.5869067907333374
# Epoch 17: Iteration 100 with loss 2.9860434532165527
# Epoch 17: Iteration 120 with loss 2.0974888801574707
# Epoch 17: Iteration 140 with loss 2.424715995788574
# Epoch 17: Iteration 160 with loss 1.5127074718475342
# Epoch 17 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.246862461705014
# Starting Training
# Epoch 18: Iteration 20 with loss 1.395183801651001
# Epoch 18: Iteration 40 with loss 1.9355179071426392
# Epoch 18: Iteration 60 with loss 1.2365134954452515
# Epoch 18: Iteration 80 with loss 0.8496489524841309
# Epoch 18: Iteration 100 with loss 1.4814529418945312
# Epoch 18: Iteration 120 with loss 1.0410116910934448
# Epoch 18: Iteration 140 with loss 2.2073330879211426
# Epoch 18: Iteration 160 with loss 1.6277509927749634
# Epoch 18 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.48202297978248
# Starting Training
# Epoch 19: Iteration 20 with loss 1.2529008388519287
# Epoch 19: Iteration 40 with loss 1.5069007873535156
# Epoch 19: Iteration 60 with loss 1.7081010341644287
# Epoch 19: Iteration 80 with loss 1.1259942054748535
# Epoch 19: Iteration 100 with loss 1.4861500263214111
# Epoch 19: Iteration 120 with loss 1.7204482555389404
# Epoch 19: Iteration 140 with loss 1.0696194171905518
# Epoch 19: Iteration 160 with loss 1.2739313840866089
# Epoch 19 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.62230679516297
# Starting Training
# Epoch 20: Iteration 20 with loss 1.3055310249328613
# Epoch 20: Iteration 40 with loss 1.1004807949066162
# Epoch 20: Iteration 60 with loss 1.3816404342651367
# Epoch 20: Iteration 80 with loss 2.4066622257232666
# Epoch 20: Iteration 100 with loss 0.8529345989227295
# Epoch 20: Iteration 120 with loss 1.3351572751998901
# Epoch 20: Iteration 140 with loss 2.1698992252349854
# Epoch 20: Iteration 160 with loss 2.0275094509124756
# Epoch 20 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.87031322369853
# Starting Training
# Epoch 21: Iteration 20 with loss 0.937394380569458
# Epoch 21: Iteration 40 with loss 1.4143121242523193
# Epoch 21: Iteration 60 with loss 1.240492820739746
# Epoch 21: Iteration 80 with loss 2.1159110069274902
# Epoch 21: Iteration 100 with loss 2.2008070945739746
# Epoch 21: Iteration 120 with loss 6.164134979248047
# Epoch 21: Iteration 140 with loss 1.5695862770080566
# Epoch 21: Iteration 160 with loss 1.8833413124084473
# Epoch 21 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.94342665498518
# Starting Training
# Epoch 22: Iteration 20 with loss 3.3239824771881104
# Epoch 22: Iteration 40 with loss 2.3980114459991455
# Epoch 22: Iteration 60 with loss 1.6778005361557007
# Epoch 22: Iteration 80 with loss 1.1955046653747559
# Epoch 22: Iteration 100 with loss 2.252345323562622
# Epoch 22: Iteration 120 with loss 1.4648158550262451
# Epoch 22: Iteration 140 with loss 1.1317777633666992
# Epoch 22: Iteration 160 with loss 1.3405979871749878
# Epoch 22 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.596425243162706
# Starting Training
# Epoch 23: Iteration 20 with loss 1.9098458290100098
# Epoch 23: Iteration 40 with loss 1.6343485116958618
# Epoch 23: Iteration 60 with loss 1.2599289417266846
# Epoch 23: Iteration 80 with loss 1.2881749868392944
# Epoch 23: Iteration 100 with loss 1.5701059103012085
# Epoch 23: Iteration 120 with loss 1.5728415250778198
# Epoch 23: Iteration 140 with loss 1.406543254852295
# Epoch 23: Iteration 160 with loss 1.4315327405929565
# Epoch 23 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.33437313407849
# Starting Training
# Epoch 24: Iteration 20 with loss 0.8602959513664246
# Epoch 24: Iteration 40 with loss 1.880078673362732
# Epoch 24: Iteration 60 with loss 1.210114598274231
# Epoch 24: Iteration 80 with loss 1.3159304857254028
# Epoch 24: Iteration 100 with loss 2.1268961429595947
# Epoch 24: Iteration 120 with loss 2.1051652431488037
# Epoch 24: Iteration 140 with loss 1.9769096374511719
# Epoch 24: Iteration 160 with loss 1.8331873416900635
# Epoch 24 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.90938666636905
# Starting Training
# Epoch 25: Iteration 20 with loss 1.748565912246704
# Epoch 25: Iteration 40 with loss 1.4910266399383545
# Epoch 25: Iteration 60 with loss 0.9909583330154419
# Epoch 25: Iteration 80 with loss 0.8311952352523804
# Epoch 25: Iteration 100 with loss 1.0442523956298828
# Epoch 25: Iteration 120 with loss 1.5960546731948853
# Epoch 25: Iteration 140 with loss 0.7521767020225525
# Epoch 25: Iteration 160 with loss 1.5329724550247192
# Epoch 25 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.001674097800795
# Starting Training
# Epoch 26: Iteration 20 with loss 1.7147910594940186
# Epoch 26: Iteration 40 with loss 1.1805453300476074
# Epoch 26: Iteration 60 with loss 0.7980501055717468
# Epoch 26: Iteration 80 with loss 1.2376673221588135
# Epoch 26: Iteration 100 with loss 0.7535812258720398
# Epoch 26: Iteration 120 with loss 0.8179882168769836
# Epoch 26: Iteration 140 with loss 0.8099294900894165
# Epoch 26: Iteration 160 with loss 1.2283673286437988
# Epoch 26 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.594645119167865
# Starting Training
# Epoch 27: Iteration 20 with loss 1.1593263149261475
# Epoch 27: Iteration 40 with loss 1.4986240863800049
# Epoch 27: Iteration 60 with loss 1.0909885168075562
# Epoch 27: Iteration 80 with loss 0.8893603086471558
# Epoch 27: Iteration 100 with loss 0.9946849346160889
# Epoch 27: Iteration 120 with loss 0.8061320781707764
# Epoch 27: Iteration 140 with loss 0.8737374544143677
# Epoch 27: Iteration 160 with loss 1.2173199653625488
# Epoch 27 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.76629036668322
# Starting Training
# Epoch 28: Iteration 20 with loss 0.7423211336135864
# Epoch 28: Iteration 40 with loss 0.9567240476608276
# Epoch 28: Iteration 60 with loss 0.821444034576416
# Epoch 28: Iteration 80 with loss 1.2899638414382935
# Epoch 28: Iteration 100 with loss 1.1501219272613525
# Epoch 28: Iteration 120 with loss 0.9953256249427795
# Epoch 28: Iteration 140 with loss 1.0908712148666382
# Epoch 28: Iteration 160 with loss 1.129552960395813
# Epoch 28 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.19397213185194
# Starting Training
# Epoch 29: Iteration 20 with loss 0.8401205539703369
# Epoch 29: Iteration 40 with loss 0.7787221670150757
# Epoch 29: Iteration 60 with loss 1.0663535594940186
# Epoch 29: Iteration 80 with loss 0.9873901009559631
# Epoch 29: Iteration 100 with loss 0.6413397192955017
# Epoch 29: Iteration 120 with loss 1.0849581956863403
# Epoch 29: Iteration 140 with loss 1.1690348386764526
# Epoch 29: Iteration 160 with loss 1.0880436897277832
# Epoch 29 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.56897003922969
# Starting Training
# Epoch 30: Iteration 20 with loss 0.6175342798233032
# Epoch 30: Iteration 40 with loss 0.747008204460144
# Epoch 30: Iteration 60 with loss 0.9054595232009888
# Epoch 30: Iteration 80 with loss 0.9448120594024658
# Epoch 30: Iteration 100 with loss 0.8859204649925232
# Epoch 30: Iteration 120 with loss 0.7936490774154663
# Epoch 30: Iteration 140 with loss 0.8141840696334839
# Epoch 30: Iteration 160 with loss 0.921378493309021
# Epoch 30 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.26450745252538
# Starting Training
# Epoch 31: Iteration 20 with loss 1.190366506576538
# Epoch 31: Iteration 40 with loss 0.6413577795028687
# Epoch 31: Iteration 60 with loss 0.747036337852478
# Epoch 31: Iteration 80 with loss 0.720727264881134
# Epoch 31: Iteration 100 with loss 0.6539113521575928
# Epoch 31: Iteration 120 with loss 0.5421664714813232
# Epoch 31: Iteration 140 with loss 0.6683367490768433
# Epoch 31: Iteration 160 with loss 0.6895880103111267
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  5.9 minutes
# iter 30 of Expectation completed in a total of  9.3 minutes
# iter 40 of Expectation completed in a total of  12.9 minutes
# iter 50 of Expectation completed in a total of  16.4 minutes
# iter 60 of Expectation completed in a total of  19.8 minutes
# Expectation step finished, posterior frame-wise accuracy  80.47%, boundary mse  0.00
# Epoch 31 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.079681474991766
# Starting Training
# Epoch 32: Iteration 20 with loss 1.4945099353790283
# Epoch 32: Iteration 40 with loss 3.20776629447937
# Epoch 32: Iteration 60 with loss 3.559764862060547
# Epoch 32: Iteration 80 with loss 4.265224933624268
# Epoch 32: Iteration 100 with loss 5.699530124664307
# Epoch 32: Iteration 120 with loss 6.275843143463135
# Epoch 32: Iteration 140 with loss 4.0206499099731445
# Epoch 32: Iteration 160 with loss 2.6700143814086914
# Epoch 32 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.73147471275272
# Starting Training
# Epoch 33: Iteration 20 with loss 2.751232862472534
# Epoch 33: Iteration 40 with loss 2.0029408931732178
# Epoch 33: Iteration 60 with loss 2.0415587425231934
# Epoch 33: Iteration 80 with loss 1.3984909057617188
# Epoch 33: Iteration 100 with loss 2.1201987266540527
# Epoch 33: Iteration 120 with loss 1.6712875366210938
# Epoch 33: Iteration 140 with loss 1.9704535007476807
# Epoch 33: Iteration 160 with loss 0.9259582161903381
# Epoch 33 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.33904386694271
# Starting Training
# Epoch 34: Iteration 20 with loss 1.945536732673645
# Epoch 34: Iteration 40 with loss 1.0034551620483398
# Epoch 34: Iteration 60 with loss 1.5995821952819824
# Epoch 34: Iteration 80 with loss 2.656674385070801
# Epoch 34: Iteration 100 with loss 2.862018585205078
# Epoch 34: Iteration 120 with loss 2.1775200366973877
# Epoch 34: Iteration 140 with loss 2.287421941757202
# Epoch 34: Iteration 160 with loss 1.3978487253189087
# Epoch 34 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.16091428061227
# Starting Training
# Epoch 35: Iteration 20 with loss 2.008478879928589
# Epoch 35: Iteration 40 with loss 1.0628705024719238
# Epoch 35: Iteration 60 with loss 1.2697035074234009
# Epoch 35: Iteration 80 with loss 1.0274550914764404
# Epoch 35: Iteration 100 with loss 2.557311534881592
# Epoch 35: Iteration 120 with loss 1.9243597984313965
# Epoch 35: Iteration 140 with loss 1.7430270910263062
# Epoch 35: Iteration 160 with loss 1.6401909589767456
# Epoch 35 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 65.35566207777859
# Starting Training
# Epoch 36: Iteration 20 with loss 1.730317234992981
# Epoch 36: Iteration 40 with loss 1.4559669494628906
# Epoch 36: Iteration 60 with loss 1.8418240547180176
# Epoch 36: Iteration 80 with loss 1.7111437320709229
# Epoch 36: Iteration 100 with loss 1.3049371242523193
# Epoch 36: Iteration 120 with loss 2.296881675720215
# Epoch 36: Iteration 140 with loss 1.1740992069244385
# Epoch 36: Iteration 160 with loss 1.839000940322876
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.9 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  9.6 minutes
# iter 40 of Expectation completed in a total of  12.8 minutes
# iter 50 of Expectation completed in a total of  16.4 minutes
# iter 60 of Expectation completed in a total of  19.5 minutes
# Expectation step finished, posterior frame-wise accuracy  80.75%, boundary mse  0.00
# Epoch 36 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.45556107387794
# Starting Training
# Epoch 37: Iteration 20 with loss 2.28702974319458
# Epoch 37: Iteration 40 with loss 1.1857413053512573
# Epoch 37: Iteration 60 with loss 2.1355810165405273
# Epoch 37: Iteration 80 with loss 1.7865265607833862
# Epoch 37: Iteration 100 with loss 1.379202127456665
# Epoch 37: Iteration 120 with loss 0.7008235454559326
# Epoch 37: Iteration 140 with loss 1.2874869108200073
# Epoch 37: Iteration 160 with loss 2.116485834121704
# Epoch 37 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.02967617368207
# Starting Training
# Epoch 38: Iteration 20 with loss 1.366461992263794
# Epoch 38: Iteration 40 with loss 0.9432249665260315
# Epoch 38: Iteration 60 with loss 1.3986871242523193
# Epoch 38: Iteration 80 with loss 1.2279647588729858
# Epoch 38: Iteration 100 with loss 1.0957294702529907
# Epoch 38: Iteration 120 with loss 1.4794855117797852
# Epoch 38: Iteration 140 with loss 1.0338749885559082
# Epoch 38: Iteration 160 with loss 1.133476734161377
# Epoch 38 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.848868030870364
# Starting Training
# Epoch 39: Iteration 20 with loss 1.7853490114212036
# Epoch 39: Iteration 40 with loss 2.332235813140869
# Epoch 39: Iteration 60 with loss 0.8355093598365784
# Epoch 39: Iteration 80 with loss 1.4820332527160645
# Epoch 39: Iteration 100 with loss 1.4558391571044922
# Epoch 39: Iteration 120 with loss 0.7937103509902954
# Epoch 39: Iteration 140 with loss 0.7439318895339966
# Epoch 39: Iteration 160 with loss 0.7335396409034729
# Epoch 39 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.17307939129805
# Starting Training
# Epoch 40: Iteration 20 with loss 2.374011516571045
# Epoch 40: Iteration 40 with loss 1.056532621383667
# Epoch 40: Iteration 60 with loss 1.1569336652755737
# Epoch 40: Iteration 80 with loss 1.7970433235168457
# Epoch 40: Iteration 100 with loss 0.9993456602096558
# Epoch 40: Iteration 120 with loss 0.8291915655136108
# Epoch 40: Iteration 140 with loss 0.751520574092865
# Epoch 40: Iteration 160 with loss 1.0282710790634155
# Epoch 40 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.14261081132359
# Starting Training
# Epoch 41: Iteration 20 with loss 0.9285482168197632
# Epoch 41: Iteration 40 with loss 0.7735670804977417
# Epoch 41: Iteration 60 with loss 0.9776284694671631
# Epoch 41: Iteration 80 with loss 0.8944299817085266
# Epoch 41: Iteration 100 with loss 0.9392037391662598
# Epoch 41: Iteration 120 with loss 1.1731224060058594
# Epoch 41: Iteration 140 with loss 0.9920058250427246
# Epoch 41: Iteration 160 with loss 0.9879094362258911
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.8 minutes
# iter 20 of Expectation completed in a total of  6.1 minutes
# iter 30 of Expectation completed in a total of  9.4 minutes
# iter 40 of Expectation completed in a total of  12.4 minutes
# iter 50 of Expectation completed in a total of  15.7 minutes
# iter 60 of Expectation completed in a total of  19.0 minutes
# Expectation step finished, posterior frame-wise accuracy  81.00%, boundary mse  0.00
# Epoch 41 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.41894855497458
# Starting Training
# Epoch 42: Iteration 20 with loss 0.7200479507446289
# Epoch 42: Iteration 40 with loss 0.6923519968986511
# Epoch 42: Iteration 60 with loss 0.7883179187774658
# Epoch 42: Iteration 80 with loss 0.8625732660293579
# Epoch 42: Iteration 100 with loss 0.700004518032074
# Epoch 42: Iteration 120 with loss 1.7097103595733643
# Epoch 42: Iteration 140 with loss 1.1298240423202515
# Epoch 42: Iteration 160 with loss 1.2893314361572266
# Epoch 42 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.6620275556498
# Starting Training
# Epoch 43: Iteration 20 with loss 0.8749615550041199
# Epoch 43: Iteration 40 with loss 0.808109700679779
# Epoch 43: Iteration 60 with loss 0.854709267616272
# Epoch 43: Iteration 80 with loss 1.996464490890503
# Epoch 43: Iteration 100 with loss 1.0157901048660278
# Epoch 43: Iteration 120 with loss 0.8729701042175293
# Epoch 43: Iteration 140 with loss 0.8284125328063965
# Epoch 43: Iteration 160 with loss 1.4205231666564941
# Epoch 43 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.397302470410324
# Starting Training
# Epoch 44: Iteration 20 with loss 0.5495325922966003
# Epoch 44: Iteration 40 with loss 1.0148676633834839
# Epoch 44: Iteration 60 with loss 1.17426335811615
# Epoch 44: Iteration 80 with loss 0.4851045310497284
# Epoch 44: Iteration 100 with loss 0.8442875146865845
# Epoch 44: Iteration 120 with loss 0.8138688802719116
# Epoch 44: Iteration 140 with loss 1.2237775325775146
# Epoch 44: Iteration 160 with loss 1.5068275928497314
# Epoch 44 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.22776658612396
# Starting Training
# Epoch 45: Iteration 20 with loss 0.605423092842102
# Epoch 45: Iteration 40 with loss 0.7978763580322266
# Epoch 45: Iteration 60 with loss 0.5081125497817993
# Epoch 45: Iteration 80 with loss 7.852025032043457
# Epoch 45: Iteration 100 with loss 6.891420364379883
# Epoch 45: Iteration 120 with loss 3.678436279296875
# Epoch 45: Iteration 140 with loss 2.2980234622955322
# Epoch 45: Iteration 160 with loss 1.802814245223999
# Epoch 45 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 65.26447955089536
# Starting Training
# Epoch 46: Iteration 20 with loss 1.1173162460327148
# Epoch 46: Iteration 40 with loss 0.8918628096580505
# Epoch 46: Iteration 60 with loss 0.9303783774375916
# Epoch 46: Iteration 80 with loss 1.3961421251296997
# Epoch 46: Iteration 100 with loss 1.1178275346755981
# Epoch 46: Iteration 120 with loss 0.8478931784629822
# Epoch 46: Iteration 140 with loss 1.1369295120239258
# Epoch 46: Iteration 160 with loss 0.897857666015625
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.9 minutes
# iter 30 of Expectation completed in a total of  10.5 minutes
# iter 40 of Expectation completed in a total of  13.9 minutes
# iter 50 of Expectation completed in a total of  16.5 minutes
# iter 60 of Expectation completed in a total of  20.3 minutes
# Expectation step finished, posterior frame-wise accuracy  80.42%, boundary mse  0.00
# Epoch 46 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.85108900061941
# Starting Training
# Epoch 47: Iteration 20 with loss 0.5740265846252441
# Epoch 47: Iteration 40 with loss 0.9646695852279663
# Epoch 47: Iteration 60 with loss 0.7755549550056458
# Epoch 47: Iteration 80 with loss 0.7306519150733948
# Epoch 47: Iteration 100 with loss 0.8046591281890869
# Epoch 47: Iteration 120 with loss 0.8054825663566589
# Epoch 47: Iteration 140 with loss 0.6929571628570557
# Epoch 47: Iteration 160 with loss 0.5520120859146118
# Epoch 47 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.345857444991935
# Starting Training
# Epoch 48: Iteration 20 with loss 0.713071346282959
# Epoch 48: Iteration 40 with loss 0.9218559265136719
# Epoch 48: Iteration 60 with loss 0.558100700378418
# Epoch 48: Iteration 80 with loss 0.9662229418754578
# Epoch 48: Iteration 100 with loss 1.4503501653671265
# Epoch 48: Iteration 120 with loss 0.6381188035011292
# Epoch 48: Iteration 140 with loss 0.7768188714981079
# Epoch 48: Iteration 160 with loss 1.064627766609192
# Epoch 48 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.87365025864811
# Starting Training
# Epoch 49: Iteration 20 with loss 0.8561840057373047
# Epoch 49: Iteration 40 with loss 0.7900515794754028
# Epoch 49: Iteration 60 with loss 0.44845858216285706
# Epoch 49: Iteration 80 with loss 0.5175727009773254
# Epoch 49: Iteration 100 with loss 0.47943103313446045
# Epoch 49: Iteration 120 with loss 1.5140533447265625
# Epoch 49: Iteration 140 with loss 1.7677700519561768
# Epoch 49: Iteration 160 with loss 2.9357657432556152
# Epoch 49 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.66808778968868
# Starting Training
# Epoch 50: Iteration 20 with loss 1.2299598455429077
# Epoch 50: Iteration 40 with loss 0.39308661222457886
# Epoch 50: Iteration 60 with loss 0.7557221055030823
# Epoch 50: Iteration 80 with loss 0.410834938287735
# Epoch 50: Iteration 100 with loss 0.6966462135314941
# Epoch 50: Iteration 120 with loss 1.4019092321395874
# Epoch 50: Iteration 140 with loss 0.7018849849700928
# Epoch 50: Iteration 160 with loss 0.8318837881088257
# Epoch 50 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.87441476331047
# Starting Training
# Epoch 51: Iteration 20 with loss 0.5564658045768738
# Epoch 51: Iteration 40 with loss 0.5999928712844849
# Epoch 51: Iteration 60 with loss 0.570822536945343
# Epoch 51: Iteration 80 with loss 0.7875451445579529
# Epoch 51: Iteration 100 with loss 0.49542269110679626
# Epoch 51: Iteration 120 with loss 0.5789327025413513
# Epoch 51: Iteration 140 with loss 0.6122978925704956
# Epoch 51: Iteration 160 with loss 1.1777607202529907
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.6 minutes
# iter 30 of Expectation completed in a total of  10.0 minutes
# iter 40 of Expectation completed in a total of  13.5 minutes
# iter 50 of Expectation completed in a total of  16.5 minutes
# iter 60 of Expectation completed in a total of  19.9 minutes
# Expectation step finished, posterior frame-wise accuracy  79.84%, boundary mse  0.00
# Epoch 51 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.828890463780894
# Starting Training
# Epoch 52: Iteration 20 with loss 0.9191594123840332
# Epoch 52: Iteration 40 with loss 0.7335911989212036
# Epoch 52: Iteration 60 with loss 0.7048586010932922
# Epoch 52: Iteration 80 with loss 0.4413411319255829
# Epoch 52: Iteration 100 with loss 0.8946626782417297
# Epoch 52: Iteration 120 with loss 1.236829400062561
# Epoch 52: Iteration 140 with loss 1.5273442268371582
# Epoch 52: Iteration 160 with loss 0.6848750710487366
# Epoch 52 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.22643288820933
# Starting Training
# Epoch 53: Iteration 20 with loss 0.6816796064376831
# Epoch 53: Iteration 40 with loss 0.3924400508403778
# Epoch 53: Iteration 60 with loss 0.6930150985717773
# Epoch 53: Iteration 80 with loss 0.6452763676643372
# Epoch 53: Iteration 100 with loss 0.3997754156589508
# Epoch 53: Iteration 120 with loss 0.6909089684486389
# Epoch 53: Iteration 140 with loss 0.4425407350063324
# Epoch 53: Iteration 160 with loss 0.6061421632766724
# Epoch 53 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.30980295868885
# Starting Training
# Epoch 54: Iteration 20 with loss 0.3272574841976166
# Epoch 54: Iteration 40 with loss 0.289720743894577
# Epoch 54: Iteration 60 with loss 0.44032061100006104
# Epoch 54: Iteration 80 with loss 0.6336060166358948
# Epoch 54: Iteration 100 with loss 0.934376060962677
# Epoch 54: Iteration 120 with loss 1.3491253852844238
# Epoch 54: Iteration 140 with loss 0.7998945713043213
# Epoch 54: Iteration 160 with loss 0.5082003474235535
# Epoch 54 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.977103922411146
# Starting Training
# Epoch 55: Iteration 20 with loss 0.38519033789634705
# Epoch 55: Iteration 40 with loss 0.44355660676956177
# Epoch 55: Iteration 60 with loss 0.3705575466156006
# Epoch 55: Iteration 80 with loss 0.3497014343738556
# Epoch 55: Iteration 100 with loss 0.7158282995223999
# Epoch 55: Iteration 120 with loss 0.6152191758155823
# Epoch 55: Iteration 140 with loss 1.2718610763549805
# Epoch 55: Iteration 160 with loss 0.7769508361816406
# Epoch 55 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.69620147209
# Starting Training
# Epoch 56: Iteration 20 with loss 1.247708797454834
# Epoch 56: Iteration 40 with loss 0.8965729475021362
# Epoch 56: Iteration 60 with loss 0.4366282522678375
# Epoch 56: Iteration 80 with loss 0.41638654470443726
# Epoch 56: Iteration 100 with loss 0.3240149915218353
# Epoch 56: Iteration 120 with loss 0.573744535446167
# Epoch 56: Iteration 140 with loss 1.351752758026123
# Epoch 56: Iteration 160 with loss 0.4125085175037384
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.9 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  9.4 minutes
# iter 40 of Expectation completed in a total of  12.7 minutes
# iter 50 of Expectation completed in a total of  16.2 minutes
# iter 60 of Expectation completed in a total of  19.6 minutes
# Expectation step finished, posterior frame-wise accuracy  79.79%, boundary mse  0.00
# Epoch 56 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.02308022834694
# Starting Training
# Epoch 57: Iteration 20 with loss 0.8700189590454102
# Epoch 57: Iteration 40 with loss 0.5819366574287415
# Epoch 57: Iteration 60 with loss 0.5975301265716553
# Epoch 57: Iteration 80 with loss 0.5186851620674133
# Epoch 57: Iteration 100 with loss 0.6627216935157776
# Epoch 57: Iteration 120 with loss 0.47812771797180176
# Epoch 57: Iteration 140 with loss 0.4057144224643707
# Epoch 57: Iteration 160 with loss 0.6061325073242188
# Epoch 57 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.25176198793534
# Starting Training
# Epoch 58: Iteration 20 with loss 0.4331704080104828
# Epoch 58: Iteration 40 with loss 0.42190608382225037
# Epoch 58: Iteration 60 with loss 0.47866347432136536
# Epoch 58: Iteration 80 with loss 0.39639440178871155
# Epoch 58: Iteration 100 with loss 0.48994919657707214
# Epoch 58: Iteration 120 with loss 0.4937792718410492
# Epoch 58: Iteration 140 with loss 0.4646964967250824
# Epoch 58: Iteration 160 with loss 0.3997870981693268
# Epoch 58 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.02498311951384
# Starting Training
# Epoch 59: Iteration 20 with loss 0.503505289554596
# Epoch 59: Iteration 40 with loss 1.4816957712173462
# Epoch 59: Iteration 60 with loss 0.548719048500061
# Epoch 59: Iteration 80 with loss 1.0351067781448364
# Epoch 59: Iteration 100 with loss 0.4770912230014801
# Epoch 59: Iteration 120 with loss 0.5785180926322937
# Epoch 59: Iteration 140 with loss 0.415424108505249
# Epoch 59: Iteration 160 with loss 0.34805357456207275
# Epoch 59 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.30913331956853
# Starting Training
# Epoch 60: Iteration 20 with loss 0.19702166318893433
# Epoch 60: Iteration 40 with loss 0.3946712017059326
# Epoch 60: Iteration 60 with loss 0.3489389419555664
# Epoch 60: Iteration 80 with loss 0.3229519724845886
# Epoch 60: Iteration 100 with loss 0.4139859080314636
# Epoch 60: Iteration 120 with loss 0.3757336437702179
# Epoch 60: Iteration 140 with loss 0.48402097821235657
# Epoch 60: Iteration 160 with loss 0.4305151700973511
# Epoch 60 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.4445176087187
# Starting Training
# Epoch 61: Iteration 20 with loss 0.42286086082458496
# Epoch 61: Iteration 40 with loss 0.3546423316001892
# Epoch 61: Iteration 60 with loss 0.3921701908111572
# Epoch 61: Iteration 80 with loss 0.28769609332084656
# Epoch 61: Iteration 100 with loss 0.4449077844619751
# Epoch 61: Iteration 120 with loss 0.6633225679397583
# Epoch 61: Iteration 140 with loss 0.3434092700481415
# Epoch 61: Iteration 160 with loss 0.5620349645614624
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.6 minutes
# iter 20 of Expectation completed in a total of  5.7 minutes
# iter 30 of Expectation completed in a total of  9.2 minutes
# iter 40 of Expectation completed in a total of  12.8 minutes
# iter 50 of Expectation completed in a total of  15.9 minutes
# iter 60 of Expectation completed in a total of  19.2 minutes
# Expectation step finished, posterior frame-wise accuracy  79.26%, boundary mse  0.00
# Epoch 61 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.10344250311103
# Starting Training
# Epoch 62: Iteration 20 with loss 3.681161403656006
# Epoch 62: Iteration 40 with loss 3.160069704055786
# Epoch 62: Iteration 60 with loss 1.701395869255066
# Epoch 62: Iteration 80 with loss 1.0063974857330322
# Epoch 62: Iteration 100 with loss 1.0251632928848267
# Epoch 62: Iteration 120 with loss 1.2668699026107788
# Epoch 62: Iteration 140 with loss 1.9588825702667236
# Epoch 62: Iteration 160 with loss 1.7716541290283203
# Epoch 62 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.56517541754789
# Starting Training
# Epoch 63: Iteration 20 with loss 0.9704160690307617
# Epoch 63: Iteration 40 with loss 0.8980852365493774
# Epoch 63: Iteration 60 with loss 1.8286107778549194
# Epoch 63: Iteration 80 with loss 1.330003261566162
# Epoch 63: Iteration 100 with loss 1.2944912910461426
# Epoch 63: Iteration 120 with loss 0.7972078323364258
# Epoch 63: Iteration 140 with loss 0.6042755842208862
# Epoch 63: Iteration 160 with loss 0.7060151100158691
# Epoch 63 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.16995440873656
# Starting Training
# Epoch 64: Iteration 20 with loss 0.5042746067047119
# Epoch 64: Iteration 40 with loss 0.46633610129356384
# Epoch 64: Iteration 60 with loss 0.5779879689216614
# Epoch 64: Iteration 80 with loss 0.57096928358078
# Epoch 64: Iteration 100 with loss 0.5503517389297485
# Epoch 64: Iteration 120 with loss 0.7044508457183838
# Epoch 64: Iteration 140 with loss 0.8271126747131348
# Epoch 64: Iteration 160 with loss 0.9964390993118286
# Epoch 64 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.29841909364345
# Starting Training
# Epoch 65: Iteration 20 with loss 0.5481017827987671
# Epoch 65: Iteration 40 with loss 0.4075029790401459
# Epoch 65: Iteration 60 with loss 0.6363913416862488
# Epoch 65: Iteration 80 with loss 0.4738016128540039
# Epoch 65: Iteration 100 with loss 0.6434704661369324
# Epoch 65: Iteration 120 with loss 0.5656868815422058
# Epoch 65: Iteration 140 with loss 0.5116013884544373
# Epoch 65: Iteration 160 with loss 0.36239513754844666
# Epoch 65 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.60097878918086
# Starting Training
# Epoch 66: Iteration 20 with loss 0.5134885311126709
# Epoch 66: Iteration 40 with loss 0.3774489760398865
# Epoch 66: Iteration 60 with loss 0.3998667597770691
# Epoch 66: Iteration 80 with loss 0.42043226957321167
# Epoch 66: Iteration 100 with loss 0.36184659600257874
# Epoch 66: Iteration 120 with loss 0.3844107985496521
# Epoch 66: Iteration 140 with loss 0.5107218623161316
# Epoch 66: Iteration 160 with loss 0.3415253758430481
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.5 minutes
# iter 20 of Expectation completed in a total of  5.7 minutes
# iter 30 of Expectation completed in a total of  8.7 minutes
# iter 40 of Expectation completed in a total of  11.8 minutes
# iter 50 of Expectation completed in a total of  15.2 minutes
# iter 60 of Expectation completed in a total of  19.2 minutes
# Expectation step finished, posterior frame-wise accuracy  79.25%, boundary mse  0.00
# Epoch 66 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.132348591804735
# Starting Training
# Epoch 67: Iteration 20 with loss 0.42223259806632996
# Epoch 67: Iteration 40 with loss 0.3401462435722351
# Epoch 67: Iteration 60 with loss 0.43327751755714417
# Epoch 67: Iteration 80 with loss 0.6896145939826965
# Epoch 67: Iteration 100 with loss 0.6050451993942261
# Epoch 67: Iteration 120 with loss 0.31507375836372375
# Epoch 67: Iteration 140 with loss 0.5001972317695618
# Epoch 67: Iteration 160 with loss 0.33405712246894836
# Epoch 67 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.59250785430885
# Starting Training
# Epoch 68: Iteration 20 with loss 0.2488943189382553
# Epoch 68: Iteration 40 with loss 0.282912015914917
# Epoch 68: Iteration 60 with loss 0.2929540276527405
# Epoch 68: Iteration 80 with loss 0.32528984546661377
# Epoch 68: Iteration 100 with loss 0.35736900568008423
# Epoch 68: Iteration 120 with loss 0.5291810631752014
# Epoch 68: Iteration 140 with loss 0.40960943698883057
# Epoch 68: Iteration 160 with loss 0.2788219451904297
# Epoch 68 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.787367257995214
# Starting Training
# Epoch 69: Iteration 20 with loss 0.2452848255634308
# Epoch 69: Iteration 40 with loss 0.3786647617816925
# Epoch 69: Iteration 60 with loss 0.29785779118537903
# Epoch 69: Iteration 80 with loss 0.4511503577232361
# Epoch 69: Iteration 100 with loss 0.37283238768577576
# Epoch 69: Iteration 120 with loss 0.24374759197235107
# Epoch 69: Iteration 140 with loss 0.2682960629463196
# Epoch 69: Iteration 160 with loss 0.5277793407440186
# Epoch 69 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.47520382140725
# Starting Training
# Epoch 70: Iteration 20 with loss 0.17808640003204346
# Epoch 70: Iteration 40 with loss 0.21296191215515137
# Epoch 70: Iteration 60 with loss 0.2899273931980133
# Epoch 70: Iteration 80 with loss 0.3923477828502655
# Epoch 70: Iteration 100 with loss 0.39227959513664246
# Epoch 70: Iteration 120 with loss 0.3875817060470581
# Epoch 70: Iteration 140 with loss 2.085716724395752
# Epoch 70: Iteration 160 with loss 0.7354593276977539
# Epoch 70 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.41238051126947
# Starting Training
# Epoch 71: Iteration 20 with loss 2.6660799980163574
# Epoch 71: Iteration 40 with loss 4.286214828491211
# Epoch 71: Iteration 60 with loss 1.4828898906707764
# Epoch 71: Iteration 80 with loss 2.9276657104492188
# Epoch 71: Iteration 100 with loss 2.9668631553649902
# Epoch 71: Iteration 120 with loss 1.0742114782333374
# Epoch 71: Iteration 140 with loss 1.5426173210144043
# Epoch 71: Iteration 160 with loss 0.6130375266075134
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  9.7 minutes
# iter 40 of Expectation completed in a total of  13.0 minutes
# iter 50 of Expectation completed in a total of  15.9 minutes
# iter 60 of Expectation completed in a total of  19.5 minutes
# Expectation step finished, posterior frame-wise accuracy  79.05%, boundary mse  0.00
# Epoch 71 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.32509305193609
# Starting Training
# Epoch 72: Iteration 20 with loss 1.2785203456878662
# Epoch 72: Iteration 40 with loss 0.6637728810310364
# Epoch 72: Iteration 60 with loss 0.6210069060325623
# Epoch 72: Iteration 80 with loss 1.1707227230072021
# Epoch 72: Iteration 100 with loss 0.583050549030304
# Epoch 72: Iteration 120 with loss 1.2837014198303223
# Epoch 72: Iteration 140 with loss 0.5025476217269897
# Epoch 72: Iteration 160 with loss 0.534040629863739
# Epoch 72 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.16272230623713
# Starting Training
# Epoch 73: Iteration 20 with loss 1.366532564163208
# Epoch 73: Iteration 40 with loss 0.8694164752960205
# Epoch 73: Iteration 60 with loss 0.7663389444351196
# Epoch 73: Iteration 80 with loss 0.5142173171043396
# Epoch 73: Iteration 100 with loss 1.2411540746688843
# Epoch 73: Iteration 120 with loss 1.146576166152954
# Epoch 73: Iteration 140 with loss 0.45263296365737915
# Epoch 73: Iteration 160 with loss 0.784940779209137
# Epoch 73 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.50466794270121
# Starting Training
# Epoch 74: Iteration 20 with loss 0.39637497067451477
# Epoch 74: Iteration 40 with loss 0.7125529646873474
# Epoch 74: Iteration 60 with loss 0.4897741675376892
# Epoch 74: Iteration 80 with loss 0.3588300943374634
# Epoch 74: Iteration 100 with loss 0.30222275853157043
# Epoch 74: Iteration 120 with loss 0.7144612073898315
# Epoch 74: Iteration 140 with loss 0.4191308617591858
# Epoch 74: Iteration 160 with loss 0.5911438465118408
# Epoch 74 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.21883806451973
# Starting Training
# Epoch 75: Iteration 20 with loss 0.5022343397140503
# Epoch 75: Iteration 40 with loss 0.3923018276691437
# Epoch 75: Iteration 60 with loss 0.4203852713108063
# Epoch 75: Iteration 80 with loss 0.3296765089035034
# Epoch 75: Iteration 100 with loss 0.965735673904419
# Epoch 75: Iteration 120 with loss 0.43405526876449585
# Epoch 75: Iteration 140 with loss 0.463543176651001
# Epoch 75: Iteration 160 with loss 0.8301597833633423
# Epoch 75 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.77955480159151
# Starting Training
# Epoch 76: Iteration 20 with loss 0.2463504523038864
# Epoch 76: Iteration 40 with loss 0.43352705240249634
# Epoch 76: Iteration 60 with loss 0.43577781319618225
# Epoch 76: Iteration 80 with loss 0.31370437145233154
# Epoch 76: Iteration 100 with loss 0.2520707845687866
# Epoch 76: Iteration 120 with loss 0.5794972777366638
# Epoch 76: Iteration 140 with loss 0.31386473774909973
# Epoch 76: Iteration 160 with loss 0.7182511687278748
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  6.9 minutes
# iter 30 of Expectation completed in a total of  10.4 minutes
# iter 40 of Expectation completed in a total of  13.7 minutes
# iter 50 of Expectation completed in a total of  17.0 minutes
# iter 60 of Expectation completed in a total of  20.2 minutes
# Expectation step finished, posterior frame-wise accuracy  78.55%, boundary mse  0.00
# Epoch 76 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.42275991763439
# Starting Training
# Epoch 77: Iteration 20 with loss 1.6265813112258911
# Epoch 77: Iteration 40 with loss 0.7312740087509155
# Epoch 77: Iteration 60 with loss 0.5332686901092529
# Epoch 77: Iteration 80 with loss 1.2002111673355103
# Epoch 77: Iteration 100 with loss 1.260962724685669
# Epoch 77: Iteration 120 with loss 4.305142402648926
# Epoch 77: Iteration 140 with loss 0.7838264107704163
# Epoch 77: Iteration 160 with loss 1.469743013381958
# ...
# Starting Training
# Epoch 123: Iteration 20 with loss 0.4164581596851349
# Epoch 123: Iteration 40 with loss 0.886605441570282
# Epoch 123: Iteration 60 with loss 0.5919210910797119
# Epoch 123: Iteration 80 with loss 0.4474763870239258
# Epoch 123: Iteration 100 with loss 0.24362991750240326
# Epoch 123: Iteration 120 with loss 0.29657506942749023
# Epoch 123: Iteration 140 with loss 0.28213053941726685
# Epoch 123: Iteration 160 with loss 0.543429434299469
# Epoch 123 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.15244334574026
# Starting Training
# Epoch 124: Iteration 20 with loss 0.5986114144325256
# Epoch 124: Iteration 40 with loss 0.3175945580005646
# Epoch 124: Iteration 60 with loss 0.38239043951034546
# Epoch 124: Iteration 80 with loss 0.4201584458351135
# Epoch 124: Iteration 100 with loss 0.3185035288333893
# Epoch 124: Iteration 120 with loss 0.25745439529418945
# Epoch 124: Iteration 140 with loss 0.23161251842975616
# Epoch 124: Iteration 160 with loss 0.2830319404602051
# Epoch 124 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.669293140105246
# Starting Training
# Epoch 125: Iteration 20 with loss 0.255801260471344
# Epoch 125: Iteration 40 with loss 0.44309526681900024
# Epoch 125: Iteration 60 with loss 0.14818868041038513
# Epoch 125: Iteration 80 with loss 0.20319361984729767
# Epoch 125: Iteration 100 with loss 0.21678030490875244
# Epoch 125: Iteration 120 with loss 0.23119239509105682
# Epoch 125: Iteration 140 with loss 0.2322351336479187
# Epoch 125: Iteration 160 with loss 0.27770158648490906
# Epoch 125 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.68391359423217
# Starting Training
# Epoch 126: Iteration 20 with loss 0.3393697738647461
# Epoch 126: Iteration 40 with loss 0.21659058332443237
# Epoch 126: Iteration 60 with loss 0.172263965010643
# Epoch 126: Iteration 80 with loss 0.1752311736345291
# Epoch 126: Iteration 100 with loss 0.22122548520565033
# Epoch 126: Iteration 120 with loss 0.20534315705299377
# Epoch 126: Iteration 140 with loss 0.19053435325622559
# Epoch 126: Iteration 160 with loss 0.23938676714897156
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.0 minutes
# iter 20 of Expectation completed in a total of  6.0 minutes
# iter 30 of Expectation completed in a total of  9.0 minutes
# iter 40 of Expectation completed in a total of  12.4 minutes
# iter 50 of Expectation completed in a total of  15.2 minutes
# iter 60 of Expectation completed in a total of  18.4 minutes
# Expectation step finished, posterior frame-wise accuracy  77.30%, boundary mse  0.00
# Epoch 126 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.96427475293107
# Starting Training
# Epoch 127: Iteration 20 with loss 0.15703913569450378
# Epoch 127: Iteration 40 with loss 0.1597813069820404
# Epoch 127: Iteration 60 with loss 0.35382699966430664
# Epoch 127: Iteration 80 with loss 0.19139812886714935
# Epoch 127: Iteration 100 with loss 0.1837213635444641
# Epoch 127: Iteration 120 with loss 0.19396239519119263
# Epoch 127: Iteration 140 with loss 0.18760481476783752
# Epoch 127: Iteration 160 with loss 0.23854601383209229
# Epoch 127 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.80936490309764
# Starting Training
# Epoch 128: Iteration 20 with loss 0.20536617934703827
# Epoch 128: Iteration 40 with loss 0.22982509434223175
# Epoch 128: Iteration 60 with loss 0.14728650450706482
# Epoch 128: Iteration 80 with loss 0.3180127441883087
# Epoch 128: Iteration 100 with loss 0.3384847342967987
# Epoch 128: Iteration 120 with loss 0.24472421407699585
# Epoch 128: Iteration 140 with loss 0.35339927673339844
# Epoch 128: Iteration 160 with loss 0.29662632942199707
# Epoch 128 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.59675448239686
# Starting Training
# Epoch 129: Iteration 20 with loss 0.2298593670129776
# Epoch 129: Iteration 40 with loss 0.23982596397399902
# Epoch 129: Iteration 60 with loss 0.2800019383430481
# Epoch 129: Iteration 80 with loss 0.21958699822425842
# Epoch 129: Iteration 100 with loss 0.42380058765411377
# Epoch 129: Iteration 120 with loss 0.36133813858032227
# Epoch 129: Iteration 140 with loss 0.43855106830596924
# Epoch 129: Iteration 160 with loss 0.3594953715801239
# Epoch 129 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.30502619963058
# Starting Training
# Epoch 130: Iteration 20 with loss 0.44978630542755127
# Epoch 130: Iteration 40 with loss 0.3721017837524414
# Epoch 130: Iteration 60 with loss 0.7067327499389648
# Epoch 130: Iteration 80 with loss 0.3767285943031311
# Epoch 130: Iteration 100 with loss 0.28762733936309814
# Epoch 130: Iteration 120 with loss 0.4148715138435364
# Epoch 130: Iteration 140 with loss 0.3204982280731201
# Epoch 130: Iteration 160 with loss 15.807071685791016
# Epoch 130 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.76643545515929
# Starting Training
# Epoch 131: Iteration 20 with loss 1.1459835767745972
# Epoch 131: Iteration 40 with loss 0.7117527723312378
# Epoch 131: Iteration 60 with loss 1.4491208791732788
# Epoch 131: Iteration 80 with loss 0.8419594764709473
# Epoch 131: Iteration 100 with loss 0.7732678651809692
# Epoch 131: Iteration 120 with loss 0.4291803538799286
# Epoch 131: Iteration 140 with loss 0.5149799585342407
# Epoch 131: Iteration 160 with loss 0.33097532391548157
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  6.7 minutes
# iter 30 of Expectation completed in a total of  9.7 minutes
# iter 40 of Expectation completed in a total of  12.7 minutes
# iter 50 of Expectation completed in a total of  15.4 minutes
# iter 60 of Expectation completed in a total of  18.3 minutes
# Expectation step finished, posterior frame-wise accuracy  76.92%, boundary mse  0.00
# Epoch 131 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.700448100178015
# Starting Training
# Epoch 132: Iteration 20 with loss 1.0810775756835938
# Epoch 132: Iteration 40 with loss 1.648098111152649
# Epoch 132: Iteration 60 with loss 1.4552639722824097
# Epoch 132: Iteration 80 with loss 2.2543222904205322
# Epoch 132: Iteration 100 with loss 1.7587172985076904
# Epoch 132: Iteration 120 with loss 0.6863136291503906
# Epoch 132: Iteration 140 with loss 1.1663744449615479
# Epoch 132: Iteration 160 with loss 0.5543423295021057
# Epoch 132 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.34676145780436
# Starting Training
# Epoch 133: Iteration 20 with loss 0.6904715299606323
# Epoch 133: Iteration 40 with loss 0.37719351053237915
# Epoch 133: Iteration 60 with loss 0.4331228733062744
# Epoch 133: Iteration 80 with loss 0.5980167388916016
# Epoch 133: Iteration 100 with loss 1.4183629751205444
# Epoch 133: Iteration 120 with loss 0.4854680299758911
# Epoch 133: Iteration 140 with loss 0.38275468349456787
# Epoch 133: Iteration 160 with loss 1.2529670000076294
# Epoch 133 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.40279909152293
# Starting Training
# Epoch 134: Iteration 20 with loss 0.5498796105384827
# Epoch 134: Iteration 40 with loss 0.5718914866447449
# Epoch 134: Iteration 60 with loss 0.6356476545333862
# Epoch 134: Iteration 80 with loss 0.4929552972316742
# Epoch 134: Iteration 100 with loss 0.5914028882980347
# Epoch 134: Iteration 120 with loss 0.6312525868415833
# Epoch 134: Iteration 140 with loss 0.419597327709198
# Epoch 134: Iteration 160 with loss 0.3234740197658539
# Epoch 134 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.408357096221565
# Starting Training
# Epoch 135: Iteration 20 with loss 0.3246869444847107
# Epoch 135: Iteration 40 with loss 0.3044842481613159
# Epoch 135: Iteration 60 with loss 0.9131702184677124
# Epoch 135: Iteration 80 with loss 0.5270795226097107
# Epoch 135: Iteration 100 with loss 0.426938533782959
# Epoch 135: Iteration 120 with loss 0.29150477051734924
# Epoch 135: Iteration 140 with loss 0.33371642231941223
# Epoch 135: Iteration 160 with loss 0.3184109330177307
# Epoch 135 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.35724131003733
# Starting Training
# Epoch 136: Iteration 20 with loss 0.3765770494937897
# Epoch 136: Iteration 40 with loss 0.3736167848110199
# Epoch 136: Iteration 60 with loss 0.26359695196151733
# Epoch 136: Iteration 80 with loss 0.8982058763504028
# Epoch 136: Iteration 100 with loss 0.25373080372810364
# Epoch 136: Iteration 120 with loss 0.3918648362159729
# Epoch 136: Iteration 140 with loss 0.32100510597229004
# Epoch 136: Iteration 160 with loss 0.30192840099334717
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  9.7 minutes
# iter 40 of Expectation completed in a total of  12.8 minutes
# iter 50 of Expectation completed in a total of  16.4 minutes
# iter 60 of Expectation completed in a total of  19.2 minutes
# Expectation step finished, posterior frame-wise accuracy  77.03%, boundary mse  0.00
# Epoch 136 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.56115200249999
# Starting Training
# Epoch 137: Iteration 20 with loss 0.619569718837738
# Epoch 137: Iteration 40 with loss 0.277983158826828
# Epoch 137: Iteration 60 with loss 0.34949129819869995
# Epoch 137: Iteration 80 with loss 0.193960040807724
# Epoch 137: Iteration 100 with loss 0.2407301515340805
# Epoch 137: Iteration 120 with loss 0.3256456255912781
# Epoch 137: Iteration 140 with loss 0.1879338175058365
# Epoch 137: Iteration 160 with loss 0.25081968307495117
# Epoch 137 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.301555236856935
# Starting Training
# Epoch 138: Iteration 20 with loss 0.9378650188446045
# Epoch 138: Iteration 40 with loss 0.4215478003025055
# Epoch 138: Iteration 60 with loss 0.2647065222263336
# Epoch 138: Iteration 80 with loss 0.1967504620552063
# Epoch 138: Iteration 100 with loss 0.2107243835926056
# Epoch 138: Iteration 120 with loss 0.23504610359668732
# Epoch 138: Iteration 140 with loss 0.22831152379512787
# Epoch 138: Iteration 160 with loss 0.25907471776008606
# Epoch 138 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.91684198190858
# Starting Training
# Epoch 139: Iteration 20 with loss 0.22877082228660583
# Epoch 139: Iteration 40 with loss 2.023740768432617
# Epoch 139: Iteration 60 with loss 0.24924516677856445
# Epoch 139: Iteration 80 with loss 0.6963915228843689
# Epoch 139: Iteration 100 with loss 1.1819149255752563
# Epoch 139: Iteration 120 with loss 0.7198821902275085
# Epoch 139: Iteration 140 with loss 0.5296632051467896
# Epoch 139: Iteration 160 with loss 0.3236214220523834
# Epoch 139 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.86005100417967
# Starting Training
# Epoch 140: Iteration 20 with loss 0.30568957328796387
# Epoch 140: Iteration 40 with loss 0.22900483012199402
# Epoch 140: Iteration 60 with loss 0.40172022581100464
# Epoch 140: Iteration 80 with loss 0.43519479036331177
# Epoch 140: Iteration 100 with loss 0.32449737191200256
# Epoch 140: Iteration 120 with loss 0.3282187283039093
# Epoch 140: Iteration 140 with loss 0.42329689860343933
# Epoch 140: Iteration 160 with loss 0.23391664028167725
# Epoch 140 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.89218252130289
# Starting Training
# Epoch 141: Iteration 20 with loss 0.33889755606651306
# Epoch 141: Iteration 40 with loss 0.27950161695480347
# Epoch 141: Iteration 60 with loss 0.31060779094696045
# Epoch 141: Iteration 80 with loss 0.21956779062747955
# Epoch 141: Iteration 100 with loss 0.2654464840888977
# Epoch 141: Iteration 120 with loss 0.29103368520736694
# Epoch 141: Iteration 140 with loss 0.2101869136095047
# Epoch 141: Iteration 160 with loss 0.31196027994155884
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  6.6 minutes
# iter 30 of Expectation completed in a total of  9.3 minutes
# iter 40 of Expectation completed in a total of  12.5 minutes
# iter 50 of Expectation completed in a total of  15.3 minutes
# iter 60 of Expectation completed in a total of  18.0 minutes
# Expectation step finished, posterior frame-wise accuracy  77.00%, boundary mse  0.00
# Epoch 141 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.88738344094062
# Starting Training
# Epoch 142: Iteration 20 with loss 0.1599494218826294
# Epoch 142: Iteration 40 with loss 0.22275125980377197
# Epoch 142: Iteration 60 with loss 0.2795253396034241
# Epoch 142: Iteration 80 with loss 0.18837115168571472
# Epoch 142: Iteration 100 with loss 0.2585698366165161
# Epoch 142: Iteration 120 with loss 0.2061336487531662
# Epoch 142: Iteration 140 with loss 0.5173070430755615
# Epoch 142: Iteration 160 with loss 0.1383785754442215
# Epoch 142 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.55289312001607
# Starting Training
# Epoch 143: Iteration 20 with loss 0.22257152199745178
# Epoch 143: Iteration 40 with loss 0.17632105946540833
# Epoch 143: Iteration 60 with loss 0.1630774885416031
# Epoch 143: Iteration 80 with loss 0.15889203548431396
# Epoch 143: Iteration 100 with loss 0.3106064796447754
# Epoch 143: Iteration 120 with loss 0.19025200605392456
# Epoch 143: Iteration 140 with loss 0.16750110685825348
# Epoch 143: Iteration 160 with loss 0.2284516543149948
# Epoch 143 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.545750302732685
# Starting Training
# Epoch 144: Iteration 20 with loss 0.14884334802627563
# Epoch 144: Iteration 40 with loss 0.12971317768096924
# Epoch 144: Iteration 60 with loss 0.17376306653022766
# Epoch 144: Iteration 80 with loss 0.21138525009155273
# Epoch 144: Iteration 100 with loss 0.14285410940647125
# Epoch 144: Iteration 120 with loss 0.1385997086763382
# Epoch 144: Iteration 140 with loss 0.20310470461845398
# Epoch 144: Iteration 160 with loss 0.26002445816993713
# Epoch 144 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.80289172493457
# Starting Training
# Epoch 145: Iteration 20 with loss 0.18960639834403992
# Epoch 145: Iteration 40 with loss 0.16992491483688354
# Epoch 145: Iteration 60 with loss 0.18997696042060852
# Epoch 145: Iteration 80 with loss 0.20955988764762878
# Epoch 145: Iteration 100 with loss 0.23603123426437378
# Epoch 145: Iteration 120 with loss 0.22350136935710907
# Epoch 145: Iteration 140 with loss 0.1540209800004959
# Epoch 145: Iteration 160 with loss 0.21914927661418915
# Epoch 145 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.74284741714611
# Starting Training
# Epoch 146: Iteration 20 with loss 0.1789558231830597
# Epoch 146: Iteration 40 with loss 0.36979958415031433
# Epoch 146: Iteration 60 with loss 0.23573985695838928
# Epoch 146: Iteration 80 with loss 0.16311481595039368
# Epoch 146: Iteration 100 with loss 0.1641703099012375
# Epoch 146: Iteration 120 with loss 0.2083863914012909
# Epoch 146: Iteration 140 with loss 0.15423043072223663
# Epoch 146: Iteration 160 with loss 0.15692171454429626
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  6.6 minutes
# iter 30 of Expectation completed in a total of  9.4 minutes
# iter 40 of Expectation completed in a total of  12.6 minutes
# iter 50 of Expectation completed in a total of  15.1 minutes

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {val_acc}")
# Out:
# Validation:: Epoch 145, Probability Accuracy 61.74284741714611

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {best_val_acc}")
# Out:
# Validation:: Epoch 145, Probability Accuracy 65.35566207777859

# %%
torch.save(model.state_dict(),
"/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-speed/final-em-maximized.wt")

# %%
config.output_dir
# Out:
# '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split1/'

# %%
model.load_state_dict(torch.load(config.output_dir + "ms-tcn-emmax-best-model.wt"))
# model.load_state_dict(torch.load(config.output_dir + "ms-tcn-initial-15-epochs.wt"))
# Out:
# <All keys matched successfully>
