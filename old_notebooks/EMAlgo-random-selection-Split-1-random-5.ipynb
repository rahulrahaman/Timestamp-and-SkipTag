# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
import os, sys
import glob
import numpy as np
import torch
import pandas as pd
import random
import torch.nn as nn
import pickle
import torch.nn.functional as F
import matplotlib.pyplot as plt
import multiprocessing as mp
from time import time
from utils import get_all_scores

# %%
from mstcn_model import *
from utility.adaptive_data_loader import Breakfast, collate_fn_override
from utility.adaptive_data_loader import BreakfastWithWeights, collate_fn_override_wtd
from utils import calculate_mof, dotdict

# %%
os.environ["WANDB_API_KEY"] = "992b3b1371ba79f48484cfca522b3786d7fa52c2"
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dipika_singhania (use `wandb login --relogin` to force relogin)
# True

# %%
seed = 42

# Ensure deterministic behavior
def set_seed():
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
set_seed()

# Device configuration
os.environ['CUDA_VISIBLE_DEVICES']='7'
# os.environ['CUDA_LAUNCH_BLOCKING']='6'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config = dotdict(
    epochs=500,
    num_class=48,
    batch_size=8,
    learning_rate=5e-4,
    weight_decay=0,
    dataset="Breakfast",
    architecture="unet-ensemble",
    features_file_name="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/",
    chunk_size=1,
    max_frames_per_video=1200,
    feature_size=2048,
    ground_truth_files_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/",
    label_id_csv="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv",
    gamma=0.1,
    step_size=500,
    split=1,
#     output_dir="/mnt/data/ar-datasets/dipika/breakfast/ms_tcn/data/breakfast/results/unsuper-finetune-split2-0.05-data-llr/",
    output_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select5/",
    project_name="breakfast-split-1",
    train_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split{}.bundle",
    test_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split{}.bundle",
    all_files="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt",
    cutoff=8,
    data_per = 0.2,
    budget=40,
    semi_supervised_split="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split{}_amt{}.bundle")

config.train_split_file = config.train_split_file.format(config.split)
config.semi_supervised_split = config.semi_supervised_split.format(config.split, config.data_per)
config.test_split_file = config.test_split_file.format(config.split)

if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)

config.output_dir = config.output_dir + f"split{config.split}"
if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)
config.output_dir = config.output_dir + "/"
if not os.path.exists(os.path.join(config.output_dir, "posterior_weights")):
    os.mkdir(os.path.join(config.output_dir, "posterior_weights"))
print(config)
# Out:
# {'epochs': 500, 'num_class': 48, 'batch_size': 8, 'learning_rate': 0.0005, 'weight_decay': 0, 'dataset': 'Breakfast', 'architecture': 'unet-ensemble', 'features_file_name': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/', 'chunk_size': 1, 'max_frames_per_video': 1200, 'feature_size': 2048, 'ground_truth_files_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/', 'label_id_csv': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv', 'gamma': 0.1, 'step_size': 500, 'split': 1, 'output_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select5/split1/', 'project_name': 'breakfast-split-1', 'train_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split1.bundle', 'test_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split1.bundle', 'all_files': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt', 'cutoff': 8, 'data_per': 0.2, 'budget': 40, 'semi_supervised_split': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split1_amt0.2.bundle'}

# %%
traindataset = BreakfastWithWeights(config, fold='train', fold_file_name=config.train_split_file)
testdataset = Breakfast(config, fold='test', fold_file_name=config.test_split_file)
# Out:
# Number of videos logged in train fold is 1460
# Number of videos not found in train fold is 0
# Number of videos logged in test fold is 252
# Number of videos not found in test fold is 0

# %%
def _init_fn(worker_id):
    np.random.seed(int(seed))
trainloader = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=config.batch_size, 
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)
testloader = torch.utils.data.DataLoader(dataset=testdataset,
                                          batch_size=config.batch_size, 
                                          shuffle=False,
                                          pin_memory=True, num_workers=4,
                                          collate_fn=lambda x: collate_fn_override(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

trainloder_expectation = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=20,
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

# %%
df = pd.read_csv(config.label_id_csv)
label_id_to_label_name = {}
label_name_to_label_id_dict = {}
for i, ele in df.iterrows():
    label_id_to_label_name[ele.label_id] = ele.label_name
    label_name_to_label_id_dict[ele.label_name] = ele.label_id

# %%
# selected_frames_dict = pickle.load(open("data/breakfast_len_assum_annotations.pkl", 'rb'))
# loaded_vidid_selected_frames
boundary_frames_dict = pickle.load(open("data/breakfast_boundary_annotations.pkl", "rb"))
num_boundary = 0
for key in boundary_frames_dict.keys():
    num_boundary += len(boundary_frames_dict[key])
# video_id_boundary_frames

# %%
selected_frames_dict = pickle.load(open("data/breakfast_random5frame_selection.pkl", "rb"))
# print(selected_frames_dict)

# %%
loaded_mean_var_actions = pickle.load(open("data/breakfast_meanvar_actions.pkl", "rb"))
mat_poisson = pickle.load(open("data/breakfast_possion_class_dict.pkl", "rb"))

def get_possion_prob(minlen, maxlen, cur_class):
    prob = mat_poisson[label_id_to_label_name[cur_class]][minlen:maxlen]
    return torch.tensor(prob)

def get_poisson_logcdf(minlen, cur_class):
    return np.log(np.sum(np.exp(mat_poisson[label_id_to_label_name[cur_class]][minlen:])) + 1e-20)

def get_possion_prob_for_all_class(minlen, maxlen):
    ele_list = []
    for i in range(config.num_class):
        prob = mat_poisson[label_id_to_label_name[i]][minlen:maxlen]
        ele_list.append(torch.tensor(prob))
    return torch.stack(ele_list, dim=-1)

# %%
def validate(model, dataloader, best_val_acc=None):
    model.eval()
    print("Calculating Validation Data Accuracy")
    correct = 0.0
    total = 0.0
    vidcount = 0
    all_scores = []
    for i, item in enumerate(testloader):
        with torch.no_grad():
            item_0 = item[0].to(device)
            item_1 = item[1].to(device)
            item_2 = item[2].to(device)
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            pred = torch.argmax(predictions[-1], dim=1)
            correct += float(torch.sum((pred == item_2) * src_mask).item())
            total += float(torch.sum(src_mask).item())
            for p, l, c in zip(pred, item_2, item_1):
                all_scores.append(get_all_scores(p[:c].detach().cpu().numpy(), 
                                                 l[:c].detach().cpu().numpy(), ['SIL']))
            
    final_scores = np.mean(np.array(all_scores), axis=0)
    val_acc = correct * 100.0 / total
    if best_val_acc is not None and val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-best-model.wt")
    torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-last-model.wt")
    print(f"Validation:: Probability Accuracy {val_acc}")
    print(f"Other scores:: Edit {final_scores[3]}, F1@[10:25:50] {final_scores[:3]}")
    _ = model.train()
    return val_acc, best_val_acc

# %%
def prob_vals_per_segment(selected_frames, cur_vid_feat, labels, first_ele_flag, last_ele_flag, vidid, gt_labels):
    prob_each_segment = []
    LOW_VAL = -10000000
    num_frames = len(cur_vid_feat)
    log_probs = torch.log(cur_vid_feat + 1e-8)
    cumsum_feat = torch.cumsum(log_probs, dim=0)
    prev_boundary = 0
    per_frame_weights = torch.zeros((num_frames, config.num_class))
    start_time = time()
    boundary_error = 0
    current_boundary = 0
    labels = [config.num_class-1] + labels if selected_frames[0] != 0 else labels
    labels = labels + [config.num_class-1] if selected_frames[-1] != num_frames-1 else labels
    selected_frames = [0] + selected_frames if selected_frames[0] != 0 else selected_frames
    selected_frames = selected_frames + [num_frames-1] if selected_frames[-1] != num_frames-1 else selected_frames

    for i, cur_ele in enumerate(selected_frames[:-1]):
        next_ele = selected_frames[i + 1]
        label_cur_ele = labels[i]
        label_next_ele = labels[i + 1]
        if cur_ele == next_ele-1:
            per_frame_weights[cur_ele, label_cur_ele] = 1.0
            if label_cur_ele != label_next_ele:
                prev_boundary = cur_ele
            continue
        
        seg_len = next_ele - cur_ele
        mat_b1_b2_c_prob = LOW_VAL * torch.ones((seg_len, seg_len, config.num_class), dtype=cumsum_feat.dtype)
        b1_prior = get_possion_prob(cur_ele-prev_boundary, next_ele-prev_boundary, label_cur_ele)
        
        # find dummy label where we will keep the diagonal (b1=b2) probabilities, later we will distribute among
        # rest of the classes after the softmax by dividing by (num_class - 2)
        dummy_label = 0
        while True:
            if dummy_label != label_cur_ele and dummy_label != label_next_ele:
                break
            else:
                dummy_label += 1
        
        for b1 in range(cur_ele, next_ele - 1):

            cur_boundary_len = b1 - prev_boundary
            strt_index = cumsum_feat[cur_ele - 1, label_cur_ele] if cur_ele > 0 else 0
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            right_sum = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1+1:next_ele, label_next_ele] # mid_seg_len
            mid_sum = (cumsum_feat[b1+1:next_ele, :] - cumsum_feat[b1, :])  # mid_seg_len
            b2_prior = get_possion_prob_for_all_class(1, next_ele-b1)  # mid_seg_len x num_class
            
            mat_b1_b2_c_prob[b1-cur_ele, b1+1-cur_ele:next_ele-cur_ele] = (left_sum + right_sum[:,None] + mid_sum) \
                                                                            + b1_prior[b1-cur_ele] + b2_prior
            # when mid segment is absent but right and left is not the same
            # we assign the probability to a dummy label for now and then later 
            # re-distribute among other classes after the softmax
            if label_cur_ele != label_next_ele:
                rightsum_wo_midseg = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1, label_next_ele]
                mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + rightsum_wo_midseg + b1_prior[b1-cur_ele]
        
#         if vidid=='P39_cam02_P39_scrambledegg' and cur_ele==574:
#             import pdb
#             pdb.set_trace()
        # when mid segment is absent b1 can also be next_ele-1
        b1 = next_ele - 1
        if label_cur_ele != label_next_ele:
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior[b1-cur_ele]
        else:
            # returns prob that the left class length >= seg len
            b1_prior_ = get_poisson_logcdf(next_ele - prev_boundary, label_cur_ele) 
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior_
        
        mat_b1_b2_c_prob[:, :, label_cur_ele] = LOW_VAL
        mat_b1_b2_c_prob[:, :, label_next_ele] = LOW_VAL
        mat_b1_b2_c_prob = torch.softmax(mat_b1_b2_c_prob.flatten(), dim=0).reshape((seg_len, seg_len, config.num_class))
        
        # re-distribute the dummy class probability among the left-over classes
        left_over_classes = config.num_class - 2 + (label_cur_ele==label_next_ele)
        for b1 in range(cur_ele, next_ele):
            assigned_prob = mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label]
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, :] = assigned_prob/left_over_classes
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_cur_ele] = 0
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_next_ele] = 0
        
        marginal_b1 = torch.sum(mat_b1_b2_c_prob, axis=(1,2))
        mean_b1 = round(torch.sum(marginal_b1.squeeze() * torch.arange(cur_ele, next_ele, 1)).item())
        cumm_b1_prob = torch.cumsum(marginal_b1, dim=0)
        cumm_b1_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=1), dim=0)
        cumm_b2_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=0), dim=0)

        per_frame_weights[cur_ele, label_cur_ele] = 1.0
        per_frame_weights[cur_ele+1:next_ele, :] = cumm_b1_c_prob[:-1] - cumm_b2_c_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_cur_ele] = 1 - cumm_b1_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] = 0
        remaining_probability = 1 - torch.sum(per_frame_weights[cur_ele+1:next_ele, :], dim=-1)
        # we use "+=" in the next line because left and right label might be the same
        # in that case using "=" would just overwrite the previous probability
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] += remaining_probability
        
        expected_boundary = round(torch.sum(torch.sum(mat_b1_b2_c_prob, axis=(0,2)).squeeze() * \
                            torch.arange(cur_ele, next_ele, 1)).item())
        if not (label_cur_ele == label_next_ele and expected_boundary >= next_ele-2):
            prev_boundary = expected_boundary
        if expected_boundary == 0 and i > 0:
            print(f'Estimated boundary has become zero! for {vidid} and cur_ele, next_ele {cur_ele, next_ele}')
            import pdb
            pdb.set_trace()
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary] - mean_b1)**2
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary+1] - prev_boundary)**2
        # current_boundary += 2
        # prob_each_segment.append(mat_b1_b2_c_prob)
        
    posterior_prediction = torch.argmax(per_frame_weights, dim=1)
    correct = torch.sum(posterior_prediction == gt_labels[:num_frames]).item()
    
    return (vidid, per_frame_weights, [correct, num_frames, boundary_error]) #, prob_each_segment)

# %%
posterior_acc_correct, posterior_acc_total = 0, 0
posterior_boundary_total_mse = 0
results = []

# Step 2: Define callback function to collect the output in `results`
def collect_result(result):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    fname = os.path.join(config.output_dir, 'posterior_weights', result[0] + '.wt')
    torch.save(result[1], fname)
    correct, total, boundary_err = result[2]
    posterior_acc_correct += correct
    posterior_acc_total += total
    posterior_boundary_total_mse += boundary_err
    # print(f'Dumped in file {fname} at time {time()}')
    return

def calculate_element_probb(data_feat, data_count, video_ids, gt_labels): # loaded_vidid_selected_frames, boundaries_dict):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    pool = mp.Pool(20)
    for iter_num in range(len(data_count)):
        cur_vidid = video_ids[iter_num]
#         if cur_vidid!='P39_cam02_P39_scrambledegg':
#             continue
        cur_vid_count = data_count[iter_num]
        cur_vid_feat = data_feat[iter_num][:cur_vid_count].detach().cpu()
        cur_gt_labels = gt_labels[iter_num].detach().cpu()
        
        cur_video_select_frames = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices_and_labels = cur_video_select_frames
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]
        with torch.no_grad():
            # Multi-processing
            pool.apply_async(prob_vals_per_segment,
                             args=(selected_frames_indices, cur_vid_feat, selected_frames_labels,
                                   cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels),
                             callback=collect_result)
#             results.append(prob_vals_per_segment(selected_frames_indices, cur_vid_feat, selected_frames_labels,
#                                    cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels))
    # Step 4: Close Pool and let all the processes complete
    pool.close()
    pool.join()  # postpones the execution of next line of code until all processes in the queue are done.
    return results

def perform_expectation(model, dataloader):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse = 0, 0, 0
    model.eval()
    correct = 0.0
    total = 0.0
    curtime = time()
    print(f'Calculating expectation')

    for i, item in enumerate(dataloader):
        with torch.no_grad():
            item_0 = item[0].to(device) # features
            item_1 = item[1].to(device) # count
            item_2 = item[2].to(device) # gt frame-wise labels
            item_4 = item[4] # video-ids
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            prob = torch.softmax(predictions[-1], dim=1)
            prob = prob.permute(0, 2, 1)
            
            calculate_element_probb(prob, item_1, item_4, item_2)
            if (i+1) % 10 == 0:
                print(f"iter {i+1} of Expectation completed in a total of {(time() - curtime)/60.: .1f} minutes")
    _ = model.train()
    print(f'Expectation step finished, '
          f'posterior frame-wise accuracy {100*posterior_acc_correct/posterior_acc_total: .2f}%, '
          f'boundary mse {(posterior_boundary_total_mse/num_boundary)**0.5: .2f}')
    return

# %%
set_seed()
model = MultiStageModel(num_stages=4, num_layers=10, num_f_maps=64, dim=2048, num_classes=48).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

# Requires loaded_vidid_selected_frames, boundaries_dict
ce_criterion = nn.CrossEntropyLoss(ignore_index=-100)
mse_criterion = nn.MSELoss(reduction='none')

# %%
# loaded_file=torch.load(os.path.join(config.output_dir, "ms-tcn-initial-30-epochs.wt"))
# model.load_state_dict(loaded_file)
# # loaded_file=torch.load('/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcnnew-full-supervised-split1/ms-tcn-best-model.wt')
# # model.load_state_dict(loaded_file)
# loaded_file=torch.load(os.path.join(config.output_dir, "ms-tcn-emmax-best-model.wt"))
loaded_file=torch.load("/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split1/ms-tcn-emmax-last-model.wt")
model.load_state_dict(loaded_file)
_ = validate(model, testloader)
# Out:
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 68.48277281163068
# Other scores:: Edit 68.65780790462246, F1@[10:25:50] [68.49952913 64.92506301 53.48251224]

# %%
# item = next(iter(trainloader))
    
# with torch.no_grad():
#     item_0 = item[0].to(device) # features
#     item_1 = item[1].to(device) # count
#     item_2 = item[2].to(device) # gt frame-wise labels
#     item_4 = item[4] # video-ids
#     src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
#     src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
#     middle_pred, predictions = model(item_0, src_mask_mse)
#     prob = torch.softmax(predictions[-1], dim=1)
#     prob = prob.permute(0, 2, 1)

#     res = calculate_element_probb(prob, item_1, item_4, item_2)

# %%
# idx = 2
# vidid = res[idx][0]
# mat = res[idx][1]
# mat.shape

# %%
# np.linspace(0, 5281, 4 + 1).astype(int)

# %%
# boundary_frames_dict[f'{vidid}.txt'], selected_frames_dict[f'{vidid}.txt'], weakly_labels[f'{vidid}.txt']

# %%
# fig = plt.figure(figsize=(20, 5))
# for i in range(48):
#     plt.plot(mat[:,i])
    
# for bd in boundary_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd, bd], [0, 2])
    
# for bd in selected_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd[0], bd[0]], [0, 2], '--')

# %%
# bd

# %%
# Calculating Expectation Step
# perform_expectation(model, trainloder_expectation)

# %%
def get_single_random(video_ids, len_frames, device):
    # Generate target for only timestamps. Do not generate pseudo labels at first 30 epochs.
    boundary_target_tensor = torch.ones((len(video_ids), len_frames), dtype=torch.long, device=device) * (-100)
    for iter_num, cur_vidid in enumerate(video_ids):
        selected_frames_indices_and_labels = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]

        frame_idx_tensor = torch.from_numpy(np.array(selected_frames_indices))
        frame_labels = torch.from_numpy(np.array(selected_frames_labels)).to(device)
        boundary_target_tensor[iter_num, frame_idx_tensor] = frame_labels

    return boundary_target_tensor

# %%
weakly_labels = pickle.load(open("data/breakfast_weaklysupervised_labels.pkl", "rb"))
prior_probs = pickle.load(open('data/breakfast_lengthmodel_multinomial_prior.pkl', 'rb'))

# %%
initialize_epoch = 30
expectation_cal_gap = 5
best_val_acc = 0
for epoch in range(0, 150):
    print("Starting Training")
    model.train()
    for i, item in enumerate(trainloader):
        item_0 = item[0].to(device)  # features
        item_1 = item[1].to(device)  # count
        item_2 = item[2].to(device)  # target
        weights = item[5].to(device)  # posterior weight
        src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
        src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
        optimizer.zero_grad()
        
        middle_pred, predictions = model(item_0, src_mask_mse)
        boundary_target_tensor = get_single_random(item[4], item_2.shape[1], item_2.device)
        
        loss = 0
        for p in predictions:
            if epoch <= initialize_epoch:
                loss += ce_criterion(p, boundary_target_tensor)
                loss += 0.15 * torch.mean(torch.clamp(mse_criterion(F.log_softmax(p[:, :, 1:], dim=1), 
                                                                    F.log_softmax(p.detach()[:, :, :-1], dim=1)), min=0,
                                            max=16) * src_mask_mse[:, :, 1:])
            else:
                prob = torch.softmax(p, dim=1)
                prob = prob.permute(0, 2, 1)
                total_count = torch.sum(src_mask)
                weighted_loss_sum = -torch.sum(torch.sum(torch.log(prob + 1e-8) * weights, dim=-1) * src_mask)
                loss += weighted_loss_sum/total_count

        loss.backward()
        optimizer.step()
        if (i+1)%20 == 0:
            print(f'Epoch {epoch+1}: Iteration {i+1} with loss {loss.item()}')

    if (epoch >= initialize_epoch) and ((epoch % (3 * expectation_cal_gap)) == 0):
        torch.save(model.state_dict(), config.output_dir + f"ms-tcn-initial-{epoch}-epochs.wt")

    if epoch >= initialize_epoch and (epoch % expectation_cal_gap == 0):
        perform_expectation(model, trainloder_expectation)
    
    print(f'Epoch {epoch+1} finished, starting validation')
    val_acc, best_val_acc = validate(model, testloader, best_val_acc)
# Out:
# Starting Training
# Epoch 1: Iteration 20 with loss 14.473981857299805
# Epoch 1: Iteration 40 with loss 14.196702003479004
# Epoch 1: Iteration 60 with loss 13.767776489257812
# Epoch 1: Iteration 80 with loss 12.938998222351074
# Epoch 1: Iteration 100 with loss 12.450570106506348
# Epoch 1: Iteration 120 with loss 10.387760162353516
# Epoch 1: Iteration 140 with loss 10.396161079406738
# Epoch 1: Iteration 160 with loss 9.988459587097168
# Epoch 1: Iteration 180 with loss 10.840205192565918
# Epoch 1 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 22.554815579852082
# Starting Training
# Epoch 2: Iteration 20 with loss 9.666767120361328
# Epoch 2: Iteration 40 with loss 9.755131721496582
# Epoch 2: Iteration 60 with loss 9.738783836364746
# Epoch 2: Iteration 80 with loss 9.555734634399414
# Epoch 2: Iteration 100 with loss 8.562029838562012
# Epoch 2: Iteration 120 with loss 9.58092212677002
# Epoch 2: Iteration 140 with loss 7.183716297149658
# Epoch 2: Iteration 160 with loss 8.642284393310547
# Epoch 2: Iteration 180 with loss 8.452396392822266
# Epoch 2 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 26.626462639141153
# Starting Training
# Epoch 3: Iteration 20 with loss 7.016199588775635
# Epoch 3: Iteration 40 with loss 6.765127658843994
# Epoch 3: Iteration 60 with loss 9.924522399902344
# Epoch 3: Iteration 80 with loss 7.3432512283325195
# Epoch 3: Iteration 100 with loss 7.180421352386475
# Epoch 3: Iteration 120 with loss 6.150623798370361
# Epoch 3: Iteration 140 with loss 7.168449878692627
# Epoch 3: Iteration 160 with loss 8.646676063537598
# Epoch 3: Iteration 180 with loss 5.91418981552124
# Epoch 3 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 34.760853306741694
# Starting Training
# Epoch 4: Iteration 20 with loss 6.9886860847473145
# Epoch 4: Iteration 40 with loss 5.984424114227295
# Epoch 4: Iteration 60 with loss 6.531152725219727
# Epoch 4: Iteration 80 with loss 5.844052314758301
# Epoch 4: Iteration 100 with loss 6.690074443817139
# Epoch 4: Iteration 120 with loss 8.542998313903809
# Epoch 4: Iteration 140 with loss 6.75390100479126
# Epoch 4: Iteration 160 with loss 6.959343433380127
# Epoch 4: Iteration 180 with loss 6.423428058624268
# Epoch 4 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 44.116006030604126
# Starting Training
# Epoch 5: Iteration 20 with loss 5.093001365661621
# Epoch 5: Iteration 40 with loss 5.422467231750488
# Epoch 5: Iteration 60 with loss 5.736192226409912
# Epoch 5: Iteration 80 with loss 5.024526119232178
# Epoch 5: Iteration 100 with loss 6.5492682456970215
# Epoch 5: Iteration 120 with loss 5.824495315551758
# Epoch 5: Iteration 140 with loss 4.589716911315918
# Epoch 5: Iteration 160 with loss 6.816046714782715
# Epoch 5: Iteration 180 with loss 5.42033052444458
# Epoch 5 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 40.61101416242269
# Starting Training
# Epoch 6: Iteration 20 with loss 5.469392776489258
# Epoch 6: Iteration 40 with loss 4.836998462677002
# Epoch 6: Iteration 60 with loss 6.437242031097412
# Epoch 6: Iteration 80 with loss 7.338108062744141
# Epoch 6: Iteration 100 with loss 5.630910873413086
# Epoch 6: Iteration 120 with loss 5.5489301681518555
# Epoch 6: Iteration 140 with loss 4.550146102905273
# Epoch 6: Iteration 160 with loss 5.604216575622559
# Epoch 6: Iteration 180 with loss 6.5696868896484375
# Epoch 6 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 48.98916153234327
# Starting Training
# Epoch 7: Iteration 20 with loss 4.0525689125061035
# Epoch 7: Iteration 40 with loss 5.305420875549316
# Epoch 7: Iteration 60 with loss 6.164847373962402
# Epoch 7: Iteration 80 with loss 3.749422311782837
# Epoch 7: Iteration 100 with loss 5.204413890838623
# Epoch 7: Iteration 120 with loss 4.7616753578186035
# Epoch 7: Iteration 140 with loss 8.232926368713379
# Epoch 7: Iteration 160 with loss 5.764468669891357
# Epoch 7: Iteration 180 with loss 3.825096607208252
# Epoch 7 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 48.28282108812042
# Starting Training
# Epoch 8: Iteration 20 with loss 5.742114067077637
# Epoch 8: Iteration 40 with loss 3.8852035999298096
# Epoch 8: Iteration 60 with loss 2.9269280433654785
# Epoch 8: Iteration 80 with loss 3.749727725982666
# Epoch 8: Iteration 100 with loss 7.214766025543213
# Epoch 8: Iteration 120 with loss 5.870302677154541
# Epoch 8: Iteration 140 with loss 4.0980024337768555
# Epoch 8: Iteration 160 with loss 3.326720952987671
# Epoch 8: Iteration 180 with loss 3.8455638885498047
# Epoch 8 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.52827142467087
# Starting Training
# Epoch 9: Iteration 20 with loss 4.070801734924316
# Epoch 9: Iteration 40 with loss 4.433724403381348
# Epoch 9: Iteration 60 with loss 3.731034278869629
# Epoch 9: Iteration 80 with loss 4.896333694458008
# Epoch 9: Iteration 100 with loss 4.273287773132324
# Epoch 9: Iteration 120 with loss 4.408014297485352
# Epoch 9: Iteration 140 with loss 4.405785083770752
# Epoch 9: Iteration 160 with loss 3.6698532104492188
# Epoch 9: Iteration 180 with loss 4.187935829162598
# Epoch 9 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.38623566049756
# Starting Training
# Epoch 10: Iteration 20 with loss 3.8272488117218018
# Epoch 10: Iteration 40 with loss 3.1424617767333984
# Epoch 10: Iteration 60 with loss 2.0607643127441406
# Epoch 10: Iteration 80 with loss 2.2254583835601807
# Epoch 10: Iteration 100 with loss 4.242457389831543
# Epoch 10: Iteration 120 with loss 4.147266387939453
# Epoch 10: Iteration 140 with loss 4.144495487213135
# Epoch 10: Iteration 160 with loss 2.3013558387756348
# Epoch 10: Iteration 180 with loss 4.357129096984863
# Epoch 10 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.0970594869238
# Starting Training
# Epoch 11: Iteration 20 with loss 3.1718826293945312
# Epoch 11: Iteration 40 with loss 2.8132965564727783
# Epoch 11: Iteration 60 with loss 4.1027936935424805
# Epoch 11: Iteration 80 with loss 3.2948052883148193
# Epoch 11: Iteration 100 with loss 4.301851749420166
# Epoch 11: Iteration 120 with loss 6.0386176109313965
# Epoch 11: Iteration 140 with loss 2.6612207889556885
# Epoch 11: Iteration 160 with loss 3.8319966793060303
# Epoch 11: Iteration 180 with loss 3.038442373275757
# Epoch 11 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.21951161603571
# Starting Training
# Epoch 12: Iteration 20 with loss 2.07912540435791
# Epoch 12: Iteration 40 with loss 4.631608009338379
# Epoch 12: Iteration 60 with loss 3.1322054862976074
# Epoch 12: Iteration 80 with loss 2.902245044708252
# Epoch 12: Iteration 100 with loss 2.922877311706543
# Epoch 12: Iteration 120 with loss 3.969768762588501
# Epoch 12: Iteration 140 with loss 3.0746026039123535
# Epoch 12: Iteration 160 with loss 2.64888072013855
# Epoch 12: Iteration 180 with loss 4.169097423553467
# Epoch 12 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.77998979070954
# Starting Training
# Epoch 13: Iteration 20 with loss 4.251313209533691
# Epoch 13: Iteration 40 with loss 2.282705783843994
# Epoch 13: Iteration 60 with loss 2.5610032081604004
# Epoch 13: Iteration 80 with loss 3.238172769546509
# Epoch 13: Iteration 100 with loss 4.2443928718566895
# Epoch 13: Iteration 120 with loss 2.1592280864715576
# Epoch 13: Iteration 140 with loss 2.6374263763427734
# Epoch 13: Iteration 160 with loss 3.563105344772339
# Epoch 13: Iteration 180 with loss 4.277236461639404
# Epoch 13 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.92209282540135
# Starting Training
# Epoch 14: Iteration 20 with loss 3.3563613891601562
# Epoch 14: Iteration 40 with loss 2.5340735912323
# Epoch 14: Iteration 60 with loss 3.8756589889526367
# Epoch 14: Iteration 80 with loss 2.3977060317993164
# Epoch 14: Iteration 100 with loss 2.8699777126312256
# Epoch 14: Iteration 120 with loss 2.6180624961853027
# Epoch 14: Iteration 140 with loss 2.839608907699585
# Epoch 14: Iteration 160 with loss 3.190566301345825
# Epoch 14: Iteration 180 with loss 2.9375979900360107
# Epoch 14 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.25780832650735
# Starting Training
# Epoch 15: Iteration 20 with loss 3.808217763900757
# Epoch 15: Iteration 40 with loss 2.941004991531372
# Epoch 15: Iteration 60 with loss 2.2290096282958984
# Epoch 15: Iteration 80 with loss 2.2440226078033447
# Epoch 15: Iteration 100 with loss 3.1044468879699707
# Epoch 15: Iteration 120 with loss 1.3804901838302612
# Epoch 15: Iteration 140 with loss 2.4851391315460205
# Epoch 15: Iteration 160 with loss 2.0349082946777344
# Epoch 15: Iteration 180 with loss 1.2924021482467651
# Epoch 15 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.75646885177139
# Starting Training
# Epoch 16: Iteration 20 with loss 2.2586536407470703
# Epoch 16: Iteration 40 with loss 2.298785448074341
# Epoch 16: Iteration 60 with loss 1.8049315214157104
# Epoch 16: Iteration 80 with loss 1.4838283061981201
# Epoch 16: Iteration 100 with loss 3.529790163040161
# Epoch 16: Iteration 120 with loss 1.39097261428833
# Epoch 16: Iteration 140 with loss 2.7005627155303955
# Epoch 16: Iteration 160 with loss 1.6340570449829102
# Epoch 16: Iteration 180 with loss 3.9127144813537598
# Epoch 16 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.90197894037062
# Starting Training
# Epoch 17: Iteration 20 with loss 1.7533947229385376
# Epoch 17: Iteration 40 with loss 2.3892667293548584
# Epoch 17: Iteration 60 with loss 2.1455254554748535
# Epoch 17: Iteration 80 with loss 1.994040846824646
# Epoch 17: Iteration 100 with loss 1.461169958114624
# Epoch 17: Iteration 120 with loss 2.3894917964935303
# Epoch 17: Iteration 140 with loss 5.451789379119873
# Epoch 17: Iteration 160 with loss 3.2682077884674072
# Epoch 17: Iteration 180 with loss 1.2651985883712769
# Epoch 17 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.225625319040326
# Starting Training
# Epoch 18: Iteration 20 with loss 2.661444902420044
# Epoch 18: Iteration 40 with loss 1.4902784824371338
# Epoch 18: Iteration 60 with loss 2.8055081367492676
# Epoch 18: Iteration 80 with loss 1.7010420560836792
# Epoch 18: Iteration 100 with loss 2.3643476963043213
# Epoch 18: Iteration 120 with loss 2.961573839187622
# Epoch 18: Iteration 140 with loss 1.5142234563827515
# Epoch 18: Iteration 160 with loss 1.6012983322143555
# Epoch 18: Iteration 180 with loss 1.512778639793396
# Epoch 18 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.96687520527401
# Starting Training
# Epoch 19: Iteration 20 with loss 2.203843593597412
# Epoch 19: Iteration 40 with loss 1.6268682479858398
# Epoch 19: Iteration 60 with loss 1.2163182497024536
# Epoch 19: Iteration 80 with loss 1.3385090827941895
# Epoch 19: Iteration 100 with loss 1.2237783670425415
# Epoch 19: Iteration 120 with loss 1.8719550371170044
# Epoch 19: Iteration 140 with loss 2.1753506660461426
# Epoch 19: Iteration 160 with loss 1.143602728843689
# Epoch 19: Iteration 180 with loss 1.6225165128707886
# Epoch 19 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.07252949020818
# Starting Training
# Epoch 20: Iteration 20 with loss 0.8809307813644409
# Epoch 20: Iteration 40 with loss 1.8130273818969727
# Epoch 20: Iteration 60 with loss 4.189298152923584
# Epoch 20: Iteration 80 with loss 1.964599609375
# Epoch 20: Iteration 100 with loss 1.5391418933868408
# Epoch 20: Iteration 120 with loss 1.0339065790176392
# Epoch 20: Iteration 140 with loss 4.060714244842529
# Epoch 20: Iteration 160 with loss 2.174912214279175
# Epoch 20: Iteration 180 with loss 1.4890738725662231
# Epoch 20 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.99433344808892
# Starting Training
# Epoch 21: Iteration 20 with loss 1.7107770442962646
# Epoch 21: Iteration 40 with loss 1.2663767337799072
# Epoch 21: Iteration 60 with loss 1.3595044612884521
# Epoch 21: Iteration 80 with loss 1.9599264860153198
# Epoch 21: Iteration 100 with loss 1.3248704671859741
# Epoch 21: Iteration 120 with loss 1.6139200925827026
# Epoch 21: Iteration 140 with loss 1.4010539054870605
# Epoch 21: Iteration 160 with loss 1.0739216804504395
# Epoch 21: Iteration 180 with loss 0.9543859958648682
# Epoch 21 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.41633328189117
# Starting Training
# Epoch 22: Iteration 20 with loss 1.808910608291626
# Epoch 22: Iteration 40 with loss 0.9575347900390625
# Epoch 22: Iteration 60 with loss 2.145292282104492
# Epoch 22: Iteration 80 with loss 1.4781603813171387
# Epoch 22: Iteration 100 with loss 0.8617896437644958
# Epoch 22: Iteration 120 with loss 1.0003986358642578
# Epoch 22: Iteration 140 with loss 1.9618862867355347
# Epoch 22: Iteration 160 with loss 2.2731449604034424
# Epoch 22: Iteration 180 with loss 2.3575758934020996
# Epoch 22 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.23175880749156
# Starting Training
# Epoch 23: Iteration 20 with loss 1.2547824382781982
# Epoch 23: Iteration 40 with loss 1.2278248071670532
# Epoch 23: Iteration 60 with loss 0.8930879235267639
# Epoch 23: Iteration 80 with loss 0.7974662780761719
# Epoch 23: Iteration 100 with loss 1.2389323711395264
# Epoch 23: Iteration 120 with loss 1.8958898782730103
# Epoch 23: Iteration 140 with loss 1.125457763671875
# Epoch 23: Iteration 160 with loss 1.2858809232711792
# Epoch 23: Iteration 180 with loss 0.8489657640457153
# Epoch 23 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.187482935052294
# Starting Training
# Epoch 24: Iteration 20 with loss 1.663743495941162
# Epoch 24: Iteration 40 with loss 1.2160930633544922
# Epoch 24: Iteration 60 with loss 1.6432775259017944
# Epoch 24: Iteration 80 with loss 1.933629035949707
# Epoch 24: Iteration 100 with loss 1.5876553058624268
# Epoch 24: Iteration 120 with loss 1.7320820093154907
# Epoch 24: Iteration 140 with loss 1.8364869356155396
# Epoch 24: Iteration 160 with loss 2.306497573852539
# Epoch 24: Iteration 180 with loss 1.1604472398757935
# Epoch 24 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.433372508517635
# Starting Training
# Epoch 25: Iteration 20 with loss 1.0284589529037476
# Epoch 25: Iteration 40 with loss 1.4298560619354248
# Epoch 25: Iteration 60 with loss 1.274013876914978
# Epoch 25: Iteration 80 with loss 1.3981850147247314
# Epoch 25: Iteration 100 with loss 1.145061731338501
# Epoch 25: Iteration 120 with loss 1.3114252090454102
# Epoch 25: Iteration 140 with loss 0.9284725785255432
# Epoch 25: Iteration 160 with loss 1.1341837644577026
# Epoch 25: Iteration 180 with loss 0.8706299066543579
# Epoch 25 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.907760247872076
# Starting Training
# Epoch 26: Iteration 20 with loss 3.420093059539795
# Epoch 26: Iteration 40 with loss 1.8063263893127441
# Epoch 26: Iteration 60 with loss 1.275518536567688
# Epoch 26: Iteration 80 with loss 0.7447439432144165
# Epoch 26: Iteration 100 with loss 1.0146201848983765
# Epoch 26: Iteration 120 with loss 1.1828055381774902
# Epoch 26: Iteration 140 with loss 1.4595612287521362
# Epoch 26: Iteration 160 with loss 1.2571998834609985
# Epoch 26: Iteration 180 with loss 1.007439136505127
# Epoch 26 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.275088935582545
# Starting Training
# Epoch 27: Iteration 20 with loss 1.3068979978561401
# Epoch 27: Iteration 40 with loss 0.89650958776474
# Epoch 27: Iteration 60 with loss 0.9198881387710571
# Epoch 27: Iteration 80 with loss 1.2225052118301392
# Epoch 27: Iteration 100 with loss 1.068640112876892
# Epoch 27: Iteration 120 with loss 1.2217013835906982
# Epoch 27: Iteration 140 with loss 0.8229039311408997
# Epoch 27: Iteration 160 with loss 1.0337193012237549
# Epoch 27: Iteration 180 with loss 1.463118314743042
# Epoch 27 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.1372279006454
# Starting Training
# Epoch 28: Iteration 20 with loss 1.5904126167297363
# Epoch 28: Iteration 40 with loss 1.4188443422317505
# Epoch 28: Iteration 60 with loss 1.4746094942092896
# Epoch 28: Iteration 80 with loss 0.9514474868774414
# Epoch 28: Iteration 100 with loss 1.2625845670700073
# Epoch 28: Iteration 120 with loss 0.8328320980072021
# Epoch 28: Iteration 140 with loss 0.6400932669639587
# Epoch 28: Iteration 160 with loss 0.9987165331840515
# Epoch 28: Iteration 180 with loss 1.1121193170547485
# Epoch 28 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.94229772348651
# Starting Training
# Epoch 29: Iteration 20 with loss 0.7593861222267151
# Epoch 29: Iteration 40 with loss 1.008871078491211
# Epoch 29: Iteration 60 with loss 0.8845118284225464
# Epoch 29: Iteration 80 with loss 0.9964534044265747
# Epoch 29: Iteration 100 with loss 0.5189375281333923
# Epoch 29: Iteration 120 with loss 1.5196924209594727
# Epoch 29: Iteration 140 with loss 0.9434409141540527
# Epoch 29: Iteration 160 with loss 1.048511028289795
# Epoch 29: Iteration 180 with loss 1.673133134841919
# Epoch 29 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.703067931352415
# Starting Training
# Epoch 30: Iteration 20 with loss 0.7013640403747559
# Epoch 30: Iteration 40 with loss 0.9553678035736084
# Epoch 30: Iteration 60 with loss 1.3236318826675415
# Epoch 30: Iteration 80 with loss 1.033768892288208
# Epoch 30: Iteration 100 with loss 1.0917075872421265
# Epoch 30: Iteration 120 with loss 0.8018161058425903
# Epoch 30: Iteration 140 with loss 1.0130326747894287
# Epoch 30: Iteration 160 with loss 0.8242928385734558
# Epoch 30: Iteration 180 with loss 0.7413204908370972
# Epoch 30 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.009370387517755
# Starting Training
# Epoch 31: Iteration 20 with loss 0.9575908780097961
# Epoch 31: Iteration 40 with loss 0.9310204386711121
# Epoch 31: Iteration 60 with loss 0.9968275427818298
# Epoch 31: Iteration 80 with loss 0.7134104371070862
# Epoch 31: Iteration 100 with loss 0.6645694971084595
# Epoch 31: Iteration 120 with loss 1.2492057085037231
# Epoch 31: Iteration 140 with loss 0.6279638409614563
# Epoch 31: Iteration 160 with loss 1.0147489309310913
# Epoch 31: Iteration 180 with loss 0.6480574607849121
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  6.4 minutes
# iter 30 of Expectation completed in a total of  9.8 minutes
# iter 40 of Expectation completed in a total of  13.1 minutes
# iter 50 of Expectation completed in a total of  16.2 minutes
# iter 60 of Expectation completed in a total of  19.5 minutes
# iter 70 of Expectation completed in a total of  22.1 minutes
# Expectation step finished, posterior frame-wise accuracy  82.26%, boundary mse  0.00
# Epoch 31 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.81800159074991
# Starting Training
# Epoch 32: Iteration 20 with loss 2.8056929111480713
# Epoch 32: Iteration 40 with loss 1.6417381763458252
# Epoch 32: Iteration 60 with loss 2.1611459255218506
# Epoch 32: Iteration 80 with loss 2.929175853729248
# Epoch 32: Iteration 100 with loss 4.020644664764404
# Epoch 32: Iteration 120 with loss 2.1570866107940674
# Epoch 32: Iteration 140 with loss 1.6476067304611206
# Epoch 32: Iteration 160 with loss 3.423795223236084
# Epoch 32: Iteration 180 with loss 6.292468070983887
# Epoch 32 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.03731139523013
# Starting Training
# Epoch 33: Iteration 20 with loss 2.6370701789855957
# Epoch 33: Iteration 40 with loss 5.41854190826416
# Epoch 33: Iteration 60 with loss 3.7728970050811768
# Epoch 33: Iteration 80 with loss 1.90139639377594
# Epoch 33: Iteration 100 with loss 1.292708396911621
# Epoch 33: Iteration 120 with loss 1.566636323928833
# Epoch 33: Iteration 140 with loss 1.2033774852752686
# Epoch 33: Iteration 160 with loss 2.631654739379883
# Epoch 33: Iteration 180 with loss 2.2086024284362793
# Epoch 33 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 65.50763520384946
# Starting Training
# Epoch 34: Iteration 20 with loss 2.132833480834961
# Epoch 34: Iteration 40 with loss 1.3247058391571045
# Epoch 34: Iteration 60 with loss 2.505509376525879
# Epoch 34: Iteration 80 with loss 1.3799669742584229
# Epoch 34: Iteration 100 with loss 0.9625417590141296
# Epoch 34: Iteration 120 with loss 0.8096500635147095
# Epoch 34: Iteration 140 with loss 1.3557941913604736
# Epoch 34: Iteration 160 with loss 1.5014421939849854
# Epoch 34: Iteration 180 with loss 1.9455921649932861
# Epoch 34 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 66.38986826849643
# Starting Training
# Epoch 35: Iteration 20 with loss 1.6095635890960693
# Epoch 35: Iteration 40 with loss 11.180802345275879
# Epoch 35: Iteration 60 with loss 7.8864593505859375
# Epoch 35: Iteration 80 with loss 3.8601772785186768
# Epoch 35: Iteration 100 with loss 3.035061836242676
# Epoch 35: Iteration 120 with loss 1.8417792320251465
# Epoch 35: Iteration 140 with loss 1.5348478555679321
# Epoch 35: Iteration 160 with loss 1.535133957862854
# Epoch 35: Iteration 180 with loss 1.4344619512557983
# Epoch 35 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 66.4110386963765
# Starting Training
# Epoch 36: Iteration 20 with loss 1.1519150733947754
# Epoch 36: Iteration 40 with loss 1.993999719619751
# Epoch 36: Iteration 60 with loss 1.2791574001312256
# Epoch 36: Iteration 80 with loss 1.2117029428482056
# Epoch 36: Iteration 100 with loss 1.5624594688415527
# Epoch 36: Iteration 120 with loss 1.677446722984314
# Epoch 36: Iteration 140 with loss 2.269148349761963
# Epoch 36: Iteration 160 with loss 2.109532117843628
# Epoch 36: Iteration 180 with loss 1.3365991115570068
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.9 minutes
# iter 20 of Expectation completed in a total of  7.3 minutes
# iter 30 of Expectation completed in a total of  10.6 minutes
# iter 40 of Expectation completed in a total of  13.4 minutes
# iter 50 of Expectation completed in a total of  16.2 minutes
# iter 60 of Expectation completed in a total of  19.6 minutes
# iter 70 of Expectation completed in a total of  23.0 minutes
# Expectation step finished, posterior frame-wise accuracy  79.94%, boundary mse  0.00
# Epoch 36 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 65.89068145035237
# Starting Training
# Epoch 37: Iteration 20 with loss 1.2392799854278564
# Epoch 37: Iteration 40 with loss 1.4431357383728027
# Epoch 37: Iteration 60 with loss 0.7851151823997498
# Epoch 37: Iteration 80 with loss 1.1786212921142578
# Epoch 37: Iteration 100 with loss 1.2986600399017334
# Epoch 37: Iteration 120 with loss 1.239327311515808
# Epoch 37: Iteration 140 with loss 2.1718809604644775
# Epoch 37: Iteration 160 with loss 1.0531635284423828
# Epoch 37: Iteration 180 with loss 1.4128220081329346
# Epoch 37 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 65.75238117850034
# Starting Training
# Epoch 38: Iteration 20 with loss 2.0022716522216797
# Epoch 38: Iteration 40 with loss 1.4021201133728027
# Epoch 38: Iteration 60 with loss 0.8810829520225525
# Epoch 38: Iteration 80 with loss 0.7349691987037659
# Epoch 38: Iteration 100 with loss 1.8015528917312622
# Epoch 38: Iteration 120 with loss 0.6428951025009155
# Epoch 38: Iteration 140 with loss 0.9419896006584167
# Epoch 38: Iteration 160 with loss 1.2187883853912354
# Epoch 38: Iteration 180 with loss 0.8444226980209351
# Epoch 38 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.95661051556917
# Starting Training
# Epoch 39: Iteration 20 with loss 0.8414249420166016
# Epoch 39: Iteration 40 with loss 1.0195525884628296
# Epoch 39: Iteration 60 with loss 1.8823844194412231
# Epoch 39: Iteration 80 with loss 1.863364577293396
# Epoch 39: Iteration 100 with loss 1.9474754333496094
# Epoch 39: Iteration 120 with loss 1.093495488166809
# Epoch 39: Iteration 140 with loss 1.5075066089630127
# Epoch 39: Iteration 160 with loss 0.7276022434234619
# Epoch 39: Iteration 180 with loss 1.1569093465805054
# Epoch 39 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 65.28425751154481
# Starting Training
# Epoch 40: Iteration 20 with loss 0.966759204864502
# Epoch 40: Iteration 40 with loss 1.0238419771194458
# Epoch 40: Iteration 60 with loss 0.5241172313690186
# Epoch 40: Iteration 80 with loss 1.1334779262542725
# Epoch 40: Iteration 100 with loss 1.9233431816101074
# Epoch 40: Iteration 120 with loss 2.5904903411865234
# Epoch 40: Iteration 140 with loss 2.063493490219116
# Epoch 40: Iteration 160 with loss 1.2196705341339111
# Epoch 40: Iteration 180 with loss 1.3233022689819336
# Epoch 40 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.53241054010311
# Starting Training
# Epoch 41: Iteration 20 with loss 0.8040460348129272
# Epoch 41: Iteration 40 with loss 0.41435766220092773
# Epoch 41: Iteration 60 with loss 0.8436801433563232
# Epoch 41: Iteration 80 with loss 0.6815159320831299
# Epoch 41: Iteration 100 with loss 1.1372425556182861
# Epoch 41: Iteration 120 with loss 0.9787801504135132
# Epoch 41: Iteration 140 with loss 0.7571685314178467
# Epoch 41: Iteration 160 with loss 1.5000829696655273
# Epoch 41: Iteration 180 with loss 1.5072053670883179
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.9 minutes
# iter 20 of Expectation completed in a total of  6.7 minutes
# iter 30 of Expectation completed in a total of  10.0 minutes
# iter 40 of Expectation completed in a total of  13.0 minutes
# iter 50 of Expectation completed in a total of  16.1 minutes
# iter 60 of Expectation completed in a total of  19.8 minutes
# iter 70 of Expectation completed in a total of  22.9 minutes
# Expectation step finished, posterior frame-wise accuracy  79.53%, boundary mse  0.00
# Epoch 41 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 65.37902980083969
# Starting Training
# Epoch 42: Iteration 20 with loss 0.7276173830032349
# Epoch 42: Iteration 40 with loss 0.33958497643470764
# Epoch 42: Iteration 60 with loss 0.724798321723938
# Epoch 42: Iteration 80 with loss 0.8104395866394043
# Epoch 42: Iteration 100 with loss 0.9038144946098328
# Epoch 42: Iteration 120 with loss 1.0966205596923828
# Epoch 42: Iteration 140 with loss 1.1700212955474854
# Epoch 42: Iteration 160 with loss 0.8178926706314087
# Epoch 42: Iteration 180 with loss 0.5177412033081055
# Epoch 42 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 65.06028625584165
# Starting Training
# Epoch 43: Iteration 20 with loss 0.3814352750778198
# Epoch 43: Iteration 40 with loss 0.5183833241462708
# Epoch 43: Iteration 60 with loss 0.615608811378479
# Epoch 43: Iteration 80 with loss 0.6014406085014343
# Epoch 43: Iteration 100 with loss 0.439573734998703
# Epoch 43: Iteration 120 with loss 0.6515271067619324
# Epoch 43: Iteration 140 with loss 1.2623711824417114
# Epoch 43: Iteration 160 with loss 0.8210649490356445
# Epoch 43: Iteration 180 with loss 0.5939310789108276
# Epoch 43 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.03579583001927
# Starting Training
# Epoch 44: Iteration 20 with loss 0.6447058320045471
# Epoch 44: Iteration 40 with loss 0.5559074878692627
# Epoch 44: Iteration 60 with loss 0.4864710867404938
# Epoch 44: Iteration 80 with loss 0.6162841320037842
# Epoch 44: Iteration 100 with loss 0.642370343208313
# Epoch 44: Iteration 120 with loss 0.5997836589813232
# Epoch 44: Iteration 140 with loss 0.7751247882843018
# Epoch 44: Iteration 160 with loss 1.1727545261383057
# Epoch 44: Iteration 180 with loss 1.6771438121795654
# Epoch 44 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.89837403199702
# Starting Training
# Epoch 45: Iteration 20 with loss 1.1511088609695435
# Epoch 45: Iteration 40 with loss 0.48695164918899536
# Epoch 45: Iteration 60 with loss 1.1090188026428223
# Epoch 45: Iteration 80 with loss 1.903956651687622
# Epoch 45: Iteration 100 with loss 1.3994114398956299
# Epoch 45: Iteration 120 with loss 1.069946527481079
# Epoch 45: Iteration 140 with loss 1.0569477081298828
# Epoch 45: Iteration 160 with loss 2.122476816177368
# Epoch 45: Iteration 180 with loss 1.2021355628967285
# Epoch 45 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.69959756401582
# Starting Training
# Epoch 46: Iteration 20 with loss 0.9486782550811768
# Epoch 46: Iteration 40 with loss 1.1563764810562134
# Epoch 46: Iteration 60 with loss 0.6857107877731323
# Epoch 46: Iteration 80 with loss 0.501617968082428
# Epoch 46: Iteration 100 with loss 0.5217311978340149
# Epoch 46: Iteration 120 with loss 1.0609130859375
# Epoch 46: Iteration 140 with loss 0.7607449293136597
# Epoch 46: Iteration 160 with loss 0.4490997791290283
# Epoch 46: Iteration 180 with loss 0.5714302062988281
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  6.4 minutes
# iter 30 of Expectation completed in a total of  9.8 minutes
# iter 40 of Expectation completed in a total of  12.6 minutes
# iter 50 of Expectation completed in a total of  15.8 minutes
# iter 60 of Expectation completed in a total of  19.1 minutes
# iter 70 of Expectation completed in a total of  21.8 minutes
# Expectation step finished, posterior frame-wise accuracy  79.29%, boundary mse  0.00
# Epoch 46 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.16895188575091
# Starting Training
# Epoch 47: Iteration 20 with loss 0.6025628447532654
# Epoch 47: Iteration 40 with loss 3.6015188694000244
# Epoch 47: Iteration 60 with loss 1.2388461828231812
# Epoch 47: Iteration 80 with loss 2.645750045776367
# Epoch 47: Iteration 100 with loss 1.2120243310928345
# Epoch 47: Iteration 120 with loss 3.3089447021484375
# Epoch 47: Iteration 140 with loss 0.8509032726287842
# Epoch 47: Iteration 160 with loss 0.8335622549057007
# Epoch 47: Iteration 180 with loss 1.2447420358657837
# Epoch 47 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.38667885450178
# Starting Training
# Epoch 48: Iteration 20 with loss 1.679502248764038
# Epoch 48: Iteration 40 with loss 0.7165236473083496
# Epoch 48: Iteration 60 with loss 0.8638864755630493
# Epoch 48: Iteration 80 with loss 1.0058194398880005
# Epoch 48: Iteration 100 with loss 0.7348284125328064
# Epoch 48: Iteration 120 with loss 0.5481448173522949
# Epoch 48: Iteration 140 with loss 0.6533966064453125
# Epoch 48: Iteration 160 with loss 0.6302852630615234
# Epoch 48: Iteration 180 with loss 0.37815016508102417
# Epoch 48 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 65.36201431674917
# Starting Training
# Epoch 49: Iteration 20 with loss 0.5297068357467651
# Epoch 49: Iteration 40 with loss 0.416403204202652
# Epoch 49: Iteration 60 with loss 0.42204880714416504
# Epoch 49: Iteration 80 with loss 0.6833943128585815
# Epoch 49: Iteration 100 with loss 1.0253098011016846
# Epoch 49: Iteration 120 with loss 0.9305480718612671
# Epoch 49: Iteration 140 with loss 1.7106891870498657
# Epoch 49: Iteration 160 with loss 0.7265011668205261
# Epoch 49: Iteration 180 with loss 0.5502797365188599
# Epoch 49 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.41552207857988
# Starting Training
# Epoch 50: Iteration 20 with loss 0.7545819878578186
# Epoch 50: Iteration 40 with loss 0.6537197828292847
# Epoch 50: Iteration 60 with loss 0.8224629759788513
# Epoch 50: Iteration 80 with loss 0.657729983329773
# Epoch 50: Iteration 100 with loss 1.2668230533599854
# Epoch 50: Iteration 120 with loss 1.1072192192077637
# Epoch 50: Iteration 140 with loss 1.1492961645126343
# Epoch 50: Iteration 160 with loss 0.6303768157958984
# Epoch 50: Iteration 180 with loss 6.461864471435547
# Epoch 50 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.89245818345857
# Starting Training
# Epoch 51: Iteration 20 with loss 1.1882686614990234
# Epoch 51: Iteration 40 with loss 1.4721462726593018
# Epoch 51: Iteration 60 with loss 0.5729708075523376
# Epoch 51: Iteration 80 with loss 0.8798316717147827
# Epoch 51: Iteration 100 with loss 0.566657543182373
# Epoch 51: Iteration 120 with loss 0.5856693983078003
# Epoch 51: Iteration 140 with loss 0.5163483619689941
# Epoch 51: Iteration 160 with loss 0.6261053681373596
# Epoch 51: Iteration 180 with loss 1.5823124647140503
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  6.6 minutes
# iter 30 of Expectation completed in a total of  9.8 minutes
# iter 40 of Expectation completed in a total of  12.8 minutes
# iter 50 of Expectation completed in a total of  15.8 minutes
# iter 60 of Expectation completed in a total of  19.2 minutes
# iter 70 of Expectation completed in a total of  22.7 minutes
# Expectation step finished, posterior frame-wise accuracy  77.56%, boundary mse  0.00
# Epoch 51 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.41497204316393
# Starting Training
# Epoch 52: Iteration 20 with loss 0.5829465389251709
# Epoch 52: Iteration 40 with loss 1.9946892261505127
# Epoch 52: Iteration 60 with loss 1.2779184579849243
# Epoch 52: Iteration 80 with loss 0.9370297193527222
# Epoch 52: Iteration 100 with loss 0.5125011205673218
# Epoch 52: Iteration 120 with loss 0.8353093862533569
# Epoch 52: Iteration 140 with loss 2.1632132530212402
# Epoch 52: Iteration 160 with loss 2.59407377243042
# Epoch 52: Iteration 180 with loss 0.5852483510971069
# Epoch 52 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.37263118740379
# Starting Training
# Epoch 53: Iteration 20 with loss 0.743485152721405
# Epoch 53: Iteration 40 with loss 0.5331383943557739
# Epoch 53: Iteration 60 with loss 0.6214736104011536
# Epoch 53: Iteration 80 with loss 0.49410825967788696
# Epoch 53: Iteration 100 with loss 0.5807240605354309
# Epoch 53: Iteration 120 with loss 0.9777879118919373
# Epoch 53: Iteration 140 with loss 1.3409432172775269
# Epoch 53: Iteration 160 with loss 1.0979427099227905
# Epoch 53: Iteration 180 with loss 1.4563652276992798
# Epoch 53 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.72125075679333
# Starting Training
# Epoch 54: Iteration 20 with loss 0.43272942304611206
# Epoch 54: Iteration 40 with loss 0.3890336751937866
# Epoch 54: Iteration 60 with loss 0.4714790880680084
# Epoch 54: Iteration 80 with loss 0.7013871669769287
# Epoch 54: Iteration 100 with loss 0.5485790967941284
# Epoch 54: Iteration 120 with loss 0.6451578736305237
# Epoch 54: Iteration 140 with loss 1.0785088539123535
# Epoch 54: Iteration 160 with loss 0.53211510181427
# Epoch 54: Iteration 180 with loss 2.569272041320801
# Epoch 54 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.09622849816589
# Starting Training
# Epoch 55: Iteration 20 with loss 0.6026003360748291
# Epoch 55: Iteration 40 with loss 0.7247301340103149
# Epoch 55: Iteration 60 with loss 0.5451436042785645
# Epoch 55: Iteration 80 with loss 0.44942939281463623
# Epoch 55: Iteration 100 with loss 0.33421194553375244
# Epoch 55: Iteration 120 with loss 1.8324283361434937
# Epoch 55: Iteration 140 with loss 2.0425148010253906
# Epoch 55: Iteration 160 with loss 1.2377090454101562
# Epoch 55: Iteration 180 with loss 0.6584231853485107
# Epoch 55 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.20896201589959
# Starting Training
# Epoch 56: Iteration 20 with loss 0.8013015389442444
# Epoch 56: Iteration 40 with loss 0.6213639974594116
# Epoch 56: Iteration 60 with loss 0.47380685806274414
# Epoch 56: Iteration 80 with loss 0.55172199010849
# Epoch 56: Iteration 100 with loss 0.7518867254257202
# Epoch 56: Iteration 120 with loss 0.6400764584541321
# Epoch 56: Iteration 140 with loss 0.4523312747478485
# Epoch 56: Iteration 160 with loss 0.7515527606010437
# Epoch 56: Iteration 180 with loss 0.5647701025009155
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  6.6 minutes
# iter 30 of Expectation completed in a total of  9.5 minutes
# iter 40 of Expectation completed in a total of  12.4 minutes
# iter 50 of Expectation completed in a total of  15.5 minutes
# iter 60 of Expectation completed in a total of  19.6 minutes
# iter 70 of Expectation completed in a total of  22.7 minutes
# Expectation step finished, posterior frame-wise accuracy  77.50%, boundary mse  0.00
# Epoch 56 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.111419764078335
# Starting Training
# Epoch 57: Iteration 20 with loss 0.6964112520217896
# Epoch 57: Iteration 40 with loss 0.6631460785865784
# Epoch 57: Iteration 60 with loss 0.8602275848388672
# Epoch 57: Iteration 80 with loss 0.29097098112106323
# Epoch 57: Iteration 100 with loss 0.32940757274627686
# Epoch 57: Iteration 120 with loss 1.2525410652160645
# Epoch 57: Iteration 140 with loss 0.4268041253089905
# Epoch 57: Iteration 160 with loss 0.9089115858078003
# Epoch 57: Iteration 180 with loss 0.7238360047340393
# Epoch 57 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.00849191368796
# Starting Training
# Epoch 58: Iteration 20 with loss 0.39276403188705444
# Epoch 58: Iteration 40 with loss 0.5877872109413147
# Epoch 58: Iteration 60 with loss 0.8370596170425415
# Epoch 58: Iteration 80 with loss 0.45396560430526733
# Epoch 58: Iteration 100 with loss 0.49494192004203796
# Epoch 58: Iteration 120 with loss 0.8206169605255127
# Epoch 58: Iteration 140 with loss 0.584732711315155
# Epoch 58: Iteration 160 with loss 0.5060725212097168
# Epoch 58: Iteration 180 with loss 0.9664599895477295
# Epoch 58 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.098207042827575
# Starting Training
# Epoch 59: Iteration 20 with loss 0.60541832447052
# Epoch 59: Iteration 40 with loss 0.6020525693893433
# Epoch 59: Iteration 60 with loss 0.826797366142273
# Epoch 59: Iteration 80 with loss 0.5170282125473022
# Epoch 59: Iteration 100 with loss 1.2371954917907715
# Epoch 59: Iteration 120 with loss 0.9181970953941345
# Epoch 59: Iteration 140 with loss 0.7612593770027161
# Epoch 59: Iteration 160 with loss 0.3203670382499695
# Epoch 59: Iteration 180 with loss 1.3917818069458008
# Epoch 59 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.72560355504905
# Starting Training
# Epoch 60: Iteration 20 with loss 0.7643869519233704
# Epoch 60: Iteration 40 with loss 0.46357908844947815
# Epoch 60: Iteration 60 with loss 0.3755332827568054
# Epoch 60: Iteration 80 with loss 0.5458253622055054
# Epoch 60: Iteration 100 with loss 0.37277472019195557
# Epoch 60: Iteration 120 with loss 0.7685330510139465
# Epoch 60: Iteration 140 with loss 0.4699382781982422
# Epoch 60: Iteration 160 with loss 0.4915459156036377
# Epoch 60: Iteration 180 with loss 0.9584547281265259
# Epoch 60 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.573651325031356
# Starting Training
# Epoch 61: Iteration 20 with loss 0.4191286563873291
# Epoch 61: Iteration 40 with loss 2.0305769443511963
# Epoch 61: Iteration 60 with loss 0.5494455695152283
# Epoch 61: Iteration 80 with loss 1.2127141952514648
# Epoch 61: Iteration 100 with loss 0.9256026744842529
# Epoch 61: Iteration 120 with loss 0.6800345778465271
# Epoch 61: Iteration 140 with loss 1.1118245124816895
# Epoch 61: Iteration 160 with loss 0.6786419749259949
# Epoch 61: Iteration 180 with loss 0.8843700885772705
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.8 minutes
# iter 20 of Expectation completed in a total of  6.1 minutes
# iter 30 of Expectation completed in a total of  9.7 minutes
# iter 40 of Expectation completed in a total of  13.1 minutes
# iter 50 of Expectation completed in a total of  16.1 minutes
# iter 60 of Expectation completed in a total of  19.6 minutes
# iter 70 of Expectation completed in a total of  23.1 minutes
# Expectation step finished, posterior frame-wise accuracy  77.16%, boundary mse  0.00
# Epoch 61 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.17908599150809
# Starting Training
# Epoch 62: Iteration 20 with loss 0.4145604074001312
# Epoch 62: Iteration 40 with loss 0.5906035304069519
# Epoch 62: Iteration 60 with loss 0.46675607562065125
# Epoch 62: Iteration 80 with loss 0.8086108565330505
# Epoch 62: Iteration 100 with loss 0.5134670734405518
# Epoch 62: Iteration 120 with loss 0.6713782548904419
# Epoch 62: Iteration 140 with loss 0.557614266872406
# Epoch 62: Iteration 160 with loss 0.5568332672119141
# Epoch 62: Iteration 180 with loss 1.9672114849090576
# Epoch 62 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.41532422411371
# Starting Training
# Epoch 63: Iteration 20 with loss 1.3137223720550537
# Epoch 63: Iteration 40 with loss 1.452265977859497
# Epoch 63: Iteration 60 with loss 1.093142032623291
# Epoch 63: Iteration 80 with loss 0.7394229769706726
# Epoch 63: Iteration 100 with loss 0.8561142086982727
# Epoch 63: Iteration 120 with loss 0.8012918829917908
# Epoch 63: Iteration 140 with loss 0.6191647052764893
# Epoch 63: Iteration 160 with loss 0.5919846296310425
# Epoch 63: Iteration 180 with loss 0.7935488820075989
# Epoch 63 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.66284016129096
# Starting Training
# Epoch 64: Iteration 20 with loss 0.49976998567581177
# Epoch 64: Iteration 40 with loss 0.411203533411026
# Epoch 64: Iteration 60 with loss 0.6502416729927063
# Epoch 64: Iteration 80 with loss 0.5965332984924316
# Epoch 64: Iteration 100 with loss 0.5115902423858643
# Epoch 64: Iteration 120 with loss 0.4454401731491089
# Epoch 64: Iteration 140 with loss 0.4448252320289612
# Epoch 64: Iteration 160 with loss 0.6807401180267334
# Epoch 64: Iteration 180 with loss 0.8683866858482361
# Epoch 64 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.29676587089601
# Starting Training
# Epoch 65: Iteration 20 with loss 0.4734300971031189
# Epoch 65: Iteration 40 with loss 0.9570344686508179
# Epoch 65: Iteration 60 with loss 0.4986291229724884
# Epoch 65: Iteration 80 with loss 0.27249062061309814
# Epoch 65: Iteration 100 with loss 0.5056638121604919
# Epoch 65: Iteration 120 with loss 0.36920517683029175
# Epoch 65: Iteration 140 with loss 0.4730425775051117
# Epoch 65: Iteration 160 with loss 0.5534621477127075
# Epoch 65: Iteration 180 with loss 0.3717421591281891
# Epoch 65 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.3700590793436
# Starting Training
# Epoch 66: Iteration 20 with loss 0.5675675272941589
# Epoch 66: Iteration 40 with loss 0.4758897125720978
# Epoch 66: Iteration 60 with loss 0.38192272186279297
# Epoch 66: Iteration 80 with loss 0.3255764842033386
# Epoch 66: Iteration 100 with loss 0.3149265646934509
# Epoch 66: Iteration 120 with loss 0.34125733375549316
# Epoch 66: Iteration 140 with loss 0.36210739612579346
# Epoch 66: Iteration 160 with loss 0.3700813949108124
# Epoch 66: Iteration 180 with loss 0.40124037861824036
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.1 minutes
# iter 20 of Expectation completed in a total of  5.7 minutes
# iter 30 of Expectation completed in a total of  9.2 minutes
# iter 40 of Expectation completed in a total of  12.7 minutes
# iter 50 of Expectation completed in a total of  16.0 minutes
# iter 60 of Expectation completed in a total of  19.5 minutes
# iter 70 of Expectation completed in a total of  22.6 minutes
# Expectation step finished, posterior frame-wise accuracy  77.64%, boundary mse  0.00
# Epoch 66 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.54927169771003
# Starting Training
# Epoch 67: Iteration 20 with loss 0.5950473546981812
# Epoch 67: Iteration 40 with loss 0.37840884923934937
# Epoch 67: Iteration 60 with loss 0.6397538185119629
# Epoch 67: Iteration 80 with loss 0.5324975848197937
# Epoch 67: Iteration 100 with loss 0.8682762384414673
# Epoch 67: Iteration 120 with loss 4.840798377990723
# Epoch 67: Iteration 140 with loss 2.1660521030426025
# Epoch 67: Iteration 160 with loss 2.7382113933563232
# Epoch 67: Iteration 180 with loss 2.1254336833953857
# Epoch 67 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.14740553438513
# Starting Training
# Epoch 68: Iteration 20 with loss 0.957118809223175
# Epoch 68: Iteration 40 with loss 1.3854598999023438
# Epoch 68: Iteration 60 with loss 1.377335786819458
# Epoch 68: Iteration 80 with loss 0.8697494268417358
# Epoch 68: Iteration 100 with loss 1.2976433038711548
# Epoch 68: Iteration 120 with loss 1.8835444450378418
# Epoch 68: Iteration 140 with loss 0.6100281476974487
# Epoch 68: Iteration 160 with loss 1.2976973056793213
# Epoch 68: Iteration 180 with loss 0.7465185523033142
# Epoch 68 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.54052257321605
# Starting Training
# Epoch 69: Iteration 20 with loss 0.44073545932769775
# Epoch 69: Iteration 40 with loss 2.480901002883911
# Epoch 69: Iteration 60 with loss 0.827759861946106
# Epoch 69: Iteration 80 with loss 0.40355217456817627
# Epoch 69: Iteration 100 with loss 0.5801969766616821
# Epoch 69: Iteration 120 with loss 0.6779841184616089
# Epoch 69: Iteration 140 with loss 0.6367185711860657
# Epoch 69: Iteration 160 with loss 0.4973917603492737
# Epoch 69: Iteration 180 with loss 0.44651275873184204
# Epoch 69 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.847042669294176
# Starting Training
# Epoch 70: Iteration 20 with loss 0.391867458820343
# Epoch 70: Iteration 40 with loss 0.42079785466194153
# Epoch 70: Iteration 60 with loss 0.37573373317718506
# Epoch 70: Iteration 80 with loss 0.3519022464752197
# Epoch 70: Iteration 100 with loss 0.5836703181266785
# Epoch 70: Iteration 120 with loss 0.4354594349861145
# Epoch 70: Iteration 140 with loss 0.34028351306915283
# Epoch 70: Iteration 160 with loss 0.4994666576385498
# Epoch 70: Iteration 180 with loss 0.39279472827911377
# Epoch 70 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.64725318644618
# Starting Training
# Epoch 71: Iteration 20 with loss 0.27487465739250183
# Epoch 71: Iteration 40 with loss 0.26823216676712036
# Epoch 71: Iteration 60 with loss 0.46521976590156555
# Epoch 71: Iteration 80 with loss 0.33456429839134216
# Epoch 71: Iteration 100 with loss 0.4589040279388428
# Epoch 71: Iteration 120 with loss 0.38524723052978516
# Epoch 71: Iteration 140 with loss 0.28188449144363403
# Epoch 71: Iteration 160 with loss 0.21000052988529205
# Epoch 71: Iteration 180 with loss 0.35833513736724854
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.8 minutes
# iter 20 of Expectation completed in a total of  6.7 minutes
# ...
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-34183:
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-14-ff1e769c794e>", line 87, in prob_vals_per_segment
#     cumm_b2_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=0), dim=0)
# KeyboardInterrupt
# Process ForkPoolWorker-34200:
# Process ForkPoolWorker-34197:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Process ForkPoolWorker-34199:
# Process ForkPoolWorker-34198:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-27-da378ef86060>", line 42, in <module>
#     perform_expectation(model, trainloder_expectation)
#   File "<ipython-input-15-e151fbc59213>", line 66, in perform_expectation
#     calculate_element_probb(prob, item_1, item_4, item_2)
#   File "<ipython-input-15-e151fbc59213>", line 42, in calculate_element_probb
#     pool.join()  # postpones the execution of next line of code until all processes in the queue are done.
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 556, in join
#     self._worker_handler.join()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/threading.py", line 1032, in join
#     self._wait_for_tstate_lock()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/threading.py", line 1048, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {val_acc}")
# Out:
# Validation:: Epoch 105, Probability Accuracy 61.02425300046298

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {best_val_acc}")
# Out:
# Validation:: Epoch 105, Probability Accuracy 63.70656599831428

# %%
torch.save(model.state_dict(),
"/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-speed/final-em-maximized.wt")

# %%
config.output_dir
# Out:
# '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split1/'

# %%
model.load_state_dict(torch.load(config.output_dir + "ms-tcn-emmax-best-model.wt"))
# model.load_state_dict(torch.load(config.output_dir + "ms-tcn-initial-15-epochs.wt"))
# Out:
# <All keys matched successfully>
