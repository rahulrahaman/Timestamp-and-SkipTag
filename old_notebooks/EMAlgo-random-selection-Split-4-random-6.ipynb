# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
import os, sys
import glob
import numpy as np
import torch
import pandas as pd
import random
import torch.nn as nn
import pickle
import torch.nn.functional as F
import matplotlib.pyplot as plt
import multiprocessing as mp
from time import time
from utils import get_all_scores

# %%
from mstcn_model import *
from utility.adaptive_data_loader import Breakfast, collate_fn_override
from utility.adaptive_data_loader import BreakfastWithWeights, collate_fn_override_wtd
from utils import calculate_mof, dotdict

# %%
os.environ["WANDB_API_KEY"] = "992b3b1371ba79f48484cfca522b3786d7fa52c2"
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dipika_singhania (use `wandb login --relogin` to force relogin)
# True

# %%
seed = 42

# Ensure deterministic behavior
def set_seed():
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
set_seed()

# Device configuration
os.environ['CUDA_VISIBLE_DEVICES']='4'
# os.environ['CUDA_LAUNCH_BLOCKING']='6'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config = dotdict(
    temp=1,
    epochs=500,
    num_class=48,
    batch_size=8,
    learning_rate=5e-4,
    weight_decay=0,
    dataset="Breakfast",
    architecture="unet-ensemble",
    features_file_name="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/",
    chunk_size=1,
    max_frames_per_video=1200,
    feature_size=2048,
    ground_truth_files_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/",
    label_id_csv="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv",
    gamma=0.1,
    step_size=500,
    split=4,
#     output_dir="/mnt/data/ar-datasets/dipika/breakfast/ms_tcn/data/breakfast/results/unsuper-finetune-split2-0.05-data-llr/",
    output_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select6-temp1-exp4/",
    project_name="breakfast-split-1",
    train_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split{}.bundle",
    test_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split{}.bundle",
    all_files="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt",
    cutoff=8,
    data_per = 0.2,
    budget=40,
    semi_supervised_split="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split{}_amt{}.bundle")

config.train_split_file = config.train_split_file.format(config.split)
config.semi_supervised_split = config.semi_supervised_split.format(config.split, config.data_per)
config.test_split_file = config.test_split_file.format(config.split)

if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)

config.output_dir = config.output_dir + f"split{config.split}"
if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)
config.output_dir = config.output_dir + "/"
if not os.path.exists(os.path.join(config.output_dir, "posterior_weights")):
    os.mkdir(os.path.join(config.output_dir, "posterior_weights"))
print(config)
# Out:
# {'temp': 1, 'epochs': 500, 'num_class': 48, 'batch_size': 8, 'learning_rate': 0.0005, 'weight_decay': 0, 'dataset': 'Breakfast', 'architecture': 'unet-ensemble', 'features_file_name': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/', 'chunk_size': 1, 'max_frames_per_video': 1200, 'feature_size': 2048, 'ground_truth_files_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/', 'label_id_csv': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv', 'gamma': 0.1, 'step_size': 500, 'split': 4, 'output_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select6-temp1-exp4/split4/', 'project_name': 'breakfast-split-1', 'train_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split4.bundle', 'test_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split4.bundle', 'all_files': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt', 'cutoff': 8, 'data_per': 0.2, 'budget': 40, 'semi_supervised_split': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split4_amt0.2.bundle'}

# %%
traindataset = BreakfastWithWeights(config, fold='train', fold_file_name=config.train_split_file)
testdataset = Breakfast(config, fold='test', fold_file_name=config.test_split_file)
# Out:
# Number of videos logged in train fold is 1136
# Number of videos not found in train fold is 0
# Number of videos logged in test fold is 576
# Number of videos not found in test fold is 0

# %%
def _init_fn(worker_id):
    np.random.seed(int(seed))
trainloader = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=config.batch_size, 
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)
testloader = torch.utils.data.DataLoader(dataset=testdataset,
                                          batch_size=config.batch_size, 
                                          shuffle=False,
                                          pin_memory=True, num_workers=4,
                                          collate_fn=lambda x: collate_fn_override(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

trainloder_expectation = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=20,
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

# %%
df = pd.read_csv(config.label_id_csv)
label_id_to_label_name = {}
label_name_to_label_id_dict = {}
for i, ele in df.iterrows():
    label_id_to_label_name[ele.label_id] = ele.label_name
    label_name_to_label_id_dict[ele.label_name] = ele.label_id

# %%
# selected_frames_dict = pickle.load(open("data/breakfast_len_assum_annotations.pkl", 'rb'))
# loaded_vidid_selected_frames
boundary_frames_dict = pickle.load(open("data/breakfast_boundary_annotations.pkl", "rb"))
num_boundary = 0
for key in boundary_frames_dict.keys():
    num_boundary += len(boundary_frames_dict[key])
# video_id_boundary_frames

# %%
selected_frames_dict = pickle.load(open("data/breakfast_random6frame_selection.pkl", "rb"))
# print(selected_frames_dict)

# %%
loaded_mean_var_actions = pickle.load(open("data/breakfast_meanvar_actions.pkl", "rb"))
mat_poisson = pickle.load(open("data/breakfast_possion_class_dict.pkl", "rb"))

def get_possion_prob(minlen, maxlen, cur_class):
    prob = mat_poisson[label_id_to_label_name[cur_class]][minlen:maxlen]
    return torch.tensor(prob)

def get_poisson_logcdf(minlen, cur_class):
    return np.log(np.sum(np.exp(mat_poisson[label_id_to_label_name[cur_class]][minlen:])) + 1e-20)

def get_possion_prob_for_all_class(minlen, maxlen):
    ele_list = []
    for i in range(config.num_class):
        prob = mat_poisson[label_id_to_label_name[i]][minlen:maxlen]
        ele_list.append(torch.tensor(prob))
    return torch.stack(ele_list, dim=-1)

# %%
def validate(model, dataloader, best_val_acc=None):
    model.eval()
    print("Calculating Validation Data Accuracy")
    correct = 0.0
    total = 0.0
    vidcount = 0
    all_scores = []
    for i, item in enumerate(testloader):
        with torch.no_grad():
            item_0 = item[0].to(device)
            item_1 = item[1].to(device)
            item_2 = item[2].to(device)
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            pred = torch.argmax(predictions[-1], dim=1)
            correct += float(torch.sum((pred == item_2) * src_mask).item())
            total += float(torch.sum(src_mask).item())
            for p, l, c in zip(pred, item_2, item_1):
                all_scores.append(get_all_scores(p[:c].detach().cpu().numpy(), 
                                                 l[:c].detach().cpu().numpy(), ['SIL']))
            
    final_scores = np.mean(np.array(all_scores), axis=0)
    val_acc = correct * 100.0 / total
    if best_val_acc is not None and val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-best-model.wt")
    torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-last-model.wt")
    print(f"Validation:: Probability Accuracy {val_acc}")
    print(f"Other scores:: Edit {final_scores[3]}, F1@[10:25:50] {final_scores[:3]}")
    _ = model.train()
    return val_acc, best_val_acc

# %%
def prob_vals_per_segment(selected_frames, cur_vid_feat, labels, first_ele_flag, last_ele_flag, vidid, gt_labels):
    prob_each_segment = []
    LOW_VAL = -10000000
    num_frames = len(cur_vid_feat)
    log_probs = torch.log(cur_vid_feat + 1e-8)
    cumsum_feat = torch.cumsum(log_probs, dim=0)
    prev_boundary = 0
    per_frame_weights = torch.zeros((num_frames, config.num_class))
    start_time = time()
    boundary_error = 0
    current_boundary = 0
    labels = [config.num_class-1] + labels if selected_frames[0] != 0 else labels
    labels = labels + [config.num_class-1] if selected_frames[-1] != num_frames-1 else labels
    selected_frames = [0] + selected_frames if selected_frames[0] != 0 else selected_frames
    selected_frames = selected_frames + [num_frames-1] if selected_frames[-1] != num_frames-1 else selected_frames

    for i, cur_ele in enumerate(selected_frames[:-1]):
        next_ele = selected_frames[i + 1]
        label_cur_ele = labels[i]
        label_next_ele = labels[i + 1]
        if cur_ele == next_ele-1:
            per_frame_weights[cur_ele, label_cur_ele] = 1.0
            if label_cur_ele != label_next_ele:
                prev_boundary = cur_ele
            continue
        
        seg_len = next_ele - cur_ele
        mat_b1_b2_c_prob = LOW_VAL * torch.ones((seg_len, seg_len, config.num_class), dtype=cumsum_feat.dtype)
        b1_prior = get_possion_prob(cur_ele-prev_boundary, next_ele-prev_boundary, label_cur_ele)
        
        # find dummy label where we will keep the diagonal (b1=b2) probabilities, later we will distribute among
        # rest of the classes after the softmax by dividing by (num_class - 2)
        dummy_label = 0
        while True:
            if dummy_label != label_cur_ele and dummy_label != label_next_ele:
                break
            else:
                dummy_label += 1
        
        for b1 in range(cur_ele, next_ele - 1):

            cur_boundary_len = b1 - prev_boundary
            strt_index = cumsum_feat[cur_ele - 1, label_cur_ele] if cur_ele > 0 else 0
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            right_sum = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1+1:next_ele, label_next_ele] # mid_seg_len
            mid_sum = (cumsum_feat[b1+1:next_ele, :] - cumsum_feat[b1, :])  # mid_seg_len
            b2_prior = get_possion_prob_for_all_class(1, next_ele-b1)  # mid_seg_len x num_class
            
            mat_b1_b2_c_prob[b1-cur_ele, b1+1-cur_ele:next_ele-cur_ele] = (left_sum + right_sum[:,None] + mid_sum) / config.temp \
                                                                            + b1_prior[b1-cur_ele] + b2_prior
            # when mid segment is absent but right and left is not the same
            # we assign the probability to a dummy label for now and then later 
            # re-distribute among other classes after the softmax
            if label_cur_ele != label_next_ele:
                rightsum_wo_midseg = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1, label_next_ele]
                mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = (left_sum + rightsum_wo_midseg) / config.temp \
                                                                        + b1_prior[b1-cur_ele]
        
#         if vidid=='P39_cam02_P39_scrambledegg' and cur_ele==574:
#             import pdb
#             pdb.set_trace()
        # when mid segment is absent b1 can also be next_ele-1
        b1 = next_ele - 1
        if label_cur_ele != label_next_ele:
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum / config.temp + b1_prior[b1-cur_ele]
        else:
            # returns prob that the left class length >= seg len
            b1_prior_ = get_poisson_logcdf(next_ele - prev_boundary, label_cur_ele) 
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum  / config.temp + b1_prior_
        
        mat_b1_b2_c_prob[:, :, label_cur_ele] = LOW_VAL
        mat_b1_b2_c_prob[:, :, label_next_ele] = LOW_VAL
        mat_b1_b2_c_prob = torch.softmax(mat_b1_b2_c_prob.flatten(), dim=0).reshape((seg_len, seg_len, config.num_class))
        
        # re-distribute the dummy class probability among the left-over classes
        left_over_classes = config.num_class - 2 + (label_cur_ele==label_next_ele)
        for b1 in range(cur_ele, next_ele):
            assigned_prob = mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label]
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, :] = assigned_prob/left_over_classes
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_cur_ele] = 0
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_next_ele] = 0
        
        marginal_b1 = torch.sum(mat_b1_b2_c_prob, axis=(1,2))
        mean_b1 = round(torch.sum(marginal_b1.squeeze() * torch.arange(cur_ele, next_ele, 1)).item())
        cumm_b1_prob = torch.cumsum(marginal_b1, dim=0)
        cumm_b1_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=1), dim=0)
        cumm_b2_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=0), dim=0)

        per_frame_weights[cur_ele, label_cur_ele] = 1.0
        per_frame_weights[cur_ele+1:next_ele, :] = cumm_b1_c_prob[:-1] - cumm_b2_c_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_cur_ele] = 1 - cumm_b1_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] = 0
        remaining_probability = 1 - torch.sum(per_frame_weights[cur_ele+1:next_ele, :], dim=-1)
        # we use "+=" in the next line because left and right label might be the same
        # in that case using "=" would just overwrite the previous probability
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] += remaining_probability
        
        expected_boundary = round(torch.sum(torch.sum(mat_b1_b2_c_prob, axis=(0,2)).squeeze() * \
                            torch.arange(cur_ele, next_ele, 1)).item())
        if not (label_cur_ele == label_next_ele and expected_boundary >= next_ele-2):
            prev_boundary = expected_boundary
        if expected_boundary == 0 and i > 0:
            print(f'Estimated boundary has become zero! for {vidid} and cur_ele, next_ele {cur_ele, next_ele}')
            import pdb
            pdb.set_trace()
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary] - mean_b1)**2
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary+1] - prev_boundary)**2
        # current_boundary += 2
        # prob_each_segment.append(mat_b1_b2_c_prob)
        
    posterior_prediction = torch.argmax(per_frame_weights, dim=1)
    correct = torch.sum(posterior_prediction == gt_labels[:num_frames]).item()
    
    return (vidid, per_frame_weights, [correct, num_frames, boundary_error]) #, prob_each_segment)

# %%
posterior_acc_correct, posterior_acc_total = 0, 0
posterior_boundary_total_mse = 0
results = []

# Step 2: Define callback function to collect the output in `results`
def collect_result(result):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    fname = os.path.join(config.output_dir, 'posterior_weights', result[0] + '.wt')
    torch.save(result[1], fname)
    correct, total, boundary_err = result[2]
    posterior_acc_correct += correct
    posterior_acc_total += total
    posterior_boundary_total_mse += boundary_err
    # print(f'Dumped in file {fname} at time {time()}')
    return

def calculate_element_probb(data_feat, data_count, video_ids, gt_labels): # loaded_vidid_selected_frames, boundaries_dict):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    pool = mp.Pool(20)
    for iter_num in range(len(data_count)):
        cur_vidid = video_ids[iter_num]
#         if cur_vidid!='P39_cam02_P39_scrambledegg':
#             continue
        cur_vid_count = data_count[iter_num]
        cur_vid_feat = data_feat[iter_num][:cur_vid_count].detach().cpu()
        cur_gt_labels = gt_labels[iter_num].detach().cpu()
        
        cur_video_select_frames = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices_and_labels = cur_video_select_frames
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]
        with torch.no_grad():
            # Multi-processing
            pool.apply_async(prob_vals_per_segment,
                             args=(selected_frames_indices, cur_vid_feat, selected_frames_labels,
                                   cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels),
                             callback=collect_result)
#             results.append(prob_vals_per_segment(selected_frames_indices, cur_vid_feat, selected_frames_labels,
#                                    cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels))
    # Step 4: Close Pool and let all the processes complete
    pool.close()
    pool.join()  # postpones the execution of next line of code until all processes in the queue are done.
    return results

def perform_expectation(model, dataloader):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse = 0, 0, 0
    model.eval()
    correct = 0.0
    total = 0.0
    curtime = time()
    print(f'Calculating expectation')

    for i, item in enumerate(dataloader):
        with torch.no_grad():
            item_0 = item[0].to(device) # features
            item_1 = item[1].to(device) # count
            item_2 = item[2].to(device) # gt frame-wise labels
            item_4 = item[4] # video-ids
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            prob = torch.softmax(predictions[-1], dim=1)
            prob = prob.permute(0, 2, 1)
            
            calculate_element_probb(prob, item_1, item_4, item_2)
            if (i+1) % 10 == 0:
                print(f"iter {i+1} of Expectation completed in a total of {(time() - curtime)/60.: .1f} minutes")
    _ = model.train()
    print(f'Expectation step finished, '
          f'posterior frame-wise accuracy {100*posterior_acc_correct/posterior_acc_total: .2f}%, '
          f'boundary mse {(posterior_boundary_total_mse/num_boundary)**0.5: .2f}')
    return

# %%
set_seed()
model = MultiStageModel(num_stages=4, num_layers=10, num_f_maps=64, dim=2048, num_classes=48).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

# Requires loaded_vidid_selected_frames, boundaries_dict
ce_criterion = nn.CrossEntropyLoss(ignore_index=-100)
mse_criterion = nn.MSELoss(reduction='none')

# %%
# loaded_file=torch.load(os.path.join(config.output_dir, "ms-tcn-initial-30-epochs.wt"))
# model.load_state_dict(loaded_file)
# # loaded_file=torch.load('/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcnnew-full-supervised-split1/ms-tcn-best-model.wt')
# # model.load_state_dict(loaded_file)
# loaded_file=torch.load(os.path.join(config.output_dir, "ms-tcn-emmax-best-model.wt"))
# loaded_file=torch.load("/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split1/ms-tcn-emmax-last-model.wt")
# model.load_state_dict(loaded_file)
# _ = validate(model, testloader)
loaded_file = torch.load('/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select6/split4/ms-tcn-initial-30-epochs.wt')
model.load_state_dict(loaded_file)
# Out:
# <All keys matched successfully>

# %%
# item = next(iter(trainloader))
    
# with torch.no_grad():
#     item_0 = item[0].to(device) # features
#     item_1 = item[1].to(device) # count
#     item_2 = item[2].to(device) # gt frame-wise labels
#     item_4 = item[4] # video-ids
#     src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
#     src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
#     middle_pred, predictions = model(item_0, src_mask_mse)
#     prob = torch.softmax(predictions[-1], dim=1)
#     prob = prob.permute(0, 2, 1)

#     res = calculate_element_probb(prob, item_1, item_4, item_2)

# %%
# idx = 2
# vidid = res[idx][0]
# mat = res[idx][1]
# mat.shape

# %%
# np.linspace(0, 5281, 4 + 1).astype(int)

# %%
# boundary_frames_dict[f'{vidid}.txt'], selected_frames_dict[f'{vidid}.txt'], weakly_labels[f'{vidid}.txt']

# %%
# fig = plt.figure(figsize=(20, 5))
# for i in range(48):
#     plt.plot(mat[:,i])
    
# for bd in boundary_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd, bd], [0, 2])
    
# for bd in selected_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd[0], bd[0]], [0, 2], '--')

# %%
# bd

# %%
# Calculating Expectation Step
# perform_expectation(model, trainloder_expectation)

# %%
def get_single_random(video_ids, len_frames, device):
    # Generate target for only timestamps. Do not generate pseudo labels at first 30 epochs.
    boundary_target_tensor = torch.ones((len(video_ids), len_frames), dtype=torch.long, device=device) * (-100)
    for iter_num, cur_vidid in enumerate(video_ids):
        selected_frames_indices_and_labels = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]

        frame_idx_tensor = torch.from_numpy(np.array(selected_frames_indices))
        frame_labels = torch.from_numpy(np.array(selected_frames_labels)).to(device)
        boundary_target_tensor[iter_num, frame_idx_tensor] = frame_labels

    return boundary_target_tensor

# %%
weakly_labels = pickle.load(open("data/breakfast_weaklysupervised_labels.pkl", "rb"))
prior_probs = pickle.load(open('data/breakfast_lengthmodel_multinomial_prior.pkl', 'rb'))

# %%
initialize_epoch = 30
expectation_cal_gap = 4
best_val_acc = 0
for epoch in range(30, 150):
    print("Starting Training")
    model.train()
    for i, item in enumerate(trainloader):
        item_0 = item[0].to(device)  # features
        item_1 = item[1].to(device)  # count
        item_2 = item[2].to(device)  # target
        weights = item[5].to(device)  # posterior weight
        src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
        src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
        optimizer.zero_grad()
        
        middle_pred, predictions = model(item_0, src_mask_mse)
        boundary_target_tensor = get_single_random(item[4], item_2.shape[1], item_2.device)
        
        loss = 0
        for p in predictions:
            if epoch <= initialize_epoch:
                loss += ce_criterion(p, boundary_target_tensor)
                loss += 0.15 * torch.mean(torch.clamp(mse_criterion(F.log_softmax(p[:, :, 1:], dim=1), 
                                                                    F.log_softmax(p.detach()[:, :, :-1], dim=1)), min=0,
                                            max=16) * src_mask_mse[:, :, 1:])
            else:
                prob = torch.softmax(p, dim=1)
                prob = prob.permute(0, 2, 1)
                total_count = torch.sum(src_mask)
                weighted_loss_sum = -torch.sum(torch.sum(torch.log(prob + 1e-8) * weights, dim=-1) * src_mask)
                loss += weighted_loss_sum/total_count

        loss.backward()
        optimizer.step()
        if (i+1)%20 == 0:
            print(f'Epoch {epoch+1}: Iteration {i+1} with loss {loss.item()}')

    if (epoch >= initialize_epoch) and ((epoch % (3 * expectation_cal_gap)) == 0):
        torch.save(model.state_dict(), config.output_dir + f"ms-tcn-initial-{epoch}-epochs.wt")

    if epoch >= initialize_epoch and (epoch % expectation_cal_gap == 0):
        perform_expectation(model, trainloder_expectation)
    
    print(f'Epoch {epoch+1} finished, starting validation')
    val_acc, best_val_acc = validate(model, testloader, best_val_acc)
# Out:
# Starting Training
# Epoch 31: Iteration 20 with loss 0.8570389151573181
# Epoch 31: Iteration 40 with loss 0.926175594329834
# Epoch 31: Iteration 60 with loss 0.6415252685546875
# Epoch 31: Iteration 80 with loss 1.757200002670288
# Epoch 31: Iteration 100 with loss 1.077072024345398
# Epoch 31: Iteration 120 with loss 1.1050399541854858
# Epoch 31: Iteration 140 with loss 1.0054270029067993
# Epoch 31 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.17823972705704
# Other scores:: Edit 37.61736756520953, F1@[10:25:50] [41.33380438 36.57528874 28.72039985]
# Starting Training
# Epoch 32: Iteration 20 with loss 0.0
# Epoch 32: Iteration 40 with loss 0.0
# Epoch 32: Iteration 60 with loss 0.0
# Epoch 32: Iteration 80 with loss 0.0
# Epoch 32: Iteration 100 with loss 0.0
# Epoch 32: Iteration 120 with loss 0.0
# Epoch 32: Iteration 140 with loss 0.0
# Epoch 32 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.1477329917189
# Other scores:: Edit 32.08932446945838, F1@[10:25:50] [33.3325254  28.65418137 20.25419776]
# Starting Training
# Epoch 33: Iteration 20 with loss 0.0
# Epoch 33: Iteration 40 with loss 0.0
# Epoch 33: Iteration 60 with loss 0.0
# Epoch 33: Iteration 80 with loss 0.0
# Epoch 33: Iteration 100 with loss 0.0
# Epoch 33: Iteration 120 with loss 0.0
# Epoch 33: Iteration 140 with loss 0.0
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.1 minutes
# iter 20 of Expectation completed in a total of  6.8 minutes
# iter 30 of Expectation completed in a total of  10.0 minutes
# iter 40 of Expectation completed in a total of  13.0 minutes
# iter 50 of Expectation completed in a total of  15.8 minutes
# Expectation step finished, posterior frame-wise accuracy  75.70%, boundary mse  0.00
# Epoch 33 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.1477329917189
# Other scores:: Edit 32.08932446945838, F1@[10:25:50] [33.3325254  28.65418137 20.25419776]
# Starting Training
# Epoch 34: Iteration 20 with loss 2.383120059967041
# Epoch 34: Iteration 40 with loss 3.505472183227539
# Epoch 34: Iteration 60 with loss 3.438434600830078
# Epoch 34: Iteration 80 with loss 4.422844886779785
# Epoch 34: Iteration 100 with loss 2.2762656211853027
# Epoch 34: Iteration 120 with loss 4.73997163772583
# Epoch 34: Iteration 140 with loss 2.964892625808716
# Epoch 34 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.39995359446794
# Other scores:: Edit 47.83020777825821, F1@[10:25:50] [44.99281467 40.29843763 28.97132909]
# Starting Training
# Epoch 35: Iteration 20 with loss 1.4601587057113647
# Epoch 35: Iteration 40 with loss 2.4579944610595703
# Epoch 35: Iteration 60 with loss 3.367114543914795
# Epoch 35: Iteration 80 with loss 2.4436733722686768
# Epoch 35: Iteration 100 with loss 3.443498134613037
# Epoch 35: Iteration 120 with loss 3.232872724533081
# Epoch 35: Iteration 140 with loss 1.8574190139770508
# Epoch 35 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.068265152059816
# Other scores:: Edit 50.65228057911486, F1@[10:25:50] [48.40289015 44.35355149 33.78370715]
# Starting Training
# Epoch 36: Iteration 20 with loss 3.2207696437835693
# Epoch 36: Iteration 40 with loss 3.2485744953155518
# Epoch 36: Iteration 60 with loss 1.9463729858398438
# Epoch 36: Iteration 80 with loss 2.8620619773864746
# Epoch 36: Iteration 100 with loss 1.347930669784546
# Epoch 36: Iteration 120 with loss 3.703794002532959
# Epoch 36: Iteration 140 with loss 1.8625638484954834
# Epoch 36 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.99581043013353
# Other scores:: Edit 53.67701132131643, F1@[10:25:50] [51.42002783 47.36739292 35.14147313]
# Starting Training
# Epoch 37: Iteration 20 with loss 3.32334041595459
# Epoch 37: Iteration 40 with loss 2.0006537437438965
# Epoch 37: Iteration 60 with loss 1.2293771505355835
# Epoch 37: Iteration 80 with loss 2.0045437812805176
# Epoch 37: Iteration 100 with loss 1.3496612310409546
# Epoch 37: Iteration 120 with loss 2.4230995178222656
# Epoch 37: Iteration 140 with loss 1.3957290649414062
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.5 minutes
# iter 30 of Expectation completed in a total of  9.2 minutes
# iter 40 of Expectation completed in a total of  13.2 minutes
# iter 50 of Expectation completed in a total of  15.8 minutes
# Expectation step finished, posterior frame-wise accuracy  75.25%, boundary mse  0.00
# Epoch 37 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.443431002817015
# Other scores:: Edit 54.333117527040045, F1@[10:25:50] [51.08282762 46.98298768 34.81061307]
# Starting Training
# Epoch 38: Iteration 20 with loss 2.2697489261627197
# Epoch 38: Iteration 40 with loss 3.0834052562713623
# Epoch 38: Iteration 60 with loss 2.7855782508850098
# Epoch 38: Iteration 80 with loss 4.665175437927246
# Epoch 38: Iteration 100 with loss 2.0777177810668945
# Epoch 38: Iteration 120 with loss 1.3254063129425049
# Epoch 38: Iteration 140 with loss 0.876132071018219
# Epoch 38 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.14603036621154
# Other scores:: Edit 58.01944317972803, F1@[10:25:50] [54.16743974 49.15760334 36.80768665]
# Starting Training
# Epoch 39: Iteration 20 with loss 1.8206803798675537
# Epoch 39: Iteration 40 with loss 1.151874303817749
# Epoch 39: Iteration 60 with loss 1.3010883331298828
# Epoch 39: Iteration 80 with loss 1.9824632406234741
# Epoch 39: Iteration 100 with loss 3.9717605113983154
# Epoch 39: Iteration 120 with loss 2.092306613922119
# Epoch 39: Iteration 140 with loss 1.5990548133850098
# Epoch 39 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.36448931038765
# Other scores:: Edit 54.887561708216886, F1@[10:25:50] [48.42504341 44.33363553 33.83130137]
# Starting Training
# Epoch 40: Iteration 20 with loss 1.7652456760406494
# Epoch 40: Iteration 40 with loss 0.9391430616378784
# Epoch 40: Iteration 60 with loss 2.8987889289855957
# Epoch 40: Iteration 80 with loss 2.0591695308685303
# Epoch 40: Iteration 100 with loss 4.962882041931152
# Epoch 40: Iteration 120 with loss 1.0084859132766724
# Epoch 40: Iteration 140 with loss 2.6184241771698
# Epoch 40 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.62513807279786
# Other scores:: Edit 58.49731453548244, F1@[10:25:50] [54.54807644 49.94384987 38.65336551]
# Starting Training
# Epoch 41: Iteration 20 with loss 2.0061428546905518
# Epoch 41: Iteration 40 with loss 2.6463441848754883
# Epoch 41: Iteration 60 with loss 1.4797619581222534
# Epoch 41: Iteration 80 with loss 1.8818504810333252
# Epoch 41: Iteration 100 with loss 2.8566224575042725
# Epoch 41: Iteration 120 with loss 2.22668194770813
# Epoch 41: Iteration 140 with loss 1.439589262008667
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.7 minutes
# iter 30 of Expectation completed in a total of  9.8 minutes
# iter 40 of Expectation completed in a total of  13.4 minutes
# iter 50 of Expectation completed in a total of  16.4 minutes
# Expectation step finished, posterior frame-wise accuracy  74.36%, boundary mse  0.00
# Epoch 41 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.362146157818025
# Other scores:: Edit 59.83296161695691, F1@[10:25:50] [55.85697364 52.08134434 39.74760456]
# Starting Training
# Epoch 42: Iteration 20 with loss 0.7459689974784851
# Epoch 42: Iteration 40 with loss 0.9918410181999207
# Epoch 42: Iteration 60 with loss 1.774983525276184
# Epoch 42: Iteration 80 with loss 1.5199388265609741
# Epoch 42: Iteration 100 with loss 1.474501132965088
# Epoch 42: Iteration 120 with loss 1.5407315492630005
# Epoch 42: Iteration 140 with loss 0.8450850248336792
# Epoch 42 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.70521049157184
# Other scores:: Edit 61.09038062710153, F1@[10:25:50] [57.95127563 54.43506355 40.51901996]
# Starting Training
# Epoch 43: Iteration 20 with loss 1.722836971282959
# Epoch 43: Iteration 40 with loss 1.0612950325012207
# Epoch 43: Iteration 60 with loss 2.386291980743408
# Epoch 43: Iteration 80 with loss 2.0234475135803223
# Epoch 43: Iteration 100 with loss 1.9406824111938477
# Epoch 43: Iteration 120 with loss 1.0537304878234863
# Epoch 43: Iteration 140 with loss 1.3287711143493652
# Epoch 43 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.40079673723358
# Other scores:: Edit 62.08720962915228, F1@[10:25:50] [59.07717051 55.64853275 42.56606336]
# Starting Training
# Epoch 44: Iteration 20 with loss 1.4991683959960938
# Epoch 44: Iteration 40 with loss 1.3807036876678467
# Epoch 44: Iteration 60 with loss 1.6433253288269043
# Epoch 44: Iteration 80 with loss 0.7648743987083435
# Epoch 44: Iteration 100 with loss 0.7501612305641174
# Epoch 44: Iteration 120 with loss 1.293426752090454
# Epoch 44: Iteration 140 with loss 0.8080489635467529
# Epoch 44 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.20422682501193
# Other scores:: Edit 62.52403875937081, F1@[10:25:50] [59.66796876 55.48220058 42.44133667]
# Starting Training
# Epoch 45: Iteration 20 with loss 0.7212363481521606
# Epoch 45: Iteration 40 with loss 1.128967523574829
# Epoch 45: Iteration 60 with loss 2.1692538261413574
# Epoch 45: Iteration 80 with loss 1.1101244688034058
# Epoch 45: Iteration 100 with loss 2.290431499481201
# Epoch 45: Iteration 120 with loss 0.7983827590942383
# Epoch 45: Iteration 140 with loss 0.6581427454948425
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  10.1 minutes
# iter 40 of Expectation completed in a total of  13.4 minutes
# iter 50 of Expectation completed in a total of  16.2 minutes
# Expectation step finished, posterior frame-wise accuracy  75.03%, boundary mse  0.00
# Epoch 45 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.488869208295476
# Other scores:: Edit 62.99647572417028, F1@[10:25:50] [59.42987172 55.12197668 42.01267445]
# Starting Training
# Epoch 46: Iteration 20 with loss 0.44710808992385864
# Epoch 46: Iteration 40 with loss 0.9693595767021179
# Epoch 46: Iteration 60 with loss 1.555374264717102
# Epoch 46: Iteration 80 with loss 0.7453592419624329
# Epoch 46: Iteration 100 with loss 0.8082538843154907
# Epoch 46: Iteration 120 with loss 0.9336247444152832
# Epoch 46: Iteration 140 with loss 0.9374307990074158
# Epoch 46 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.73716821678573
# Other scores:: Edit 64.79156709644941, F1@[10:25:50] [63.05491726 58.56448017 45.10453135]
# Starting Training
# Epoch 47: Iteration 20 with loss 1.2663531303405762
# Epoch 47: Iteration 40 with loss 2.4960601329803467
# Epoch 47: Iteration 60 with loss 1.0944972038269043
# Epoch 47: Iteration 80 with loss 0.8860030174255371
# Epoch 47: Iteration 100 with loss 0.8526384830474854
# Epoch 47: Iteration 120 with loss 1.285453200340271
# Epoch 47: Iteration 140 with loss 1.0799214839935303
# Epoch 47 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.912816423636755
# Other scores:: Edit 62.67743018388608, F1@[10:25:50] [59.6330165  55.51743221 43.39915031]
# Starting Training
# Epoch 48: Iteration 20 with loss 0.785085141658783
# Epoch 48: Iteration 40 with loss 0.7401397228240967
# Epoch 48: Iteration 60 with loss 0.815121054649353
# Epoch 48: Iteration 80 with loss 0.5949442386627197
# Epoch 48: Iteration 100 with loss 1.4120101928710938
# Epoch 48: Iteration 120 with loss 1.993929147720337
# Epoch 48: Iteration 140 with loss 0.8605461120605469
# Epoch 48 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.2628808031425
# Other scores:: Edit 61.68802506239011, F1@[10:25:50] [58.67841148 54.60655772 40.33602543]
# Starting Training
# Epoch 49: Iteration 20 with loss 0.9050112366676331
# Epoch 49: Iteration 40 with loss 1.589777946472168
# Epoch 49: Iteration 60 with loss 0.911186158657074
# Epoch 49: Iteration 80 with loss 0.5548754334449768
# Epoch 49: Iteration 100 with loss 1.0864648818969727
# Epoch 49: Iteration 120 with loss 0.9405449628829956
# Epoch 49: Iteration 140 with loss 1.2050020694732666
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.0 minutes
# iter 20 of Expectation completed in a total of  5.6 minutes
# iter 30 of Expectation completed in a total of  8.2 minutes
# iter 40 of Expectation completed in a total of  12.2 minutes
# iter 50 of Expectation completed in a total of  15.5 minutes
# Expectation step finished, posterior frame-wise accuracy  58.52%, boundary mse  0.00
# Epoch 49 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 46.41223145249315
# Other scores:: Edit 57.8557041847287, F1@[10:25:50] [52.05517552 48.21896747 37.78512776]
# Starting Training
# Epoch 50: Iteration 20 with loss 5.762620449066162
# Epoch 50: Iteration 40 with loss 5.067525863647461
# Epoch 50: Iteration 60 with loss 3.754152774810791
# Epoch 50: Iteration 80 with loss 4.982841491699219
# Epoch 50: Iteration 100 with loss 5.867550373077393
# Epoch 50: Iteration 120 with loss 4.4276533126831055
# Epoch 50: Iteration 140 with loss 3.7647271156311035
# Epoch 50 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 46.045317289655486
# Other scores:: Edit 57.909237595496016, F1@[10:25:50] [53.43651326 49.32401584 38.69051082]
# Starting Training
# Epoch 51: Iteration 20 with loss 2.8133764266967773
# Epoch 51: Iteration 40 with loss 1.549185037612915
# Epoch 51: Iteration 60 with loss 3.2488110065460205
# Epoch 51: Iteration 80 with loss 3.4600136280059814
# Epoch 51: Iteration 100 with loss 2.75183367729187
# Epoch 51: Iteration 120 with loss 2.558882713317871
# Epoch 51: Iteration 140 with loss 3.2481298446655273
# Epoch 51 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.58800057516716
# Other scores:: Edit 57.045062532786716, F1@[10:25:50] [52.59663261 48.13637006 35.77482743]
# Starting Training
# Epoch 52: Iteration 20 with loss 3.267695188522339
# Epoch 52: Iteration 40 with loss 4.237768650054932
# Epoch 52: Iteration 60 with loss 3.8532192707061768
# Epoch 52: Iteration 80 with loss 1.9191040992736816
# Epoch 52: Iteration 100 with loss 2.7654213905334473
# Epoch 52: Iteration 120 with loss 2.857635259628296
# Epoch 52: Iteration 140 with loss 2.0327229499816895
# Epoch 52 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 46.126526970764516
# Other scores:: Edit 58.416412535571595, F1@[10:25:50] [53.06693782 48.9366422  37.42044159]
# Starting Training
# Epoch 53: Iteration 20 with loss 1.1619057655334473
# Epoch 53: Iteration 40 with loss 1.8776888847351074
# Epoch 53: Iteration 60 with loss 3.2639145851135254
# Epoch 53: Iteration 80 with loss 2.690727472305298
# Epoch 53: Iteration 100 with loss 2.759751558303833
# Epoch 53: Iteration 120 with loss 1.6368088722229004
# Epoch 53: Iteration 140 with loss 1.3331763744354248
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  6.5 minutes
# iter 30 of Expectation completed in a total of  9.8 minutes
# iter 40 of Expectation completed in a total of  13.2 minutes
# iter 50 of Expectation completed in a total of  16.6 minutes
# Expectation step finished, posterior frame-wise accuracy  60.64%, boundary mse  0.00
# Epoch 53 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 47.00022549166988
# Other scores:: Edit 56.24363273511571, F1@[10:25:50] [51.67089069 48.32045652 37.93534276]
# Starting Training
# Epoch 54: Iteration 20 with loss 0.6515122056007385
# Epoch 54: Iteration 40 with loss 0.900246262550354
# Epoch 54: Iteration 60 with loss 1.8338215351104736
# Epoch 54: Iteration 80 with loss 1.7213225364685059
# Epoch 54: Iteration 100 with loss 1.4917116165161133
# Epoch 54: Iteration 120 with loss 1.4936882257461548
# Epoch 54: Iteration 140 with loss 5.911332130432129
# Epoch 54 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 44.45315002058837
# Other scores:: Edit 56.21435227047298, F1@[10:25:50] [51.31950895 47.49576603 36.38646063]
# Starting Training
# Epoch 55: Iteration 20 with loss 2.1783876419067383
# Epoch 55: Iteration 40 with loss 1.4714438915252686
# Epoch 55: Iteration 60 with loss 1.4286916255950928
# Epoch 55: Iteration 80 with loss 1.7640516757965088
# Epoch 55: Iteration 100 with loss 1.1016881465911865
# Epoch 55: Iteration 120 with loss 0.8086349964141846
# Epoch 55: Iteration 140 with loss 1.2396886348724365
# Epoch 55 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.91765305655593
# Other scores:: Edit 59.114102692427394, F1@[10:25:50] [54.75035583 51.01059357 39.37403328]
# Starting Training
# Epoch 56: Iteration 20 with loss 1.733315348625183
# Epoch 56: Iteration 40 with loss 1.9823064804077148
# Epoch 56: Iteration 60 with loss 1.1393446922302246
# Epoch 56: Iteration 80 with loss 2.8520684242248535
# Epoch 56: Iteration 100 with loss 0.8439885973930359
# Epoch 56: Iteration 120 with loss 1.6490778923034668
# Epoch 56: Iteration 140 with loss 2.768453359603882
# Epoch 56 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 46.16198471885437
# Other scores:: Edit 59.089739689682105, F1@[10:25:50] [52.72559295 49.77553272 37.94289458]
# Starting Training
# Epoch 57: Iteration 20 with loss 1.1528310775756836
# Epoch 57: Iteration 40 with loss 1.1106189489364624
# Epoch 57: Iteration 60 with loss 0.531948983669281
# Epoch 57: Iteration 80 with loss 1.2209885120391846
# Epoch 57: Iteration 100 with loss 0.7603543400764465
# Epoch 57: Iteration 120 with loss 1.9924206733703613
# Epoch 57: Iteration 140 with loss 0.7612805366516113
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.1 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  9.7 minutes
# iter 40 of Expectation completed in a total of  12.5 minutes
# iter 50 of Expectation completed in a total of  15.7 minutes
# Expectation step finished, posterior frame-wise accuracy  62.62%, boundary mse  0.00
# Epoch 57 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.71176935796966
# Other scores:: Edit 60.21092294045208, F1@[10:25:50] [57.28983933 54.04486319 41.34657631]
# Starting Training
# Epoch 58: Iteration 20 with loss 1.721459150314331
# Epoch 58: Iteration 40 with loss 1.1107282638549805
# Epoch 58: Iteration 60 with loss 0.9154382348060608
# Epoch 58: Iteration 80 with loss 0.8474218845367432
# Epoch 58: Iteration 100 with loss 1.0950151681900024
# Epoch 58: Iteration 120 with loss 1.8301734924316406
# Epoch 58: Iteration 140 with loss 0.6471977829933167
# Epoch 58 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.019872678906395
# Other scores:: Edit 61.773722143482274, F1@[10:25:50] [58.09375534 54.7911897  41.82390081]
# Starting Training
# Epoch 59: Iteration 20 with loss 1.3964715003967285
# Epoch 59: Iteration 40 with loss 0.8522996306419373
# Epoch 59: Iteration 60 with loss 1.483288049697876
# Epoch 59: Iteration 80 with loss 1.113214135169983
# Epoch 59: Iteration 100 with loss 0.7968766689300537
# Epoch 59: Iteration 120 with loss 0.810932457447052
# Epoch 59: Iteration 140 with loss 2.517552137374878
# Epoch 59 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.972146876776975
# Other scores:: Edit 61.26710864597957, F1@[10:25:50] [58.72018903 55.17497946 42.69125048]
# Starting Training
# Epoch 60: Iteration 20 with loss 0.7873760461807251
# Epoch 60: Iteration 40 with loss 1.3624169826507568
# Epoch 60: Iteration 60 with loss 1.3035789728164673
# Epoch 60: Iteration 80 with loss 0.5703963041305542
# Epoch 60: Iteration 100 with loss 0.8508061170578003
# Epoch 60: Iteration 120 with loss 1.1796318292617798
# Epoch 60: Iteration 140 with loss 0.7391080856323242
# Epoch 60 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.78825351799685
# Other scores:: Edit 61.50686604941072, F1@[10:25:50] [58.71630054 55.52160158 43.31664131]
# Starting Training
# Epoch 61: Iteration 20 with loss 1.1275928020477295
# Epoch 61: Iteration 40 with loss 1.3678910732269287
# Epoch 61: Iteration 60 with loss 1.6157255172729492
# Epoch 61: Iteration 80 with loss 1.3393222093582153
# Epoch 61: Iteration 100 with loss 1.1864670515060425
# Epoch 61: Iteration 120 with loss 0.9392597675323486
# Epoch 61: Iteration 140 with loss 0.9697425365447998
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.7 minutes
# iter 20 of Expectation completed in a total of  6.6 minutes
# iter 30 of Expectation completed in a total of  9.7 minutes
# iter 40 of Expectation completed in a total of  12.7 minutes
# iter 50 of Expectation completed in a total of  16.3 minutes
# Expectation step finished, posterior frame-wise accuracy  63.20%, boundary mse  0.00
# Epoch 61 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.763001718965484
# Other scores:: Edit 61.45235898071111, F1@[10:25:50] [59.10040393 56.05811323 43.71667895]
# Starting Training
# Epoch 62: Iteration 20 with loss 1.3929800987243652
# Epoch 62: Iteration 40 with loss 1.1196458339691162
# Epoch 62: Iteration 60 with loss 1.236279845237732
# Epoch 62: Iteration 80 with loss 0.7112359404563904
# Epoch 62: Iteration 100 with loss 0.745535135269165
# Epoch 62: Iteration 120 with loss 0.548293948173523
# Epoch 62: Iteration 140 with loss 1.6846600770950317
# Epoch 62 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.34774737089785
# Other scores:: Edit 62.348626110235195, F1@[10:25:50] [60.73036365 57.14798366 44.69683798]
# Starting Training
# Epoch 63: Iteration 20 with loss 0.7448343634605408
# Epoch 63: Iteration 40 with loss 0.9804351925849915
# Epoch 63: Iteration 60 with loss 0.6470839381217957
# Epoch 63: Iteration 80 with loss 1.8353031873703003
# Epoch 63: Iteration 100 with loss 1.5297505855560303
# Epoch 63: Iteration 120 with loss 1.2403446435928345
# Epoch 63: Iteration 140 with loss 1.6626453399658203
# Epoch 63 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.16857299720913
# Other scores:: Edit 61.614711835336465, F1@[10:25:50] [59.18660843 56.25834673 44.22467238]
# Starting Training
# Epoch 64: Iteration 20 with loss 0.3447185754776001
# Epoch 64: Iteration 40 with loss 0.58579421043396
# Epoch 64: Iteration 60 with loss 1.0788533687591553
# Epoch 64: Iteration 80 with loss 0.7880527973175049
# Epoch 64: Iteration 100 with loss 0.6672074794769287
# Epoch 64: Iteration 120 with loss 1.4518318176269531
# Epoch 64: Iteration 140 with loss 0.6776741147041321
# Epoch 64 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 48.201377133183875
# Other scores:: Edit 61.86746655512783, F1@[10:25:50] [58.54824042 55.4582784  43.34765719]
# Starting Training
# Epoch 65: Iteration 20 with loss 2.033174991607666
# Epoch 65: Iteration 40 with loss 0.7476286292076111
# Epoch 65: Iteration 60 with loss 0.5554220080375671
# Epoch 65: Iteration 80 with loss 0.8710194826126099
# Epoch 65: Iteration 100 with loss 1.4099215269088745
# Epoch 65: Iteration 120 with loss 1.9802370071411133
# Epoch 65: Iteration 140 with loss 0.5216089487075806
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  6.4 minutes
# iter 30 of Expectation completed in a total of  9.8 minutes
# iter 40 of Expectation completed in a total of  12.9 minutes
# iter 50 of Expectation completed in a total of  16.0 minutes
# Expectation step finished, posterior frame-wise accuracy  64.14%, boundary mse  0.00
# Epoch 65 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.32754789246989
# Other scores:: Edit 61.48392480700423, F1@[10:25:50] [59.75386563 56.05316539 43.7411015 ]
# Starting Training
# Epoch 66: Iteration 20 with loss 1.6650147438049316
# Epoch 66: Iteration 40 with loss 1.27931809425354
# Epoch 66: Iteration 60 with loss 0.9439803957939148
# Epoch 66: Iteration 80 with loss 1.0362772941589355
# Epoch 66: Iteration 100 with loss 0.5351430773735046
# Epoch 66: Iteration 120 with loss 0.5882869362831116
# Epoch 66: Iteration 140 with loss 0.44892337918281555
# Epoch 66 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.556804292838514
# Other scores:: Edit 62.249188651564296, F1@[10:25:50] [61.28122906 57.5323942  44.79686991]
# Starting Training
# Epoch 67: Iteration 20 with loss 0.8907971978187561
# Epoch 67: Iteration 40 with loss 1.2451645135879517
# Epoch 67: Iteration 60 with loss 0.8118728995323181
# Epoch 67: Iteration 80 with loss 0.807848334312439
# Epoch 67: Iteration 100 with loss 0.8729081153869629
# Epoch 67: Iteration 120 with loss 0.7842792868614197
# Epoch 67: Iteration 140 with loss 0.4657401442527771
# Epoch 67 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.44193426100824
# Other scores:: Edit 62.317763193053125, F1@[10:25:50] [60.36067793 56.67029707 43.28371124]
# Starting Training
# Epoch 68: Iteration 20 with loss 0.7541056275367737
# Epoch 68: Iteration 40 with loss 0.88892662525177
# Epoch 68: Iteration 60 with loss 1.609843134880066
# Epoch 68: Iteration 80 with loss 3.107203722000122
# Epoch 68: Iteration 100 with loss 1.1602857112884521
# Epoch 68: Iteration 120 with loss 0.872774600982666
# Epoch 68: Iteration 140 with loss 0.6907342076301575
# Epoch 68 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.764880816214486
# Other scores:: Edit 61.80721346805343, F1@[10:25:50] [58.82406066 55.43392159 41.97634159]
# Starting Training
# Epoch 69: Iteration 20 with loss 0.49659463763237
# Epoch 69: Iteration 40 with loss 0.7275538444519043
# Epoch 69: Iteration 60 with loss 0.5538632273674011
# Epoch 69: Iteration 80 with loss 0.8052007555961609
# Epoch 69: Iteration 100 with loss 0.5013077259063721
# Epoch 69: Iteration 120 with loss 0.6026480197906494
# Epoch 69: Iteration 140 with loss 0.6258742809295654
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  9.0 minutes
# iter 40 of Expectation completed in a total of  12.1 minutes
# iter 50 of Expectation completed in a total of  15.7 minutes
# Expectation step finished, posterior frame-wise accuracy  64.30%, boundary mse  0.00
# Epoch 69 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.004594801273214
# Other scores:: Edit 61.8480013428634, F1@[10:25:50] [60.85311063 57.41432342 44.32835779]
# Starting Training
# Epoch 70: Iteration 20 with loss 0.8409876227378845
# Epoch 70: Iteration 40 with loss 0.5072933435440063
# Epoch 70: Iteration 60 with loss 0.7555640935897827
# Epoch 70: Iteration 80 with loss 0.7886461019515991
# Epoch 70: Iteration 100 with loss 0.4897952377796173
# Epoch 70: Iteration 120 with loss 0.5123986601829529
# Epoch 70: Iteration 140 with loss 1.9301003217697144
# Epoch 70 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.18334760357911
# Other scores:: Edit 62.52397349983588, F1@[10:25:50] [60.88301072 57.46005634 44.96939254]
# Starting Training
# Epoch 71: Iteration 20 with loss 0.9662994742393494
# Epoch 71: Iteration 40 with loss 0.5399590730667114
# Epoch 71: Iteration 60 with loss 0.6364036798477173
# Epoch 71: Iteration 80 with loss 0.6808210611343384
# Epoch 71: Iteration 100 with loss 1.1377615928649902
# Epoch 71: Iteration 120 with loss 1.9473609924316406
# Epoch 71: Iteration 140 with loss 1.0510419607162476
# Epoch 71 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.923774011594844
# Other scores:: Edit 61.02275742554483, F1@[10:25:50] [58.65175801 55.45994709 43.43478308]
# Starting Training
# Epoch 72: Iteration 20 with loss 0.657658576965332
# Epoch 72: Iteration 40 with loss 0.4398030936717987
# Epoch 72: Iteration 60 with loss 0.4472978711128235
# Epoch 72: Iteration 80 with loss 0.8204830288887024
# Epoch 72: Iteration 100 with loss 0.7881296277046204
# Epoch 72: Iteration 120 with loss 0.5689623951911926
# Epoch 72: Iteration 140 with loss 1.1443254947662354
# Epoch 72 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.031869489343066
# Other scores:: Edit 61.76231617779518, F1@[10:25:50] [60.68859073 57.32674037 43.96383215]
# Starting Training
# Epoch 73: Iteration 20 with loss 0.409965842962265
# Epoch 73: Iteration 40 with loss 0.4097577929496765
# Epoch 73: Iteration 60 with loss 0.4961240291595459
# Epoch 73: Iteration 80 with loss 0.3853147625923157
# Epoch 73: Iteration 100 with loss 0.8241530656814575
# Epoch 73: Iteration 120 with loss 0.9507785439491272
# Epoch 73: Iteration 140 with loss 0.6225806474685669
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  6.5 minutes
# iter 30 of Expectation completed in a total of  10.0 minutes
# iter 40 of Expectation completed in a total of  13.1 minutes
# iter 50 of Expectation completed in a total of  16.2 minutes
# Expectation step finished, posterior frame-wise accuracy  64.22%, boundary mse  0.00
# Epoch 73 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.4891437198936
# Other scores:: Edit 62.18491222522867, F1@[10:25:50] [60.19107764 56.74815768 44.8130961 ]
# Starting Training
# Epoch 74: Iteration 20 with loss 0.6539056897163391
# Epoch 74: Iteration 40 with loss 0.5498664975166321
# Epoch 74: Iteration 60 with loss 0.5512987375259399
# Epoch 74: Iteration 80 with loss 0.40790095925331116
# Epoch 74: Iteration 100 with loss 0.39658457040786743
# Epoch 74: Iteration 120 with loss 0.8478412628173828
# Epoch 74: Iteration 140 with loss 0.8238604068756104
# Epoch 74 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.41047327106713
# Other scores:: Edit 61.31688592224985, F1@[10:25:50] [59.41745312 55.65930703 43.89654349]
# Starting Training
# Epoch 75: Iteration 20 with loss 0.9085507392883301
# Epoch 75: Iteration 40 with loss 2.0093448162078857
# Epoch 75: Iteration 60 with loss 1.715394377708435
# Epoch 75: Iteration 80 with loss 1.2967395782470703
# Epoch 75: Iteration 100 with loss 0.6095238327980042
# Epoch 75: Iteration 120 with loss 0.5246666073799133
# Epoch 75: Iteration 140 with loss 0.7190074920654297
# Epoch 75 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.640049934966896
# Other scores:: Edit 62.2057593366391, F1@[10:25:50] [59.62085815 55.91097151 43.99446546]
# Starting Training
# Epoch 76: Iteration 20 with loss 0.8136448860168457
# Epoch 76: Iteration 40 with loss 0.8984459638595581
# Epoch 76: Iteration 60 with loss 1.4029194116592407
# Epoch 76: Iteration 80 with loss 1.4420967102050781
# Epoch 76: Iteration 100 with loss 0.8418051600456238
# Epoch 76: Iteration 120 with loss 0.6563515663146973
# Epoch 76: Iteration 140 with loss 0.6247237324714661
# Epoch 76 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.80786148929078
# Other scores:: Edit 62.7265501066025, F1@[10:25:50] [61.33351319 58.17676243 46.25159972]
# Starting Training
# Epoch 77: Iteration 20 with loss 0.7095574140548706
# Epoch 77: Iteration 40 with loss 0.444959819316864
# Epoch 77: Iteration 60 with loss 0.5725811719894409
# Epoch 77: Iteration 80 with loss 0.48256826400756836
# Epoch 77: Iteration 100 with loss 0.37535879015922546
# Epoch 77: Iteration 120 with loss 0.47626808285713196
# Epoch 77: Iteration 140 with loss 0.4266894459724426
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  9.3 minutes
# iter 40 of Expectation completed in a total of  12.7 minutes
# iter 50 of Expectation completed in a total of  15.9 minutes
# Expectation step finished, posterior frame-wise accuracy  64.43%, boundary mse  0.00
# Epoch 77 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.1354780096602
# Other scores:: Edit 63.97881981367367, F1@[10:25:50] [62.33899017 59.24975572 46.34576477]
# Starting Training
# Epoch 78: Iteration 20 with loss 0.7552306056022644
# Epoch 78: Iteration 40 with loss 0.521632969379425
# Epoch 78: Iteration 60 with loss 0.40199097990989685
# Epoch 78: Iteration 80 with loss 0.4120953381061554
# Epoch 78: Iteration 100 with loss 0.2706778347492218
# Epoch 78: Iteration 120 with loss 0.8313734531402588
# Epoch 78: Iteration 140 with loss 0.7502359747886658
# Epoch 78 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.39242413349107
# Other scores:: Edit 63.286461013344656, F1@[10:25:50] [62.6322438  59.39032357 46.76113595]
# Starting Training
# Epoch 79: Iteration 20 with loss 0.4921320080757141
# Epoch 79: Iteration 40 with loss 0.6059613227844238
# Epoch 79: Iteration 60 with loss 0.4749366044998169
# Epoch 79: Iteration 80 with loss 0.37172120809555054
# Epoch 79: Iteration 100 with loss 0.3109348714351654
# Epoch 79: Iteration 120 with loss 0.43278971314430237
# Epoch 79: Iteration 140 with loss 0.26142165064811707
# Epoch 79 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.11000071895895
# Other scores:: Edit 63.33436208094876, F1@[10:25:50] [62.6670419  58.73239469 46.01354796]
# Starting Training
# Epoch 80: Iteration 20 with loss 0.3133358657360077
# Epoch 80: Iteration 40 with loss 0.551314115524292
# Epoch 80: Iteration 60 with loss 0.4348808825016022
# Epoch 80: Iteration 80 with loss 0.4290425479412079
# Epoch 80: Iteration 100 with loss 0.3162444233894348
# Epoch 80: Iteration 120 with loss 2.6000373363494873
# Epoch 80: Iteration 140 with loss 0.4750915765762329
# Epoch 80 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.33791724128916
# Other scores:: Edit 63.085877003269985, F1@[10:25:50] [61.4234567  57.68800945 45.12376423]
# Starting Training
# Epoch 81: Iteration 20 with loss 0.35485416650772095
# Epoch 81: Iteration 40 with loss 0.40068718791007996
# Epoch 81: Iteration 60 with loss 0.4063645005226135
# Epoch 81: Iteration 80 with loss 0.2775003910064697
# Epoch 81: Iteration 100 with loss 0.42293018102645874
# Epoch 81: Iteration 120 with loss 0.7567335963249207
# Epoch 81: Iteration 140 with loss 1.0564208030700684
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.5 minutes
# iter 30 of Expectation completed in a total of  9.4 minutes
# iter 40 of Expectation completed in a total of  12.6 minutes
# iter 50 of Expectation completed in a total of  15.7 minutes
# Expectation step finished, posterior frame-wise accuracy  61.87%, boundary mse  0.00
# Epoch 81 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 45.73894273818783
# Other scores:: Edit 56.463443285411536, F1@[10:25:50] [53.66668497 50.323538   38.92701848]
# Starting Training
# Epoch 82: Iteration 20 with loss 1.749812364578247
# Epoch 82: Iteration 40 with loss 1.3780590295791626
# Epoch 82: Iteration 60 with loss 1.5305142402648926
# Epoch 82: Iteration 80 with loss 1.6123400926589966
# Epoch 82: Iteration 100 with loss 0.7866649627685547
# Epoch 82: Iteration 120 with loss 1.4450360536575317
# Epoch 82: Iteration 140 with loss 0.9564030170440674
# Epoch 82 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.07826848541494
# Other scores:: Edit 60.22204553157147, F1@[10:25:50] [58.06524585 54.96976433 43.03811993]
# Starting Training
# Epoch 83: Iteration 20 with loss 1.1587140560150146
# Epoch 83: Iteration 40 with loss 0.604998767375946
# Epoch 83: Iteration 60 with loss 0.8290233612060547
# Epoch 83: Iteration 80 with loss 1.4594229459762573
# Epoch 83: Iteration 100 with loss 1.663219690322876
# Epoch 83: Iteration 120 with loss 0.8928940296173096
# Epoch 83: Iteration 140 with loss 0.9544111490249634
# Epoch 83 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 48.951708834698266
# Other scores:: Edit 58.95326108762341, F1@[10:25:50] [57.82012988 53.57375148 42.34196534]
# Starting Training
# Epoch 84: Iteration 20 with loss 1.305600643157959
# Epoch 84: Iteration 40 with loss 1.3963147401809692
# Epoch 84: Iteration 60 with loss 3.1486005783081055
# Epoch 84: Iteration 80 with loss 2.540083646774292
# Epoch 84: Iteration 100 with loss 1.8062046766281128
# Epoch 84: Iteration 120 with loss 1.68073570728302
# Epoch 84: Iteration 140 with loss 1.2159541845321655
# Epoch 84 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.71022359623265
# Other scores:: Edit 59.318687783392015, F1@[10:25:50] [58.8789339  54.91134983 43.29127638]
# Starting Training
# Epoch 85: Iteration 20 with loss 1.3409810066223145
# Epoch 85: Iteration 40 with loss 1.5328717231750488
# Epoch 85: Iteration 60 with loss 1.2350149154663086
# Epoch 85: Iteration 80 with loss 0.8320997357368469
# Epoch 85: Iteration 100 with loss 0.9948465824127197
# Epoch 85: Iteration 120 with loss 0.8346964120864868
# Epoch 85: Iteration 140 with loss 0.7604748010635376
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.1 minutes
# iter 30 of Expectation completed in a total of  9.3 minutes
# iter 40 of Expectation completed in a total of  12.2 minutes
# iter 50 of Expectation completed in a total of  15.7 minutes
# Expectation step finished, posterior frame-wise accuracy  62.44%, boundary mse  0.00
# Epoch 85 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.118709926208666
# Other scores:: Edit 60.93499361747273, F1@[10:25:50] [57.91557042 54.39491904 43.89705647]
# Starting Training
# Epoch 86: Iteration 20 with loss 0.6700284481048584
# Epoch 86: Iteration 40 with loss 0.5490615963935852
# Epoch 86: Iteration 60 with loss 0.4646459221839905
# Epoch 86: Iteration 80 with loss 0.9753694534301758
# Epoch 86: Iteration 100 with loss 0.6229358911514282
# Epoch 86: Iteration 120 with loss 0.7727428674697876
# Epoch 86: Iteration 140 with loss 0.49802830815315247
# Epoch 86 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.28234825064216
# Other scores:: Edit 59.86350304723445, F1@[10:25:50] [57.27150363 53.91961155 42.93640719]
# Starting Training
# Epoch 87: Iteration 20 with loss 0.7424919009208679
# Epoch 87: Iteration 40 with loss 0.40009862184524536
# Epoch 87: Iteration 60 with loss 0.7627416849136353
# Epoch 87: Iteration 80 with loss 0.459587424993515
# Epoch 87: Iteration 100 with loss 0.9270904660224915
# Epoch 87: Iteration 120 with loss 0.5909441709518433
# Epoch 87: Iteration 140 with loss 0.762333869934082
# Epoch 87 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.8414336041412
# Other scores:: Edit 62.53777583359595, F1@[10:25:50] [60.39691836 57.20579559 45.61346859]
# Starting Training
# Epoch 88: Iteration 20 with loss 0.72372967004776
# Epoch 88: Iteration 40 with loss 0.5687583684921265
# Epoch 88: Iteration 60 with loss 0.3046528697013855
# Epoch 88: Iteration 80 with loss 0.5957018733024597
# Epoch 88: Iteration 100 with loss 0.774909257888794
# Epoch 88: Iteration 120 with loss 0.5264087915420532
# Epoch 88: Iteration 140 with loss 1.1588329076766968
# Epoch 88 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.00082353479434
# Other scores:: Edit 62.42831837858702, F1@[10:25:50] [60.76118142 57.01413701 45.63901902]
# Starting Training
# Epoch 89: Iteration 20 with loss 0.5512422919273376
# Epoch 89: Iteration 40 with loss 0.7937828898429871
# Epoch 89: Iteration 60 with loss 0.7031494975090027
# Epoch 89: Iteration 80 with loss 0.5087276697158813
# Epoch 89: Iteration 100 with loss 0.4645053446292877
# Epoch 89: Iteration 120 with loss 0.831942081451416
# Epoch 89: Iteration 140 with loss 0.969974935054779
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  7.2 minutes
# iter 30 of Expectation completed in a total of  10.2 minutes
# iter 40 of Expectation completed in a total of  13.1 minutes
# iter 50 of Expectation completed in a total of  16.1 minutes
# Expectation step finished, posterior frame-wise accuracy  62.77%, boundary mse  0.00
# Epoch 89 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.026313897476456
# Other scores:: Edit 61.01880277660402, F1@[10:25:50] [59.68339146 55.93514565 44.93642356]
# Starting Training
# Epoch 90: Iteration 20 with loss 0.33378729224205017
# Epoch 90: Iteration 40 with loss 2.583733558654785
# Epoch 90: Iteration 60 with loss 0.9160325527191162
# Epoch 90: Iteration 80 with loss 0.9977558851242065
# Epoch 90: Iteration 100 with loss 1.193789005279541
# Epoch 90: Iteration 120 with loss 0.6522073149681091
# Epoch 90: Iteration 140 with loss 0.9134585857391357
# Epoch 90 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.12997797371224
# Other scores:: Edit 61.09167850377623, F1@[10:25:50] [58.61978851 54.78542352 43.96372312]
# Starting Training
# Epoch 91: Iteration 20 with loss 0.44956174492836
# Epoch 91: Iteration 40 with loss 0.549240231513977
# Epoch 91: Iteration 60 with loss 0.6226065754890442
# Epoch 91: Iteration 80 with loss 0.5428885817527771
# Epoch 91: Iteration 100 with loss 0.5529690980911255
# Epoch 91: Iteration 120 with loss 0.3786740005016327
# Epoch 91: Iteration 140 with loss 0.9726834893226624
# Epoch 91 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.29364244210746
# Other scores:: Edit 62.04461825353118, F1@[10:25:50] [61.23788747 57.2998805  45.97431447]
# Starting Training
# Epoch 92: Iteration 20 with loss 0.3722323179244995
# Epoch 92: Iteration 40 with loss 0.346793532371521
# Epoch 92: Iteration 60 with loss 0.4008685350418091
# Epoch 92: Iteration 80 with loss 0.5858194828033447
# Epoch 92: Iteration 100 with loss 0.8989607095718384
# Epoch 92: Iteration 120 with loss 0.555039644241333
# Epoch 92: Iteration 140 with loss 0.7784452438354492
# Epoch 92 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.91136216576579
# Other scores:: Edit 61.433334809646254, F1@[10:25:50] [59.61358429 56.2929071  44.49307629]
# Starting Training
# Epoch 93: Iteration 20 with loss 0.5199763774871826
# Epoch 93: Iteration 40 with loss 0.3089197278022766
# Epoch 93: Iteration 60 with loss 0.5012835264205933
# Epoch 93: Iteration 80 with loss 0.5246135592460632
# Epoch 93: Iteration 100 with loss 0.6786706447601318
# Epoch 93: Iteration 120 with loss 0.4942213296890259
# Epoch 93: Iteration 140 with loss 0.4385143518447876
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.9 minutes
# iter 30 of Expectation completed in a total of  10.1 minutes
# iter 40 of Expectation completed in a total of  13.4 minutes
# iter 50 of Expectation completed in a total of  16.2 minutes
# Expectation step finished, posterior frame-wise accuracy  62.91%, boundary mse  0.00
# Epoch 93 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.101150987914956
# Other scores:: Edit 60.97850971660879, F1@[10:25:50] [60.65504474 56.76069818 44.73639764]
# Starting Training
# Epoch 94: Iteration 20 with loss 0.37375006079673767
# Epoch 94: Iteration 40 with loss 0.6680423021316528
# Epoch 94: Iteration 60 with loss 0.9546954035758972
# Epoch 94: Iteration 80 with loss 0.5076124668121338
# Epoch 94: Iteration 100 with loss 0.7361437082290649
# Epoch 94: Iteration 120 with loss 0.3241266906261444
# Epoch 94: Iteration 140 with loss 0.5136888027191162
# Epoch 94 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.77067497173184
# Other scores:: Edit 60.255077483889764, F1@[10:25:50] [59.34764672 56.27309329 44.04402605]
# Starting Training
# Epoch 95: Iteration 20 with loss 0.9611630439758301
# Epoch 95: Iteration 40 with loss 0.4284745752811432
# Epoch 95: Iteration 60 with loss 0.8718726634979248
# Epoch 95: Iteration 80 with loss 1.1623954772949219
# Epoch 95: Iteration 100 with loss 0.4410269856452942
# Epoch 95: Iteration 120 with loss 2.2358179092407227
# Epoch 95: Iteration 140 with loss 2.1484808921813965
# Epoch 95 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 48.99149667644887
# Other scores:: Edit 58.21191338347259, F1@[10:25:50] [56.9819783  52.81451591 41.11605103]
# Starting Training
# Epoch 96: Iteration 20 with loss 0.5853111743927002
# Epoch 96: Iteration 40 with loss 1.3140769004821777
# Epoch 96: Iteration 60 with loss 0.5762677788734436
# Epoch 96: Iteration 80 with loss 0.852980375289917
# Epoch 96: Iteration 100 with loss 0.6717665195465088
# Epoch 96: Iteration 120 with loss 0.5180292129516602
# Epoch 96: Iteration 140 with loss 1.3815736770629883
# Epoch 96 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.40752553938261
# Other scores:: Edit 60.88777081405293, F1@[10:25:50] [60.38245604 57.01884786 46.14264935]
# Starting Training
# Epoch 97: Iteration 20 with loss 0.4457772374153137
# Epoch 97: Iteration 40 with loss 0.34774166345596313
# Epoch 97: Iteration 60 with loss 0.35068437457084656
# Epoch 97: Iteration 80 with loss 0.47380197048187256
# Epoch 97: Iteration 100 with loss 0.7722335457801819
# Epoch 97: Iteration 120 with loss 0.7488956451416016
# Epoch 97: Iteration 140 with loss 0.5509614944458008
# Calculating expectation
# iter 10 of Expectation completed in a total of  4.0 minutes
# iter 20 of Expectation completed in a total of  7.0 minutes
# iter 30 of Expectation completed in a total of  9.9 minutes
# iter 40 of Expectation completed in a total of  13.2 minutes
# iter 50 of Expectation completed in a total of  16.4 minutes
# Expectation step finished, posterior frame-wise accuracy  62.75%, boundary mse  0.00
# Epoch 97 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.67916456970307
# Other scores:: Edit 60.14836533923499, F1@[10:25:50] [58.96968195 55.2093049  43.14443843]
# Starting Training
# Epoch 98: Iteration 20 with loss 0.474888414144516
# Epoch 98: Iteration 40 with loss 0.6995047330856323
# Epoch 98: Iteration 60 with loss 2.4199609756469727
# Epoch 98: Iteration 80 with loss 0.6237353682518005
# Epoch 98: Iteration 100 with loss 0.7177958488464355
# Epoch 98: Iteration 120 with loss 1.1094472408294678
# Epoch 98: Iteration 140 with loss 2.854166269302368
# Epoch 98 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 45.42799299341826
# Other scores:: Edit 58.60533374862044, F1@[10:25:50] [54.32996999 51.0860105  39.78794921]
# Starting Training
# Epoch 99: Iteration 20 with loss 1.4990336894989014
# Epoch 99: Iteration 40 with loss 0.9821898937225342
# Epoch 99: Iteration 60 with loss 1.0955578088760376
# Epoch 99: Iteration 80 with loss 0.41990309953689575
# Epoch 99: Iteration 100 with loss 0.954697847366333
# Epoch 99: Iteration 120 with loss 0.6661338210105896
# Epoch 99: Iteration 140 with loss 0.8015400171279907
# Epoch 99 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.709726860959876
# Other scores:: Edit 59.35578403718033, F1@[10:25:50] [58.79502446 55.64427289 44.00257741]
# Starting Training
# Epoch 100: Iteration 20 with loss 2.5647659301757812
# Epoch 100: Iteration 40 with loss 2.0049922466278076
# Epoch 100: Iteration 60 with loss 0.9294883012771606
# Epoch 100: Iteration 80 with loss 0.6474313735961914
# Epoch 100: Iteration 100 with loss 0.8276538848876953
# Epoch 100: Iteration 120 with loss 0.48555895686149597
# Epoch 100: Iteration 140 with loss 0.7210751175880432
# Epoch 100 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 48.667474950816676
# Other scores:: Edit 60.41443642668681, F1@[10:25:50] [59.80460736 56.42704379 43.80784518]
# Starting Training
# Epoch 101: Iteration 20 with loss 0.7917588353157043
# Epoch 101: Iteration 40 with loss 0.44818875193595886
# Epoch 101: Iteration 60 with loss 0.9302865266799927
# Epoch 101: Iteration 80 with loss 1.0629112720489502
# Epoch 101: Iteration 100 with loss 0.6893173456192017
# Epoch 101: Iteration 120 with loss 0.5694635510444641
# Epoch 101: Iteration 140 with loss 0.46115735173225403
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.0 minutes
# iter 20 of Expectation completed in a total of  6.5 minutes
# iter 30 of Expectation completed in a total of  9.8 minutes
# iter 40 of Expectation completed in a total of  13.0 minutes
# Process ForkPoolWorker-20968:
# Process ForkPoolWorker-20974:
# Process ForkPoolWorker-20976:
# Process ForkPoolWorker-20972:
# Process ForkPoolWorker-20962:
# Process ForkPoolWorker-20969:
# Process ForkPoolWorker-20975:
# Traceback (most recent call last):
# Process ForkPoolWorker-20964:
# Process ForkPoolWorker-20973:
# Traceback (most recent call last):
# Process ForkPoolWorker-20970:
# Process ForkPoolWorker-20963:
# Traceback (most recent call last):
# Process ForkPoolWorker-20966:
# Process ForkPoolWorker-20967:
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-20958:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-20957:
# Process ForkPoolWorker-20960:
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dipika16/anaconda3/envs/video_r/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {val_acc}")
# Out:
# Validation:: Epoch 105, Probability Accuracy 61.02425300046298

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {best_val_acc}")
# Out:
# Validation:: Epoch 70, Probability Accuracy 63.49910783730613
# ERROR! Session/line number was not unique in database. History logging moved to new session 4843

# %%
torch.save(model.state_dict(),
"/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-speed/final-em-maximized.wt")

# %%
config.output_dir
# Out:
# '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split1/'

# %%
model.load_state_dict(torch.load(config.output_dir + "ms-tcn-emmax-best-model.wt"))
# model.load_state_dict(torch.load(config.output_dir + "ms-tcn-initial-15-epochs.wt"))
# Out:
# <All keys matched successfully>
