# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
import os, sys
import glob
import numpy as np
import torch
import pandas as pd
import random
import torch.nn as nn
import pickle
import torch.nn.functional as F
import matplotlib.pyplot as plt
import multiprocessing as mp
from time import time

# %%
from mstcn_model import *
from utility.adaptive_data_loader import Breakfast, collate_fn_override
from utility.adaptive_data_loader import BreakfastWithWeights, collate_fn_override_wtd
from utils import calculate_mof, dotdict

# %%
os.environ["WANDB_API_KEY"] = "992b3b1371ba79f48484cfca522b3786d7fa52c2"
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dipika_singhania (use `wandb login --relogin` to force relogin)
# True

# %%
seed = 42

# Ensure deterministic behavior
def set_seed():
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
set_seed()

# Device configuration
os.environ['CUDA_VISIBLE_DEVICES']='4'
# os.environ['CUDA_LAUNCH_BLOCKING']='6'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config = dotdict(
    epochs=500,
    num_class=48,
    batch_size=8,
    learning_rate=5e-4,
    weight_decay=0,
    dataset="Breakfast",
    architecture="unet-ensemble",
    features_file_name="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/",
    chunk_size=1,
    max_frames_per_video=1200,
    feature_size=2048,
    ground_truth_files_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/",
    label_id_csv="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv",
    gamma=0.1,
    step_size=500,
    split=4,
#     output_dir="/mnt/data/ar-datasets/dipika/breakfast/ms_tcn/data/breakfast/results/unsuper-finetune-split2-0.05-data-llr/",
    output_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select5/",
    train_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split{}.bundle",
    test_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split{}.bundle",
    all_files="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt",
    cutoff=8,
    data_per = 0.2,
    budget=40,
    semi_supervised_split="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split{}_amt{}.bundle")

config.train_split_file = config.train_split_file.format(config.split)
config.semi_supervised_split = config.semi_supervised_split.format(config.split, config.data_per)
config.test_split_file = config.test_split_file.format(config.split)

if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)

config.output_dir = config.output_dir + f"split{config.split}"
if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)
config.output_dir = config.output_dir + "/"
if not os.path.exists(os.path.join(config.output_dir, "posterior_weights")):
    os.mkdir(os.path.join(config.output_dir, "posterior_weights"))
print(config)
# Out:
# {'epochs': 500, 'num_class': 48, 'batch_size': 8, 'learning_rate': 0.0005, 'weight_decay': 0, 'dataset': 'Breakfast', 'architecture': 'unet-ensemble', 'features_file_name': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/', 'chunk_size': 1, 'max_frames_per_video': 1200, 'feature_size': 2048, 'ground_truth_files_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/', 'label_id_csv': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv', 'gamma': 0.1, 'step_size': 500, 'split': 4, 'output_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select5/split4/', 'train_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split4.bundle', 'test_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split4.bundle', 'all_files': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt', 'cutoff': 8, 'data_per': 0.2, 'budget': 40, 'semi_supervised_split': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split4_amt0.2.bundle'}

# %%
traindataset = BreakfastWithWeights(config, fold='train', fold_file_name=config.train_split_file)
testdataset = Breakfast(config, fold='test', fold_file_name=config.test_split_file)
# Out:
# Number of videos logged in train fold is 1136
# Number of videos not found in train fold is 0
# Number of videos logged in test fold is 576
# Number of videos not found in test fold is 0

# %%
def _init_fn(worker_id):
    np.random.seed(int(seed))
trainloader = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=config.batch_size, 
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)
testloader = torch.utils.data.DataLoader(dataset=testdataset,
                                          batch_size=config.batch_size, 
                                          shuffle=False,
                                          pin_memory=True, num_workers=4,
                                          collate_fn=lambda x: collate_fn_override(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

trainloder_expectation = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=20,
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

# %%
df = pd.read_csv(config.label_id_csv)
label_id_to_label_name = {}
label_name_to_label_id_dict = {}
for i, ele in df.iterrows():
    label_id_to_label_name[ele.label_id] = ele.label_name
    label_name_to_label_id_dict[ele.label_name] = ele.label_id

# %%
# selected_frames_dict = pickle.load(open("data/breakfast_len_assum_annotations.pkl", 'rb'))
# loaded_vidid_selected_frames
boundary_frames_dict = pickle.load(open("data/breakfast_boundary_annotations.pkl", "rb"))
num_boundary = 0
for key in boundary_frames_dict.keys():
    num_boundary += len(boundary_frames_dict[key])
# video_id_boundary_frames

# %%
selected_frames_dict = pickle.load(open("data/breakfast_random5frame_selection.pkl", "rb"))
# print(selected_frames_dict)

# %%
loaded_mean_var_actions = pickle.load(open("data/breakfast_meanvar_actions.pkl", "rb"))
mat_poisson = pickle.load(open("data/breakfast_possion_class_dict.pkl", "rb"))

def get_possion_prob(minlen, maxlen, cur_class):
    prob = mat_poisson[label_id_to_label_name[cur_class]][minlen:maxlen]
    return torch.tensor(prob)

def get_poisson_logcdf(minlen, cur_class):
    return np.log(np.sum(np.exp(mat_poisson[label_id_to_label_name[cur_class]][minlen:])) + 1e-20)

def get_possion_prob_for_all_class(minlen, maxlen):
    ele_list = []
    for i in range(config.num_class):
        prob = mat_poisson[label_id_to_label_name[i]][minlen:maxlen]
        ele_list.append(torch.tensor(prob))
    return torch.stack(ele_list, dim=-1)

# %%
def validate(model, dataloader, best_val_acc=None):
    model.eval()
    print("Calculating Validation Data Accuracy")
    correct = 0.0
    total = 0.0
    for i, item in enumerate(testloader):
        with torch.no_grad():
            item_0 = item[0].to(device)
            item_1 = item[1].to(device)
            item_2 = item[2].to(device)
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            pred = torch.argmax(predictions[-1], dim=1)
            correct += float(torch.sum((pred == item_2) * src_mask).item())
            total += float(torch.sum(src_mask).item())
    val_acc = correct * 100.0 / total
    if best_val_acc is not None and val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-best-model.wt")
    torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-last-model.wt")
    print(f"Validation:: Probability Accuracy {val_acc}")
    _ = model.train()
    return val_acc, best_val_acc

# %%
def prob_vals_per_segment(selected_frames, cur_vid_feat, labels, first_ele_flag, last_ele_flag, vidid, gt_labels):
    prob_each_segment = []
    LOW_VAL = -10000000
    num_frames = len(cur_vid_feat)
    log_probs = torch.log(cur_vid_feat + 1e-8)
    cumsum_feat = torch.cumsum(log_probs, dim=0)
    prev_boundary = 0
    per_frame_weights = torch.zeros((num_frames, config.num_class))
    start_time = time()
    boundary_error = 0
    current_boundary = 0
    labels = [config.num_class-1] + labels if selected_frames[0] != 0 else labels
    labels = labels + [config.num_class-1] if selected_frames[-1] != num_frames-1 else labels
    selected_frames = [0] + selected_frames if selected_frames[0] != 0 else selected_frames
    selected_frames = selected_frames + [num_frames-1] if selected_frames[-1] != num_frames-1 else selected_frames

    for i, cur_ele in enumerate(selected_frames[:-1]):
        next_ele = selected_frames[i + 1]
        label_cur_ele = labels[i]
        label_next_ele = labels[i + 1]
        if cur_ele == next_ele-1:
            per_frame_weights[cur_ele, label_cur_ele] = 1.0
            if label_cur_ele != label_next_ele:
                prev_boundary = cur_ele
            continue
        
        seg_len = next_ele - cur_ele
        mat_b1_b2_c_prob = LOW_VAL * torch.ones((seg_len, seg_len, config.num_class), dtype=cumsum_feat.dtype)
        b1_prior = get_possion_prob(cur_ele-prev_boundary, next_ele-prev_boundary, label_cur_ele)
        
        # find dummy label where we will keep the diagonal (b1=b2) probabilities, later we will distribute among
        # rest of the classes after the softmax by dividing by (num_class - 2)
        dummy_label = 0
        while True:
            if dummy_label != label_cur_ele and dummy_label != label_next_ele:
                break
            else:
                dummy_label += 1
        
        for b1 in range(cur_ele, next_ele - 1):

            cur_boundary_len = b1 - prev_boundary
            strt_index = cumsum_feat[cur_ele - 1, label_cur_ele] if cur_ele > 0 else 0
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            right_sum = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1+1:next_ele, label_next_ele] # mid_seg_len
            mid_sum = (cumsum_feat[b1+1:next_ele, :] - cumsum_feat[b1, :])  # mid_seg_len
            b2_prior = get_possion_prob_for_all_class(1, next_ele-b1)  # mid_seg_len x num_class
            
            mat_b1_b2_c_prob[b1-cur_ele, b1+1-cur_ele:next_ele-cur_ele] = (left_sum + right_sum[:,None] + mid_sum) \
                                                                            + b1_prior[b1-cur_ele] + b2_prior
            # when mid segment is absent but right and left is not the same
            # we assign the probability to a dummy label for now and then later 
            # re-distribute among other classes after the softmax
            if label_cur_ele != label_next_ele:
                rightsum_wo_midseg = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1, label_next_ele]
                mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + rightsum_wo_midseg + b1_prior[b1-cur_ele]
        
#         if vidid=='P39_cam02_P39_scrambledegg' and cur_ele==574:
#             import pdb
#             pdb.set_trace()
        # when mid segment is absent b1 can also be next_ele-1
        b1 = next_ele - 1
        if label_cur_ele != label_next_ele:
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior[b1-cur_ele]
        else:
            # returns prob that the left class length >= seg len
            b1_prior_ = get_poisson_logcdf(next_ele - prev_boundary, label_cur_ele) 
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior_
        
        mat_b1_b2_c_prob[:, :, label_cur_ele] = LOW_VAL
        mat_b1_b2_c_prob[:, :, label_next_ele] = LOW_VAL
        mat_b1_b2_c_prob = torch.softmax(mat_b1_b2_c_prob.flatten(), dim=0).reshape((seg_len, seg_len, config.num_class))
        
        # re-distribute the dummy class probability among the left-over classes
        left_over_classes = config.num_class - 2 + (label_cur_ele==label_next_ele)
        for b1 in range(cur_ele, next_ele):
            assigned_prob = mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label]
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, :] = assigned_prob/left_over_classes
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_cur_ele] = 0
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_next_ele] = 0
        
        marginal_b1 = torch.sum(mat_b1_b2_c_prob, axis=(1,2))
        mean_b1 = round(torch.sum(marginal_b1.squeeze() * torch.arange(cur_ele, next_ele, 1)).item())
        cumm_b1_prob = torch.cumsum(marginal_b1, dim=0)
        cumm_b1_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=1), dim=0)
        cumm_b2_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=0), dim=0)

        per_frame_weights[cur_ele, label_cur_ele] = 1.0
        per_frame_weights[cur_ele+1:next_ele, :] = cumm_b1_c_prob[:-1] - cumm_b2_c_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_cur_ele] = 1 - cumm_b1_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] = 0
        remaining_probability = 1 - torch.sum(per_frame_weights[cur_ele+1:next_ele, :], dim=-1)
        # we use "+=" in the next line because left and right label might be the same
        # in that case using "=" would just overwrite the previous probability
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] += remaining_probability
        
        expected_boundary = round(torch.sum(torch.sum(mat_b1_b2_c_prob, axis=(0,2)).squeeze() * \
                            torch.arange(cur_ele, next_ele, 1)).item())
        if not (label_cur_ele == label_next_ele and expected_boundary >= next_ele-2):
            prev_boundary = expected_boundary
        if expected_boundary == 0 and i > 0:
            print(f'Estimated boundary has become zero! for {vidid} and cur_ele, next_ele {cur_ele, next_ele}')
            import pdb
            pdb.set_trace()
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary] - mean_b1)**2
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary+1] - prev_boundary)**2
        # current_boundary += 2
        # prob_each_segment.append(mat_b1_b2_c_prob)
        
    posterior_prediction = torch.argmax(per_frame_weights, dim=1)
    correct = torch.sum(posterior_prediction == gt_labels[:num_frames]).item()
    
    return (vidid, per_frame_weights, [correct, num_frames, boundary_error]) #, prob_each_segment)

# %%
posterior_acc_correct, posterior_acc_total = 0, 0
posterior_boundary_total_mse = 0
results = []

# Step 2: Define callback function to collect the output in `results`
def collect_result(result):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    fname = os.path.join(config.output_dir, 'posterior_weights', result[0] + '.wt')
    torch.save(result[1], fname)
    correct, total, boundary_err = result[2]
    posterior_acc_correct += correct
    posterior_acc_total += total
    posterior_boundary_total_mse += boundary_err
    # print(f'Dumped in file {fname} at time {time()}')
    return

def calculate_element_probb(data_feat, data_count, video_ids, gt_labels): # loaded_vidid_selected_frames, boundaries_dict):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    pool = mp.Pool(20)
    for iter_num in range(len(data_count)):
        cur_vidid = video_ids[iter_num]
#         if cur_vidid!='P39_cam02_P39_scrambledegg':
#             continue
        cur_vid_count = data_count[iter_num]
        cur_vid_feat = data_feat[iter_num][:cur_vid_count].detach().cpu()
        cur_gt_labels = gt_labels[iter_num].detach().cpu()
        
        cur_video_select_frames = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices_and_labels = cur_video_select_frames
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]
        with torch.no_grad():
            # Multi-processing
            pool.apply_async(prob_vals_per_segment,
                             args=(selected_frames_indices, cur_vid_feat, selected_frames_labels,
                                   cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels),
                             callback=collect_result)
#             results.append(prob_vals_per_segment(selected_frames_indices, cur_vid_feat, selected_frames_labels,
#                                    cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels))
    # Step 4: Close Pool and let all the processes complete
    pool.close()
    pool.join()  # postpones the execution of next line of code until all processes in the queue are done.
    return results

def perform_expectation(model, dataloader):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse = 0, 0, 0
    model.eval()
    correct = 0.0
    total = 0.0
    curtime = time()
    print(f'Calculating expectation')

    for i, item in enumerate(dataloader):
        with torch.no_grad():
            item_0 = item[0].to(device) # features
            item_1 = item[1].to(device) # count
            item_2 = item[2].to(device) # gt frame-wise labels
            item_4 = item[4] # video-ids
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            prob = torch.softmax(predictions[-1], dim=1)
            prob = prob.permute(0, 2, 1)
            
            calculate_element_probb(prob, item_1, item_4, item_2)
            if (i+1) % 10 == 0:
                print(f"iter {i+1} of Expectation completed in a total of {(time() - curtime)/60.: .1f} minutes")
    _ = model.train()
    print(f'Expectation step finished, '
          f'posterior frame-wise accuracy {100*posterior_acc_correct/posterior_acc_total: .2f}%, '
          f'boundary mse {(posterior_boundary_total_mse/num_boundary)**0.5: .2f}')
    return

# %%
set_seed()
model = MultiStageModel(num_stages=4, num_layers=10, num_f_maps=64, dim=2048, num_classes=48).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

# Requires loaded_vidid_selected_frames, boundaries_dict
ce_criterion = nn.CrossEntropyLoss(ignore_index=-100)
mse_criterion = nn.MSELoss(reduction='none')

# %%
# loaded_file=torch.load(os.path.join(config.output_dir, "ms-tcn-initial-30-epochs.wt"))
# model.load_state_dict(loaded_file)
# # loaded_file=torch.load('/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcnnew-full-supervised-split1/ms-tcn-best-model.wt')
# # model.load_state_dict(loaded_file)
# _ = validate(model, testloader)

# %%
# item = next(iter(trainloader))
    
# with torch.no_grad():
#     item_0 = item[0].to(device) # features
#     item_1 = item[1].to(device) # count
#     item_2 = item[2].to(device) # gt frame-wise labels
#     item_4 = item[4] # video-ids
#     src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
#     src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
#     middle_pred, predictions = model(item_0, src_mask_mse)
#     prob = torch.softmax(predictions[-1], dim=1)
#     prob = prob.permute(0, 2, 1)

#     res = calculate_element_probb(prob, item_1, item_4, item_2)

# %%
# idx = 2
# vidid = res[idx][0]
# mat = res[idx][1]
# mat.shape

# %%
# np.linspace(0, 5281, 4 + 1).astype(int)

# %%
# boundary_frames_dict[f'{vidid}.txt'], selected_frames_dict[f'{vidid}.txt'], weakly_labels[f'{vidid}.txt']

# %%
# fig = plt.figure(figsize=(20, 5))
# for i in range(48):
#     plt.plot(mat[:,i])
    
# for bd in boundary_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd, bd], [0, 2])
    
# for bd in selected_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd[0], bd[0]], [0, 2], '--')

# %%
# bd

# %%
# Calculating Expectation Step
# perform_expectation(model, trainloder_expectation)

# %%
def get_single_random(video_ids, len_frames, device):
    # Generate target for only timestamps. Do not generate pseudo labels at first 30 epochs.
    boundary_target_tensor = torch.ones((len(video_ids), len_frames), dtype=torch.long, device=device) * (-100)
    for iter_num, cur_vidid in enumerate(video_ids):
        selected_frames_indices_and_labels = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]

        frame_idx_tensor = torch.from_numpy(np.array(selected_frames_indices))
        frame_labels = torch.from_numpy(np.array(selected_frames_labels)).to(device)
        boundary_target_tensor[iter_num, frame_idx_tensor] = frame_labels

    return boundary_target_tensor

# %%
weakly_labels = pickle.load(open("data/breakfast_weaklysupervised_labels.pkl", "rb"))
prior_probs = pickle.load(open('data/breakfast_lengthmodel_multinomial_prior.pkl', 'rb'))

# %%
initialize_epoch = 30
expectation_cal_gap = 5
best_val_acc = 0
for epoch in range(0, 150):
    print("Starting Training")
    model.train()
    for i, item in enumerate(trainloader):
        item_0 = item[0].to(device)  # features
        item_1 = item[1].to(device)  # count
        item_2 = item[2].to(device)  # target
        weights = item[5].to(device)  # posterior weight
        src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
        src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
        optimizer.zero_grad()
        
        middle_pred, predictions = model(item_0, src_mask_mse)
        boundary_target_tensor = get_single_random(item[4], item_2.shape[1], item_2.device)
        
        loss = 0
        for p in predictions:
            if epoch <= initialize_epoch:
                loss += ce_criterion(p, boundary_target_tensor)
                loss += 0.15 * torch.mean(torch.clamp(mse_criterion(F.log_softmax(p[:, :, 1:], dim=1), 
                                                                    F.log_softmax(p.detach()[:, :, :-1], dim=1)), min=0,
                                            max=16) * src_mask_mse[:, :, 1:])
            else:
                prob = torch.softmax(p, dim=1)
                prob = prob.permute(0, 2, 1)
                total_count = torch.sum(src_mask)
                weighted_loss_sum = -torch.sum(torch.sum(torch.log(prob + 1e-8) * weights, dim=-1) * src_mask)
                loss += weighted_loss_sum/total_count

        loss.backward()
        optimizer.step()
        if (i+1)%20 == 0:
            print(f'Epoch {epoch+1}: Iteration {i+1} with loss {loss.item()}')

    if (epoch >= initialize_epoch) and ((epoch % (3 * expectation_cal_gap)) == 0):
        torch.save(model.state_dict(), config.output_dir + f"ms-tcn-initial-{epoch}-epochs.wt")

    if epoch >= initialize_epoch and (epoch % expectation_cal_gap == 0):
        perform_expectation(model, trainloder_expectation)
    
    print(f'Epoch {epoch+1} finished, starting validation')
    val_acc, best_val_acc = validate(model, testloader, best_val_acc)
# Out:
# Starting Training
# Epoch 1: Iteration 20 with loss 14.217679023742676
# Epoch 1: Iteration 40 with loss 12.78119945526123
# Epoch 1: Iteration 60 with loss 13.52536392211914
# Epoch 1: Iteration 80 with loss 12.323592185974121
# Epoch 1: Iteration 100 with loss 12.24020004272461
# Epoch 1: Iteration 120 with loss 10.04228687286377
# Epoch 1: Iteration 140 with loss 9.703210830688477
# Epoch 1 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 14.639229668167765
# Starting Training
# Epoch 2: Iteration 20 with loss 10.055891990661621
# Epoch 2: Iteration 40 with loss 11.132219314575195
# Epoch 2: Iteration 60 with loss 11.477500915527344
# Epoch 2: Iteration 80 with loss 10.363356590270996
# Epoch 2: Iteration 100 with loss 12.471477508544922
# Epoch 2: Iteration 120 with loss 8.783330917358398
# Epoch 2: Iteration 140 with loss 7.922874450683594
# Epoch 2 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 15.70598500643795
# Starting Training
# Epoch 3: Iteration 20 with loss 9.160341262817383
# Epoch 3: Iteration 40 with loss 9.286247253417969
# Epoch 3: Iteration 60 with loss 11.47539234161377
# Epoch 3: Iteration 80 with loss 9.36667251586914
# Epoch 3: Iteration 100 with loss 7.11210823059082
# Epoch 3: Iteration 120 with loss 7.35943603515625
# Epoch 3: Iteration 140 with loss 7.855412006378174
# Epoch 3 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 19.460748109464767
# Starting Training
# Epoch 4: Iteration 20 with loss 7.728304862976074
# Epoch 4: Iteration 40 with loss 5.916446685791016
# Epoch 4: Iteration 60 with loss 8.108469009399414
# Epoch 4: Iteration 80 with loss 6.895484447479248
# Epoch 4: Iteration 100 with loss 6.521936893463135
# Epoch 4: Iteration 120 with loss 8.16765308380127
# Epoch 4: Iteration 140 with loss 7.949496746063232
# Epoch 4 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 28.354760488630646
# Starting Training
# Epoch 5: Iteration 20 with loss 6.693455696105957
# Epoch 5: Iteration 40 with loss 6.110170841217041
# Epoch 5: Iteration 60 with loss 7.987651348114014
# Epoch 5: Iteration 80 with loss 5.85536527633667
# Epoch 5: Iteration 100 with loss 5.935023784637451
# Epoch 5: Iteration 120 with loss 8.742684364318848
# Epoch 5: Iteration 140 with loss 6.189477920532227
# Epoch 5 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 33.51124843953229
# Starting Training
# Epoch 6: Iteration 20 with loss 5.425422668457031
# Epoch 6: Iteration 40 with loss 5.1923627853393555
# Epoch 6: Iteration 60 with loss 4.961892127990723
# Epoch 6: Iteration 80 with loss 5.866502285003662
# Epoch 6: Iteration 100 with loss 4.735384464263916
# Epoch 6: Iteration 120 with loss 4.80170202255249
# Epoch 6: Iteration 140 with loss 5.525493144989014
# Epoch 6 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 45.95348662409558
# Starting Training
# Epoch 7: Iteration 20 with loss 4.443910598754883
# Epoch 7: Iteration 40 with loss 4.692445755004883
# Epoch 7: Iteration 60 with loss 4.804225444793701
# Epoch 7: Iteration 80 with loss 3.398496627807617
# Epoch 7: Iteration 100 with loss 7.7137532234191895
# Epoch 7: Iteration 120 with loss 6.439725399017334
# Epoch 7: Iteration 140 with loss 7.067582130432129
# Epoch 7 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 47.26191020856346
# Starting Training
# Epoch 8: Iteration 20 with loss 3.814232110977173
# Epoch 8: Iteration 40 with loss 5.229649066925049
# Epoch 8: Iteration 60 with loss 7.024270057678223
# Epoch 8: Iteration 80 with loss 4.338452339172363
# Epoch 8: Iteration 100 with loss 4.843961715698242
# Epoch 8: Iteration 120 with loss 5.504443168640137
# Epoch 8: Iteration 140 with loss 4.200339317321777
# Epoch 8 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.981950862423936
# Starting Training
# Epoch 9: Iteration 20 with loss 4.037299633026123
# Epoch 9: Iteration 40 with loss 5.752492904663086
# Epoch 9: Iteration 60 with loss 5.0841145515441895
# Epoch 9: Iteration 80 with loss 3.4765470027923584
# Epoch 9: Iteration 100 with loss 3.379728317260742
# Epoch 9: Iteration 120 with loss 5.355557918548584
# Epoch 9: Iteration 140 with loss 5.393301963806152
# Epoch 9 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.05229445944091
# Starting Training
# Epoch 10: Iteration 20 with loss 3.0367534160614014
# Epoch 10: Iteration 40 with loss 4.379177570343018
# Epoch 10: Iteration 60 with loss 2.493271589279175
# Epoch 10: Iteration 80 with loss 3.891716718673706
# Epoch 10: Iteration 100 with loss 3.504570484161377
# Epoch 10: Iteration 120 with loss 3.6904356479644775
# Epoch 10: Iteration 140 with loss 3.300330638885498
# Epoch 10 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.22001124190354
# Starting Training
# Epoch 11: Iteration 20 with loss 2.905808210372925
# Epoch 11: Iteration 40 with loss 4.051952362060547
# Epoch 11: Iteration 60 with loss 4.370927810668945
# Epoch 11: Iteration 80 with loss 4.806469917297363
# Epoch 11: Iteration 100 with loss 4.844200134277344
# Epoch 11: Iteration 120 with loss 4.711698532104492
# Epoch 11: Iteration 140 with loss 5.207767963409424
# Epoch 11 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.511196151608836
# Starting Training
# Epoch 12: Iteration 20 with loss 2.3226568698883057
# Epoch 12: Iteration 40 with loss 2.833200216293335
# Epoch 12: Iteration 60 with loss 4.3489766120910645
# Epoch 12: Iteration 80 with loss 2.537782669067383
# Epoch 12: Iteration 100 with loss 3.3784339427948
# Epoch 12: Iteration 120 with loss 3.7204840183258057
# Epoch 12: Iteration 140 with loss 1.8989458084106445
# Epoch 12 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 48.936757756586644
# Starting Training
# Epoch 13: Iteration 20 with loss 3.738311529159546
# Epoch 13: Iteration 40 with loss 2.5043067932128906
# Epoch 13: Iteration 60 with loss 5.526057243347168
# Epoch 13: Iteration 80 with loss 3.0251107215881348
# Epoch 13: Iteration 100 with loss 3.8468215465545654
# Epoch 13: Iteration 120 with loss 3.8150689601898193
# Epoch 13: Iteration 140 with loss 3.350184202194214
# Epoch 13 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.03708520970725
# Starting Training
# Epoch 14: Iteration 20 with loss 2.8276073932647705
# Epoch 14: Iteration 40 with loss 2.503201961517334
# Epoch 14: Iteration 60 with loss 2.606821060180664
# Epoch 14: Iteration 80 with loss 2.5568459033966064
# Epoch 14: Iteration 100 with loss 1.7723337411880493
# Epoch 14: Iteration 120 with loss 2.384554624557495
# Epoch 14: Iteration 140 with loss 3.2325727939605713
# Epoch 14 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.34562970999811
# Starting Training
# Epoch 15: Iteration 20 with loss 2.1774837970733643
# Epoch 15: Iteration 40 with loss 1.726287603378296
# Epoch 15: Iteration 60 with loss 1.7380352020263672
# Epoch 15: Iteration 80 with loss 2.904445171356201
# Epoch 15: Iteration 100 with loss 2.026223659515381
# Epoch 15: Iteration 120 with loss 2.265679359436035
# Epoch 15: Iteration 140 with loss 3.264049530029297
# Epoch 15 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.23909960195818
# Starting Training
# Epoch 16: Iteration 20 with loss 1.5074082612991333
# Epoch 16: Iteration 40 with loss 2.303452968597412
# Epoch 16: Iteration 60 with loss 2.7540831565856934
# Epoch 16: Iteration 80 with loss 4.276708602905273
# Epoch 16: Iteration 100 with loss 2.71980619430542
# Epoch 16: Iteration 120 with loss 3.405491828918457
# Epoch 16: Iteration 140 with loss 2.292726516723633
# Epoch 16 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.60216079843659
# Starting Training
# Epoch 17: Iteration 20 with loss 2.0969462394714355
# Epoch 17: Iteration 40 with loss 2.289281129837036
# Epoch 17: Iteration 60 with loss 1.5477745532989502
# Epoch 17: Iteration 80 with loss 1.742623209953308
# Epoch 17: Iteration 100 with loss 1.313386082649231
# Epoch 17: Iteration 120 with loss 3.4846150875091553
# Epoch 17: Iteration 140 with loss 3.4360220432281494
# Epoch 17 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.184511009875884
# Starting Training
# Epoch 18: Iteration 20 with loss 2.251577138900757
# Epoch 18: Iteration 40 with loss 1.9582695960998535
# Epoch 18: Iteration 60 with loss 2.7048802375793457
# Epoch 18: Iteration 80 with loss 2.445652723312378
# Epoch 18: Iteration 100 with loss 1.622178316116333
# Epoch 18: Iteration 120 with loss 1.9871718883514404
# Epoch 18: Iteration 140 with loss 1.5397249460220337
# Epoch 18 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.98297047693122
# Starting Training
# Epoch 19: Iteration 20 with loss 1.3762959241867065
# Epoch 19: Iteration 40 with loss 1.3536900281906128
# Epoch 19: Iteration 60 with loss 2.1010806560516357
# Epoch 19: Iteration 80 with loss 2.4444520473480225
# Epoch 19: Iteration 100 with loss 1.1805998086929321
# Epoch 19: Iteration 120 with loss 1.3559106588363647
# Epoch 19: Iteration 140 with loss 1.2390224933624268
# Epoch 19 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.0709743200936
# Starting Training
# Epoch 20: Iteration 20 with loss 1.5665020942687988
# Epoch 20: Iteration 40 with loss 1.2842503786087036
# Epoch 20: Iteration 60 with loss 1.0819518566131592
# Epoch 20: Iteration 80 with loss 1.360605001449585
# Epoch 20: Iteration 100 with loss 1.349020004272461
# Epoch 20: Iteration 120 with loss 1.842605710029602
# Epoch 20: Iteration 140 with loss 1.2437385320663452
# Epoch 20 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.56100366669063
# Starting Training
# Epoch 21: Iteration 20 with loss 1.7866324186325073
# Epoch 21: Iteration 40 with loss 1.694932222366333
# Epoch 21: Iteration 60 with loss 1.5612950325012207
# Epoch 21: Iteration 80 with loss 1.132021427154541
# Epoch 21: Iteration 100 with loss 1.2674732208251953
# Epoch 21: Iteration 120 with loss 1.8180638551712036
# Epoch 21: Iteration 140 with loss 1.2878588438034058
# Epoch 21 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.562876227949204
# Starting Training
# Epoch 22: Iteration 20 with loss 1.515792965888977
# Epoch 22: Iteration 40 with loss 1.293363094329834
# Epoch 22: Iteration 60 with loss 1.404563069343567
# Epoch 22: Iteration 80 with loss 1.232090950012207
# Epoch 22: Iteration 100 with loss 1.3547484874725342
# Epoch 22: Iteration 120 with loss 1.155622959136963
# Epoch 22: Iteration 140 with loss 1.174152135848999
# Epoch 22 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.09588624762253
# Starting Training
# Epoch 23: Iteration 20 with loss 1.2918199300765991
# Epoch 23: Iteration 40 with loss 1.1403491497039795
# Epoch 23: Iteration 60 with loss 3.8949596881866455
# Epoch 23: Iteration 80 with loss 2.093550205230713
# Epoch 23: Iteration 100 with loss 2.3119537830352783
# Epoch 23: Iteration 120 with loss 1.9018031358718872
# Epoch 23: Iteration 140 with loss 2.058781862258911
# Epoch 23 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.10198105869973
# Starting Training
# Epoch 24: Iteration 20 with loss 1.8405259847640991
# Epoch 24: Iteration 40 with loss 1.4267529249191284
# Epoch 24: Iteration 60 with loss 1.300957202911377
# Epoch 24: Iteration 80 with loss 2.150540351867676
# Epoch 24: Iteration 100 with loss 1.2419469356536865
# Epoch 24: Iteration 120 with loss 2.266798496246338
# Epoch 24: Iteration 140 with loss 1.2068419456481934
# Epoch 24 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.505045784612975
# Starting Training
# Epoch 25: Iteration 20 with loss 1.0604045391082764
# Epoch 25: Iteration 40 with loss 0.9560768008232117
# Epoch 25: Iteration 60 with loss 1.1715832948684692
# Epoch 25: Iteration 80 with loss 0.9671657681465149
# Epoch 25: Iteration 100 with loss 0.7713654637336731
# Epoch 25: Iteration 120 with loss 1.332478642463684
# Epoch 25: Iteration 140 with loss 1.382633090019226
# Epoch 25 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.466538996986905
# Starting Training
# Epoch 26: Iteration 20 with loss 1.6386263370513916
# Epoch 26: Iteration 40 with loss 2.7314467430114746
# Epoch 26: Iteration 60 with loss 1.074853539466858
# Epoch 26: Iteration 80 with loss 1.4502421617507935
# Epoch 26: Iteration 100 with loss 1.1252623796463013
# Epoch 26: Iteration 120 with loss 1.838180422782898
# Epoch 26: Iteration 140 with loss 2.356264114379883
# Epoch 26 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.06033372767142
# Starting Training
# Epoch 27: Iteration 20 with loss 0.8179706335067749
# Epoch 27: Iteration 40 with loss 0.9460839629173279
# Epoch 27: Iteration 60 with loss 2.3260254859924316
# Epoch 27: Iteration 80 with loss 1.2774033546447754
# Epoch 27: Iteration 100 with loss 0.9245300889015198
# Epoch 27: Iteration 120 with loss 1.2627270221710205
# Epoch 27: Iteration 140 with loss 1.0046027898788452
# Epoch 27 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.21958640252551
# Starting Training
# Epoch 28: Iteration 20 with loss 1.0997804403305054
# Epoch 28: Iteration 40 with loss 1.0285568237304688
# Epoch 28: Iteration 60 with loss 1.806717038154602
# Epoch 28: Iteration 80 with loss 1.1099635362625122
# Epoch 28: Iteration 100 with loss 1.0748101472854614
# Epoch 28: Iteration 120 with loss 1.082697868347168
# Epoch 28: Iteration 140 with loss 1.1759454011917114
# Epoch 28 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.01998705873895
# Starting Training
# Epoch 29: Iteration 20 with loss 1.2469712495803833
# Epoch 29: Iteration 40 with loss 1.1370755434036255
# Epoch 29: Iteration 60 with loss 1.3448323011398315
# Epoch 29: Iteration 80 with loss 0.8630104064941406
# Epoch 29: Iteration 100 with loss 0.5931492447853088
# Epoch 29: Iteration 120 with loss 0.6548954248428345
# Epoch 29: Iteration 140 with loss 0.7380664944648743
# Epoch 29 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.89955489905163
# Starting Training
# Epoch 30: Iteration 20 with loss 0.9120789170265198
# Epoch 30: Iteration 40 with loss 0.6657635569572449
# Epoch 30: Iteration 60 with loss 0.8711020350456238
# Epoch 30: Iteration 80 with loss 0.4816262722015381
# Epoch 30: Iteration 100 with loss 0.698739767074585
# Epoch 30: Iteration 120 with loss 0.7605284452438354
# Epoch 30: Iteration 140 with loss 0.9068652987480164
# Epoch 30 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.64859247446062
# Starting Training
# Epoch 31: Iteration 20 with loss 0.8529524803161621
# Epoch 31: Iteration 40 with loss 0.5490769147872925
# Epoch 31: Iteration 60 with loss 0.6514748334884644
# Epoch 31: Iteration 80 with loss 0.6558302044868469
# Epoch 31: Iteration 100 with loss 0.895861804485321
# Epoch 31: Iteration 120 with loss 0.9770230054855347
# Epoch 31: Iteration 140 with loss 0.5869612097740173
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.1 minutes
# iter 20 of Expectation completed in a total of  6.3 minutes
# iter 30 of Expectation completed in a total of  9.5 minutes
# iter 40 of Expectation completed in a total of  13.4 minutes
# iter 50 of Expectation completed in a total of  16.8 minutes
# Expectation step finished, posterior frame-wise accuracy  82.10%, boundary mse  0.00
# Epoch 31 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.497454231727005
# Starting Training
# Epoch 32: Iteration 20 with loss 3.446781635284424
# Epoch 32: Iteration 40 with loss 2.2009458541870117
# Epoch 32: Iteration 60 with loss 4.980120658874512
# Epoch 32: Iteration 80 with loss 1.9256706237792969
# Epoch 32: Iteration 100 with loss 4.797480583190918
# Epoch 32: Iteration 120 with loss 6.347405433654785
# Epoch 32: Iteration 140 with loss 5.001199722290039
# Epoch 32 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.57363446819914
# Starting Training
# Epoch 33: Iteration 20 with loss 2.7188239097595215
# Epoch 33: Iteration 40 with loss 2.943826198577881
# Epoch 33: Iteration 60 with loss 2.566718578338623
# Epoch 33: Iteration 80 with loss 2.3891327381134033
# Epoch 33: Iteration 100 with loss 2.2287681102752686
# Epoch 33: Iteration 120 with loss 2.908482074737549
# Epoch 33: Iteration 140 with loss 3.3967366218566895
# Epoch 33 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.067882796619585
# Starting Training
# Epoch 34: Iteration 20 with loss 1.6434916257858276
# Epoch 34: Iteration 40 with loss 2.091320276260376
# Epoch 34: Iteration 60 with loss 1.3390458822250366
# Epoch 34: Iteration 80 with loss 2.3591384887695312
# Epoch 34: Iteration 100 with loss 1.8807940483093262
# Epoch 34: Iteration 120 with loss 1.586317539215088
# Epoch 34: Iteration 140 with loss 1.6360981464385986
# Epoch 34 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.54817678546919
# Starting Training
# Epoch 35: Iteration 20 with loss 1.9300130605697632
# Epoch 35: Iteration 40 with loss 3.2342569828033447
# Epoch 35: Iteration 60 with loss 2.584197521209717
# Epoch 35: Iteration 80 with loss 1.5931880474090576
# Epoch 35: Iteration 100 with loss 1.2340593338012695
# Epoch 35: Iteration 120 with loss 1.7154273986816406
# Epoch 35: Iteration 140 with loss 1.4022796154022217
# Epoch 35 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.4933823096883
# Starting Training
# Epoch 36: Iteration 20 with loss 1.6807384490966797
# Epoch 36: Iteration 40 with loss 1.3622649908065796
# Epoch 36: Iteration 60 with loss 1.734675407409668
# Epoch 36: Iteration 80 with loss 1.2647672891616821
# Epoch 36: Iteration 100 with loss 1.452157735824585
# Epoch 36: Iteration 120 with loss 1.128119707107544
# Epoch 36: Iteration 140 with loss 0.7293345928192139
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.8 minutes
# iter 30 of Expectation completed in a total of  10.0 minutes
# iter 40 of Expectation completed in a total of  13.2 minutes
# iter 50 of Expectation completed in a total of  16.6 minutes
# Expectation step finished, posterior frame-wise accuracy  82.37%, boundary mse  0.00
# Epoch 36 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.2890574448199
# Starting Training
# Epoch 37: Iteration 20 with loss 1.2732311487197876
# Epoch 37: Iteration 40 with loss 1.766036033630371
# Epoch 37: Iteration 60 with loss 1.0204639434814453
# Epoch 37: Iteration 80 with loss 3.8310694694519043
# Epoch 37: Iteration 100 with loss 1.413304328918457
# Epoch 37: Iteration 120 with loss 1.073232889175415
# Epoch 37: Iteration 140 with loss 1.8554368019104004
# Epoch 37 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.15212844528396
# Starting Training
# Epoch 38: Iteration 20 with loss 0.9033912420272827
# Epoch 38: Iteration 40 with loss 0.6905600428581238
# Epoch 38: Iteration 60 with loss 0.9173482656478882
# Epoch 38: Iteration 80 with loss 1.3554493188858032
# Epoch 38: Iteration 100 with loss 1.0461297035217285
# Epoch 38: Iteration 120 with loss 1.153662085533142
# Epoch 38: Iteration 140 with loss 0.48278525471687317
# Epoch 38 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.66755991869228
# Starting Training
# Epoch 39: Iteration 20 with loss 1.1261897087097168
# Epoch 39: Iteration 40 with loss 3.2499191761016846
# Epoch 39: Iteration 60 with loss 1.5045075416564941
# Epoch 39: Iteration 80 with loss 1.3260550498962402
# Epoch 39: Iteration 100 with loss 0.8901587724685669
# Epoch 39: Iteration 120 with loss 1.0820531845092773
# Epoch 39: Iteration 140 with loss 1.0218554735183716
# Epoch 39 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.14616435401538
# Starting Training
# Epoch 40: Iteration 20 with loss 1.31352698802948
# Epoch 40: Iteration 40 with loss 1.1754753589630127
# Epoch 40: Iteration 60 with loss 0.8194985389709473
# Epoch 40: Iteration 80 with loss 1.0871046781539917
# Epoch 40: Iteration 100 with loss 0.692477822303772
# Epoch 40: Iteration 120 with loss 0.9157913327217102
# Epoch 40: Iteration 140 with loss 1.5061668157577515
# Epoch 40 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.22452107530114
# Starting Training
# Epoch 41: Iteration 20 with loss 0.9665331840515137
# Epoch 41: Iteration 40 with loss 1.1207629442214966
# Epoch 41: Iteration 60 with loss 0.8879777789115906
# Epoch 41: Iteration 80 with loss 1.0545766353607178
# Epoch 41: Iteration 100 with loss 1.104320764541626
# Epoch 41: Iteration 120 with loss 0.5973354578018188
# Epoch 41: Iteration 140 with loss 1.8361536264419556
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.7 minutes
# iter 20 of Expectation completed in a total of  6.7 minutes
# iter 30 of Expectation completed in a total of  9.6 minutes
# iter 40 of Expectation completed in a total of  13.6 minutes
# iter 50 of Expectation completed in a total of  16.8 minutes
# Expectation step finished, posterior frame-wise accuracy  80.79%, boundary mse  0.00
# Epoch 41 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.56772266485402
# Starting Training
# Epoch 42: Iteration 20 with loss 2.367703437805176
# Epoch 42: Iteration 40 with loss 3.531538963317871
# Epoch 42: Iteration 60 with loss 1.0512523651123047
# Epoch 42: Iteration 80 with loss 0.9779053330421448
# Epoch 42: Iteration 100 with loss 1.1573972702026367
# Epoch 42: Iteration 120 with loss 3.248040199279785
# Epoch 42: Iteration 140 with loss 1.4252705574035645
# Epoch 42 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.332080601834
# Starting Training
# Epoch 43: Iteration 20 with loss 0.9016155004501343
# Epoch 43: Iteration 40 with loss 1.279389500617981
# Epoch 43: Iteration 60 with loss 1.4877034425735474
# Epoch 43: Iteration 80 with loss 1.2944152355194092
# Epoch 43: Iteration 100 with loss 1.0865981578826904
# Epoch 43: Iteration 120 with loss 0.6919465661048889
# Epoch 43: Iteration 140 with loss 1.3211874961853027
# Epoch 43 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.216249779410326
# Starting Training
# Epoch 44: Iteration 20 with loss 1.1058810949325562
# Epoch 44: Iteration 40 with loss 2.482090711593628
# Epoch 44: Iteration 60 with loss 1.259734869003296
# Epoch 44: Iteration 80 with loss 1.2216238975524902
# Epoch 44: Iteration 100 with loss 1.260067105293274
# Epoch 44: Iteration 120 with loss 1.1701641082763672
# Epoch 44: Iteration 140 with loss 1.4316246509552002
# Epoch 44 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.611193537212664
# Starting Training
# Epoch 45: Iteration 20 with loss 0.8850504159927368
# Epoch 45: Iteration 40 with loss 0.7402818202972412
# Epoch 45: Iteration 60 with loss 0.9088122844696045
# Epoch 45: Iteration 80 with loss 0.9947260618209839
# Epoch 45: Iteration 100 with loss 0.8538205623626709
# Epoch 45: Iteration 120 with loss 0.4998123347759247
# Epoch 45: Iteration 140 with loss 0.8258147835731506
# Epoch 45 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.535457748089854
# Starting Training
# Epoch 46: Iteration 20 with loss 0.542626678943634
# Epoch 46: Iteration 40 with loss 0.4354947805404663
# Epoch 46: Iteration 60 with loss 0.5697106719017029
# Epoch 46: Iteration 80 with loss 0.9209741950035095
# Epoch 46: Iteration 100 with loss 0.7966393232345581
# Epoch 46: Iteration 120 with loss 0.9031133651733398
# Epoch 46: Iteration 140 with loss 0.8112109899520874
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.0 minutes
# iter 30 of Expectation completed in a total of  8.7 minutes
# iter 40 of Expectation completed in a total of  12.5 minutes
# iter 50 of Expectation completed in a total of  15.6 minutes
# Expectation step finished, posterior frame-wise accuracy  80.52%, boundary mse  0.00
# Epoch 46 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.47713056948085
# Starting Training
# Epoch 47: Iteration 20 with loss 0.624854564666748
# Epoch 47: Iteration 40 with loss 0.8015657067298889
# Epoch 47: Iteration 60 with loss 0.5600385665893555
# Epoch 47: Iteration 80 with loss 0.7241014242172241
# Epoch 47: Iteration 100 with loss 0.727142333984375
# Epoch 47: Iteration 120 with loss 1.1022855043411255
# Epoch 47: Iteration 140 with loss 1.2459802627563477
# Epoch 47 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.054817351747396
# Starting Training
# Epoch 48: Iteration 20 with loss 0.7373648881912231
# Epoch 48: Iteration 40 with loss 0.5970630645751953
# Epoch 48: Iteration 60 with loss 0.9869359135627747
# Epoch 48: Iteration 80 with loss 1.7695640325546265
# Epoch 48: Iteration 100 with loss 0.6843478083610535
# Epoch 48: Iteration 120 with loss 0.8423606157302856
# Epoch 48: Iteration 140 with loss 0.510894775390625
# Epoch 48 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.301884326041346
# Starting Training
# Epoch 49: Iteration 20 with loss 0.5317116975784302
# Epoch 49: Iteration 40 with loss 0.853589653968811
# Epoch 49: Iteration 60 with loss 0.6375483274459839
# Epoch 49: Iteration 80 with loss 0.5800040364265442
# Epoch 49: Iteration 100 with loss 1.2874493598937988
# Epoch 49: Iteration 120 with loss 0.6434755325317383
# Epoch 49: Iteration 140 with loss 0.6353471279144287
# Epoch 49 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.46292132628318
# Starting Training
# Epoch 50: Iteration 20 with loss 1.4786109924316406
# Epoch 50: Iteration 40 with loss 0.47015005350112915
# Epoch 50: Iteration 60 with loss 0.581863522529602
# Epoch 50: Iteration 80 with loss 0.671194851398468
# Epoch 50: Iteration 100 with loss 0.49798470735549927
# Epoch 50: Iteration 120 with loss 0.30955517292022705
# Epoch 50: Iteration 140 with loss 3.2660725116729736
# Epoch 50 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.13332440081308
# Starting Training
# Epoch 51: Iteration 20 with loss 0.9384548664093018
# Epoch 51: Iteration 40 with loss 1.1702592372894287
# Epoch 51: Iteration 60 with loss 0.8973808884620667
# Epoch 51: Iteration 80 with loss 0.48986026644706726
# Epoch 51: Iteration 100 with loss 0.755942165851593
# Epoch 51: Iteration 120 with loss 0.5496789216995239
# Epoch 51: Iteration 140 with loss 0.8650802969932556
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  6.6 minutes
# iter 30 of Expectation completed in a total of  9.8 minutes
# iter 40 of Expectation completed in a total of  12.5 minutes
# iter 50 of Expectation completed in a total of  16.3 minutes
# Expectation step finished, posterior frame-wise accuracy  80.29%, boundary mse  0.00
# Epoch 51 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.01871907659527
# Starting Training
# Epoch 52: Iteration 20 with loss 0.41422566771507263
# Epoch 52: Iteration 40 with loss 0.5767622590065002
# Epoch 52: Iteration 60 with loss 0.46833306550979614
# Epoch 52: Iteration 80 with loss 0.9071972370147705
# Epoch 52: Iteration 100 with loss 0.5956477522850037
# Epoch 52: Iteration 120 with loss 1.1663429737091064
# Epoch 52: Iteration 140 with loss 0.8790179491043091
# Epoch 52 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.2950280720789
# Starting Training
# Epoch 53: Iteration 20 with loss 0.4175974726676941
# Epoch 53: Iteration 40 with loss 0.5216884016990662
# Epoch 53: Iteration 60 with loss 0.5759207010269165
# Epoch 53: Iteration 80 with loss 0.7282284498214722
# Epoch 53: Iteration 100 with loss 0.6656083464622498
# Epoch 53: Iteration 120 with loss 0.5400636792182922
# Epoch 53: Iteration 140 with loss 0.3742015063762665
# Epoch 53 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.15246178079595
# Starting Training
# Epoch 54: Iteration 20 with loss 0.4429217576980591
# Epoch 54: Iteration 40 with loss 0.7937074303627014
# Epoch 54: Iteration 60 with loss 0.6292029619216919
# Epoch 54: Iteration 80 with loss 0.5224155187606812
# Epoch 54: Iteration 100 with loss 0.38754600286483765
# Epoch 54: Iteration 120 with loss 0.6101321578025818
# Epoch 54: Iteration 140 with loss 0.3891621530056
# Epoch 54 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.38203844469572
# Starting Training
# Epoch 55: Iteration 20 with loss 0.33994826674461365
# Epoch 55: Iteration 40 with loss 0.41877707839012146
# Epoch 55: Iteration 60 with loss 0.8337496519088745
# Epoch 55: Iteration 80 with loss 0.4469660520553589
# Epoch 55: Iteration 100 with loss 0.6146650314331055
# Epoch 55: Iteration 120 with loss 0.3904951810836792
# Epoch 55: Iteration 140 with loss 0.7900131940841675
# Epoch 55 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.11430793665318
# Starting Training
# Epoch 56: Iteration 20 with loss 0.6705801486968994
# Epoch 56: Iteration 40 with loss 0.4918596148490906
# Epoch 56: Iteration 60 with loss 0.4521731734275818
# Epoch 56: Iteration 80 with loss 0.6201757192611694
# Epoch 56: Iteration 100 with loss 0.3487236797809601
# Epoch 56: Iteration 120 with loss 0.4586581885814667
# Epoch 56: Iteration 140 with loss 0.3861508369445801
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.3 minutes
# iter 30 of Expectation completed in a total of  9.6 minutes
# iter 40 of Expectation completed in a total of  12.7 minutes
# iter 50 of Expectation completed in a total of  16.2 minutes
# Expectation step finished, posterior frame-wise accuracy  80.07%, boundary mse  0.00
# Epoch 56 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.24363884731272
# Starting Training
# Epoch 57: Iteration 20 with loss 0.6177673935890198
# Epoch 57: Iteration 40 with loss 0.5141083002090454
# Epoch 57: Iteration 60 with loss 0.3961184024810791
# Epoch 57: Iteration 80 with loss 0.6516757607460022
# Epoch 57: Iteration 100 with loss 0.4306406080722809
# Epoch 57: Iteration 120 with loss 0.3955517113208771
# Epoch 57: Iteration 140 with loss 0.6242683529853821
# Epoch 57 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.56789913659566
# Starting Training
# Epoch 58: Iteration 20 with loss 0.47407403588294983
# Epoch 58: Iteration 40 with loss 0.4967226982116699
# Epoch 58: Iteration 60 with loss 0.47334930300712585
# Epoch 58: Iteration 80 with loss 0.8823518753051758
# Epoch 58: Iteration 100 with loss 1.2272778749465942
# Epoch 58: Iteration 120 with loss 1.319533348083496
# Epoch 58: Iteration 140 with loss 11.233797073364258
# Epoch 58 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.36037817240636
# Starting Training
# Epoch 59: Iteration 20 with loss 4.378573894500732
# Epoch 59: Iteration 40 with loss 3.300905466079712
# Epoch 59: Iteration 60 with loss 2.7682342529296875
# Epoch 59: Iteration 80 with loss 1.0142184495925903
# Epoch 59: Iteration 100 with loss 1.4071998596191406
# Epoch 59: Iteration 120 with loss 1.0076804161071777
# Epoch 59: Iteration 140 with loss 0.9939176440238953
# Epoch 59 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.48161752691194
# Starting Training
# Epoch 60: Iteration 20 with loss 3.7925076484680176
# Epoch 60: Iteration 40 with loss 3.297088146209717
# Epoch 60: Iteration 60 with loss 1.5587751865386963
# Epoch 60: Iteration 80 with loss 2.344559669494629
# Epoch 60: Iteration 100 with loss 1.2992939949035645
# Epoch 60: Iteration 120 with loss 1.076555848121643
# Epoch 60: Iteration 140 with loss 0.5795436501502991
# Epoch 60 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.84379309668691
# Starting Training
# Epoch 61: Iteration 20 with loss 1.3014127016067505
# Epoch 61: Iteration 40 with loss 0.9021710157394409
# Epoch 61: Iteration 60 with loss 1.1060699224472046
# Epoch 61: Iteration 80 with loss 0.43896764516830444
# Epoch 61: Iteration 100 with loss 0.6835976243019104
# Epoch 61: Iteration 120 with loss 0.43558210134506226
# Epoch 61: Iteration 140 with loss 0.9752806425094604
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  6.9 minutes
# iter 30 of Expectation completed in a total of  10.4 minutes
# iter 40 of Expectation completed in a total of  12.9 minutes
# iter 50 of Expectation completed in a total of  16.4 minutes
# Expectation step finished, posterior frame-wise accuracy  79.97%, boundary mse  0.00
# Epoch 61 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.07231419813202
# Starting Training
# Epoch 62: Iteration 20 with loss 1.005552887916565
# Epoch 62: Iteration 40 with loss 0.5544012784957886
# Epoch 62: Iteration 60 with loss 0.5590804219245911
# Epoch 62: Iteration 80 with loss 0.4976632595062256
# Epoch 62: Iteration 100 with loss 0.4114144742488861
# Epoch 62: Iteration 120 with loss 0.8116844892501831
# Epoch 62: Iteration 140 with loss 0.49539855122566223
# Epoch 62 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.8981300531376
# Starting Training
# Epoch 63: Iteration 20 with loss 0.40427276492118835
# Epoch 63: Iteration 40 with loss 0.40144017338752747
# Epoch 63: Iteration 60 with loss 0.39678022265434265
# Epoch 63: Iteration 80 with loss 0.42920151352882385
# Epoch 63: Iteration 100 with loss 0.528960645198822
# Epoch 63: Iteration 120 with loss 0.37215813994407654
# Epoch 63: Iteration 140 with loss 0.5042397975921631
# Epoch 63 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.41038830319152
# Starting Training
# Epoch 64: Iteration 20 with loss 0.33624178171157837
# Epoch 64: Iteration 40 with loss 0.38494718074798584
# Epoch 64: Iteration 60 with loss 0.2701777517795563
# Epoch 64: Iteration 80 with loss 0.3680213689804077
# Epoch 64: Iteration 100 with loss 0.5215846300125122
# Epoch 64: Iteration 120 with loss 0.34477123618125916
# Epoch 64: Iteration 140 with loss 0.34796905517578125
# Epoch 64 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.77844626435467
# Starting Training
# Epoch 65: Iteration 20 with loss 0.2530730366706848
# Epoch 65: Iteration 40 with loss 0.4325382113456726
# Epoch 65: Iteration 60 with loss 0.27271974086761475
# Epoch 65: Iteration 80 with loss 0.28273865580558777
# Epoch 65: Iteration 100 with loss 0.2581638991832733
# Epoch 65: Iteration 120 with loss 1.4476127624511719
# Epoch 65: Iteration 140 with loss 0.4149177670478821
# Epoch 65 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.73832508709207
# Starting Training
# Epoch 66: Iteration 20 with loss 0.34313011169433594
# Epoch 66: Iteration 40 with loss 0.2884215712547302
# Epoch 66: Iteration 60 with loss 0.2901097238063812
# Epoch 66: Iteration 80 with loss 0.5702936053276062
# Epoch 66: Iteration 100 with loss 0.3359942138195038
# Epoch 66: Iteration 120 with loss 0.34420046210289
# Epoch 66: Iteration 140 with loss 0.28017479181289673
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.7 minutes
# iter 30 of Expectation completed in a total of  9.8 minutes
# iter 40 of Expectation completed in a total of  12.6 minutes
# iter 50 of Expectation completed in a total of  16.0 minutes
# Expectation step finished, posterior frame-wise accuracy  79.77%, boundary mse  0.00
# Epoch 66 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.48391819554377
# Starting Training
# Epoch 67: Iteration 20 with loss 0.519526481628418
# Epoch 67: Iteration 40 with loss 0.20097088813781738
# Epoch 67: Iteration 60 with loss 0.3585469722747803
# Epoch 67: Iteration 80 with loss 0.6248558163642883
# Epoch 67: Iteration 100 with loss 0.36828991770744324
# Epoch 67: Iteration 120 with loss 0.5888885855674744
# Epoch 67: Iteration 140 with loss 0.3275528848171234
# Epoch 67 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.01691514323623
# Starting Training
# Epoch 68: Iteration 20 with loss 0.41109487414360046
# Epoch 68: Iteration 40 with loss 0.3809526562690735
# Epoch 68: Iteration 60 with loss 0.32261931896209717
# Epoch 68: Iteration 80 with loss 0.32276564836502075
# Epoch 68: Iteration 100 with loss 0.32445359230041504
# Epoch 68: Iteration 120 with loss 0.3106687068939209
# Epoch 68: Iteration 140 with loss 0.3216054439544678
# Epoch 68 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.13546820567454
# Starting Training
# Epoch 69: Iteration 20 with loss 0.22851569950580597
# Epoch 69: Iteration 40 with loss 0.3555387258529663
# Epoch 69: Iteration 60 with loss 0.3013395071029663
# Epoch 69: Iteration 80 with loss 0.3196007013320923
# Epoch 69: Iteration 100 with loss 0.38551363348960876
# Epoch 69: Iteration 120 with loss 0.39743173122406006
# Epoch 69: Iteration 140 with loss 0.529391348361969
# Epoch 69 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.93824469440977
# Starting Training
# Epoch 70: Iteration 20 with loss 0.32303792238235474
# Epoch 70: Iteration 40 with loss 0.28724804520606995
# Epoch 70: Iteration 60 with loss 0.2398684173822403
# Epoch 70: Iteration 80 with loss 0.26626479625701904
# Epoch 70: Iteration 100 with loss 0.34812596440315247
# Epoch 70: Iteration 120 with loss 0.2848750948905945
# Epoch 70: Iteration 140 with loss 0.4746520221233368
# Epoch 70 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 64.22345897685605
# Starting Training
# Epoch 71: Iteration 20 with loss 0.1931605190038681
# Epoch 71: Iteration 40 with loss 0.2371848076581955
# Epoch 71: Iteration 60 with loss 0.24512650072574615
# Epoch 71: Iteration 80 with loss 0.23309962451457977
# Epoch 71: Iteration 100 with loss 0.33686038851737976
# Epoch 71: Iteration 120 with loss 0.2908766269683838
# Epoch 71: Iteration 140 with loss 0.41098320484161377
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.8 minutes
# iter 20 of Expectation completed in a total of  5.8 minutes
# iter 30 of Expectation completed in a total of  9.2 minutes
# iter 40 of Expectation completed in a total of  12.7 minutes
# iter 50 of Expectation completed in a total of  16.6 minutes
# Expectation step finished, posterior frame-wise accuracy  79.54%, boundary mse  0.00
# Epoch 71 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.08685024085125
# Starting Training
# Epoch 72: Iteration 20 with loss 0.5050486922264099
# Epoch 72: Iteration 40 with loss 0.5039474368095398
# Epoch 72: Iteration 60 with loss 0.4023950397968292
# Epoch 72: Iteration 80 with loss 0.6661897301673889
# Epoch 72: Iteration 100 with loss 1.0740044116973877
# Epoch 72: Iteration 120 with loss 0.9758930206298828
# Epoch 72: Iteration 140 with loss 0.450892835855484
# Epoch 72 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.10073922051778
# Starting Training
# Epoch 73: Iteration 20 with loss 0.45988520979881287
# Epoch 73: Iteration 40 with loss 0.32177117466926575
# Epoch 73: Iteration 60 with loss 0.4384629428386688
# Epoch 73: Iteration 80 with loss 0.46769797801971436
# Epoch 73: Iteration 100 with loss 0.6911798715591431
# Epoch 73: Iteration 120 with loss 0.6595686078071594
# Epoch 73: Iteration 140 with loss 1.036935806274414
# Epoch 73 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.01103275184805
# Starting Training
# Epoch 74: Iteration 20 with loss 0.3980770707130432
# Epoch 74: Iteration 40 with loss 1.9824851751327515
# Epoch 74: Iteration 60 with loss 0.6121617555618286
# Epoch 74: Iteration 80 with loss 0.5467243194580078
# Epoch 74: Iteration 100 with loss 0.7393275499343872
# Epoch 74: Iteration 120 with loss 0.4920462369918823
# Epoch 74: Iteration 140 with loss 0.5148220658302307
# Epoch 74 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.69412545180034
# Starting Training
# Epoch 75: Iteration 20 with loss 0.33857911825180054
# Epoch 75: Iteration 40 with loss 0.2872137129306793
# Epoch 75: Iteration 60 with loss 0.31228020787239075
# Epoch 75: Iteration 80 with loss 0.4286092519760132
# Epoch 75: Iteration 100 with loss 0.34420034289360046
# Epoch 75: Iteration 120 with loss 0.381570041179657
# Epoch 75: Iteration 140 with loss 0.2547100782394409
# Epoch 75 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.21405695462062
# Starting Training
# Epoch 76: Iteration 20 with loss 1.5191481113433838
# Epoch 76: Iteration 40 with loss 0.779037594795227
# Epoch 76: Iteration 60 with loss 0.5480650067329407
# Epoch 76: Iteration 80 with loss 0.9588024616241455
# Epoch 76: Iteration 100 with loss 1.3661571741104126
# Epoch 76: Iteration 120 with loss 1.22509765625
# Epoch 76: Iteration 140 with loss 0.8385596871376038
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  7.0 minutes
# iter 30 of Expectation completed in a total of  9.7 minutes
# iter 40 of Expectation completed in a total of  13.2 minutes
# iter 50 of Expectation completed in a total of  16.5 minutes
# Expectation step finished, posterior frame-wise accuracy  79.42%, boundary mse  0.00
# Epoch 76 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.30081569160583
# Starting Training
# Epoch 77: Iteration 20 with loss 0.710933268070221
# Epoch 77: Iteration 40 with loss 0.44548463821411133
# Epoch 77: Iteration 60 with loss 0.5647280812263489
# Epoch 77: Iteration 80 with loss 6.571742057800293
# Epoch 77: Iteration 100 with loss 2.1526570320129395
# Epoch 77: Iteration 120 with loss 1.4354029893875122
# Epoch 77: Iteration 140 with loss 1.016074776649475
# Epoch 77 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.18781168504369
# Starting Training
# Epoch 78: Iteration 20 with loss 1.001960039138794
# Epoch 78: Iteration 40 with loss 0.8444405794143677
# Epoch 78: Iteration 60 with loss 0.7376071810722351
# Epoch 78: Iteration 80 with loss 1.619979977607727
# Epoch 78: Iteration 100 with loss 1.2506887912750244
# Epoch 78: Iteration 120 with loss 1.008275032043457
# Epoch 78: Iteration 140 with loss 0.8512020111083984
# Epoch 78 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.38758096458147
# Starting Training
# Epoch 79: Iteration 20 with loss 0.5218756198883057
# Epoch 79: Iteration 40 with loss 0.8123030662536621
# Epoch 79: Iteration 60 with loss 0.7039310336112976
# Epoch 79: Iteration 80 with loss 0.6328194737434387
# Epoch 79: Iteration 100 with loss 0.7593283653259277
# Epoch 79: Iteration 120 with loss 0.42929843068122864
# Epoch 79: Iteration 140 with loss 0.5871245265007019
# Epoch 79 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.67263838325741
# Starting Training
# Epoch 80: Iteration 20 with loss 0.2726607620716095
# Epoch 80: Iteration 40 with loss 0.3898933529853821
# Epoch 80: Iteration 60 with loss 2.551274299621582
# Epoch 80: Iteration 80 with loss 0.4544035792350769
# Epoch 80: Iteration 100 with loss 0.43729594349861145
# Epoch 80: Iteration 120 with loss 1.058940052986145
# Epoch 80: Iteration 140 with loss 0.40523937344551086
# Epoch 80 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.61797462728514
# Starting Training
# Epoch 81: Iteration 20 with loss 0.3370932638645172
# Epoch 81: Iteration 40 with loss 0.24127009510993958
# Epoch 81: Iteration 60 with loss 0.35079556703567505
# Epoch 81: Iteration 80 with loss 0.24114015698432922
# Epoch 81: Iteration 100 with loss 0.37414267659187317
# Epoch 81: Iteration 120 with loss 0.31693464517593384
# Epoch 81: Iteration 140 with loss 0.46188971400260925
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  7.0 minutes
# iter 30 of Expectation completed in a total of  10.4 minutes
# iter 40 of Expectation completed in a total of  13.5 minutes
# iter 50 of Expectation completed in a total of  16.6 minutes
# Expectation step finished, posterior frame-wise accuracy  79.36%, boundary mse  0.00
# Epoch 81 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.177210308564106
# Starting Training
# Epoch 82: Iteration 20 with loss 0.2448311299085617
# Epoch 82: Iteration 40 with loss 0.5799921751022339
# Epoch 82: Iteration 60 with loss 0.3859696090221405
# Epoch 82: Iteration 80 with loss 0.4188782274723053
# Epoch 82: Iteration 100 with loss 0.2647131383419037
# Epoch 82: Iteration 120 with loss 0.4618924856185913
# Epoch 82: Iteration 140 with loss 0.29640233516693115
# Epoch 82 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.033173419434114
# Starting Training
# Epoch 83: Iteration 20 with loss 0.22913816571235657
# Epoch 83: Iteration 40 with loss 0.30554091930389404
# Epoch 83: Iteration 60 with loss 0.38982638716697693
# Epoch 83: Iteration 80 with loss 0.45703864097595215
# Epoch 83: Iteration 100 with loss 0.40464726090431213
# Epoch 83: Iteration 120 with loss 0.42789632081985474
# Epoch 83: Iteration 140 with loss 0.6248990297317505
# Epoch 83 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.635049902286944
# Starting Training
# Epoch 84: Iteration 20 with loss 0.5272115468978882
# Epoch 84: Iteration 40 with loss 0.4389702081680298
# Epoch 84: Iteration 60 with loss 0.8907177448272705
# Epoch 84: Iteration 80 with loss 0.45616739988327026
# Epoch 84: Iteration 100 with loss 0.3564595878124237
# Epoch 84: Iteration 120 with loss 0.43118059635162354
# Epoch 84: Iteration 140 with loss 0.2918696105480194
# Epoch 84 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.08791233929634
# Starting Training
# Epoch 85: Iteration 20 with loss 0.31417611241340637
# Epoch 85: Iteration 40 with loss 0.31651994585990906
# Epoch 85: Iteration 60 with loss 0.18976572155952454
# Epoch 85: Iteration 80 with loss 0.41061630845069885
# Epoch 85: Iteration 100 with loss 0.25013455748558044
# Epoch 85: Iteration 120 with loss 0.21153974533081055
# Epoch 85: Iteration 140 with loss 0.2798320949077606
# Epoch 85 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.23121392950281
# Starting Training
# ...
# Epoch 124: Iteration 100 with loss 0.3987845480442047
# Epoch 124: Iteration 120 with loss 0.557976484298706
# Epoch 124: Iteration 140 with loss 0.7797476649284363
# Epoch 124 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.255861149419275
# Starting Training
# Epoch 125: Iteration 20 with loss 0.5097463130950928
# Epoch 125: Iteration 40 with loss 1.273223638534546
# Epoch 125: Iteration 60 with loss 1.2995953559875488
# Epoch 125: Iteration 80 with loss 1.353310465812683
# Epoch 125: Iteration 100 with loss 1.8533735275268555
# Epoch 125: Iteration 120 with loss 1.1627237796783447
# Epoch 125: Iteration 140 with loss 0.5639163851737976
# Epoch 125 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.13324923692312
# Starting Training
# Epoch 126: Iteration 20 with loss 0.7816523313522339
# Epoch 126: Iteration 40 with loss 0.6472943425178528
# Epoch 126: Iteration 60 with loss 0.5882596373558044
# Epoch 126: Iteration 80 with loss 0.7262319922447205
# Epoch 126: Iteration 100 with loss 0.5785765051841736
# Epoch 126: Iteration 120 with loss 0.6242488622665405
# Epoch 126: Iteration 140 with loss 0.6370915770530701
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  6.8 minutes
# iter 30 of Expectation completed in a total of  9.9 minutes
# iter 40 of Expectation completed in a total of  12.7 minutes
# iter 50 of Expectation completed in a total of  15.7 minutes
# Expectation step finished, posterior frame-wise accuracy  76.41%, boundary mse  0.00
# Epoch 126 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.179641697004556
# Starting Training
# Epoch 127: Iteration 20 with loss 0.3711364269256592
# Epoch 127: Iteration 40 with loss 0.7178770899772644
# Epoch 127: Iteration 60 with loss 1.1878949403762817
# Epoch 127: Iteration 80 with loss 0.41406145691871643
# Epoch 127: Iteration 100 with loss 1.177527904510498
# Epoch 127: Iteration 120 with loss 2.469975471496582
# Epoch 127: Iteration 140 with loss 0.5760956406593323
# Epoch 127 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.391394714998135
# Starting Training
# Epoch 128: Iteration 20 with loss 0.45018279552459717
# Epoch 128: Iteration 40 with loss 1.0099713802337646
# Epoch 128: Iteration 60 with loss 0.5870299339294434
# Epoch 128: Iteration 80 with loss 0.5135828256607056
# Epoch 128: Iteration 100 with loss 0.5978683829307556
# Epoch 128: Iteration 120 with loss 0.3796587288379669
# Epoch 128: Iteration 140 with loss 0.3756265640258789
# Epoch 128 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.086101869946866
# Starting Training
# Epoch 129: Iteration 20 with loss 0.3023592531681061
# Epoch 129: Iteration 40 with loss 0.3730090260505676
# Epoch 129: Iteration 60 with loss 0.3440699279308319
# Epoch 129: Iteration 80 with loss 1.0069202184677124
# Epoch 129: Iteration 100 with loss 0.5724364519119263
# Epoch 129: Iteration 120 with loss 0.2724665701389313
# Epoch 129: Iteration 140 with loss 0.4084838926792145
# Epoch 129 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.73038059072282
# Starting Training
# Epoch 130: Iteration 20 with loss 0.29317590594291687
# Epoch 130: Iteration 40 with loss 0.25351500511169434
# Epoch 130: Iteration 60 with loss 0.43079137802124023
# Epoch 130: Iteration 80 with loss 0.2548654079437256
# Epoch 130: Iteration 100 with loss 0.263663649559021
# Epoch 130: Iteration 120 with loss 0.2796346843242645
# Epoch 130: Iteration 140 with loss 0.21114228665828705
# Epoch 130 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.405378466525924
# Starting Training
# Epoch 131: Iteration 20 with loss 0.43526196479797363
# Epoch 131: Iteration 40 with loss 0.2217891663312912
# Epoch 131: Iteration 60 with loss 0.23041287064552307
# Epoch 131: Iteration 80 with loss 0.5121475458145142
# Epoch 131: Iteration 100 with loss 0.32722312211990356
# Epoch 131: Iteration 120 with loss 0.34963977336883545
# Epoch 131: Iteration 140 with loss 0.2521432638168335
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  8.8 minutes
# iter 40 of Expectation completed in a total of  12.0 minutes
# iter 50 of Expectation completed in a total of  15.1 minutes
# Expectation step finished, posterior frame-wise accuracy  76.35%, boundary mse  0.00
# Epoch 131 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.39957777501814
# Starting Training
# Epoch 132: Iteration 20 with loss 0.22612078487873077
# Epoch 132: Iteration 40 with loss 0.20075851678848267
# Epoch 132: Iteration 60 with loss 0.28366339206695557
# Epoch 132: Iteration 80 with loss 0.22702938318252563
# Epoch 132: Iteration 100 with loss 0.30956751108169556
# Epoch 132: Iteration 120 with loss 0.27366000413894653
# Epoch 132: Iteration 140 with loss 0.22206974029541016
# Epoch 132 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.12531127654429
# Starting Training
# Epoch 133: Iteration 20 with loss 0.2812727391719818
# Epoch 133: Iteration 40 with loss 0.24398884177207947
# Epoch 133: Iteration 60 with loss 0.19870153069496155
# Epoch 133: Iteration 80 with loss 0.22138187289237976
# Epoch 133: Iteration 100 with loss 0.22992950677871704
# Epoch 133: Iteration 120 with loss 0.9298880100250244
# Epoch 133: Iteration 140 with loss 0.40316662192344666
# Epoch 133 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.28242014653691
# Starting Training
# Epoch 134: Iteration 20 with loss 0.2852685749530792
# Epoch 134: Iteration 40 with loss 0.4537321627140045
# Epoch 134: Iteration 60 with loss 0.34178417921066284
# Epoch 134: Iteration 80 with loss 0.36297544836997986
# Epoch 134: Iteration 100 with loss 0.2969565987586975
# Epoch 134: Iteration 120 with loss 0.402170866727829
# Epoch 134: Iteration 140 with loss 0.34100717306137085
# Epoch 134 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.303417015797486
# Starting Training
# Epoch 135: Iteration 20 with loss 0.47402364015579224
# Epoch 135: Iteration 40 with loss 0.3132977783679962
# Epoch 135: Iteration 60 with loss 0.3329334557056427
# Epoch 135: Iteration 80 with loss 0.27292272448539734
# Epoch 135: Iteration 100 with loss 0.2272236943244934
# Epoch 135: Iteration 120 with loss 0.34756362438201904
# Epoch 135: Iteration 140 with loss 0.22948476672172546
# Epoch 135 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.73103418976594
# Starting Training
# Epoch 136: Iteration 20 with loss 0.23749327659606934
# Epoch 136: Iteration 40 with loss 0.12747570872306824
# Epoch 136: Iteration 60 with loss 0.2667020857334137
# Epoch 136: Iteration 80 with loss 0.19406841695308685
# Epoch 136: Iteration 100 with loss 0.154619500041008
# Epoch 136: Iteration 120 with loss 0.17395776510238647
# Epoch 136: Iteration 140 with loss 0.2896367907524109
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.7 minutes
# iter 20 of Expectation completed in a total of  6.7 minutes
# iter 30 of Expectation completed in a total of  9.6 minutes
# iter 40 of Expectation completed in a total of  12.5 minutes
# iter 50 of Expectation completed in a total of  15.9 minutes
# Expectation step finished, posterior frame-wise accuracy  76.24%, boundary mse  0.00
# Epoch 136 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.76167164491271
# Starting Training
# Epoch 137: Iteration 20 with loss 0.18544040620326996
# Epoch 137: Iteration 40 with loss 0.1663830280303955
# Epoch 137: Iteration 60 with loss 0.31321707367897034
# Epoch 137: Iteration 80 with loss 0.14710329473018646
# Epoch 137: Iteration 100 with loss 0.3234362006187439
# Epoch 137: Iteration 120 with loss 0.39911189675331116
# Epoch 137: Iteration 140 with loss 0.41450637578964233
# Epoch 137 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.689210386995995
# Starting Training
# Epoch 138: Iteration 20 with loss 0.16989484429359436
# Epoch 138: Iteration 40 with loss 0.2169719934463501
# Epoch 138: Iteration 60 with loss 0.24259895086288452
# Epoch 138: Iteration 80 with loss 0.18113167583942413
# Epoch 138: Iteration 100 with loss 0.22092603147029877
# Epoch 138: Iteration 120 with loss 0.21464335918426514
# Epoch 138: Iteration 140 with loss 0.24951063096523285
# Epoch 138 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.51755240230328
# Starting Training
# Epoch 139: Iteration 20 with loss 0.16205447912216187
# Epoch 139: Iteration 40 with loss 0.27856913208961487
# Epoch 139: Iteration 60 with loss 0.2043805569410324
# Epoch 139: Iteration 80 with loss 0.16105304658412933
# Epoch 139: Iteration 100 with loss 0.20591197907924652
# Epoch 139: Iteration 120 with loss 0.17869113385677338
# Epoch 139: Iteration 140 with loss 0.27787551283836365
# Epoch 139 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.99581696612396
# Starting Training
# Epoch 140: Iteration 20 with loss 0.17767846584320068
# Epoch 140: Iteration 40 with loss 0.13790860772132874
# Epoch 140: Iteration 60 with loss 0.2742565870285034
# Epoch 140: Iteration 80 with loss 0.16160060465335846
# Epoch 140: Iteration 100 with loss 0.173495352268219
# Epoch 140: Iteration 120 with loss 0.3206039369106293
# Epoch 140: Iteration 140 with loss 0.17519919574260712
# Epoch 140 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.81355106896123
# Starting Training
# Epoch 141: Iteration 20 with loss 0.1332099437713623
# Epoch 141: Iteration 40 with loss 0.17992961406707764
# Epoch 141: Iteration 60 with loss 0.15390703082084656
# Epoch 141: Iteration 80 with loss 0.15643692016601562
# Epoch 141: Iteration 100 with loss 0.28993305563926697
# Epoch 141: Iteration 120 with loss 0.22591868042945862
# Epoch 141: Iteration 140 with loss 0.2757861614227295
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.8 minutes
# iter 30 of Expectation completed in a total of  10.1 minutes
# iter 40 of Expectation completed in a total of  12.8 minutes
# iter 50 of Expectation completed in a total of  16.0 minutes
# Expectation step finished, posterior frame-wise accuracy  76.18%, boundary mse  0.00
# Epoch 141 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.382427336126376
# Starting Training
# Epoch 142: Iteration 20 with loss 0.16622713208198547
# Epoch 142: Iteration 40 with loss 0.15840934216976166
# Epoch 142: Iteration 60 with loss 0.1409323364496231
# Epoch 142: Iteration 80 with loss 0.18820655345916748
# Epoch 142: Iteration 100 with loss 0.12152986228466034
# Epoch 142: Iteration 120 with loss 0.16909104585647583
# Epoch 142: Iteration 140 with loss 0.19428713619709015
# Epoch 142 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.17049784639115
# Starting Training
# Epoch 143: Iteration 20 with loss 0.26420438289642334
# Epoch 143: Iteration 40 with loss 0.1225876733660698
# Epoch 143: Iteration 60 with loss 0.1687760353088379
# Epoch 143: Iteration 80 with loss 0.24668586254119873
# Epoch 143: Iteration 100 with loss 0.16782011091709137
# Epoch 143: Iteration 120 with loss 0.22868284583091736
# Epoch 143: Iteration 140 with loss 0.14881233870983124
# Epoch 143 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.41951254583363
# Starting Training
# Epoch 144: Iteration 20 with loss 0.21756036579608917
# Epoch 144: Iteration 40 with loss 0.17019063234329224
# Epoch 144: Iteration 60 with loss 0.27876007556915283
# Epoch 144: Iteration 80 with loss 0.18848246335983276
# Epoch 144: Iteration 100 with loss 0.2644527554512024
# Epoch 144: Iteration 120 with loss 0.28513142466545105
# Epoch 144: Iteration 140 with loss 0.1475541591644287
# Epoch 144 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.08495807162139
# Starting Training
# Epoch 145: Iteration 20 with loss 0.3480883538722992
# Epoch 145: Iteration 40 with loss 0.20310942828655243
# Epoch 145: Iteration 60 with loss 0.19199275970458984
# Epoch 145: Iteration 80 with loss 0.2578650414943695
# Epoch 145: Iteration 100 with loss 0.1947259157896042
# Epoch 145: Iteration 120 with loss 0.3764953017234802
# Epoch 145: Iteration 140 with loss 0.45954620838165283
# Epoch 145 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.34058392538513
# Starting Training
# Epoch 146: Iteration 20 with loss 0.19806422293186188
# Epoch 146: Iteration 40 with loss 0.585477888584137
# Epoch 146: Iteration 60 with loss 0.4201303720474243
# Epoch 146: Iteration 80 with loss 0.33910828828811646
# Epoch 146: Iteration 100 with loss 0.24134176969528198
# Epoch 146: Iteration 120 with loss 1.3713011741638184
# Epoch 146: Iteration 140 with loss 0.6179308295249939
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.6 minutes
# iter 30 of Expectation completed in a total of  10.5 minutes
# iter 40 of Expectation completed in a total of  13.3 minutes
# iter 50 of Expectation completed in a total of  16.0 minutes
# Expectation step finished, posterior frame-wise accuracy  75.94%, boundary mse  0.00
# Epoch 146 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.725295590167256
# Starting Training
# Epoch 147: Iteration 20 with loss 1.9732052087783813
# Epoch 147: Iteration 40 with loss 1.52163565158844
# Epoch 147: Iteration 60 with loss 0.8862005472183228
# Epoch 147: Iteration 80 with loss 0.8193527460098267
# Epoch 147: Iteration 100 with loss 0.6379202008247375
# Epoch 147: Iteration 120 with loss 0.622241199016571
# Epoch 147: Iteration 140 with loss 2.090153694152832
# Epoch 147 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.622441976744945
# Starting Training
# Epoch 148: Iteration 20 with loss 1.4637410640716553
# Epoch 148: Iteration 40 with loss 1.8800499439239502
# Epoch 148: Iteration 60 with loss 1.1313456296920776
# Epoch 148: Iteration 80 with loss 0.6079967021942139
# Epoch 148: Iteration 100 with loss 0.8231786489486694
# Epoch 148: Iteration 120 with loss 1.0251344442367554
# Epoch 148: Iteration 140 with loss 0.49830299615859985
# Epoch 148 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.60006274550814
# Starting Training
# Epoch 149: Iteration 20 with loss 0.6830756664276123
# Epoch 149: Iteration 40 with loss 0.4116710126399994
# Epoch 149: Iteration 60 with loss 0.3938855528831482
# Epoch 149: Iteration 80 with loss 0.35954996943473816
# Epoch 149: Iteration 100 with loss 0.4416574239730835
# Epoch 149: Iteration 120 with loss 0.5824332237243652
# Epoch 149: Iteration 140 with loss 0.5657870769500732
# Epoch 149 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.618118419074634
# Starting Training
# Epoch 150: Iteration 20 with loss 0.35281461477279663
# Epoch 150: Iteration 40 with loss 0.48130202293395996
# Epoch 150: Iteration 60 with loss 0.21355198323726654
# Epoch 150: Iteration 80 with loss 0.4996640682220459
# Epoch 150: Iteration 100 with loss 0.4357427954673767
# Epoch 150: Iteration 120 with loss 0.4867507219314575
# Epoch 150: Iteration 140 with loss 0.3092787265777588
# Epoch 150 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.952107530114574

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {val_acc}")
# Out:
# Validation:: Epoch 105, Probability Accuracy 61.02425300046298

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {best_val_acc}")
# Out:
# Validation:: Epoch 149, Probability Accuracy 64.77844626435467

# %%
torch.save(model.state_dict(),
"/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-speed/final-em-maximized.wt")

# %%
config.output_dir
# Out:
# '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split1/'

# %%
model.load_state_dict(torch.load(config.output_dir + "ms-tcn-emmax-best-model.wt"))
# model.load_state_dict(torch.load(config.output_dir + "ms-tcn-initial-15-epochs.wt"))
# Out:
# <All keys matched successfully>
