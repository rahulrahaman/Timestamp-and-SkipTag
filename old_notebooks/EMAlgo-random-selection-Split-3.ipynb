# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
import os, sys
import glob
import numpy as np
import torch
import pandas as pd
import random
import torch.nn as nn
import pickle
import torch.nn.functional as F
import matplotlib.pyplot as plt
import multiprocessing as mp
from time import time

# %%
from mstcn_model import *
from utility.adaptive_data_loader import Breakfast, collate_fn_override
from utility.adaptive_data_loader import BreakfastWithWeights, collate_fn_override_wtd
from utils import calculate_mof, dotdict

# %%
os.environ["WANDB_API_KEY"] = "992b3b1371ba79f48484cfca522b3786d7fa52c2"
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dipika_singhania (use `wandb login --relogin` to force relogin)
# True

# %%
seed = 42

# Ensure deterministic behavior
def set_seed():
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
set_seed()

# Device configuration
os.environ['CUDA_VISIBLE_DEVICES']='5'
# os.environ['CUDA_LAUNCH_BLOCKING']='6'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config = dotdict(
    epochs=500,
    num_class=48,
    batch_size=8,
    learning_rate=5e-4,
    weight_decay=0,
    dataset="Breakfast",
    architecture="unet-ensemble",
    features_file_name="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/",
    chunk_size=1,
    max_frames_per_video=1200,
    feature_size=2048,
    ground_truth_files_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/",
    label_id_csv="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv",
    gamma=0.1,
    step_size=500,
    split=3,
#     output_dir="/mnt/data/ar-datasets/dipika/breakfast/ms_tcn/data/breakfast/results/unsuper-finetune-split2-0.05-data-llr/",
    output_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select4/",
    train_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split{}.bundle",
    test_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split{}.bundle",
    all_files="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt",
    cutoff=8,
    data_per = 0.2,
    budget=40,
    semi_supervised_split="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split{}_amt{}.bundle")

config.train_split_file = config.train_split_file.format(config.split)
config.semi_supervised_split = config.semi_supervised_split.format(config.split, config.data_per)
config.test_split_file = config.test_split_file.format(config.split)

if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)

config.output_dir = config.output_dir + f"split{config.split}"
if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)
config.output_dir = config.output_dir + "/"
if not os.path.exists(os.path.join(config.output_dir, "posterior_weights")):
    os.mkdir(os.path.join(config.output_dir, "posterior_weights"))
print(config)
# Out:
# {'epochs': 500, 'num_class': 48, 'batch_size': 8, 'learning_rate': 0.0005, 'weight_decay': 0, 'dataset': 'Breakfast', 'architecture': 'unet-ensemble', 'features_file_name': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/', 'chunk_size': 1, 'max_frames_per_video': 1200, 'feature_size': 2048, 'ground_truth_files_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/', 'label_id_csv': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv', 'gamma': 0.1, 'step_size': 500, 'split': 3, 'output_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select4/split3/', 'train_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split3.bundle', 'test_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split3.bundle', 'all_files': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt', 'cutoff': 8, 'data_per': 0.2, 'budget': 40, 'semi_supervised_split': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split3_amt0.2.bundle'}

# %%
traindataset = BreakfastWithWeights(config, fold='train', fold_file_name=config.train_split_file)
testdataset = Breakfast(config, fold='test', fold_file_name=config.test_split_file)
# Out:
# Number of videos logged in train fold is 1279
# Number of videos not found in train fold is 0
# Number of videos logged in test fold is 433
# Number of videos not found in test fold is 0

# %%
def _init_fn(worker_id):
    np.random.seed(int(seed))
trainloader = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=config.batch_size, 
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)
testloader = torch.utils.data.DataLoader(dataset=testdataset,
                                          batch_size=config.batch_size, 
                                          shuffle=False,
                                          pin_memory=True, num_workers=4,
                                          collate_fn=lambda x: collate_fn_override(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

trainloder_expectation = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=20,
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

# %%
df = pd.read_csv(config.label_id_csv)
label_id_to_label_name = {}
label_name_to_label_id_dict = {}
for i, ele in df.iterrows():
    label_id_to_label_name[ele.label_id] = ele.label_name
    label_name_to_label_id_dict[ele.label_name] = ele.label_id

# %%
# selected_frames_dict = pickle.load(open("data/breakfast_len_assum_annotations.pkl", 'rb'))
# loaded_vidid_selected_frames
boundary_frames_dict = pickle.load(open("data/breakfast_boundary_annotations.pkl", "rb"))
num_boundary = 0
for key in boundary_frames_dict.keys():
    num_boundary += len(boundary_frames_dict[key])
# video_id_boundary_frames

# %%
selected_frames_dict = pickle.load(open("data/breakfast_random4frame_selection.pkl", "rb"))
# print(selected_frames_dict)

# %%
loaded_mean_var_actions = pickle.load(open("data/breakfast_meanvar_actions.pkl", "rb"))
mat_poisson = pickle.load(open("data/breakfast_possion_class_dict.pkl", "rb"))

def get_possion_prob(minlen, maxlen, cur_class):
    prob = mat_poisson[label_id_to_label_name[cur_class]][minlen:maxlen]
    return torch.tensor(prob)

def get_poisson_logcdf(minlen, cur_class):
    return np.log(np.sum(np.exp(mat_poisson[label_id_to_label_name[cur_class]][minlen:])) + 1e-20)

def get_possion_prob_for_all_class(minlen, maxlen):
    ele_list = []
    for i in range(config.num_class):
        prob = mat_poisson[label_id_to_label_name[i]][minlen:maxlen]
        ele_list.append(torch.tensor(prob))
    return torch.stack(ele_list, dim=-1)

# %%
def validate(model, dataloader, best_val_acc=None):
    model.eval()
    print("Calculating Validation Data Accuracy")
    correct = 0.0
    total = 0.0
    for i, item in enumerate(testloader):
        with torch.no_grad():
            item_0 = item[0].to(device)
            item_1 = item[1].to(device)
            item_2 = item[2].to(device)
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            pred = torch.argmax(predictions[-1], dim=1)
            correct += float(torch.sum((pred == item_2) * src_mask).item())
            total += float(torch.sum(src_mask).item())
    val_acc = correct * 100.0 / total
    if best_val_acc is not None and val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-best-model.wt")
    torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-last-model.wt")
    print(f"Validation:: Probability Accuracy {val_acc}")
    _ = model.train()
    return val_acc, best_val_acc

# %%
def prob_vals_per_segment(selected_frames, cur_vid_feat, labels, first_ele_flag, last_ele_flag, vidid, gt_labels):
    prob_each_segment = []
    LOW_VAL = -10000000
    num_frames = len(cur_vid_feat)
    log_probs = torch.log(cur_vid_feat + 1e-8)
    cumsum_feat = torch.cumsum(log_probs, dim=0)
    prev_boundary = 0
    per_frame_weights = torch.zeros((num_frames, config.num_class))
    start_time = time()
    boundary_error = 0
    current_boundary = 0
    labels = [config.num_class-1] + labels if selected_frames[0] != 0 else labels
    labels = labels + [config.num_class-1] if selected_frames[-1] != num_frames-1 else labels
    selected_frames = [0] + selected_frames if selected_frames[0] != 0 else selected_frames
    selected_frames = selected_frames + [num_frames-1] if selected_frames[-1] != num_frames-1 else selected_frames

    for i, cur_ele in enumerate(selected_frames[:-1]):
        next_ele = selected_frames[i + 1]
        label_cur_ele = labels[i]
        label_next_ele = labels[i + 1]
        if cur_ele == next_ele-1:
            per_frame_weights[cur_ele, label_cur_ele] = 1.0
            if label_cur_ele != label_next_ele:
                prev_boundary = cur_ele
            continue
        
        seg_len = next_ele - cur_ele
        mat_b1_b2_c_prob = LOW_VAL * torch.ones((seg_len, seg_len, config.num_class), dtype=cumsum_feat.dtype)
        b1_prior = get_possion_prob(cur_ele-prev_boundary, next_ele-prev_boundary, label_cur_ele)
        
        # find dummy label where we will keep the diagonal (b1=b2) probabilities, later we will distribute among
        # rest of the classes after the softmax by dividing by (num_class - 2)
        dummy_label = 0
        while True:
            if dummy_label != label_cur_ele and dummy_label != label_next_ele:
                break
            else:
                dummy_label += 1
        
        for b1 in range(cur_ele, next_ele - 1):

            cur_boundary_len = b1 - prev_boundary
            strt_index = cumsum_feat[cur_ele - 1, label_cur_ele] if cur_ele > 0 else 0
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            right_sum = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1+1:next_ele, label_next_ele] # mid_seg_len
            mid_sum = (cumsum_feat[b1+1:next_ele, :] - cumsum_feat[b1, :])  # mid_seg_len
            b2_prior = get_possion_prob_for_all_class(1, next_ele-b1)  # mid_seg_len x num_class
            
            mat_b1_b2_c_prob[b1-cur_ele, b1+1-cur_ele:next_ele-cur_ele] = (left_sum + right_sum[:,None] + mid_sum) \
                                                                            + b1_prior[b1-cur_ele] + b2_prior
            # when mid segment is absent but right and left is not the same
            # we assign the probability to a dummy label for now and then later 
            # re-distribute among other classes after the softmax
            if label_cur_ele != label_next_ele:
                rightsum_wo_midseg = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1, label_next_ele]
                mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + rightsum_wo_midseg + b1_prior[b1-cur_ele]
        
        # when mid segment is absent b1 can also be next_ele-1
        b1 = next_ele - 1
        if label_cur_ele != label_next_ele:
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior[b1-cur_ele]
        else:
            # returns prob that the left class length >= seg len
            b1_prior_ = get_poisson_logcdf(next_ele - prev_boundary, label_cur_ele) 
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior_
        
        mat_b1_b2_c_prob[:, :, label_cur_ele] = LOW_VAL
        mat_b1_b2_c_prob[:, :, label_next_ele] = LOW_VAL
        mat_b1_b2_c_prob = torch.softmax(mat_b1_b2_c_prob.flatten(), dim=0).reshape((seg_len, seg_len, config.num_class))
        
        # re-distribute the dummy class probability among the left-over classes
        left_over_classes = config.num_class - 2 + (label_cur_ele==label_next_ele)
        for b1 in range(cur_ele, next_ele):
            assigned_prob = mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label]
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, :] = assigned_prob/left_over_classes
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_cur_ele] = 0
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_next_ele] = 0
        
        marginal_b1 = torch.sum(mat_b1_b2_c_prob, axis=(1,2))
        mean_b1 = round(torch.sum(marginal_b1.squeeze() * torch.arange(cur_ele, next_ele, 1)).item())
        cumm_b1_prob = torch.cumsum(marginal_b1, dim=0)
        cumm_b1_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=1), dim=0)
        cumm_b2_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=0), dim=0)

        per_frame_weights[cur_ele, label_cur_ele] = 1.0
        per_frame_weights[cur_ele+1:next_ele, :] = cumm_b1_c_prob[:-1] - cumm_b2_c_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_cur_ele] = 1 - cumm_b1_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] = 0
        remaining_probability = 1 - torch.sum(per_frame_weights[cur_ele+1:next_ele, :], dim=-1)
        # we use "+=" in the next line because left and right label might be the same
        # in that case using "=" would just overwrite the previous probability
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] += remaining_probability
        
        expected_boundary = round(torch.sum(torch.sum(mat_b1_b2_c_prob, axis=(0,2)).squeeze() * \
                            torch.arange(cur_ele, next_ele, 1)).item())
        if not (label_cur_ele == label_next_ele and expected_boundary >= next_ele-2):
            prev_boundary = expected_boundary
        if expected_boundary == 0 and i > 0:
            print(f'Estimated boundary has become zero! for {vidid} and cur_ele, next_ele {cur_ele, next_ele}')
            import pdb
            pdb.set_trace()
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary] - mean_b1)**2
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary+1] - prev_boundary)**2
        # current_boundary += 2
        # prob_each_segment.append(mat_b1_b2_c_prob)
        
    posterior_prediction = torch.argmax(per_frame_weights, dim=1)
    correct = torch.sum(posterior_prediction == gt_labels[:num_frames]).item()
    
    return (vidid, per_frame_weights, [correct, num_frames, boundary_error]) #, prob_each_segment)

# %%
posterior_acc_correct, posterior_acc_total = 0, 0
posterior_boundary_total_mse = 0
results = []

# Step 2: Define callback function to collect the output in `results`
def collect_result(result):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    fname = os.path.join(config.output_dir, 'posterior_weights', result[0] + '.wt')
    torch.save(result[1], fname)
    correct, total, boundary_err = result[2]
    posterior_acc_correct += correct
    posterior_acc_total += total
    posterior_boundary_total_mse += boundary_err
    # print(f'Dumped in file {fname} at time {time()}')
    return

def calculate_element_probb(data_feat, data_count, video_ids, gt_labels): # loaded_vidid_selected_frames, boundaries_dict):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    pool = mp.Pool(20)
    for iter_num in range(len(data_count)):
        cur_vidid = video_ids[iter_num]
        cur_vid_count = data_count[iter_num]
        cur_vid_feat = data_feat[iter_num][:cur_vid_count].detach().cpu()
        cur_gt_labels = gt_labels[iter_num].detach().cpu()
        
        cur_video_select_frames = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices_and_labels = cur_video_select_frames
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]
        with torch.no_grad():
            # Multi-processing
            pool.apply_async(prob_vals_per_segment,
                             args=(selected_frames_indices, cur_vid_feat, selected_frames_labels,
                                   cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels),
                             callback=collect_result)
#             results.append(prob_vals_per_segment(selected_frames_indices, cur_vid_feat, selected_frames_labels,
#                                    cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels))
    # Step 4: Close Pool and let all the processes complete
    pool.close()
    pool.join()  # postpones the execution of next line of code until all processes in the queue are done.
    return

def perform_expectation(model, dataloader):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse = 0, 0, 0
    model.eval()
    correct = 0.0
    total = 0.0
    curtime = time()
    print(f'Calculating expectation')

    for i, item in enumerate(dataloader):
        with torch.no_grad():
            item_0 = item[0].to(device) # features
            item_1 = item[1].to(device) # count
            item_2 = item[2].to(device) # gt frame-wise labels
            item_4 = item[4] # video-ids
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            prob = torch.softmax(predictions[-1], dim=1)
            prob = prob.permute(0, 2, 1)
            
            calculate_element_probb(prob, item_1, item_4, item_2)
            if (i+1) % 10 == 0:
                print(f"iter {i+1} of Expectation completed in a total of {(time() - curtime)/60.: .1f} minutes")
    _ = model.train()
    print(f'Expectation step finished, '
          f'posterior frame-wise accuracy {100*posterior_acc_correct/posterior_acc_total: .2f}%, '
          f'boundary mse {(posterior_boundary_total_mse/num_boundary)**0.5: .2f}')
    return

# %%
set_seed()
model = MultiStageModel(num_stages=4, num_layers=10, num_f_maps=64, dim=2048, num_classes=48).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

# Requires loaded_vidid_selected_frames, boundaries_dict
ce_criterion = nn.CrossEntropyLoss(ignore_index=-100)
mse_criterion = nn.MSELoss(reduction='none')

# %%
loaded_file=torch.load(os.path.join(config.output_dir, "ms-tcn-initial-30-epochs.wt"))
model.load_state_dict(loaded_file)
# loaded_file=torch.load('/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcnnew-full-supervised-split1/ms-tcn-best-model.wt')
# model.load_state_dict(loaded_file)
_ = validate(model, testloader)
# Out:
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.71305963694399

# %%
# item = next(iter(trainloader))
    
# with torch.no_grad():
#     item_0 = item[0].to(device) # features
#     item_1 = item[1].to(device) # count
#     item_2 = item[2].to(device) # gt frame-wise labels
#     item_4 = item[4] # video-ids
#     src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
#     src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
#     middle_pred, predictions = model(item_0, src_mask_mse)
#     prob = torch.softmax(predictions[-1], dim=1)
#     prob = prob.permute(0, 2, 1)

#     res = calculate_element_probb(prob, item_1, item_4, item_2)

# %%
# idx = 2
# vidid = res[idx][0]
# mat = res[idx][1]
# mat.shape

# %%
# np.linspace(0, 5281, 4 + 1).astype(int)

# %%
# boundary_frames_dict[f'{vidid}.txt'], selected_frames_dict[f'{vidid}.txt'], weakly_labels[f'{vidid}.txt']

# %%
# fig = plt.figure(figsize=(20, 5))
# for i in range(48):
#     plt.plot(mat[:,i])
    
# for bd in boundary_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd, bd], [0, 2])
    
# for bd in selected_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd[0], bd[0]], [0, 2], '--')

# %%
# bd

# %%
# Calculating Expectation Step
# perform_expectation(model, trainloder_expectation)

# %%
def get_single_random(video_ids, len_frames, device):
    # Generate target for only timestamps. Do not generate pseudo labels at first 30 epochs.
    boundary_target_tensor = torch.ones((len(video_ids), len_frames), dtype=torch.long, device=device) * (-100)
    for iter_num, cur_vidid in enumerate(video_ids):
        selected_frames_indices_and_labels = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]

        frame_idx_tensor = torch.from_numpy(np.array(selected_frames_indices))
        frame_labels = torch.from_numpy(np.array(selected_frames_labels)).to(device)
        boundary_target_tensor[iter_num, frame_idx_tensor] = frame_labels

    return boundary_target_tensor

# %%
weakly_labels = pickle.load(open("data/breakfast_weaklysupervised_labels.pkl", "rb"))
prior_probs = pickle.load(open('data/breakfast_lengthmodel_multinomial_prior.pkl', 'rb'))

# %%
initialize_epoch = 30
expectation_cal_gap = 5
best_val_acc = 0
for epoch in range(30, 150):
    print("Starting Training")
    model.train()
    for i, item in enumerate(trainloader):
        item_0 = item[0].to(device)  # features
        item_1 = item[1].to(device)  # count
        item_2 = item[2].to(device)  # target
        weights = item[5].to(device)  # posterior weight
        src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
        src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
        optimizer.zero_grad()
        
        middle_pred, predictions = model(item_0, src_mask_mse)
        boundary_target_tensor = get_single_random(item[4], item_2.shape[1], item_2.device)
        
        loss = 0
        for p in predictions:
            if epoch <= initialize_epoch:
                loss += ce_criterion(p, boundary_target_tensor)
                loss += 0.15 * torch.mean(torch.clamp(mse_criterion(F.log_softmax(p[:, :, 1:], dim=1), 
                                                                    F.log_softmax(p.detach()[:, :, :-1], dim=1)), min=0,
                                            max=16) * src_mask_mse[:, :, 1:])
            else:
                prob = torch.softmax(p, dim=1)
                prob = prob.permute(0, 2, 1)
                total_count = torch.sum(src_mask)
                weighted_loss_sum = -torch.sum(torch.sum(torch.log(prob + 1e-8) * weights, dim=-1) * src_mask)
                loss += weighted_loss_sum/total_count

        loss.backward()
        optimizer.step()
        if (i+1)%20 == 0:
            print(f'Epoch {epoch+1}: Iteration {i+1} with loss {loss.item()}')

    if (epoch >= initialize_epoch) and ((epoch % (3 * expectation_cal_gap)) == 0):
        torch.save(model.state_dict(), config.output_dir + f"ms-tcn-initial-{epoch}-epochs.wt")

    if epoch >= initialize_epoch and (epoch % expectation_cal_gap == 0):
        perform_expectation(model, trainloder_expectation)
    
    print(f'Epoch {epoch+1} finished, starting validation')
    val_acc, best_val_acc = validate(model, testloader, best_val_acc)
# Out:
# Starting Training
# Epoch 31: Iteration 20 with loss 0.7355397343635559
# Epoch 31: Iteration 40 with loss 0.805980920791626
# Epoch 31: Iteration 60 with loss 0.7162990570068359
# Epoch 31: Iteration 80 with loss 1.6085330247879028
# Epoch 31: Iteration 100 with loss 1.0332382917404175
# Epoch 31: Iteration 120 with loss 3.3151512145996094
# Epoch 31: Iteration 140 with loss 0.6652244329452515
# Epoch 31: Iteration 160 with loss 1.3972336053848267
# Calculating expectation
# iter 10 of Expectation completed in a total of  6.5 minutes
# iter 20 of Expectation completed in a total of  12.3 minutes
# iter 30 of Expectation completed in a total of  17.2 minutes
# iter 40 of Expectation completed in a total of  23.6 minutes
# iter 50 of Expectation completed in a total of  28.9 minutes
# iter 60 of Expectation completed in a total of  32.6 minutes
# Expectation step finished, posterior frame-wise accuracy  74.88%, boundary mse  0.00
# Epoch 31 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.58751346253648
# Starting Training
# Epoch 32: Iteration 20 with loss 4.496201515197754
# Epoch 32: Iteration 40 with loss 1.9810365438461304
# Epoch 32: Iteration 60 with loss 2.2078845500946045
# Epoch 32: Iteration 80 with loss 3.15867018699646
# Epoch 32: Iteration 100 with loss 1.342023491859436
# Epoch 32: Iteration 120 with loss 2.9777140617370605
# Epoch 32: Iteration 140 with loss 2.530714511871338
# Epoch 32: Iteration 160 with loss 2.733193874359131
# Epoch 32 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.977338296103255
# Starting Training
# Epoch 33: Iteration 20 with loss 2.93082857131958
# Epoch 33: Iteration 40 with loss 1.5755207538604736
# Epoch 33: Iteration 60 with loss 1.4639135599136353
# Epoch 33: Iteration 80 with loss 1.9572422504425049
# Epoch 33: Iteration 100 with loss 2.735107183456421
# Epoch 33: Iteration 120 with loss 2.1338512897491455
# Epoch 33: Iteration 140 with loss 2.881730556488037
# Epoch 33: Iteration 160 with loss 3.585744857788086
# Epoch 33 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.00088727183442
# Starting Training
# Epoch 34: Iteration 20 with loss 2.367020606994629
# Epoch 34: Iteration 40 with loss 2.6926846504211426
# Epoch 34: Iteration 60 with loss 2.1540403366088867
# Epoch 34: Iteration 80 with loss 2.130377769470215
# Epoch 34: Iteration 100 with loss 2.0231893062591553
# Epoch 34: Iteration 120 with loss 3.284503936767578
# Epoch 34: Iteration 140 with loss 2.0306193828582764
# Epoch 34: Iteration 160 with loss 2.7241950035095215
# Epoch 34 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.16796781267961
# Starting Training
# Epoch 35: Iteration 20 with loss 2.2280113697052
# Epoch 35: Iteration 40 with loss 1.8336185216903687
# Epoch 35: Iteration 60 with loss 1.1149243116378784
# Epoch 35: Iteration 80 with loss 2.3906941413879395
# Epoch 35: Iteration 100 with loss 2.0529959201812744
# Epoch 35: Iteration 120 with loss 1.6783066987991333
# Epoch 35: Iteration 140 with loss 0.7801708579063416
# Epoch 35: Iteration 160 with loss 2.340947151184082
# Epoch 35 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.55914866546504
# Starting Training
# Epoch 36: Iteration 20 with loss 2.134340524673462
# Epoch 36: Iteration 40 with loss 2.8945441246032715
# Epoch 36: Iteration 60 with loss 1.0545122623443604
# Epoch 36: Iteration 80 with loss 2.639392614364624
# Epoch 36: Iteration 100 with loss 1.936749815940857
# Epoch 36: Iteration 120 with loss 1.8143160343170166
# Epoch 36: Iteration 140 with loss 1.8532993793487549
# Epoch 36: Iteration 160 with loss 3.531057119369507
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  7.4 minutes
# iter 30 of Expectation completed in a total of  10.3 minutes
# iter 40 of Expectation completed in a total of  13.8 minutes
# iter 50 of Expectation completed in a total of  17.4 minutes
# iter 60 of Expectation completed in a total of  21.2 minutes
# Expectation step finished, posterior frame-wise accuracy  74.47%, boundary mse  0.00
# Epoch 36 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.772317118766075
# Starting Training
# Epoch 37: Iteration 20 with loss 1.317158818244934
# Epoch 37: Iteration 40 with loss 2.1048340797424316
# Epoch 37: Iteration 60 with loss 2.126986265182495
# Epoch 37: Iteration 80 with loss 4.029637336730957
# Epoch 37: Iteration 100 with loss 5.07249641418457
# Epoch 37: Iteration 120 with loss 1.7827459573745728
# Epoch 37: Iteration 140 with loss 1.3741856813430786
# Epoch 37: Iteration 160 with loss 1.723582148551941
# Epoch 37 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.22577999006702
# Starting Training
# Epoch 38: Iteration 20 with loss 1.3742644786834717
# Epoch 38: Iteration 40 with loss 2.0837242603302
# Epoch 38: Iteration 60 with loss 2.3432116508483887
# Epoch 38: Iteration 80 with loss 2.496960163116455
# Epoch 38: Iteration 100 with loss 1.6569801568984985
# Epoch 38: Iteration 120 with loss 1.3309190273284912
# Epoch 38: Iteration 140 with loss 1.752813458442688
# Epoch 38: Iteration 160 with loss 1.737900733947754
# Epoch 38 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.58189965457782
# Starting Training
# Epoch 39: Iteration 20 with loss 1.3060474395751953
# Epoch 39: Iteration 40 with loss 1.66896653175354
# Epoch 39: Iteration 60 with loss 1.6102505922317505
# Epoch 39: Iteration 80 with loss 1.4148879051208496
# Epoch 39: Iteration 100 with loss 1.431422233581543
# Epoch 39: Iteration 120 with loss 2.134246826171875
# Epoch 39: Iteration 140 with loss 1.2199597358703613
# Epoch 39: Iteration 160 with loss 1.4297795295715332
# Epoch 39 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.94876702696972
# Starting Training
# Epoch 40: Iteration 20 with loss 0.9175363183021545
# Epoch 40: Iteration 40 with loss 0.9510869979858398
# Epoch 40: Iteration 60 with loss 1.2435734272003174
# Epoch 40: Iteration 80 with loss 1.8392833471298218
# Epoch 40: Iteration 100 with loss 0.8255236148834229
# Epoch 40: Iteration 120 with loss 1.4591879844665527
# Epoch 40: Iteration 140 with loss 1.3699769973754883
# Epoch 41: Iteration 80 with loss 1.7445306777954102
# Epoch 41: Iteration 100 with loss 1.4875869750976562
# Epoch 41: Iteration 120 with loss 1.2529033422470093
# Epoch 41: Iteration 140 with loss 1.2991321086883545
# Epoch 41: Iteration 160 with loss 0.8561335802078247
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  6.7 minutes
# iter 30 of Expectation completed in a total of  9.9 minutes
# iter 40 of Expectation completed in a total of  13.2 minutes
# iter 50 of Expectation completed in a total of  17.4 minutes
# iter 60 of Expectation completed in a total of  20.5 minutes
# Expectation step finished, posterior frame-wise accuracy  74.68%, boundary mse  0.00
# Epoch 41 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.42232465220618
# Starting Training
# Epoch 42: Iteration 20 with loss 2.2507402896881104
# Epoch 42: Iteration 40 with loss 2.113532066345215
# Epoch 42: Iteration 60 with loss 1.6965460777282715
# Epoch 42: Iteration 80 with loss 1.110444188117981
# Epoch 42: Iteration 100 with loss 1.047349452972412
# Epoch 42: Iteration 120 with loss 1.8105038404464722
# Epoch 42: Iteration 140 with loss 1.7889776229858398
# Epoch 42: Iteration 160 with loss 1.2779899835586548
# Epoch 42 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.70692127834108
# Starting Training
# Epoch 43: Iteration 20 with loss 2.545682430267334
# Epoch 43: Iteration 40 with loss 2.004094123840332
# Epoch 43: Iteration 60 with loss 1.2387299537658691
# Epoch 43: Iteration 80 with loss 1.0175830125808716
# Epoch 43: Iteration 100 with loss 1.0526045560836792
# Epoch 43: Iteration 120 with loss 1.3636633157730103
# Epoch 43: Iteration 140 with loss 1.5626559257507324
# Epoch 43: Iteration 160 with loss 1.4240248203277588
# Epoch 43 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.89653517558496
# Starting Training
# Epoch 44: Iteration 20 with loss 1.282200813293457
# Epoch 44: Iteration 40 with loss 1.2697211503982544
# Epoch 44: Iteration 60 with loss 1.0786352157592773
# Epoch 44: Iteration 80 with loss 1.0928969383239746
# Epoch 44: Iteration 100 with loss 1.1209237575531006
# Epoch 44: Iteration 120 with loss 0.9506574869155884
# Epoch 44: Iteration 140 with loss 0.6080577373504639
# Epoch 44: Iteration 160 with loss 1.4461511373519897
# Epoch 44 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.70958867417035
# Starting Training
# Epoch 45: Iteration 20 with loss 0.7957040071487427
# Epoch 45: Iteration 40 with loss 1.1295068264007568
# Epoch 45: Iteration 60 with loss 0.5477492213249207
# Epoch 45: Iteration 80 with loss 0.8457913994789124
# Epoch 45: Iteration 100 with loss 2.101506233215332
# Epoch 45: Iteration 120 with loss 0.7417954206466675
# Epoch 45: Iteration 140 with loss 1.038239598274231
# Epoch 45: Iteration 160 with loss 0.7927179336547852
# Epoch 45 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.47241365840593
# Starting Training
# Epoch 46: Iteration 20 with loss 0.5705650448799133
# Epoch 46: Iteration 40 with loss 1.260240912437439
# Epoch 46: Iteration 60 with loss 0.6346489787101746
# Epoch 46: Iteration 80 with loss 0.9583371877670288
# Epoch 46: Iteration 100 with loss 1.3625645637512207
# Epoch 46: Iteration 120 with loss 0.8257241249084473
# Epoch 46: Iteration 140 with loss 0.8604407906532288
# Epoch 46: Iteration 160 with loss 2.2271413803100586
# Calculating expectation
# iter 10 of Expectation completed in a total of  4.1 minutes
# iter 20 of Expectation completed in a total of  7.9 minutes
# iter 30 of Expectation completed in a total of  11.4 minutes
# iter 40 of Expectation completed in a total of  14.6 minutes
# iter 50 of Expectation completed in a total of  18.2 minutes
# iter 60 of Expectation completed in a total of  21.8 minutes
# Expectation step finished, posterior frame-wise accuracy  73.81%, boundary mse  0.00
# Epoch 46 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.86852751937768
# Starting Training
# Epoch 47: Iteration 20 with loss 1.260246753692627
# Epoch 47: Iteration 40 with loss 1.416675329208374
# Epoch 47: Iteration 60 with loss 1.004540205001831
# Epoch 47: Iteration 80 with loss 0.9945470690727234
# Epoch 47: Iteration 100 with loss 2.8805885314941406
# Epoch 47: Iteration 120 with loss 1.6916358470916748
# Epoch 47: Iteration 140 with loss 1.8998370170593262
# Epoch 47: Iteration 160 with loss 1.2788852453231812
# Epoch 47 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.16207498842083
# Starting Training
# Epoch 48: Iteration 20 with loss 1.2225311994552612
# Epoch 48: Iteration 40 with loss 1.1376152038574219
# Epoch 48: Iteration 60 with loss 1.536434292793274
# Epoch 48: Iteration 80 with loss 1.6760649681091309
# Epoch 48: Iteration 100 with loss 0.8810179829597473
# Epoch 48: Iteration 120 with loss 0.7854881286621094
# Epoch 48: Iteration 140 with loss 1.4402711391448975
# Epoch 48: Iteration 160 with loss 1.5202943086624146
# Epoch 48 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.740615286745054
# Starting Training
# Epoch 49: Iteration 20 with loss 1.202818512916565
# Epoch 49: Iteration 40 with loss 0.5606512427330017
# Epoch 49: Iteration 60 with loss 2.6023809909820557
# Epoch 49: Iteration 80 with loss 0.8046906590461731
# Epoch 49: Iteration 100 with loss 0.8384633660316467
# Epoch 49: Iteration 120 with loss 0.8161587119102478
# Epoch 49: Iteration 140 with loss 0.5986698865890503
# Epoch 49: Iteration 160 with loss 0.9687355756759644
# Epoch 49 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.93223810134988
# Starting Training
# Epoch 50: Iteration 20 with loss 0.66971355676651
# Epoch 50: Iteration 40 with loss 1.2854857444763184
# Epoch 50: Iteration 60 with loss 1.1309314966201782
# Epoch 50: Iteration 80 with loss 1.0209980010986328
# Epoch 50: Iteration 100 with loss 0.5056393146514893
# Epoch 50: Iteration 120 with loss 1.0587637424468994
# Epoch 50: Iteration 140 with loss 1.0534449815750122
# Epoch 50: Iteration 160 with loss 0.7144774794578552
# Epoch 50 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.35154937751464
# Starting Training
# Epoch 51: Iteration 20 with loss 0.8588118553161621
# Epoch 51: Iteration 40 with loss 1.057966709136963
# Epoch 51: Iteration 60 with loss 0.5972460508346558
# Epoch 51: Iteration 80 with loss 0.9828322529792786
# Epoch 51: Iteration 100 with loss 0.8457436561584473
# Epoch 51: Iteration 120 with loss 0.8914710283279419
# Epoch 51: Iteration 140 with loss 1.1012835502624512
# Epoch 51: Iteration 160 with loss 2.0633037090301514
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  7.4 minutes
# iter 30 of Expectation completed in a total of  10.1 minutes
# iter 40 of Expectation completed in a total of  13.6 minutes
# iter 50 of Expectation completed in a total of  16.8 minutes
# iter 60 of Expectation completed in a total of  20.7 minutes
# Expectation step finished, posterior frame-wise accuracy  72.40%, boundary mse  0.00
# Epoch 51 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.599438619204136
# Starting Training
# Epoch 52: Iteration 20 with loss 2.249650478363037
# Epoch 52: Iteration 40 with loss 2.1377134323120117
# Epoch 52: Iteration 60 with loss 2.0491783618927
# Epoch 52: Iteration 80 with loss 1.479517936706543
# Epoch 52: Iteration 100 with loss 2.5105292797088623
# Epoch 52: Iteration 120 with loss 1.1090748310089111
# Epoch 52: Iteration 140 with loss 1.4696710109710693
# Epoch 52: Iteration 160 with loss 0.8222895860671997
# Epoch 52 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.31249267582212
# Starting Training
# Epoch 53: Iteration 20 with loss 0.8303227424621582
# Epoch 53: Iteration 40 with loss 0.8220096826553345
# Epoch 53: Iteration 60 with loss 0.7198532819747925
# Epoch 53: Iteration 80 with loss 0.9102045297622681
# Epoch 53: Iteration 100 with loss 0.7203698754310608
# Epoch 53: Iteration 120 with loss 0.9701619744300842
# Epoch 53: Iteration 140 with loss 1.2103303670883179
# Epoch 53: Iteration 160 with loss 2.0287089347839355
# Epoch 53 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.95047460672652
# Starting Training
# Epoch 54: Iteration 20 with loss 2.0365357398986816
# Epoch 54: Iteration 40 with loss 2.062715768814087
# Epoch 54: Iteration 60 with loss 1.0389025211334229
# Epoch 54: Iteration 80 with loss 1.8954362869262695
# Epoch 54: Iteration 100 with loss 2.7375192642211914
# Epoch 54: Iteration 120 with loss 1.5153316259384155
# Epoch 54: Iteration 140 with loss 2.9192471504211426
# Epoch 54: Iteration 160 with loss 1.0802768468856812
# Epoch 54 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.27656095669109
# Starting Training
# Epoch 55: Iteration 20 with loss 1.0105699300765991
# Epoch 55: Iteration 40 with loss 0.7005051374435425
# Epoch 55: Iteration 60 with loss 2.9202070236206055
# Epoch 55: Iteration 80 with loss 1.6470719575881958
# Epoch 55: Iteration 100 with loss 1.0694146156311035
# Epoch 55: Iteration 120 with loss 2.124384880065918
# Epoch 55: Iteration 140 with loss 0.9563804864883423
# Epoch 55: Iteration 160 with loss 1.1258611679077148
# Epoch 55 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.125774967773616
# Starting Training
# Epoch 56: Iteration 20 with loss 0.9729999303817749
# Epoch 56: Iteration 40 with loss 0.9544968008995056
# Epoch 56: Iteration 60 with loss 0.7932450771331787
# Epoch 56: Iteration 80 with loss 3.066196918487549
# Epoch 56: Iteration 100 with loss 0.6998616456985474
# Epoch 56: Iteration 120 with loss 1.1714318990707397
# Epoch 56: Iteration 140 with loss 1.7083017826080322
# Epoch 56: Iteration 160 with loss 1.5700706243515015
# Calculating expectation
# iter 10 of Expectation completed in a total of  4.0 minutes
# iter 20 of Expectation completed in a total of  7.9 minutes
# iter 30 of Expectation completed in a total of  11.0 minutes
# iter 40 of Expectation completed in a total of  14.5 minutes
# iter 50 of Expectation completed in a total of  17.5 minutes
# iter 60 of Expectation completed in a total of  20.5 minutes
# Expectation step finished, posterior frame-wise accuracy  72.97%, boundary mse  0.00
# Epoch 56 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.06762797082605
# Starting Training
# Epoch 57: Iteration 20 with loss 0.6935122013092041
# Epoch 57: Iteration 40 with loss 0.6494072675704956
# Epoch 57: Iteration 60 with loss 0.9717316031455994
# Epoch 57: Iteration 80 with loss 0.6435350775718689
# Epoch 57: Iteration 100 with loss 0.7208994626998901
# Epoch 57: Iteration 120 with loss 1.2331230640411377
# Epoch 57: Iteration 140 with loss 0.8647483587265015
# Epoch 57: Iteration 160 with loss 2.457016706466675
# Epoch 57 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.79453239658261
# Starting Training
# Epoch 58: Iteration 20 with loss 2.284750461578369
# Epoch 58: Iteration 40 with loss 0.8146395683288574
# Epoch 58: Iteration 60 with loss 0.9976813197135925
# Epoch 58: Iteration 80 with loss 1.6154580116271973
# Epoch 58: Iteration 100 with loss 1.3617510795593262
# Epoch 58: Iteration 120 with loss 0.7580644488334656
# Epoch 58: Iteration 140 with loss 0.7029252648353577
# Epoch 58: Iteration 160 with loss 0.7839229106903076
# Epoch 58 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.58592864995173
# Starting Training
# Epoch 59: Iteration 20 with loss 0.7751792669296265
# Epoch 59: Iteration 40 with loss 0.5152550935745239
# Epoch 59: Iteration 60 with loss 0.8787556290626526
# Epoch 59: Iteration 80 with loss 1.799477458000183
# Epoch 59: Iteration 100 with loss 0.9878380298614502
# Epoch 59: Iteration 120 with loss 1.5685083866119385
# Epoch 59: Iteration 140 with loss 0.8911458253860474
# Epoch 59: Iteration 160 with loss 0.6493441462516785
# Epoch 59 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.30255969553741
# Starting Training
# Epoch 60: Iteration 20 with loss 1.115741491317749
# Epoch 60: Iteration 40 with loss 0.6574427485466003
# Epoch 60: Iteration 60 with loss 0.8523111343383789
# Epoch 60: Iteration 80 with loss 0.4940832555294037
# Epoch 60: Iteration 100 with loss 0.8899953365325928
# Epoch 60: Iteration 120 with loss 0.769534707069397
# Epoch 60: Iteration 140 with loss 0.6880707740783691
# Epoch 60: Iteration 160 with loss 0.5896354913711548
# Epoch 60 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.387380650777615
# Starting Training
# Epoch 61: Iteration 20 with loss 0.7385614514350891
# Epoch 61: Iteration 40 with loss 0.5263532996177673
# Epoch 61: Iteration 60 with loss 0.4446195065975189
# Epoch 61: Iteration 80 with loss 0.7925440073013306
# Epoch 61: Iteration 100 with loss 0.5477829575538635
# Epoch 61: Iteration 120 with loss 0.686060905456543
# Epoch 61: Iteration 140 with loss 0.6866169571876526
# Epoch 61: Iteration 160 with loss 0.822916567325592
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.9 minutes
# iter 30 of Expectation completed in a total of  11.3 minutes
# iter 40 of Expectation completed in a total of  14.5 minutes
# iter 50 of Expectation completed in a total of  17.6 minutes
# iter 60 of Expectation completed in a total of  21.4 minutes
# Expectation step finished, posterior frame-wise accuracy  72.61%, boundary mse  0.00
# Epoch 61 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.05657334501482
# Starting Training
# Epoch 62: Iteration 20 with loss 0.5103685259819031
# Epoch 62: Iteration 40 with loss 0.43146535754203796
# Epoch 62: Iteration 60 with loss 0.9794738292694092
# Epoch 62: Iteration 80 with loss 1.1152076721191406
# Epoch 62: Iteration 100 with loss 0.59895920753479
# Epoch 62: Iteration 120 with loss 0.9877979755401611
# Epoch 62: Iteration 140 with loss 0.7702854871749878
# Epoch 62: Iteration 160 with loss 0.7707257270812988
# Epoch 62 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.50099050786547
# Starting Training
# Epoch 63: Iteration 20 with loss 0.6273579597473145
# Epoch 63: Iteration 40 with loss 0.7138277888298035
# Epoch 63: Iteration 60 with loss 0.5013284683227539
# Epoch 63: Iteration 80 with loss 0.8466045260429382
# Epoch 63: Iteration 100 with loss 0.7745832800865173
# Epoch 63: Iteration 120 with loss 1.0495537519454956
# Epoch 63: Iteration 140 with loss 0.46657806634902954
# Epoch 63: Iteration 160 with loss 1.1159005165100098
# Epoch 63 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.269741798315856
# Starting Training
# Epoch 64: Iteration 20 with loss 0.5054175853729248
# Epoch 64: Iteration 40 with loss 0.7146875858306885
# Epoch 64: Iteration 60 with loss 0.4205108880996704
# Epoch 64: Iteration 80 with loss 0.567963719367981
# Epoch 64: Iteration 100 with loss 0.671267569065094
# Epoch 64: Iteration 120 with loss 0.9332952499389648
# Epoch 64: Iteration 140 with loss 0.6544331908226013
# Epoch 64: Iteration 160 with loss 0.9283525943756104
# Epoch 64 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.90847149290462
# Starting Training
# Epoch 65: Iteration 20 with loss 0.47440841794013977
# Epoch 65: Iteration 40 with loss 0.5545642375946045
# Epoch 65: Iteration 60 with loss 0.5542609095573425
# Epoch 65: Iteration 80 with loss 0.31373488903045654
# Epoch 65: Iteration 100 with loss 0.5819838643074036
# Epoch 65: Iteration 120 with loss 0.5823637843132019
# Epoch 65: Iteration 140 with loss 1.6202129125595093
# Epoch 65: Iteration 160 with loss 1.1296848058700562
# Epoch 65 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.77690414674025
# Starting Training
# Epoch 66: Iteration 20 with loss 0.9196585416793823
# Epoch 66: Iteration 40 with loss 0.6093916893005371
# Epoch 66: Iteration 60 with loss 0.9021241664886475
# Epoch 66: Iteration 80 with loss 0.7509263157844543
# Epoch 66: Iteration 100 with loss 0.6017469167709351
# Epoch 66: Iteration 120 with loss 1.4936871528625488
# Epoch 66: Iteration 140 with loss 0.7085279226303101
# Epoch 66: Iteration 160 with loss 0.8145444393157959
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  7.4 minutes
# iter 30 of Expectation completed in a total of  10.8 minutes
# iter 40 of Expectation completed in a total of  15.0 minutes
# iter 50 of Expectation completed in a total of  18.3 minutes
# iter 60 of Expectation completed in a total of  22.2 minutes
# Expectation step finished, posterior frame-wise accuracy  72.87%, boundary mse  0.00
# Epoch 66 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.810480968298165
# Starting Training
# Epoch 67: Iteration 20 with loss 0.5779860019683838
# Epoch 67: Iteration 40 with loss 0.6869878172874451
# Epoch 67: Iteration 60 with loss 2.3465166091918945
# Epoch 67: Iteration 80 with loss 0.8162522315979004
# Epoch 67: Iteration 100 with loss 4.70170783996582
# Epoch 67: Iteration 120 with loss 4.245431900024414
# Epoch 67: Iteration 140 with loss 2.553741931915283
# Epoch 67: Iteration 160 with loss 4.253787040710449
# Epoch 67 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.6360790397375
# Starting Training
# Epoch 68: Iteration 20 with loss 8.60917854309082
# Epoch 68: Iteration 40 with loss 1.6577531099319458
# Epoch 68: Iteration 60 with loss 0.7074027061462402
# Epoch 68: Iteration 80 with loss 0.8725541830062866
# Epoch 68: Iteration 100 with loss 0.9941380023956299
# Epoch 68: Iteration 120 with loss 0.8886053562164307
# Epoch 68: Iteration 140 with loss 0.8534738421440125
# Epoch 68: Iteration 160 with loss 0.6798278093338013
# Epoch 68 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.77555928817362
# Starting Training
# Epoch 69: Iteration 20 with loss 0.5653083324432373
# Epoch 69: Iteration 40 with loss 0.8535141348838806
# Epoch 69: Iteration 60 with loss 0.5829524397850037
# Epoch 69: Iteration 80 with loss 0.7170488834381104
# Epoch 69: Iteration 100 with loss 0.5301536917686462
# Epoch 69: Iteration 120 with loss 0.7979235053062439
# Epoch 69: Iteration 140 with loss 1.483703851699829
# Epoch 69: Iteration 160 with loss 0.7442435026168823
# Epoch 69 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 63.49908761669857
# Starting Training
# Epoch 70: Iteration 20 with loss 1.1227110624313354
# Epoch 70: Iteration 40 with loss 0.6273564100265503
# Epoch 70: Iteration 60 with loss 0.9798964262008667
# Epoch 70: Iteration 80 with loss 2.993922710418701
# Epoch 70: Iteration 100 with loss 0.6480392217636108
# Epoch 70: Iteration 120 with loss 0.9316287040710449
# Epoch 70: Iteration 140 with loss 0.49680083990097046
# Epoch 70: Iteration 160 with loss 0.3990629315376282
# Epoch 70 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.18637172783634
# Starting Training
# Epoch 71: Iteration 20 with loss 0.558256983757019
# Epoch 71: Iteration 40 with loss 0.8555545806884766
# Epoch 71: Iteration 60 with loss 0.4252277910709381
# Epoch 71: Iteration 80 with loss 0.7034130692481995
# Epoch 71: Iteration 100 with loss 0.5765464901924133
# Epoch 71: Iteration 120 with loss 0.4526153802871704
# Epoch 71: Iteration 140 with loss 1.3295656442642212
# Epoch 71: Iteration 160 with loss 0.49502772092819214
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.1 minutes
# iter 20 of Expectation completed in a total of  6.1 minutes
# iter 30 of Expectation completed in a total of  10.5 minutes
# iter 40 of Expectation completed in a total of  14.3 minutes
# iter 50 of Expectation completed in a total of  18.2 minutes
# iter 60 of Expectation completed in a total of  22.3 minutes
# Expectation step finished, posterior frame-wise accuracy  72.41%, boundary mse  0.00
# Epoch 71 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.19742635364758
# Starting Training
# Epoch 72: Iteration 20 with loss 0.4101938009262085
# Epoch 72: Iteration 40 with loss 0.4540531635284424
# Epoch 72: Iteration 60 with loss 0.4779166579246521
# Epoch 72: Iteration 80 with loss 0.4747832119464874
# Epoch 72: Iteration 100 with loss 0.4140087366104126
# Epoch 72: Iteration 120 with loss 0.4608720541000366
# Epoch 72: Iteration 140 with loss 0.49028280377388
# Epoch 72: Iteration 160 with loss 0.606547474861145
# Epoch 72 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.6675130161104
# Starting Training
# Epoch 73: Iteration 20 with loss 0.6119728088378906
# Epoch 73: Iteration 40 with loss 0.36147913336753845
# Epoch 73: Iteration 60 with loss 0.43556371331214905
# Epoch 73: Iteration 80 with loss 0.4299744963645935
# Epoch 73: Iteration 100 with loss 0.4016042947769165
# Epoch 73: Iteration 120 with loss 0.4818653166294098
# Epoch 73: Iteration 140 with loss 0.3029455840587616
# Epoch 73: Iteration 160 with loss 0.6197621822357178
# Epoch 73 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.678450455075584
# Starting Training
# Epoch 74: Iteration 20 with loss 0.39864182472229004
# Epoch 74: Iteration 40 with loss 0.9169235825538635
# Epoch 74: Iteration 60 with loss 0.3866582214832306
# Epoch 74: Iteration 80 with loss 1.2346086502075195
# Epoch 74: Iteration 100 with loss 0.602353572845459
# Epoch 74: Iteration 120 with loss 0.47099944949150085
# Epoch 74: Iteration 140 with loss 0.47846025228500366
# Epoch 74: Iteration 160 with loss 0.4570380449295044
# Epoch 74 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.86617820213057
# Starting Training
# Epoch 75: Iteration 20 with loss 0.4762324392795563
# Epoch 75: Iteration 40 with loss 0.4124810993671417
# Epoch 75: Iteration 60 with loss 0.30803173780441284
# Epoch 75: Iteration 80 with loss 0.4491468071937561
# Epoch 75: Iteration 100 with loss 0.36074069142341614
# Epoch 75: Iteration 120 with loss 0.40524929761886597
# Epoch 75: Iteration 140 with loss 0.3299594521522522
# Epoch 75: Iteration 160 with loss 0.47259604930877686
# Epoch 75 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.70244585688696
# Starting Training
# Epoch 76: Iteration 20 with loss 0.403116911649704
# Epoch 76: Iteration 40 with loss 0.43380481004714966
# Epoch 76: Iteration 60 with loss 0.6362500786781311
# Epoch 76: Iteration 80 with loss 0.4210279881954193
# Epoch 76: Iteration 100 with loss 0.4678134024143219
# Epoch 76: Iteration 120 with loss 0.48691326379776
# Epoch 76: Iteration 140 with loss 0.4470983147621155
# Epoch 76: Iteration 160 with loss 0.3234059810638428
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  7.3 minutes
# iter 30 of Expectation completed in a total of  11.0 minutes
# iter 40 of Expectation completed in a total of  14.7 minutes
# iter 50 of Expectation completed in a total of  17.9 minutes
# iter 60 of Expectation completed in a total of  22.3 minutes
# Expectation step finished, posterior frame-wise accuracy  72.43%, boundary mse  0.00
# Epoch 76 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.83190942014833
# Starting Training
# Epoch 77: Iteration 20 with loss 0.3698732852935791
# Epoch 77: Iteration 40 with loss 0.43084800243377686
# Epoch 77: Iteration 60 with loss 0.3644880950450897
# Epoch 77: Iteration 80 with loss 0.49181607365608215
# Epoch 77: Iteration 100 with loss 0.350547730922699
# Epoch 77: Iteration 120 with loss 0.4181579053401947
# Epoch 77: Iteration 140 with loss 0.9468530416488647
# Epoch 77: Iteration 160 with loss 0.4020569920539856
# Epoch 77 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.87331543908795
# Starting Training
# Epoch 78: Iteration 20 with loss 1.27862548828125
# Epoch 78: Iteration 40 with loss 0.4059046506881714
# Epoch 78: Iteration 60 with loss 0.5036587715148926
# Epoch 78: Iteration 80 with loss 0.802203893661499
# Epoch 78: Iteration 100 with loss 0.41306638717651367
# Epoch 78: Iteration 120 with loss 0.4160690903663635
# Epoch 78: Iteration 140 with loss 0.5629002451896667
# Epoch 78: Iteration 160 with loss 0.33998385071754456
# Epoch 78 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.051885871172594
# Starting Training
# Epoch 79: Iteration 20 with loss 0.357986181974411
# Epoch 79: Iteration 40 with loss 0.44253283739089966
# Epoch 79: Iteration 60 with loss 0.2873750329017639
# Epoch 79: Iteration 80 with loss 0.4056349992752075
# Epoch 79: Iteration 100 with loss 0.45608216524124146
# Epoch 79: Iteration 120 with loss 0.39037513732910156
# Epoch 79: Iteration 140 with loss 0.528306245803833
# Epoch 79: Iteration 160 with loss 0.9510518908500671
# Epoch 79 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.84754549360774
# Starting Training
# Epoch 80: Iteration 20 with loss 0.8626163005828857
# Epoch 80: Iteration 40 with loss 0.5046548843383789
# Epoch 80: Iteration 60 with loss 0.30913689732551575
# Epoch 80: Iteration 80 with loss 0.6387475728988647
# Epoch 80: Iteration 100 with loss 1.4373146295547485
# Epoch 80: Iteration 120 with loss 1.750049352645874
# Epoch 80: Iteration 140 with loss 0.7080749869346619
# Epoch 80: Iteration 160 with loss 0.7067500352859497
# Epoch 80 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.05579767970045
# Starting Training
# Epoch 81: Iteration 20 with loss 1.2825199365615845
# Epoch 81: Iteration 40 with loss 1.0448782444000244
# Epoch 81: Iteration 60 with loss 0.7387706637382507
# Epoch 81: Iteration 80 with loss 0.6373001337051392
# Epoch 81: Iteration 100 with loss 0.5131630301475525
# Epoch 81: Iteration 120 with loss 0.5436823964118958
# Epoch 81: Iteration 140 with loss 0.8395002484321594
# Epoch 81: Iteration 160 with loss 2.0400748252868652
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.6 minutes
# iter 20 of Expectation completed in a total of  7.0 minutes
# iter 30 of Expectation completed in a total of  10.9 minutes
# iter 40 of Expectation completed in a total of  15.2 minutes
# iter 50 of Expectation completed in a total of  18.9 minutes
# iter 60 of Expectation completed in a total of  22.2 minutes
# Expectation step finished, posterior frame-wise accuracy  72.74%, boundary mse  0.00
# Epoch 81 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.96217655035407
# Starting Training
# Epoch 82: Iteration 20 with loss 1.328057050704956
# Epoch 82: Iteration 40 with loss 3.499237537384033
# Epoch 82: Iteration 60 with loss 1.0385956764221191
# Epoch 82: Iteration 80 with loss 0.7280586361885071
# Epoch 82: Iteration 100 with loss 1.5529825687408447
# Epoch 82: Iteration 120 with loss 1.886886715888977
# Epoch 82: Iteration 140 with loss 2.300631284713745
# Epoch 82: Iteration 160 with loss 3.1471660137176514
# Epoch 82 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.55668774169787
# Starting Training
# Epoch 83: Iteration 20 with loss 0.7463915944099426
# Epoch 83: Iteration 40 with loss 0.6014208793640137
# Epoch 83: Iteration 60 with loss 0.5327291488647461
# Epoch 83: Iteration 80 with loss 0.6180250644683838
# Epoch 83: Iteration 100 with loss 1.9727733135223389
# Epoch 83: Iteration 120 with loss 0.5771480202674866
# Epoch 83: Iteration 140 with loss 0.6266240477561951
# Epoch 83: Iteration 160 with loss 0.9897032976150513
# Epoch 83 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.877450460655915
# Starting Training

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {val_acc}")
# Out:
# Validation:: Epoch 105, Probability Accuracy 61.02425300046298

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {best_val_acc}")
# Out:
# Validation:: Epoch 105, Probability Accuracy 63.70656599831428

# %%
torch.save(model.state_dict(),
"/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-speed/final-em-maximized.wt")

# %%
config.output_dir
# Out:
# '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split1/'

# %%
model.load_state_dict(torch.load(config.output_dir + "ms-tcn-emmax-best-model.wt"))
# model.load_state_dict(torch.load(config.output_dir + "ms-tcn-initial-15-epochs.wt"))
# Out:
# <All keys matched successfully>
