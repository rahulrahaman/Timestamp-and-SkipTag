# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
import os, sys
import glob
import numpy as np
import torch
import pandas as pd
import random
import torch.nn as nn
import pickle
import torch.nn.functional as F

# %%
from model import C2F_TCN
from dataset import AugmentDataset, collate_fn_override
from utils import calculate_mof, dotdict

# %%
os.environ["WANDB_API_KEY"] = "992b3b1371ba79f48484cfca522b3786d7fa52c2"
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dipika_singhania (use `wandb login --relogin` to force relogin)
# True

# %%
seed = 42

# Ensure deterministic behavior
def set_seed():
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
set_seed()

# Device configuration
os.environ['CUDA_VISIBLE_DEVICES']='4'
# os.environ['CUDA_LAUNCH_BLOCKING']='6'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config = dotdict(
    epochs=500,
    num_class=48,
    batch_size=50,
    learning_rate=1e-4,
    weight_decay=3e-3,
    dataset="Breakfast",
    architecture="unet-ensemble",
    features_file_name="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/",
    chunk_size=10,
    max_frames_per_video=1200,
    feature_size=2048,
    ground_truth_files_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/",
    label_id_csv="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv",
    gamma=0.1,
    step_size=500,
    split=2,
#     output_dir="/mnt/data/ar-datasets/dipika/breakfast/ms_tcn/data/breakfast/results/unsuper-finetune-split2-0.05-data-llr/",
    output_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-full-length-ensem/",
    project_name="breakfast-split-2",
    train_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split{}.bundle",
    test_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split{}.bundle",
    all_files="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt",
    cutoff=8,
    data_per = 0.2,
    budget=40,
    semi_supervised_split="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split{}_amt{}.bundle")

config.train_split_file = config.train_split_file.format(config.split)
config.semi_supervised_split = config.semi_supervised_split.format(config.split, config.data_per)
config.test_split_file = config.test_split_file.format(config.split)

if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)

print(config)
# Out:
# {'epochs': 500, 'num_class': 48, 'batch_size': 50, 'learning_rate': 0.0001, 'weight_decay': 0.003, 'dataset': 'Breakfast', 'architecture': 'unet-ensemble', 'features_file_name': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/', 'chunk_size': 10, 'max_frames_per_video': 1200, 'feature_size': 2048, 'ground_truth_files_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/', 'label_id_csv': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv', 'gamma': 0.1, 'step_size': 500, 'split': 2, 'output_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-full-length-ensem/', 'project_name': 'breakfast-split-2', 'train_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split2.bundle', 'test_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split2.bundle', 'all_files': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt', 'cutoff': 8, 'data_per': 0.2, 'budget': 40, 'semi_supervised_split': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split2_amt0.2.bundle'}

# %%
traindataset = AugmentDataset(config, fold='train', fold_file_name=config.train_split_file, augment=False)
testdataset = AugmentDataset(config, fold='test', fold_file_name=config.test_split_file, augment=False)
# Out:
# Number of videos logged in train fold is 1261
# Number of videos not found in train fold is 0
# Number of videos logged in test fold is 451
# Number of videos not found in test fold is 0

# %%
def _init_fn(worker_id):
    np.random.seed(int(seed))
trainloader = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=config.batch_size, 
                                          shuffle=True,
                                          pin_memory=False, num_workers=4, collate_fn=collate_fn_override,
                                          worker_init_fn=_init_fn)
testloader = torch.utils.data.DataLoader(dataset=testdataset,
                                          batch_size=config.batch_size, 
                                          shuffle=False,
                                          pin_memory=False, num_workers=4, collate_fn=collate_fn_override,
                                          worker_init_fn=_init_fn)

# %%
# item = iter(trainloader).next()
# print(item[0]) # -- data feature
# print(item[1]) # -- valid count
# item[2] # -- Actual labels
# print(item[5]) # video names
# video_id_boundary_frames

# %%
loaded_vidid_selected_frames = pickle.load(open("dump_dir/breakfast_split2_selected_frames_dict.pkl", "rb"))
# loaded_vidid_selected_frames
video_id_boundary_frames = pickle.load(open("dump_dir/breakfast_split2_boundary_frames_dict.pkl", "rb"))
# video_id_boundary_frames

# %%
loaded_mean_var_actions = pickle.load(open("dump_dir/mean_var_actions.pkl", "rb"))
def get_possion_prob(cur_len, cur_class, min_len):
    mean_class, std_class = loaded_mean_var_actions[cur_class]   
    prob = (cur_len * np.log(mean_class + 1e-5))
    prob = prob - mean_class
    prob = prob - np.sum(np.log(np.arange(1, cur_len, 1)))
    return prob

get_possion_prob(20, 20, 10)
# Out:
# 0.48488744950308416

# %%
prob_video_each_segment_dict = {}

# %%
def prob_vals_per_segment(selected_frames, cur_vid_feat, labels):
    prob_each_segment = []
    
    log_probs = torch.log(cur_vid_feat + 1e-8)
    cumsum_feat = torch.cumsum(log_probs, dim=0)
    
    cur_boundary = 0
    for i, cur_ele in enumerate(selected_frames[:-1]):
        
        next_ele = selected_frames[i + 1]
        label_cur_ele = labels[cur_ele]
        label_next_ele = labels[next_ele]
        prob_list = []
        for ele in range(cur_ele, next_ele, 1):
            start_sum = cumsum_feat[cur_ele - 1, :] if cur_ele > 0 else 0
            sum_window_class_1 = (cumsum_feat[ele, :] - start_sum)[label_cur_ele]
            sum_window_class_2 = (cumsum_feat[next_ele - 1, :] - cumsum_feat[ele, :])[label_next_ele]
            
            len_cur_class = ele - cur_boundary
            len_prob = get_possion_prob(len_cur_class, label_cur_ele.item(), cur_ele)
            prob_list.append((sum_window_class_1 + sum_window_class_2) + len_prob.item())
            
        prob_list = torch.softmax(torch.stack(prob_list), dim=0)
        cur_boundary = round(np.sum(np.arange(cur_ele, next_ele, 1) * prob_list.detach().cpu().numpy()).item())
        prob_each_segment.append(prob_list)
    
    return prob_each_segment

# %%
# selected_frames = torch.tensor([2, 10, 17, 21])
# cur_vid_feat = torch.randn((27, 48))
# labels = torch.tensor([47, 47, 47, 47, 47, 4, 4, 4, 4, 4, 4, 4, 8, 8, 8, 8, 8, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10])
# # print(len(labels))
# probs_all_segs = prob_vals_per_segment(selected_frames, cur_vid_feat, labels)
# print(probs_all_segs)

# %%
def calculate_element_probb(data_feat, data_count, video_ids, labels_all): #, loaded_vidid_selected_frames, boundaries_dict):
    global prob_video_each_segment_dict, loaded_vidid_selected_frames
    for iter_num in range(len(data_count)):
        cur_vidid = video_ids[iter_num]
        cur_vid_feat = data_feat[iter_num]
        cur_vid_count = data_count[iter_num]
        labels = labels_all[iter_num]
        
        selected_frames = loaded_vidid_selected_frames[cur_vidid]
        prob_video = prob_vals_per_segment(selected_frames, cur_vid_feat, labels)
        prob_video_each_segment_dict[cur_vidid] = prob_video

# %%
def get_estimated_loss(data_feat, data_count, video_ids, labels_all): #, loaded_vidid_selected_frames, boundaries_dict):
    global prob_video_each_segment_dict, loaded_vidid_selected_frames
    loss_arr = []
    for iter_num in range(len(data_count)):
        cur_vidid = video_ids[iter_num]
        cur_vid_feat = data_feat[iter_num]
        cur_vid_count = data_count[iter_num]
        labels = labels_all[iter_num]
        
        selected_frames = loaded_vidid_selected_frames[cur_vidid]
        prob_each_video = prob_video_each_segment_dict[cur_vidid]
        
        log_probs = torch.log(cur_vid_feat + 1e-8)
        cumsum_feat = torch.cumsum(log_probs, dim=0)
        
        
        current_vid_prob_arr = []
        # Start segment log probability
        start_ele_idx = selected_frames[0]
        if start_ele_idx > 0:
            start_ele_label_idx = labels[selected_frames[0]]
            first_segment_prob = (cumsum_feat[start_ele_idx - 1, :])[start_ele_label_idx]
            current_vid_prob_arr.append(first_segment_prob)
        
        for i, cur_ele in enumerate(selected_frames[:-1]):
            next_ele = selected_frames[i + 1]
            label_cur_ele = labels[cur_ele]
            label_next_ele = labels[next_ele]

            count = 0
            for ele in range(cur_ele, next_ele, 1):
                start_sum = cumsum_feat[cur_ele - 1, :] if cur_ele > 0 else 0
                sum_window_class_1 = (cumsum_feat[ele, :] - start_sum)[label_cur_ele]
                sum_window_class_2 = (cumsum_feat[next_ele - 1, :] - cumsum_feat[ele, :])[label_next_ele]
                current_vid_prob_arr.append((sum_window_class_1 + sum_window_class_2)  * (prob_each_video[i][count].item()))
                count = count + 1
        
        # End segment log probability
        end_index = cur_vid_count.item() - 1
        last_ele_label_idx = labels[selected_frames[-1]]
        last_segment_sum_prob = (cumsum_feat[end_index, :] - cumsum_feat[selected_frames[-1] - 1, :])[last_ele_label_idx]
        current_vid_prob_arr.append(last_segment_sum_prob)
            
        loss_arr.append(torch.stack(current_vid_prob_arr))
    return -torch.mean(torch.cat(loss_arr)), loss_arr
#     return loss_arr

# %%
def get_estimated_boundaries():
    global prob_video_each_segment_dict, loaded_vidid_selected_frames, video_id_boundary_frames
    estimated_boundary_dict = {}
    for ele in video_id_boundary_frames.keys():
        
        estimated_boundary_probs = prob_video_each_segment_dict[ele]
        selected_ele_list = loaded_vidid_selected_frames[ele]
        boundary_list = []
        for i, segment in enumerate(estimated_boundary_probs):
            estimated_boundary = np.sum(np.arange(selected_ele_list[i], selected_ele_list[i + 1], 1) \
                                        * segment.detach().cpu().numpy())
            estimated_boundary = round(estimated_boundary.item())
            
            if (estimated_boundary < selected_ele_list[i]) or (estimated_boundary > selected_ele_list[i + 1]):
                print("Estimated value wrong")
                import pdb
                pdb.set_trace()
            boundary_list.append(estimated_boundary)

        estimated_boundary_dict[ele] = boundary_list
    return estimated_boundary_dict

# %%
def get_boundary_err():
    global prob_video_each_segment_dict, loaded_vidid_selected_frames
    err_list = []
    correct = 0.0
    total = 0.0
    estimated_boundar_dict = get_estimated_boundaries()
    for ele in video_id_boundary_frames.keys():
        
        estimated_boundary_probs = prob_video_each_segment_dict[ele]
        estimated_boundary_list = estimated_boundar_dict[ele]
        
        estimated = np.array(estimated_boundary_list) #.detach().cpu().numpy()
        actual = np.array(video_id_boundary_frames[ele][:-1])
        if len(actual) != len(estimated):
            print(ele)
            continue
        
        mse_err = (actual - estimated)**2
        err_list.append(mse_err)
        
        estimated_labels = []
        actual_labels = []
        start_v1 = 0
        start_v2 = 0
        for i, v1 in enumerate(estimated):
            estimated_labels.extend([i] * (v1 - start_v1))
            start_v1 = v1
            v2 = actual[i]
            actual_labels.extend([i] * (v2 - start_v2))
            start_v2 = v2
            
        last_ele = video_id_boundary_frames[ele][-1]
        estimated_labels.extend([i+1] * (last_ele - start_v1))
        actual_labels.extend([i+1] * (last_ele - start_v2))
        
        correct += np.sum(np.array(actual_labels) == np.array(estimated_labels))
        total += len(actual_labels)
        
    print(f"Train Boundary avergage error = {np.sqrt(np.mean(np.concatenate(err_list))):.3f}")
    print(f"Train From boundary avergage accuracy = {correct * 100.0 / total:.3f}")

# %%
def get_ensemble_out(outp):
    
    weights = [1, 1, 1, 1, 0, 0]
    ensemble_prob = F.softmax(outp[0], dim=1) * weights[0] / sum(weights)

    for i, outp_ele in enumerate(outp[1]):
        upped_logit = F.upsample(outp_ele, size=outp[0].shape[-1], mode='linear', align_corners=True)
        ensemble_prob = ensemble_prob + F.softmax(upped_logit, dim=1) * weights[i + 1] / sum(weights)
    
    return ensemble_prob

# %%
def get_validation_acc(model):
    model.eval()
    print("Calculating Validation Accuracy")
    correct = 0.0
    total = 0.0
    for i, item in enumerate(testloader):
        with torch.no_grad():
            item[0] = item[0].to(device)
            item[1] = item[1].to(device)
            item[2] = item[2].to(device)
            y, y_list, features = model(item[0].permute(0,2,1))
            
            prob = get_ensemble_out([y, y_list]).permute(0, 2, 1)

            src_mask = torch.arange(item[2].shape[1], device=item[2].device)[None, :] < item[1][:, None]
            pred = torch.argmax(prob, dim=2)
            correct += float(torch.sum((pred == item[2]) * src_mask).item())
            total += float(torch.sum(src_mask).item())
    val_acc = correct * 100.0 / total
    print(f"Validation Accuracy calculated with model probabilities {val_acc: .3f}")
    return val_acc

# %%
set_seed()
model = C2F_TCN(n_channels=config.feature_size, n_classes=config.num_class).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=3e-3)

# Requires loaded_vidid_selected_frames, boundaries_dict
ce_criterion = nn.CrossEntropyLoss(ignore_index=-100)
mse_criterion = nn.MSELoss(reduction='none')

# %%
val_acc_arr = []
for epoch in range(2000):
    if epoch % 5 == 0:
        model.eval()
        print("Calculating Expectation")
        correct = 0.0
        total = 0.0
        for i, item in enumerate(trainloader):
            with torch.no_grad():
                item[0] = item[0].to(device)
                item[1] = item[1].to(device)
                item[2] = item[2].to(device)
                y, y_list, features = model(item[0].permute(0,2,1))
                prob = get_ensemble_out([y, y_list])
                prob = prob.permute(0,2,1)
                calculate_element_probb(prob, item[1], item[5], item[2])
                
                src_mask = torch.arange(item[2].shape[1], device=item[2].device)[None, :] < item[1][:, None]
                pred = torch.argmax(prob, dim=2)
                correct += float(torch.sum((pred == item[2]) * src_mask).item())
                total += float(torch.sum(src_mask).item())
        print(f"Epoch {epoch} Train Accuracy calculated with probabilities {correct * 100.0 / total: .3f}")
        get_boundary_err()
        
        val_acc = get_validation_acc(model)
        val_acc_arr.append(val_acc)
        val_acc_arr.sort()
        print(f"Epoch {epoch} " + "Best 3 val accuracy till now = ", val_acc_arr[-3:])

    model.train()
    print("Starting Maximization")
    for i, item in enumerate(trainloader):
        item[0] = item[0].to(device)
        item[1] = item[1].to(device)
        item[2] = item[2].to(device)

        optimizer.zero_grad()
        y, y_list, features = model(item[0].permute(0,2,1))
        prob = get_ensemble_out([y, y_list])
        prob = prob.permute(0,2,1)
        loss, _ = get_estimated_loss(prob, item[1], item[5], item[2].to(device))
        loss.backward()
        optimizer.step()
        if i % 10 == 0:
            print(f"Epoch {epoch} iteration {i} Current loss {loss.item()}")
# Out:
# Calculating Expectation
# /home/dipika16/anaconda3/envs/video_r/lib/python3.7/site-packages/torch/nn/functional.py:2952: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Epoch 0 Train Accuracy calculated with probabilities  5.817
# Train Boundary avergage error = 39.769
# Train From boundary avergage accuracy = 24.457
# Calculating Validation Accuracy
# /home/dipika16/anaconda3/envs/video_r/lib/python3.7/site-packages/ipykernel_launcher.py:36: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# Validation Accuracy calculated with model probabilities  6.195
# Epoch 0 Best 3 val accuracy till now =  [6.194708557255064]
# Starting Maximization
# Epoch 0 iteration 0 Current loss 4.315332889556885
# Epoch 0 iteration 10 Current loss 3.452861785888672
# Epoch 1 iteration 10 Current loss 2.399174928665161
# Epoch 1 iteration 20 Current loss 2.287780523300171
# Starting Maximization
# Epoch 2 iteration 0 Current loss 2.1093080043792725
# Epoch 2 iteration 10 Current loss 1.911488652229309
# Epoch 2 iteration 20 Current loss 1.9681557416915894
# Starting Maximization
# Epoch 3 iteration 0 Current loss 1.7800472974777222
# Epoch 3 iteration 10 Current loss 1.808814525604248
# Epoch 3 iteration 20 Current loss 1.6529275178909302
# Starting Maximization
# Epoch 4 iteration 0 Current loss 1.5837632417678833
# Epoch 4 iteration 10 Current loss 1.5679020881652832
# Epoch 4 iteration 20 Current loss 1.5516881942749023
# Calculating Expectation
# Epoch 5 Train Accuracy calculated with probabilities  55.253
# Train Boundary avergage error = 40.927
# Train From boundary avergage accuracy = 27.656
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  44.986
# Epoch 5 Best 3 val accuracy till now =  [6.194708557255064, 44.985531211244314]
# Starting Maximization
# Epoch 5 iteration 0 Current loss 1.240282416343689
# Epoch 5 iteration 10 Current loss 1.1688752174377441
# Epoch 5 iteration 20 Current loss 1.2449065446853638
# Starting Maximization
# Epoch 6 iteration 0 Current loss 1.1807864904403687
# Epoch 6 iteration 10 Current loss 1.0172219276428223
# Epoch 6 iteration 20 Current loss 1.0419870615005493
# Starting Maximization
# Epoch 7 iteration 0 Current loss 1.2042509317398071
# Epoch 7 iteration 10 Current loss 1.057847261428833
# Epoch 7 iteration 20 Current loss 1.0955044031143188
# Starting Maximization
# Epoch 8 iteration 0 Current loss 1.0551393032073975
# Epoch 8 iteration 10 Current loss 1.0404362678527832
# Epoch 8 iteration 20 Current loss 0.9102654457092285
# Starting Maximization
# Epoch 9 iteration 0 Current loss 0.816727340221405
# Epoch 9 iteration 10 Current loss 0.9335171580314636
# Epoch 9 iteration 20 Current loss 1.1168502569198608
# Calculating Expectation
# Epoch 10 Train Accuracy calculated with probabilities  63.051
# Train Boundary avergage error = 40.908
# Train From boundary avergage accuracy = 28.600
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  46.378
# Epoch 10 Best 3 val accuracy till now =  [6.194708557255064, 44.985531211244314, 46.37763538652336]
# Starting Maximization
# Epoch 10 iteration 0 Current loss 0.8031532168388367
# Epoch 10 iteration 10 Current loss 0.8729660511016846
# Epoch 10 iteration 20 Current loss 0.7476133704185486
# Starting Maximization
# Epoch 11 iteration 0 Current loss 0.8806736469268799
# Epoch 11 iteration 10 Current loss 0.7434321045875549
# Epoch 11 iteration 20 Current loss 0.6491567492485046
# Starting Maximization
# Epoch 12 iteration 0 Current loss 0.8868771195411682
# Epoch 12 iteration 10 Current loss 0.7992666959762573
# Epoch 12 iteration 20 Current loss 0.7265650033950806
# Starting Maximization
# Epoch 13 iteration 0 Current loss 0.7074880599975586
# Epoch 13 iteration 10 Current loss 0.7226511240005493
# Epoch 13 iteration 20 Current loss 0.7791296243667603
# Starting Maximization
# Epoch 14 iteration 0 Current loss 0.6568422317504883
# Epoch 14 iteration 10 Current loss 0.6905933618545532
# Epoch 14 iteration 20 Current loss 0.7417832016944885
# Calculating Expectation
# Epoch 15 Train Accuracy calculated with probabilities  63.842
# Train Boundary avergage error = 41.317
# Train From boundary avergage accuracy = 28.661
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  48.880
# Epoch 15 Best 3 val accuracy till now =  [44.985531211244314, 46.37763538652336, 48.8797023563456]
# Starting Maximization
# Epoch 15 iteration 0 Current loss 0.6473774909973145
# Epoch 15 iteration 10 Current loss 0.6077818274497986
# Epoch 15 iteration 20 Current loss 0.6088781356811523
# Starting Maximization
# Epoch 16 iteration 0 Current loss 0.5650418996810913
# Epoch 16 iteration 10 Current loss 0.5792216658592224
# Epoch 16 iteration 20 Current loss 0.5914192199707031
# Starting Maximization
# Epoch 17 iteration 0 Current loss 0.5922908186912537
# Epoch 17 iteration 10 Current loss 0.5382102727890015
# Epoch 17 iteration 20 Current loss 0.5812245607376099
# Starting Maximization
# Epoch 18 iteration 0 Current loss 0.5395362973213196
# Epoch 18 iteration 10 Current loss 0.5782827138900757
# Epoch 18 iteration 20 Current loss 0.535027265548706
# Starting Maximization
# Epoch 19 iteration 0 Current loss 0.5544171929359436
# Epoch 19 iteration 10 Current loss 0.7075550556182861
# Epoch 19 iteration 20 Current loss 0.5691218376159668
# Calculating Expectation
# Epoch 20 Train Accuracy calculated with probabilities  64.991
# Train Boundary avergage error = 41.398
# Train From boundary avergage accuracy = 27.957
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  50.395
# Epoch 20 Best 3 val accuracy till now =  [46.37763538652336, 48.8797023563456, 50.39479123604795]
# Starting Maximization
# Epoch 20 iteration 0 Current loss 0.6287543773651123
# Epoch 20 iteration 10 Current loss 0.5947918891906738
# Epoch 20 iteration 20 Current loss 0.5181316137313843
# Starting Maximization
# Epoch 21 iteration 0 Current loss 0.5146613717079163
# Epoch 21 iteration 10 Current loss 0.5344812870025635
# Epoch 21 iteration 20 Current loss 0.5860474705696106
# Starting Maximization
# Epoch 22 iteration 0 Current loss 0.5953742861747742
# Epoch 22 iteration 10 Current loss 0.6497923135757446
# Epoch 22 iteration 20 Current loss 0.6961714625358582
# Starting Maximization
# Epoch 23 iteration 0 Current loss 0.4970375895500183
# Epoch 23 iteration 10 Current loss 0.586028516292572
# Epoch 23 iteration 20 Current loss 0.5063106417655945
# Starting Maximization
# Epoch 24 iteration 0 Current loss 0.4556839168071747
# Epoch 24 iteration 10 Current loss 0.4701201915740967
# Epoch 24 iteration 20 Current loss 0.5118308663368225
# Calculating Expectation
# Epoch 25 Train Accuracy calculated with probabilities  70.167
# Train Boundary avergage error = 41.220
# Train From boundary avergage accuracy = 28.226
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  56.005
# Epoch 25 Best 3 val accuracy till now =  [48.8797023563456, 50.39479123604795, 56.004547333608926]
# Starting Maximization
# Epoch 25 iteration 0 Current loss 0.44401437044143677
# Epoch 25 iteration 10 Current loss 0.46728071570396423
# Epoch 25 iteration 20 Current loss 0.4432808756828308
# Starting Maximization
# Epoch 26 iteration 0 Current loss 0.43548867106437683
# Epoch 26 iteration 10 Current loss 0.40139028429985046
# Epoch 26 iteration 20 Current loss 0.3880699872970581
# Starting Maximization
# Epoch 27 iteration 0 Current loss 0.4169985353946686
# Epoch 27 iteration 10 Current loss 0.41410985589027405
# Epoch 27 iteration 20 Current loss 0.40717869997024536
# Starting Maximization
# Epoch 28 iteration 0 Current loss 0.5130228996276855
# Epoch 28 iteration 10 Current loss 0.42318961024284363
# Epoch 28 iteration 20 Current loss 0.41153621673583984
# Starting Maximization
# Epoch 29 iteration 0 Current loss 0.3782987594604492
# Epoch 29 iteration 10 Current loss 0.45390331745147705
# Epoch 29 iteration 20 Current loss 0.4008145034313202
# Calculating Expectation
# Epoch 30 Train Accuracy calculated with probabilities  70.708
# Train Boundary avergage error = 41.240
# Train From boundary avergage accuracy = 27.482
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  55.294
# Epoch 30 Best 3 val accuracy till now =  [50.39479123604795, 55.293509714758166, 56.004547333608926]
# Starting Maximization
# Epoch 30 iteration 0 Current loss 0.3727879524230957
# Epoch 30 iteration 10 Current loss 0.3996317982673645
# Epoch 30 iteration 20 Current loss 0.39176976680755615
# Starting Maximization
# Epoch 31 iteration 0 Current loss 0.4199744164943695
# Epoch 31 iteration 10 Current loss 0.48002371191978455
# Epoch 31 iteration 20 Current loss 0.3843691349029541
# Starting Maximization
# Epoch 32 iteration 0 Current loss 0.3695433735847473
# Epoch 32 iteration 10 Current loss 0.4416831433773041
# Epoch 32 iteration 20 Current loss 0.7193585634231567
# Starting Maximization
# Epoch 33 iteration 0 Current loss 0.552773654460907
# Epoch 33 iteration 10 Current loss 0.4335906207561493
# Epoch 33 iteration 20 Current loss 0.49110954999923706
# Starting Maximization
# Epoch 34 iteration 0 Current loss 0.40692588686943054
# Epoch 34 iteration 10 Current loss 0.3741306662559509
# Epoch 34 iteration 20 Current loss 0.38155657052993774
# Calculating Expectation
# Epoch 35 Train Accuracy calculated with probabilities  70.382
# Train Boundary avergage error = 41.415
# Train From boundary avergage accuracy = 27.523
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  57.198
# Epoch 35 Best 3 val accuracy till now =  [55.293509714758166, 56.004547333608926, 57.198222405952876]
# Starting Maximization
# Epoch 35 iteration 0 Current loss 0.31661659479141235
# Epoch 35 iteration 10 Current loss 0.38177603483200073
# Epoch 35 iteration 20 Current loss 0.3821878731250763
# Starting Maximization
# Epoch 36 iteration 0 Current loss 0.3885484039783478
# Epoch 36 iteration 10 Current loss 0.42334869503974915
# Epoch 36 iteration 20 Current loss 0.3660438656806946
# Starting Maximization
# Epoch 37 iteration 0 Current loss 0.36483514308929443
# Epoch 37 iteration 10 Current loss 0.4064403772354126
# Epoch 37 iteration 20 Current loss 0.3556598722934723
# Starting Maximization
# Epoch 38 iteration 0 Current loss 0.3942555785179138
# Epoch 38 iteration 10 Current loss 0.38359934091567993
# Epoch 38 iteration 20 Current loss 0.3559950888156891
# Starting Maximization
# Epoch 39 iteration 0 Current loss 0.3628844916820526
# Epoch 39 iteration 10 Current loss 0.3610699474811554
# Epoch 39 iteration 20 Current loss 0.33690622448921204
# Calculating Expectation
# Epoch 40 Train Accuracy calculated with probabilities  70.684
# Train Boundary avergage error = 41.445
# Train From boundary avergage accuracy = 26.040
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  55.176
# Epoch 40 Best 3 val accuracy till now =  [55.293509714758166, 56.004547333608926, 57.198222405952876]
# Starting Maximization
# Epoch 40 iteration 0 Current loss 0.32333388924598694
# Epoch 40 iteration 10 Current loss 0.36356422305107117
# Epoch 40 iteration 20 Current loss 0.39319249987602234
# Starting Maximization
# Epoch 41 iteration 0 Current loss 0.3402286171913147
# Epoch 41 iteration 10 Current loss 0.32629477977752686
# Epoch 41 iteration 20 Current loss 0.3687092065811157
# Starting Maximization
# Epoch 42 iteration 0 Current loss 0.3637765049934387
# Epoch 42 iteration 10 Current loss 0.3764497637748718
# Epoch 42 iteration 20 Current loss 0.37384751439094543
# Starting Maximization
# Epoch 43 iteration 0 Current loss 0.40794000029563904
# Epoch 43 iteration 10 Current loss 0.5749660134315491
# Epoch 43 iteration 20 Current loss 0.4189039170742035
# Starting Maximization
# Epoch 44 iteration 0 Current loss 0.4671217203140259
# Epoch 44 iteration 10 Current loss 0.40357649326324463
# Epoch 44 iteration 20 Current loss 0.3547998368740082
# Calculating Expectation
# Epoch 45 Train Accuracy calculated with probabilities  71.286
# Train Boundary avergage error = 41.335
# Train From boundary avergage accuracy = 26.909
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  55.130
# Epoch 45 Best 3 val accuracy till now =  [55.293509714758166, 56.004547333608926, 57.198222405952876]
# Starting Maximization
# Epoch 45 iteration 0 Current loss 0.30354204773902893
# Epoch 45 iteration 10 Current loss 0.34346890449523926
# Epoch 45 iteration 20 Current loss 0.4602319300174713
# Starting Maximization
# Epoch 46 iteration 0 Current loss 0.44468215107917786
# Epoch 46 iteration 10 Current loss 0.34869861602783203
# Epoch 46 iteration 20 Current loss 0.38027268648147583
# Starting Maximization
# Epoch 47 iteration 0 Current loss 0.282478004693985
# Epoch 47 iteration 10 Current loss 0.33714884519577026
# Epoch 47 iteration 20 Current loss 0.28039392828941345
# Starting Maximization
# Epoch 48 iteration 0 Current loss 0.3508618474006653
# Epoch 48 iteration 10 Current loss 0.3066982924938202
# Epoch 48 iteration 20 Current loss 0.31994369626045227
# Starting Maximization
# Epoch 49 iteration 0 Current loss 0.27368462085723877
# Epoch 49 iteration 10 Current loss 0.2681722342967987
# Epoch 49 iteration 20 Current loss 0.3684921860694885
# Calculating Expectation
# Epoch 50 Train Accuracy calculated with probabilities  72.514
# Train Boundary avergage error = 41.300
# Train From boundary avergage accuracy = 26.076
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  57.418
# Epoch 50 Best 3 val accuracy till now =  [56.004547333608926, 57.198222405952876, 57.418354692021495]
# Starting Maximization
# Epoch 50 iteration 0 Current loss 0.27407971024513245
# Epoch 50 iteration 10 Current loss 0.29878541827201843
# Epoch 50 iteration 20 Current loss 0.26127898693084717
# Starting Maximization
# Epoch 51 iteration 0 Current loss 0.27597442269325256
# Epoch 51 iteration 10 Current loss 0.29222115874290466
# Epoch 51 iteration 20 Current loss 0.23305006325244904
# Starting Maximization
# Epoch 52 iteration 0 Current loss 0.23889687657356262
# Epoch 52 iteration 10 Current loss 0.2590228021144867
# Epoch 52 iteration 20 Current loss 0.28182297945022583
# Starting Maximization
# Epoch 53 iteration 0 Current loss 0.2502228617668152
# Epoch 53 iteration 10 Current loss 0.2435702681541443
# Epoch 53 iteration 20 Current loss 0.23394766449928284
# Starting Maximization
# Epoch 54 iteration 0 Current loss 0.30163660645484924
# Epoch 54 iteration 10 Current loss 0.2761957347393036
# Epoch 54 iteration 20 Current loss 0.26986175775527954
# Calculating Expectation
# Epoch 55 Train Accuracy calculated with probabilities  72.625
# Train Boundary avergage error = 41.445
# Train From boundary avergage accuracy = 25.841
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  56.112
# Epoch 55 Best 3 val accuracy till now =  [56.11202976436544, 57.198222405952876, 57.418354692021495]
# Starting Maximization
# Epoch 55 iteration 0 Current loss 0.219342902302742
# Epoch 55 iteration 10 Current loss 0.24356502294540405
# Epoch 55 iteration 20 Current loss 0.28118786215782166
# Starting Maximization
# Epoch 56 iteration 0 Current loss 0.24708403646945953
# Epoch 56 iteration 10 Current loss 0.23454788327217102
# Epoch 56 iteration 20 Current loss 0.2962337136268616
# Starting Maximization
# Epoch 57 iteration 0 Current loss 0.21839332580566406
# Epoch 57 iteration 10 Current loss 0.25407320261001587
# Epoch 57 iteration 20 Current loss 0.2544686496257782
# Starting Maximization
# Epoch 58 iteration 0 Current loss 0.25474774837493896
# Epoch 58 iteration 10 Current loss 0.23984424769878387
# Epoch 58 iteration 20 Current loss 0.2824409008026123
# Starting Maximization
# Epoch 59 iteration 0 Current loss 0.23657013475894928
# Epoch 59 iteration 10 Current loss 0.2232472151517868
# Epoch 59 iteration 20 Current loss 0.21038246154785156
# Calculating Expectation
# Epoch 60 Train Accuracy calculated with probabilities  72.927
# Train Boundary avergage error = 41.486
# Train From boundary avergage accuracy = 25.501
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  56.749
# Epoch 60 Best 3 val accuracy till now =  [56.74865646961555, 57.198222405952876, 57.418354692021495]
# Starting Maximization
# Epoch 60 iteration 0 Current loss 0.23652908205986023
# Epoch 60 iteration 10 Current loss 0.22869589924812317
# Epoch 60 iteration 20 Current loss 0.3146634101867676
# Starting Maximization
# Epoch 61 iteration 0 Current loss 0.23447218537330627
# Epoch 61 iteration 10 Current loss 0.22379902005195618
# Epoch 61 iteration 20 Current loss 0.21789011359214783
# Starting Maximization
# Epoch 62 iteration 0 Current loss 0.23480336368083954
# Epoch 62 iteration 10 Current loss 0.457940936088562
# Epoch 62 iteration 20 Current loss 0.4180918335914612
# Starting Maximization
# Epoch 63 iteration 0 Current loss 0.3566306531429291
# Epoch 63 iteration 20 Current loss 0.5444427132606506
# Starting Maximization
# Epoch 64 iteration 0 Current loss 0.37639912962913513
# Epoch 64 iteration 10 Current loss 0.3816553056240082
# Epoch 64 iteration 20 Current loss 0.34036919474601746
# Calculating Expectation
# Epoch 65 Train Accuracy calculated with probabilities  69.902
# Train Boundary avergage error = 41.110
# Train From boundary avergage accuracy = 27.056
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  53.033
# Epoch 65 Best 3 val accuracy till now =  [56.74865646961555, 57.198222405952876, 57.418354692021495]
# Starting Maximization
# Epoch 65 iteration 0 Current loss 0.31664857268333435
# Epoch 65 iteration 10 Current loss 0.33688315749168396
# Epoch 65 iteration 20 Current loss 0.29749611020088196
# Starting Maximization
# Epoch 66 iteration 0 Current loss 0.2834969162940979
# Epoch 66 iteration 10 Current loss 0.3068709075450897
# Epoch 66 iteration 20 Current loss 0.4261999726295471
# Starting Maximization
# Epoch 67 iteration 0 Current loss 0.32324427366256714
# Epoch 67 iteration 10 Current loss 0.29502102732658386
# Epoch 67 iteration 20 Current loss 0.29305607080459595
# Starting Maximization
# Epoch 68 iteration 0 Current loss 0.279259592294693
# Epoch 68 iteration 10 Current loss 0.5251449942588806
# Epoch 68 iteration 20 Current loss 0.3827590346336365
# Starting Maximization
# Epoch 69 iteration 0 Current loss 0.35454532504081726
# Epoch 69 iteration 10 Current loss 0.5357838273048401
# Epoch 69 iteration 20 Current loss 0.4263109266757965
# Calculating Expectation
# Epoch 70 Train Accuracy calculated with probabilities  62.690
# Train Boundary avergage error = 42.583
# Train From boundary avergage accuracy = 27.425
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  47.390
# Epoch 70 Best 3 val accuracy till now =  [56.74865646961555, 57.198222405952876, 57.418354692021495]
# Starting Maximization
# Epoch 70 iteration 0 Current loss 0.6354513168334961
# Epoch 70 iteration 10 Current loss 0.4985143542289734
# Epoch 70 iteration 20 Current loss 0.4775794744491577
# Starting Maximization
# Epoch 71 iteration 0 Current loss 0.42338716983795166
# Epoch 71 iteration 10 Current loss 0.4754093289375305
# Epoch 71 iteration 20 Current loss 0.40174922347068787
# Starting Maximization
# Epoch 72 iteration 0 Current loss 0.34226474165916443
# Epoch 72 iteration 10 Current loss 0.391169011592865
# Epoch 72 iteration 20 Current loss 0.3192380666732788
# Starting Maximization
# Epoch 73 iteration 0 Current loss 0.3626468777656555
# Epoch 73 iteration 10 Current loss 0.35468044877052307
# Epoch 73 iteration 20 Current loss 0.32858607172966003
# Starting Maximization
# Epoch 74 iteration 0 Current loss 0.30462202429771423
# Epoch 74 iteration 10 Current loss 0.35030773282051086
# Epoch 74 iteration 20 Current loss 0.3182511329650879
# Calculating Expectation
# Epoch 75 Train Accuracy calculated with probabilities  70.366
# Train Boundary avergage error = 41.913
# Train From boundary avergage accuracy = 26.277
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  56.473
# Epoch 75 Best 3 val accuracy till now =  [56.74865646961555, 57.198222405952876, 57.418354692021495]
# Starting Maximization
# Epoch 75 iteration 0 Current loss 0.24904325604438782
# Epoch 75 iteration 10 Current loss 0.3185741603374481
# Epoch 75 iteration 20 Current loss 0.27692005038261414
# Starting Maximization
# Epoch 76 iteration 0 Current loss 0.2704660892486572
# Epoch 76 iteration 10 Current loss 0.24463610351085663
# Epoch 76 iteration 20 Current loss 0.28587883710861206
# Starting Maximization
# Epoch 77 iteration 0 Current loss 0.22288675606250763
# Epoch 77 iteration 10 Current loss 0.2374417930841446
# Epoch 77 iteration 20 Current loss 0.2714824080467224
# Starting Maximization
# Epoch 78 iteration 0 Current loss 0.25580623745918274
# Epoch 78 iteration 10 Current loss 0.3388448655605316
# Epoch 78 iteration 20 Current loss 0.31991568207740784
# Starting Maximization
# Epoch 79 iteration 0 Current loss 0.2959750294685364
# Epoch 79 iteration 10 Current loss 0.3227502405643463
# Epoch 79 iteration 20 Current loss 0.27586817741394043
# Calculating Expectation
# Epoch 80 Train Accuracy calculated with probabilities  70.180
# Train Boundary avergage error = 42.017
# Train From boundary avergage accuracy = 24.949
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  55.457
# Epoch 80 Best 3 val accuracy till now =  [56.74865646961555, 57.198222405952876, 57.418354692021495]
# Starting Maximization
# Epoch 80 iteration 0 Current loss 0.3088766634464264
# Epoch 80 iteration 10 Current loss 0.2327544391155243
# Epoch 80 iteration 20 Current loss 0.2743211090564728
# Starting Maximization
# Epoch 81 iteration 0 Current loss 0.2691091001033783
# Epoch 81 iteration 10 Current loss 0.22915589809417725
# Epoch 81 iteration 20 Current loss 0.2809511721134186
# Starting Maximization
# Epoch 82 iteration 0 Current loss 0.21406544744968414
# Epoch 82 iteration 10 Current loss 0.2666104733943939
# Epoch 82 iteration 20 Current loss 0.22250264883041382
# Starting Maximization
# Epoch 83 iteration 0 Current loss 0.2661683261394501
# Epoch 83 iteration 10 Current loss 0.237111434340477
# Epoch 83 iteration 20 Current loss 0.2509213387966156
# Starting Maximization
# Epoch 84 iteration 0 Current loss 0.25734710693359375
# Epoch 84 iteration 10 Current loss 0.22892805933952332
# Epoch 84 iteration 20 Current loss 0.2398228794336319
# Calculating Expectation
# Epoch 85 Train Accuracy calculated with probabilities  70.321
# Train Boundary avergage error = 42.173
# Train From boundary avergage accuracy = 24.396
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  56.612
# Epoch 85 Best 3 val accuracy till now =  [56.74865646961555, 57.198222405952876, 57.418354692021495]
# Starting Maximization
# Epoch 85 iteration 0 Current loss 0.25523197650909424
# Epoch 85 iteration 10 Current loss 0.2306627482175827
# Epoch 85 iteration 20 Current loss 0.22048693895339966
# Starting Maximization
# Epoch 86 iteration 0 Current loss 0.28211453557014465
# Epoch 86 iteration 10 Current loss 0.21738027036190033
# Epoch 86 iteration 20 Current loss 0.2085505574941635
# Starting Maximization
# Epoch 87 iteration 0 Current loss 0.259052574634552
# Epoch 87 iteration 10 Current loss 0.25333091616630554
# Epoch 87 iteration 20 Current loss 0.23465020954608917
# Starting Maximization
# Epoch 88 iteration 0 Current loss 0.1942320615053177
# Epoch 88 iteration 10 Current loss 0.2364862561225891
# Epoch 88 iteration 20 Current loss 0.2095104455947876
# Starting Maximization
# Epoch 89 iteration 0 Current loss 0.20402312278747559
# Epoch 89 iteration 10 Current loss 0.22361604869365692
# Epoch 89 iteration 20 Current loss 0.2142881453037262
# Calculating Expectation
# Epoch 90 Train Accuracy calculated with probabilities  70.867
# Train Boundary avergage error = 42.099
# Train From boundary avergage accuracy = 24.167
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  57.152
# Epoch 90 Best 3 val accuracy till now =  [57.15171558495246, 57.198222405952876, 57.418354692021495]
# Starting Maximization
# Epoch 90 iteration 0 Current loss 0.2251252830028534
# Epoch 90 iteration 10 Current loss 0.21371912956237793
# Epoch 90 iteration 20 Current loss 0.18403322994709015
# Starting Maximization
# Epoch 91 iteration 0 Current loss 0.21854759752750397
# Epoch 91 iteration 10 Current loss 0.2624737322330475
# Epoch 91 iteration 20 Current loss 0.2571529746055603
# Starting Maximization
# Epoch 92 iteration 0 Current loss 0.2194424420595169
# Epoch 92 iteration 10 Current loss 0.2307032346725464
# Epoch 92 iteration 20 Current loss 0.23806074261665344
# Starting Maximization
# Epoch 93 iteration 0 Current loss 0.21386119723320007
# Epoch 93 iteration 10 Current loss 0.19572538137435913
# Epoch 93 iteration 20 Current loss 0.2267756164073944
# Starting Maximization
# Epoch 94 iteration 0 Current loss 0.2086424082517624
# Epoch 94 iteration 10 Current loss 0.2112078219652176
# Epoch 94 iteration 20 Current loss 0.22288940846920013
# Calculating Expectation
# Epoch 95 Train Accuracy calculated with probabilities  71.073
# Train Boundary avergage error = 42.012
# Train From boundary avergage accuracy = 24.741
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  57.421
# Epoch 95 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 95 iteration 0 Current loss 0.18594315648078918
# Epoch 95 iteration 10 Current loss 0.213576078414917
# Epoch 95 iteration 20 Current loss 0.21430975198745728
# Starting Maximization
# Epoch 96 iteration 0 Current loss 0.24401171505451202
# Epoch 96 iteration 10 Current loss 0.22049197554588318
# Epoch 96 iteration 20 Current loss 0.21006381511688232
# Starting Maximization
# Epoch 97 iteration 0 Current loss 0.19125016033649445
# Epoch 97 iteration 10 Current loss 0.22607854008674622
# Epoch 97 iteration 20 Current loss 0.19338682293891907
# Starting Maximization
# Epoch 98 iteration 0 Current loss 0.20408011972904205
# Epoch 98 iteration 10 Current loss 0.27745580673217773
# Epoch 98 iteration 20 Current loss 0.26642534136772156
# Starting Maximization
# Epoch 99 iteration 0 Current loss 0.29581403732299805
# Epoch 99 iteration 10 Current loss 0.2649100720882416
# Epoch 99 iteration 20 Current loss 0.27099063992500305
# Calculating Expectation
# Epoch 100 Train Accuracy calculated with probabilities  69.688
# Train Boundary avergage error = 42.036
# Train From boundary avergage accuracy = 23.071
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  54.807
# Epoch 100 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 100 iteration 0 Current loss 0.2421247512102127
# Epoch 100 iteration 10 Current loss 0.2936322093009949
# Epoch 100 iteration 20 Current loss 0.25510045886039734
# Starting Maximization
# Epoch 101 iteration 0 Current loss 0.27331626415252686
# Epoch 101 iteration 10 Current loss 0.2468508929014206
# Epoch 101 iteration 20 Current loss 0.29324212670326233
# Starting Maximization
# Epoch 102 iteration 0 Current loss 0.2380763441324234
# Epoch 102 iteration 10 Current loss 0.25290513038635254
# Epoch 102 iteration 20 Current loss 0.24560652673244476
# Starting Maximization
# Epoch 103 iteration 0 Current loss 0.20940402150154114
# Epoch 103 iteration 10 Current loss 0.26478224992752075
# Epoch 103 iteration 20 Current loss 0.2086540311574936
# Starting Maximization
# Epoch 104 iteration 0 Current loss 0.21594175696372986
# Epoch 104 iteration 10 Current loss 0.21093599498271942
# Epoch 104 iteration 20 Current loss 0.23598547279834747
# Calculating Expectation
# Epoch 105 Train Accuracy calculated with probabilities  70.623
# Train Boundary avergage error = 42.014
# Train From boundary avergage accuracy = 24.234
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  56.753
# Epoch 105 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 105 iteration 0 Current loss 0.22372502088546753
# Epoch 105 iteration 10 Current loss 0.21548150479793549
# Epoch 105 iteration 20 Current loss 0.2058480829000473
# Starting Maximization
# Epoch 106 iteration 0 Current loss 0.23228727281093597
# Epoch 106 iteration 10 Current loss 0.22187501192092896
# Epoch 106 iteration 20 Current loss 0.18148009479045868
# Starting Maximization
# Epoch 107 iteration 0 Current loss 0.20226718485355377
# Epoch 107 iteration 10 Current loss 0.22857964038848877
# Epoch 107 iteration 20 Current loss 0.19368092715740204
# Starting Maximization
# Epoch 108 iteration 0 Current loss 0.2146381288766861
# Epoch 108 iteration 10 Current loss 0.24704033136367798
# Epoch 108 iteration 20 Current loss 0.2027815580368042
# Starting Maximization
# Epoch 109 iteration 0 Current loss 0.21139149367809296
# Epoch 109 iteration 10 Current loss 0.3371939957141876
# Epoch 109 iteration 20 Current loss 0.3391439616680145
# Calculating Expectation
# Epoch 110 Train Accuracy calculated with probabilities  65.577
# Train Boundary avergage error = 42.192
# Train From boundary avergage accuracy = 23.799
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  50.373
# Epoch 110 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 110 iteration 0 Current loss 0.2660723924636841
# Epoch 110 iteration 10 Current loss 0.39059463143348694
# Epoch 110 iteration 20 Current loss 0.3612256348133087
# Starting Maximization
# Epoch 111 iteration 0 Current loss 0.261037677526474
# Epoch 111 iteration 10 Current loss 0.2499086558818817
# Epoch 111 iteration 20 Current loss 0.25393131375312805
# Starting Maximization
# Epoch 112 iteration 0 Current loss 0.25752541422843933
# Epoch 112 iteration 10 Current loss 0.2482016384601593
# Epoch 112 iteration 20 Current loss 0.280248761177063
# Starting Maximization
# Epoch 113 iteration 0 Current loss 0.2549458146095276
# Epoch 113 iteration 10 Current loss 0.2950141131877899
# Epoch 113 iteration 20 Current loss 0.2829955518245697
# Starting Maximization
# Epoch 114 iteration 0 Current loss 0.2265634387731552
# Epoch 114 iteration 10 Current loss 0.23703300952911377
# Epoch 114 iteration 20 Current loss 0.23728571832180023
# Calculating Expectation
# Epoch 115 Train Accuracy calculated with probabilities  69.233
# Train Boundary avergage error = 42.411
# Train From boundary avergage accuracy = 24.235
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  55.876
# Epoch 115 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 115 iteration 0 Current loss 0.21639952063560486
# Epoch 115 iteration 10 Current loss 0.19573961198329926
# Epoch 115 iteration 20 Current loss 0.19660630822181702
# Starting Maximization
# Epoch 116 iteration 0 Current loss 0.21468280255794525
# Epoch 116 iteration 10 Current loss 0.21709924936294556
# Epoch 116 iteration 20 Current loss 0.16315658390522003
# Starting Maximization
# Epoch 117 iteration 0 Current loss 0.18645521998405457
# Epoch 117 iteration 10 Current loss 0.19907410442829132
# Epoch 117 iteration 20 Current loss 0.21725372970104218
# Starting Maximization
# Epoch 118 iteration 0 Current loss 0.18308378756046295
# Epoch 118 iteration 10 Current loss 0.2167498618364334
# Epoch 118 iteration 20 Current loss 0.2485494613647461
# Starting Maximization
# Epoch 119 iteration 0 Current loss 0.19239689409732819
# Epoch 119 iteration 10 Current loss 0.18498000502586365
# Epoch 119 iteration 20 Current loss 0.197335883975029
# Calculating Expectation
# Epoch 120 Train Accuracy calculated with probabilities  69.677
# Train Boundary avergage error = 42.416
# Train From boundary avergage accuracy = 23.521
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  55.735
# Epoch 120 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 120 iteration 0 Current loss 0.17967194318771362
# Epoch 120 iteration 10 Current loss 0.17796620726585388
# Epoch 120 iteration 20 Current loss 0.17160271108150482
# Starting Maximization
# Epoch 121 iteration 0 Current loss 0.23841975629329681
# Epoch 121 iteration 10 Current loss 0.18457163870334625
# Epoch 121 iteration 20 Current loss 0.1878466010093689
# Starting Maximization
# Epoch 122 iteration 0 Current loss 0.18236054480075836
# Epoch 122 iteration 10 Current loss 0.17835469543933868
# Epoch 122 iteration 20 Current loss 0.17765308916568756
# Starting Maximization
# Epoch 123 iteration 0 Current loss 0.16657045483589172
# Epoch 123 iteration 10 Current loss 0.1637430042028427
# Epoch 123 iteration 20 Current loss 0.17811176180839539
# Starting Maximization
# Epoch 124 iteration 0 Current loss 0.19557280838489532
# Epoch 124 iteration 10 Current loss 0.2310413420200348
# Epoch 124 iteration 20 Current loss 0.1834319531917572
# Calculating Expectation
# Epoch 125 Train Accuracy calculated with probabilities  69.924
# Train Boundary avergage error = 42.394
# Train From boundary avergage accuracy = 24.246
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  56.160
# Epoch 125 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 125 iteration 0 Current loss 0.19384406507015228
# Epoch 125 iteration 10 Current loss 0.20809981226921082
# Epoch 125 iteration 20 Current loss 0.18281510472297668
# Starting Maximization
# Epoch 126 iteration 0 Current loss 0.18166965246200562
# Epoch 126 iteration 10 Current loss 0.1789654642343521
# Epoch 126 iteration 20 Current loss 0.18014104664325714
# Starting Maximization
# Epoch 127 iteration 0 Current loss 0.17663393914699554
# Epoch 127 iteration 10 Current loss 0.2023870050907135
# Epoch 127 iteration 20 Current loss 0.19038867950439453
# Starting Maximization
# Epoch 128 iteration 0 Current loss 0.18819421529769897
# Epoch 128 iteration 10 Current loss 0.2036987841129303
# Epoch 128 iteration 20 Current loss 0.15810857713222504
# Starting Maximization
# Epoch 129 iteration 0 Current loss 0.19789594411849976
# Epoch 129 iteration 10 Current loss 0.16937915980815887
# Epoch 129 iteration 20 Current loss 0.17946390807628632
# Calculating Expectation
# Epoch 130 Train Accuracy calculated with probabilities  69.897
# Train Boundary avergage error = 42.456
# Train From boundary avergage accuracy = 23.774
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  55.671
# Epoch 130 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 130 iteration 0 Current loss 0.1738075315952301
# Epoch 130 iteration 10 Current loss 0.2037123292684555
# Epoch 130 iteration 20 Current loss 0.19279508292675018
# Starting Maximization
# Epoch 131 iteration 0 Current loss 0.20410123467445374
# Epoch 131 iteration 10 Current loss 0.1728850156068802
# Epoch 131 iteration 20 Current loss 0.20235580205917358
# Starting Maximization
# Epoch 132 iteration 0 Current loss 0.1683472990989685
# Epoch 132 iteration 10 Current loss 0.15391938388347626
# Epoch 132 iteration 20 Current loss 0.17617419362068176
# Starting Maximization
# Epoch 133 iteration 0 Current loss 0.17365825176239014
# Epoch 133 iteration 10 Current loss 0.19058161973953247
# Epoch 133 iteration 20 Current loss 0.17725451290607452
# Starting Maximization
# Epoch 134 iteration 0 Current loss 0.16448810696601868
# Epoch 134 iteration 10 Current loss 0.16846108436584473
# Epoch 134 iteration 20 Current loss 0.17388562858104706
# Calculating Expectation
# Epoch 135 Train Accuracy calculated with probabilities  69.984
# Train Boundary avergage error = 42.453
# Train From boundary avergage accuracy = 23.962
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  55.569
# Epoch 135 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 135 iteration 0 Current loss 0.1551300436258316
# Epoch 135 iteration 10 Current loss 0.2314649224281311
# Epoch 135 iteration 20 Current loss 0.22591309249401093
# Starting Maximization
# Epoch 136 iteration 0 Current loss 0.2321397066116333
# Epoch 136 iteration 10 Current loss 0.22312812507152557
# Epoch 136 iteration 20 Current loss 0.21397915482521057
# Starting Maximization
# Epoch 137 iteration 0 Current loss 0.21513190865516663
# Epoch 137 iteration 10 Current loss 0.18979093432426453
# Epoch 137 iteration 20 Current loss 0.19065600633621216
# Starting Maximization
# Epoch 138 iteration 0 Current loss 0.19721180200576782
# Epoch 138 iteration 10 Current loss 0.2862492501735687
# Epoch 138 iteration 20 Current loss 0.2446836233139038
# Starting Maximization
# Epoch 139 iteration 0 Current loss 0.19832350313663483
# Epoch 139 iteration 10 Current loss 0.2709663212299347
# Epoch 139 iteration 20 Current loss 0.20377857983112335
# Calculating Expectation
# Epoch 140 Train Accuracy calculated with probabilities  69.302
# Train Boundary avergage error = 42.195
# Train From boundary avergage accuracy = 24.788
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  53.307
# Epoch 140 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 140 iteration 0 Current loss 0.23485997319221497
# Epoch 140 iteration 10 Current loss 0.1890673190355301
# Epoch 140 iteration 20 Current loss 0.22470998764038086
# Starting Maximization
# Epoch 141 iteration 0 Current loss 0.20831851661205292
# Epoch 141 iteration 10 Current loss 0.1973695009946823
# Epoch 141 iteration 20 Current loss 0.20210595428943634
# Starting Maximization
# Epoch 142 iteration 0 Current loss 0.1909220963716507
# Epoch 142 iteration 10 Current loss 0.19362802803516388
# Epoch 142 iteration 20 Current loss 0.18383803963661194
# Starting Maximization
# Epoch 143 iteration 0 Current loss 0.17542700469493866
# Epoch 143 iteration 10 Current loss 0.1997200846672058
# Epoch 143 iteration 20 Current loss 0.2406148463487625
# Starting Maximization
# Epoch 144 iteration 0 Current loss 0.17055167257785797
# Epoch 144 iteration 10 Current loss 0.21727290749549866
# Epoch 144 iteration 20 Current loss 0.19081099331378937
# Calculating Expectation
# Epoch 145 Train Accuracy calculated with probabilities  67.945
# Train Boundary avergage error = 42.017
# Train From boundary avergage accuracy = 24.965
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  52.421
# Epoch 145 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 145 iteration 0 Current loss 0.19265638291835785
# Epoch 145 iteration 10 Current loss 0.21002615988254547
# Epoch 145 iteration 20 Current loss 0.20028594136238098
# Starting Maximization
# Epoch 146 iteration 0 Current loss 0.20335310697555542
# Epoch 146 iteration 10 Current loss 0.243635892868042
# Epoch 146 iteration 20 Current loss 0.22802698612213135
# Starting Maximization
# Epoch 147 iteration 0 Current loss 0.2601044774055481
# Epoch 147 iteration 10 Current loss 0.3133481740951538
# Epoch 147 iteration 20 Current loss 0.2332836091518402
# Starting Maximization
# Epoch 148 iteration 0 Current loss 0.21489794552326202
# Epoch 148 iteration 10 Current loss 0.2147953361272812
# Epoch 148 iteration 20 Current loss 0.23736411333084106
# Starting Maximization
# Epoch 149 iteration 0 Current loss 0.1841435581445694
# Epoch 149 iteration 10 Current loss 0.19886699318885803
# Epoch 149 iteration 20 Current loss 0.22100134193897247
# Calculating Expectation
# Epoch 150 Train Accuracy calculated with probabilities  71.360
# Train Boundary avergage error = 41.923
# Train From boundary avergage accuracy = 23.088
# Calculating Validation Accuracy
# Validation Accuracy calculated with model probabilities  55.592
# Epoch 150 Best 3 val accuracy till now =  [57.198222405952876, 57.418354692021495, 57.42145514675486]
# Starting Maximization
# Epoch 150 iteration 0 Current loss 0.19914935529232025
# Epoch 150 iteration 10 Current loss 0.18894746899604797
# Epoch 150 iteration 20 Current loss 0.210256889462471
# Starting Maximization
# Epoch 151 iteration 0 Current loss 0.18753838539123535
# Epoch 151 iteration 10 Current loss 0.1807241290807724

# %%
def get_selected_labels(labels_arr):
    unique_ids = []
    
    prev_ele = None
    start = 0
    for i, ele in enumerate(labels_arr):
        if prev_ele is not None and prev_ele != ele:
            select_item = np.random.randint(start, i, 1)[0]
            unique_ids.append(select_item)
            start = i
        prev_ele = ele
    
    select_item = np.random.randint(start, len(labels_arr), 1)[0]
    unique_ids.append(select_item)
    return unique_ids
# get_selected_labels(ab)

# %%
def get_boundary(labels_arr):
    unique_ids = []
    
    prev_ele = None
    start = 0
    for i, ele in enumerate(labels_arr):
        if prev_ele is not None and prev_ele != ele:
            unique_ids.append(i - 1)
            start = i
        prev_ele = ele
    
    unique_ids.append(len(labels_arr) - 1)
    return unique_ids
# get_boundary(np.array([2, 2, 2, 2, 3, 3, 4, 4, 4, 1, 1, 1, 1]))

# %%
loaded_vidid_selected_frames = {}
for batch in trainloader:
    count_all = batch[1]
    labels_all = batch[2]
    video_ids = batch[5]
    for i, count in enumerate(count_all):
        video_id = video_ids[i]
        labels = labels_all[i][:count]
        selected_ids = get_selected_labels(labels)

        loaded_vidid_selected_frames[video_id] = selected_ids

# %%
video_id_boundary_frames = {}
for batch in trainloader:
    count_all = batch[1]
    labels_all = batch[2]
    video_ids = batch[5]
    for i, count in enumerate(count_all):
        
        labels = labels_all[i][:count]
        selected_ids = get_boundary(labels)
        video_id = video_ids[i]
        video_id_boundary_frames[video_id] = selected_ids

# %%
for ele in video_id_boundary_frames.keys():
    if len(video_id_boundary_frames[ele]) != len(loaded_vidid_selected_frames[ele]):
        print(ele)

# %%
"""
loaded_vidid_selected_frames = pickle.load(open("dump_dir/breakfast_split2_selected_frames_dict.pkl", "rb"))
# loaded_vidid_selected_frames
video_id_boundary_frames = pickle.load(open("dump_dir/breakfast_split2_boundary_frames_dict.pkl", "rb"))
# video_id_boundary_frames
"""
import pickle
pickle.dump(video_id_boundary_frames, open("dump_dir/breakfast_split2_selected_frames_dict.pkl", "wb"))
pickle.dump(loaded_vidid_selected_frames, open("dump_dir/breakfast_split2_boundary_frames_dict.pkl", "wb"))

# %%
model.load_state_dict(torch.load('/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/results/c2f-tcn-model/split2_c2ftcn_model.wt'))
# Out:
# <All keys matched successfully>

# %%
model.eval()
loss_arr = []
correct = 0.0
total = 0.0
for i, item in enumerate(trainloader):
    with torch.no_grad():
        item[0] = item[0].to(device)
        item[1] = item[1].to(device)
        y, y_list, _ = model(item[0].permute(0,2,1))
        prob = torch.softmax(y, dim=1).permute(0,2,1)
#         prob = get_ensemble_out([y, y_list]).permute(0,2,1)
        calculate_element_probb(prob, item[1], item[5], item[2].to(device))
        loss, _ = get_estimated_loss(prob, item[1], item[5], item[2].to(device))
        loss_arr.append(loss)
        
        estimated_labels = torch.argmax(prob, dim=2)
        correct += torch.sum(estimated_labels == )
#         probs = get_ensemble_out([y, y_list])
#         features = torch.log(probs + 1e-4).permute(0,2,1)
#         get_estimated_boundary(features, item[1], item[5])
get_boundary_err()
print("Average loss", torch.mean(torch.tensor(loss_arr)))
# Out:
# Boundary avergage error = 25.242
# From boundary avergage accuracy = 69.543
# tensor(0.4019)

# %%
for i in range(prob.shape[0]):
    loss_i, _ = get_estimated_loss(prob[i].unsqueeze(0), item[1][i].unsqueeze(0), [item[5][i]], item[2][i].unsqueeze(0))
    print(loss_i)
#     print(torch.mean(torch.cat(loss_i)))
# Out:
# tensor(0.4542, device='cuda:0')
# tensor(0.1349, device='cuda:0')
# tensor(1.5728, device='cuda:0')
# tensor(0.6470, device='cuda:0')
# tensor(0.2702, device='cuda:0')
# tensor(0.5915, device='cuda:0')
# tensor(2.8901, device='cuda:0')

# %%
loss_i
# Out:
# tensor(0.7432, device='cuda:0')

# %%
with torch.no_grad():
    idx = 6

    cur_vid_feat = prob[idx]
    cur_vidid = item[5][idx]
    labels = item[2][idx]
    selected_frames = torch.tensor(loaded_vidid_selected_frames[cur_vidid], dtype=torch.long, 
                                   device=cur_vid_feat.device)
    prob_each_segment = prob_vals_per_segment(selected_frames, cur_vid_feat, labels)

# %%
loss_i, _ = get_estimated_loss(prob[idx].unsqueeze(0), item[1][idx].unsqueeze(0), [item[5][idx]], item[2][idx].unsqueeze(0))

# %%
loss_i
# Out:
# tensor(2.8901, device='cuda:0')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(18, 5))

ymax = 1.2

plt.plot([0, item[1][idx].item()], [0, 0])

for pivot in loaded_vidid_selected_frames[cur_vidid]:
    plt.plot([pivot, pivot], [0, ymax], '--')
    
for pivot in video_id_boundary_frames[cur_vidid]:
    plt.plot([pivot, pivot], [0, ymax])
    
all_prob = []
for i, segment in enumerate(prob_each_segment):
#     all_prob.append(segment/torch.sum(segment))
    prob_i = segment / torch.sum(segment)
    prob_i = prob_i.cpu().numpy()
    xs = np.arange(loaded_vidid_selected_frames[cur_vidid][i], loaded_vidid_selected_frames[cur_vidid][i+1])
    plt.plot(xs, prob_i, '*')

plt.ylim([0, ymax])
# all_prob = torch.cat(all_prob).cpu().numpy()
# xs = np.arange(loaded_vidid_selected_frames[cur_vidid][0] + 1, loaded_vidid_selected_frames[cur_vidid][-1])
# plt.plot(xs, all_prob, '-')
# Out:
# (0, 1.2)

# %%
cur_vid_feat = torch.softmax(y, dim=1).permute(0,2,1)[idx]
cur_vid_count = item[1][idx]
labels = item[2][idx]

selected_frames = loaded_vidid_selected_frames[cur_vidid]
prob_each_video = prob_video_each_segment_dict[cur_vidid]

log_probs = torch.log(cur_vid_feat + 1e-8)
cumsum_feat = torch.cumsum(log_probs, dim=0)

full_arr = []
for i, cur_ele in enumerate(selected_frames[:-1]):
    next_ele = selected_frames[i + 1]
    label_cur_ele = labels[cur_ele]
    label_next_ele = labels[next_ele]
    prob_list = [] 

    count = 0
    for ele in range(cur_ele, next_ele, 1):
        start_sum = cumsum_feat[cur_ele - 1, :] if cur_ele > 0 else 0
        sum_window_class_1 = (cumsum_feat[ele, :] - start_sum)[label_cur_ele]
        sum_window_class_2 = (cumsum_feat[next_ele - 1, :] - cumsum_feat[ele, :])[label_next_ele]
        prob_list.append((sum_window_class_1 + sum_window_class_2)  * (prob_each_video[i][count].item()))
        count = count + 1
    full_arr.append(torch.stack(prob_list))

# %%
-torch.mean(torch.cat(full_arr))
# Out:
# tensor(0.3756, device='cuda:0')

# %%
label_cur_ele
# Out:
# tensor(14)

# %%
label_next_ele
# Out:
# tensor(47)

# %%
selected_frames
# Out:
# [0, 10, 18, 60, 102, 183, 198, 242]

# %%
plt_arr = []


for i in range(item[1][idx].item()):
    plt_arr.append(cur_vid_feat[i,item[2][idx][i]].item()) 

fig = plt.figure(figsize=(18, 5))
plt.plot(np.arange(item[1][idx].item()), plt_arr)

all_prob = []
for i, segment in enumerate(prob_each_segment):
#     all_prob.append(segment/torch.sum(segment))
    prob_i = segment / torch.sum(segment)
    prob_i = prob_i.cpu().numpy()
    xs = np.arange(loaded_vidid_selected_frames[cur_vidid][i], loaded_vidid_selected_frames[cur_vidid][i+1])
    plt.plot(xs, prob_i, '*')

for pivot in loaded_vidid_selected_frames[cur_vidid]:
    plt.plot([pivot, pivot], [0, ymax], '--')
    
for pivot in video_id_boundary_frames[cur_vidid]:
    plt.plot([pivot, pivot], [0, 1])
