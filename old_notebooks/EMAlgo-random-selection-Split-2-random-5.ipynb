# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
import os, sys
import glob
import numpy as np
import torch
import pandas as pd
import random
import torch.nn as nn
import pickle
import torch.nn.functional as F
import matplotlib.pyplot as plt
import multiprocessing as mp
from time import time

# %%
from mstcn_model import *
from utility.adaptive_data_loader import Breakfast, collate_fn_override
from utility.adaptive_data_loader import BreakfastWithWeights, collate_fn_override_wtd
from utils import calculate_mof, dotdict

# %%
os.environ["WANDB_API_KEY"] = "992b3b1371ba79f48484cfca522b3786d7fa52c2"
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dipika_singhania (use `wandb login --relogin` to force relogin)
# True

# %%
seed = 42

# Ensure deterministic behavior
def set_seed():
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
set_seed()

# Device configuration
os.environ['CUDA_VISIBLE_DEVICES']='6'
# os.environ['CUDA_LAUNCH_BLOCKING']='6'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config = dotdict(
    epochs=500,
    num_class=48,
    batch_size=8,
    learning_rate=5e-4,
    weight_decay=0,
    dataset="Breakfast",
    architecture="unet-ensemble",
    features_file_name="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/",
    chunk_size=1,
    max_frames_per_video=1200,
    feature_size=2048,
    ground_truth_files_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/",
    label_id_csv="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv",
    gamma=0.1,
    step_size=500,
    split=2,
#     output_dir="/mnt/data/ar-datasets/dipika/breakfast/ms_tcn/data/breakfast/results/unsuper-finetune-split2-0.05-data-llr/",
    output_dir="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select5/",
    train_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split{}.bundle",
    test_split_file="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split{}.bundle",
    all_files="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt",
    cutoff=8,
    data_per = 0.2,
    budget=40,
    semi_supervised_split="/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split{}_amt{}.bundle")

config.train_split_file = config.train_split_file.format(config.split)
config.semi_supervised_split = config.semi_supervised_split.format(config.split, config.data_per)
config.test_split_file = config.test_split_file.format(config.split)

if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)

config.output_dir = config.output_dir + f"split{config.split}"
if not os.path.exists(config.output_dir):
    os.mkdir(config.output_dir)
config.output_dir = config.output_dir + "/"
if not os.path.exists(os.path.join(config.output_dir, "posterior_weights")):
    os.mkdir(os.path.join(config.output_dir, "posterior_weights"))
print(config)
# Out:
# {'epochs': 500, 'num_class': 48, 'batch_size': 8, 'learning_rate': 0.0005, 'weight_decay': 0, 'dataset': 'Breakfast', 'architecture': 'unet-ensemble', 'features_file_name': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/features/', 'chunk_size': 1, 'max_frames_per_video': 1200, 'feature_size': 2048, 'ground_truth_files_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/groundTruth/', 'label_id_csv': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/mapping.csv', 'gamma': 0.1, 'step_size': 500, 'split': 2, 'output_dir': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-random-select5/split2/', 'train_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/train.split2.bundle', 'test_split_file': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/test.split2.bundle', 'all_files': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/splits/all_files.txt', 'cutoff': 8, 'data_per': 0.2, 'budget': 40, 'semi_supervised_split': '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast/semi_supervised/train.split2_amt0.2.bundle'}

# %%
traindataset = BreakfastWithWeights(config, fold='train', fold_file_name=config.train_split_file)
testdataset = Breakfast(config, fold='test', fold_file_name=config.test_split_file)
# Out:
# Number of videos logged in train fold is 1261
# Number of videos not found in train fold is 0
# Number of videos logged in test fold is 451
# Number of videos not found in test fold is 0

# %%
def _init_fn(worker_id):
    np.random.seed(int(seed))
trainloader = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=config.batch_size, 
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)
testloader = torch.utils.data.DataLoader(dataset=testdataset,
                                          batch_size=config.batch_size, 
                                          shuffle=False,
                                          pin_memory=True, num_workers=4,
                                          collate_fn=lambda x: collate_fn_override(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

trainloder_expectation = torch.utils.data.DataLoader(dataset=traindataset,
                                          batch_size=20,
                                          shuffle=True,
                                          pin_memory=True, num_workers=4, 
                                          collate_fn=lambda x: collate_fn_override_wtd(x, config.max_frames_per_video),
                                          worker_init_fn=_init_fn)

# %%
df = pd.read_csv(config.label_id_csv)
label_id_to_label_name = {}
label_name_to_label_id_dict = {}
for i, ele in df.iterrows():
    label_id_to_label_name[ele.label_id] = ele.label_name
    label_name_to_label_id_dict[ele.label_name] = ele.label_id

# %%
# selected_frames_dict = pickle.load(open("data/breakfast_len_assum_annotations.pkl", 'rb'))
# loaded_vidid_selected_frames
boundary_frames_dict = pickle.load(open("data/breakfast_boundary_annotations.pkl", "rb"))
num_boundary = 0
for key in boundary_frames_dict.keys():
    num_boundary += len(boundary_frames_dict[key])
# video_id_boundary_frames

# %%
selected_frames_dict = pickle.load(open("data/breakfast_random5frame_selection.pkl", "rb"))
# print(selected_frames_dict)

# %%
loaded_mean_var_actions = pickle.load(open("data/breakfast_meanvar_actions.pkl", "rb"))
mat_poisson = pickle.load(open("data/breakfast_possion_class_dict.pkl", "rb"))

def get_possion_prob(minlen, maxlen, cur_class):
    prob = mat_poisson[label_id_to_label_name[cur_class]][minlen:maxlen]
    return torch.tensor(prob)

def get_poisson_logcdf(minlen, cur_class):
    return np.log(np.sum(np.exp(mat_poisson[label_id_to_label_name[cur_class]][minlen:])) + 1e-20)

def get_possion_prob_for_all_class(minlen, maxlen):
    ele_list = []
    for i in range(config.num_class):
        prob = mat_poisson[label_id_to_label_name[i]][minlen:maxlen]
        ele_list.append(torch.tensor(prob))
    return torch.stack(ele_list, dim=-1)

# %%
def validate(model, dataloader, best_val_acc=None):
    model.eval()
    print("Calculating Validation Data Accuracy")
    correct = 0.0
    total = 0.0
    for i, item in enumerate(testloader):
        with torch.no_grad():
            item_0 = item[0].to(device)
            item_1 = item[1].to(device)
            item_2 = item[2].to(device)
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            pred = torch.argmax(predictions[-1], dim=1)
            correct += float(torch.sum((pred == item_2) * src_mask).item())
            total += float(torch.sum(src_mask).item())
    val_acc = correct * 100.0 / total
    if best_val_acc is not None and val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-best-model.wt")
    torch.save(model.state_dict(), config.output_dir + "ms-tcn-emmax-last-model.wt")
    print(f"Validation:: Probability Accuracy {val_acc}")
    _ = model.train()
    return val_acc, best_val_acc

# %%
def prob_vals_per_segment(selected_frames, cur_vid_feat, labels, first_ele_flag, last_ele_flag, vidid, gt_labels):
    prob_each_segment = []
    LOW_VAL = -10000000
    num_frames = len(cur_vid_feat)
    log_probs = torch.log(cur_vid_feat + 1e-8)
    cumsum_feat = torch.cumsum(log_probs, dim=0)
    prev_boundary = 0
    per_frame_weights = torch.zeros((num_frames, config.num_class))
    start_time = time()
    boundary_error = 0
    current_boundary = 0
    labels = [config.num_class-1] + labels if selected_frames[0] != 0 else labels
    labels = labels + [config.num_class-1] if selected_frames[-1] != num_frames-1 else labels
    selected_frames = [0] + selected_frames if selected_frames[0] != 0 else selected_frames
    selected_frames = selected_frames + [num_frames-1] if selected_frames[-1] != num_frames-1 else selected_frames

    for i, cur_ele in enumerate(selected_frames[:-1]):
        next_ele = selected_frames[i + 1]
        label_cur_ele = labels[i]
        label_next_ele = labels[i + 1]
        if cur_ele == next_ele-1:
            per_frame_weights[cur_ele, label_cur_ele] = 1.0
            if label_cur_ele != label_next_ele:
                prev_boundary = cur_ele
            continue
        
        seg_len = next_ele - cur_ele
        mat_b1_b2_c_prob = LOW_VAL * torch.ones((seg_len, seg_len, config.num_class), dtype=cumsum_feat.dtype)
        b1_prior = get_possion_prob(cur_ele-prev_boundary, next_ele-prev_boundary, label_cur_ele)
        
        # find dummy label where we will keep the diagonal (b1=b2) probabilities, later we will distribute among
        # rest of the classes after the softmax by dividing by (num_class - 2)
        dummy_label = 0
        while True:
            if dummy_label != label_cur_ele and dummy_label != label_next_ele:
                break
            else:
                dummy_label += 1
        
        for b1 in range(cur_ele, next_ele - 1):

            cur_boundary_len = b1 - prev_boundary
            strt_index = cumsum_feat[cur_ele - 1, label_cur_ele] if cur_ele > 0 else 0
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            right_sum = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1+1:next_ele, label_next_ele] # mid_seg_len
            mid_sum = (cumsum_feat[b1+1:next_ele, :] - cumsum_feat[b1, :])  # mid_seg_len
            b2_prior = get_possion_prob_for_all_class(1, next_ele-b1)  # mid_seg_len x num_class
            
            mat_b1_b2_c_prob[b1-cur_ele, b1+1-cur_ele:next_ele-cur_ele] = (left_sum + right_sum[:,None] + mid_sum) \
                                                                            + b1_prior[b1-cur_ele] + b2_prior
            # when mid segment is absent but right and left is not the same
            # we assign the probability to a dummy label for now and then later 
            # re-distribute among other classes after the softmax
            if label_cur_ele != label_next_ele:
                rightsum_wo_midseg = cumsum_feat[next_ele-1, label_next_ele] - cumsum_feat[b1, label_next_ele]
                mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + rightsum_wo_midseg + b1_prior[b1-cur_ele]
        
#         if vidid=='P39_cam02_P39_scrambledegg' and cur_ele==574:
#             import pdb
#             pdb.set_trace()
        # when mid segment is absent b1 can also be next_ele-1
        b1 = next_ele - 1
        if label_cur_ele != label_next_ele:
            left_sum = (cumsum_feat[b1, label_cur_ele] - strt_index)
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior[b1-cur_ele]
        else:
            # returns prob that the left class length >= seg len
            b1_prior_ = get_poisson_logcdf(next_ele - prev_boundary, label_cur_ele) 
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label] = left_sum + b1_prior_
        
        mat_b1_b2_c_prob[:, :, label_cur_ele] = LOW_VAL
        mat_b1_b2_c_prob[:, :, label_next_ele] = LOW_VAL
        mat_b1_b2_c_prob = torch.softmax(mat_b1_b2_c_prob.flatten(), dim=0).reshape((seg_len, seg_len, config.num_class))
        
        # re-distribute the dummy class probability among the left-over classes
        left_over_classes = config.num_class - 2 + (label_cur_ele==label_next_ele)
        for b1 in range(cur_ele, next_ele):
            assigned_prob = mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, dummy_label]
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, :] = assigned_prob/left_over_classes
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_cur_ele] = 0
            mat_b1_b2_c_prob[b1-cur_ele, b1-cur_ele, label_next_ele] = 0
        
        marginal_b1 = torch.sum(mat_b1_b2_c_prob, axis=(1,2))
        mean_b1 = round(torch.sum(marginal_b1.squeeze() * torch.arange(cur_ele, next_ele, 1)).item())
        cumm_b1_prob = torch.cumsum(marginal_b1, dim=0)
        cumm_b1_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=1), dim=0)
        cumm_b2_c_prob = torch.cumsum(torch.sum(mat_b1_b2_c_prob, dim=0), dim=0)

        per_frame_weights[cur_ele, label_cur_ele] = 1.0
        per_frame_weights[cur_ele+1:next_ele, :] = cumm_b1_c_prob[:-1] - cumm_b2_c_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_cur_ele] = 1 - cumm_b1_prob[:-1]
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] = 0
        remaining_probability = 1 - torch.sum(per_frame_weights[cur_ele+1:next_ele, :], dim=-1)
        # we use "+=" in the next line because left and right label might be the same
        # in that case using "=" would just overwrite the previous probability
        per_frame_weights[cur_ele+1:next_ele, label_next_ele] += remaining_probability
        
        expected_boundary = round(torch.sum(torch.sum(mat_b1_b2_c_prob, axis=(0,2)).squeeze() * \
                            torch.arange(cur_ele, next_ele, 1)).item())
        if not (label_cur_ele == label_next_ele and expected_boundary >= next_ele-2):
            prev_boundary = expected_boundary
        if expected_boundary == 0 and i > 0:
            print(f'Estimated boundary has become zero! for {vidid} and cur_ele, next_ele {cur_ele, next_ele}')
            import pdb
            pdb.set_trace()
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary] - mean_b1)**2
        # boundary_error += (boundary_frames_dict[vidid + '.txt'][current_boundary+1] - prev_boundary)**2
        # current_boundary += 2
        # prob_each_segment.append(mat_b1_b2_c_prob)
        
    posterior_prediction = torch.argmax(per_frame_weights, dim=1)
    correct = torch.sum(posterior_prediction == gt_labels[:num_frames]).item()
    
    return (vidid, per_frame_weights, [correct, num_frames, boundary_error]) #, prob_each_segment)

# %%
posterior_acc_correct, posterior_acc_total = 0, 0
posterior_boundary_total_mse = 0
results = []

# Step 2: Define callback function to collect the output in `results`
def collect_result(result):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    fname = os.path.join(config.output_dir, 'posterior_weights', result[0] + '.wt')
    torch.save(result[1], fname)
    correct, total, boundary_err = result[2]
    posterior_acc_correct += correct
    posterior_acc_total += total
    posterior_boundary_total_mse += boundary_err
    # print(f'Dumped in file {fname} at time {time()}')
    return

def calculate_element_probb(data_feat, data_count, video_ids, gt_labels): # loaded_vidid_selected_frames, boundaries_dict):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    pool = mp.Pool(20)
    for iter_num in range(len(data_count)):
        cur_vidid = video_ids[iter_num]
#         if cur_vidid!='P39_cam02_P39_scrambledegg':
#             continue
        cur_vid_count = data_count[iter_num]
        cur_vid_feat = data_feat[iter_num][:cur_vid_count].detach().cpu()
        cur_gt_labels = gt_labels[iter_num].detach().cpu()
        
        cur_video_select_frames = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices_and_labels = cur_video_select_frames
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]
        with torch.no_grad():
            # Multi-processing
            pool.apply_async(prob_vals_per_segment,
                             args=(selected_frames_indices, cur_vid_feat, selected_frames_labels,
                                   cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels),
                             callback=collect_result)
#             results.append(prob_vals_per_segment(selected_frames_indices, cur_vid_feat, selected_frames_labels,
#                                    cur_video_select_frames[1], cur_video_select_frames[2], cur_vidid, cur_gt_labels))
    # Step 4: Close Pool and let all the processes complete
    pool.close()
    pool.join()  # postpones the execution of next line of code until all processes in the queue are done.
    return results

def perform_expectation(model, dataloader):
    global posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse
    posterior_acc_correct, posterior_acc_total, posterior_boundary_total_mse = 0, 0, 0
    model.eval()
    correct = 0.0
    total = 0.0
    curtime = time()
    print(f'Calculating expectation')

    for i, item in enumerate(dataloader):
        with torch.no_grad():
            item_0 = item[0].to(device) # features
            item_1 = item[1].to(device) # count
            item_2 = item[2].to(device) # gt frame-wise labels
            item_4 = item[4] # video-ids
            src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
            src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
            middle_pred, predictions = model(item_0, src_mask_mse)
            prob = torch.softmax(predictions[-1], dim=1)
            prob = prob.permute(0, 2, 1)
            
            calculate_element_probb(prob, item_1, item_4, item_2)
            if (i+1) % 10 == 0:
                print(f"iter {i+1} of Expectation completed in a total of {(time() - curtime)/60.: .1f} minutes")
    _ = model.train()
    print(f'Expectation step finished, '
          f'posterior frame-wise accuracy {100*posterior_acc_correct/posterior_acc_total: .2f}%, '
          f'boundary mse {(posterior_boundary_total_mse/num_boundary)**0.5: .2f}')
    return

# %%
set_seed()
model = MultiStageModel(num_stages=4, num_layers=10, num_f_maps=64, dim=2048, num_classes=48).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

# Requires loaded_vidid_selected_frames, boundaries_dict
ce_criterion = nn.CrossEntropyLoss(ignore_index=-100)
mse_criterion = nn.MSELoss(reduction='none')

# %%
# loaded_file=torch.load(os.path.join(config.output_dir, "ms-tcn-initial-30-epochs.wt"))
# model.load_state_dict(loaded_file)
# # loaded_file=torch.load('/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/mstcnnew-full-supervised-split1/ms-tcn-best-model.wt')
# # model.load_state_dict(loaded_file)
# _ = validate(model, testloader)

# %%
# item = next(iter(trainloader))
    
# with torch.no_grad():
#     item_0 = item[0].to(device) # features
#     item_1 = item[1].to(device) # count
#     item_2 = item[2].to(device) # gt frame-wise labels
#     item_4 = item[4] # video-ids
#     src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
#     src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
#     middle_pred, predictions = model(item_0, src_mask_mse)
#     prob = torch.softmax(predictions[-1], dim=1)
#     prob = prob.permute(0, 2, 1)

#     res = calculate_element_probb(prob, item_1, item_4, item_2)

# %%
# idx = 2
# vidid = res[idx][0]
# mat = res[idx][1]
# mat.shape

# %%
# np.linspace(0, 5281, 4 + 1).astype(int)

# %%
# boundary_frames_dict[f'{vidid}.txt'], selected_frames_dict[f'{vidid}.txt'], weakly_labels[f'{vidid}.txt']

# %%
# fig = plt.figure(figsize=(20, 5))
# for i in range(48):
#     plt.plot(mat[:,i])
    
# for bd in boundary_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd, bd], [0, 2])
    
# for bd in selected_frames_dict[f'{vidid}.txt']:
#     plt.plot([bd[0], bd[0]], [0, 2], '--')

# %%
# bd

# %%
# Calculating Expectation Step
# perform_expectation(model, trainloder_expectation)

# %%
def get_single_random(video_ids, len_frames, device):
    # Generate target for only timestamps. Do not generate pseudo labels at first 30 epochs.
    boundary_target_tensor = torch.ones((len(video_ids), len_frames), dtype=torch.long, device=device) * (-100)
    for iter_num, cur_vidid in enumerate(video_ids):
        selected_frames_indices_and_labels = selected_frames_dict[cur_vidid + ".txt"]
        selected_frames_indices = [ele[0] for ele in selected_frames_indices_and_labels]
        selected_frames_labels = [label_name_to_label_id_dict[ele[1]] for ele in selected_frames_indices_and_labels]

        frame_idx_tensor = torch.from_numpy(np.array(selected_frames_indices))
        frame_labels = torch.from_numpy(np.array(selected_frames_labels)).to(device)
        boundary_target_tensor[iter_num, frame_idx_tensor] = frame_labels

    return boundary_target_tensor

# %%
weakly_labels = pickle.load(open("data/breakfast_weaklysupervised_labels.pkl", "rb"))
prior_probs = pickle.load(open('data/breakfast_lengthmodel_multinomial_prior.pkl', 'rb'))

# %%
initialize_epoch = 30
expectation_cal_gap = 5
best_val_acc = 0
for epoch in range(0, 150):
    print("Starting Training")
    model.train()
    for i, item in enumerate(trainloader):
        item_0 = item[0].to(device)  # features
        item_1 = item[1].to(device)  # count
        item_2 = item[2].to(device)  # target
        weights = item[5].to(device)  # posterior weight
        src_mask = torch.arange(item_2.shape[1], device=item_2.device)[None, :] < item_1[:, None]
        src_mask_mse = src_mask.unsqueeze(1).to(torch.float32).to(device)
        optimizer.zero_grad()
        
        middle_pred, predictions = model(item_0, src_mask_mse)
        boundary_target_tensor = get_single_random(item[4], item_2.shape[1], item_2.device)
        
        loss = 0
        for p in predictions:
            if epoch <= initialize_epoch:
                loss += ce_criterion(p, boundary_target_tensor)
                loss += 0.15 * torch.mean(torch.clamp(mse_criterion(F.log_softmax(p[:, :, 1:], dim=1), 
                                                                    F.log_softmax(p.detach()[:, :, :-1], dim=1)), min=0,
                                            max=16) * src_mask_mse[:, :, 1:])
            else:
                prob = torch.softmax(p, dim=1)
                prob = prob.permute(0, 2, 1)
                total_count = torch.sum(src_mask)
                weighted_loss_sum = -torch.sum(torch.sum(torch.log(prob + 1e-8) * weights, dim=-1) * src_mask)
                loss += weighted_loss_sum/total_count

        loss.backward()
        optimizer.step()
        if (i+1)%20 == 0:
            print(f'Epoch {epoch+1}: Iteration {i+1} with loss {loss.item()}')

    if (epoch >= initialize_epoch) and ((epoch % (3 * expectation_cal_gap)) == 0):
        torch.save(model.state_dict(), config.output_dir + f"ms-tcn-initial-{epoch}-epochs.wt")

    if epoch >= initialize_epoch and (epoch % expectation_cal_gap == 0):
        perform_expectation(model, trainloder_expectation)
    
    print(f'Epoch {epoch+1} finished, starting validation')
    val_acc, best_val_acc = validate(model, testloader, best_val_acc)
# Out:
# Starting Training
# Epoch 1: Iteration 20 with loss 14.245320320129395
# Epoch 1: Iteration 40 with loss 14.003326416015625
# Epoch 1: Iteration 60 with loss 12.168647766113281
# Epoch 1: Iteration 80 with loss 13.048243522644043
# Epoch 1: Iteration 100 with loss 12.3617582321167
# Epoch 1: Iteration 120 with loss 11.289863586425781
# Epoch 1: Iteration 140 with loss 10.491085052490234
# Epoch 1 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 16.56999627128475
# Starting Training
# Epoch 2: Iteration 20 with loss 10.392182350158691
# Epoch 2: Iteration 40 with loss 10.678564071655273
# Epoch 2: Iteration 60 with loss 9.118927955627441
# Epoch 2: Iteration 80 with loss 10.40345573425293
# Epoch 2: Iteration 100 with loss 10.012513160705566
# Epoch 2: Iteration 120 with loss 11.174749374389648
# Epoch 2: Iteration 140 with loss 7.948122501373291
# Epoch 2 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 19.867319882338318
# Starting Training
# Epoch 3: Iteration 20 with loss 8.109039306640625
# Epoch 3: Iteration 40 with loss 6.425180435180664
# Epoch 3: Iteration 60 with loss 9.221851348876953
# Epoch 3: Iteration 80 with loss 10.073718070983887
# Epoch 3: Iteration 100 with loss 8.16987133026123
# Epoch 3: Iteration 120 with loss 7.683672904968262
# Epoch 3: Iteration 140 with loss 8.649824142456055
# Epoch 3 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 23.07277209263786
# Starting Training
# Epoch 4: Iteration 20 with loss 7.020649433135986
# Epoch 4: Iteration 40 with loss 7.464523792266846
# Epoch 4: Iteration 60 with loss 6.139284133911133
# Epoch 4: Iteration 80 with loss 7.687474250793457
# Epoch 4: Iteration 100 with loss 5.645144939422607
# Epoch 4: Iteration 120 with loss 6.00220251083374
# Epoch 4: Iteration 140 with loss 6.486091136932373
# Epoch 4 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 37.923312756349176
# Starting Training
# Epoch 5: Iteration 20 with loss 5.414742469787598
# Epoch 5: Iteration 40 with loss 5.815886974334717
# Epoch 5: Iteration 60 with loss 5.8746819496154785
# Epoch 5: Iteration 80 with loss 5.193308353424072
# Epoch 5: Iteration 100 with loss 5.847569465637207
# Epoch 5: Iteration 120 with loss 5.851791858673096
# Epoch 5: Iteration 140 with loss 4.37522554397583
# Epoch 5 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 45.4079835936529
# Starting Training
# Epoch 6: Iteration 20 with loss 3.9739646911621094
# Epoch 6: Iteration 40 with loss 3.986574411392212
# Epoch 6: Iteration 60 with loss 4.725174427032471
# Epoch 6: Iteration 80 with loss 3.762549877166748
# Epoch 6: Iteration 100 with loss 4.227003574371338
# Epoch 6: Iteration 120 with loss 5.812983989715576
# Epoch 6: Iteration 140 with loss 6.12468147277832
# Epoch 6 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 46.46828520528649
# Starting Training
# Epoch 7: Iteration 20 with loss 4.107335567474365
# Epoch 7: Iteration 40 with loss 4.930427074432373
# Epoch 7: Iteration 60 with loss 5.23871374130249
# Epoch 7: Iteration 80 with loss 4.375555038452148
# Epoch 7: Iteration 100 with loss 4.468420028686523
# Epoch 7: Iteration 120 with loss 4.664605617523193
# Epoch 7: Iteration 140 with loss 3.6629202365875244
# Epoch 7 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 41.339437378298875
# Starting Training
# Epoch 8: Iteration 20 with loss 5.4010443687438965
# Epoch 8: Iteration 40 with loss 4.087748050689697
# Epoch 8: Iteration 60 with loss 4.79730224609375
# Epoch 8: Iteration 80 with loss 7.4487786293029785
# Epoch 8: Iteration 100 with loss 5.003041744232178
# Epoch 8: Iteration 120 with loss 5.35526180267334
# Epoch 8: Iteration 140 with loss 3.7174081802368164
# Epoch 8 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.0904213448233
# Starting Training
# Epoch 9: Iteration 20 with loss 5.512045383453369
# Epoch 9: Iteration 40 with loss 3.593900680541992
# Epoch 9: Iteration 60 with loss 3.399413824081421
# Epoch 9: Iteration 80 with loss 5.116301536560059
# Epoch 9: Iteration 100 with loss 3.3874547481536865
# Epoch 9: Iteration 120 with loss 5.690781116485596
# Epoch 9: Iteration 140 with loss 3.9909510612487793
# Epoch 9 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.28564030326884
# Starting Training
# Epoch 10: Iteration 20 with loss 3.754589557647705
# Epoch 10: Iteration 40 with loss 4.318211078643799
# Epoch 10: Iteration 60 with loss 4.619520664215088
# Epoch 10: Iteration 80 with loss 3.248046875
# Epoch 10: Iteration 100 with loss 4.120844841003418
# Epoch 10: Iteration 120 with loss 3.762117385864258
# Epoch 10: Iteration 140 with loss 2.708631753921509
# Epoch 10 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.83616439491237
# Starting Training
# Epoch 11: Iteration 20 with loss 2.0668046474456787
# Epoch 11: Iteration 40 with loss 2.2919414043426514
# Epoch 11: Iteration 60 with loss 2.153566360473633
# Epoch 11: Iteration 80 with loss 3.2022252082824707
# Epoch 11: Iteration 100 with loss 3.8079700469970703
# Epoch 11: Iteration 120 with loss 3.460916042327881
# Epoch 11: Iteration 140 with loss 4.42411470413208
# Epoch 11 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.679330488461694
# Starting Training
# Epoch 12: Iteration 20 with loss 2.2183303833007812
# Epoch 12: Iteration 40 with loss 3.227203607559204
# Epoch 12: Iteration 60 with loss 5.330557346343994
# Epoch 12: Iteration 80 with loss 4.0931291580200195
# Epoch 12: Iteration 100 with loss 3.423335313796997
# Epoch 12: Iteration 120 with loss 2.1681368350982666
# Epoch 12: Iteration 140 with loss 4.4239420890808105
# Epoch 12 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.06355387993537
# Starting Training
# Epoch 13: Iteration 20 with loss 3.440526247024536
# Epoch 13: Iteration 40 with loss 2.4921059608459473
# Epoch 13: Iteration 60 with loss 2.5182552337646484
# Epoch 13: Iteration 80 with loss 2.5080223083496094
# Epoch 13: Iteration 100 with loss 3.1634373664855957
# Epoch 13: Iteration 120 with loss 2.303990364074707
# Epoch 13: Iteration 140 with loss 2.458522081375122
# Epoch 13 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.82646973526122
# Starting Training
# Epoch 14: Iteration 20 with loss 1.6713193655014038
# Epoch 14: Iteration 40 with loss 2.3187029361724854
# Epoch 14: Iteration 60 with loss 2.6924386024475098
# Epoch 14: Iteration 80 with loss 2.8041820526123047
# Epoch 14: Iteration 100 with loss 2.1735754013061523
# Epoch 14: Iteration 120 with loss 2.3224668502807617
# Epoch 14: Iteration 140 with loss 1.948372483253479
# Epoch 14 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.33865020507934
# Starting Training
# Epoch 15: Iteration 20 with loss 1.9311919212341309
# Epoch 15: Iteration 40 with loss 2.700939178466797
# Epoch 15: Iteration 60 with loss 2.2543375492095947
# Epoch 15: Iteration 80 with loss 2.7819087505340576
# Epoch 15: Iteration 100 with loss 2.2608187198638916
# Epoch 15: Iteration 120 with loss 2.2676310539245605
# Epoch 15: Iteration 140 with loss 2.6737282276153564
# Epoch 15 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.429402991258236
# Starting Training
# Epoch 16: Iteration 20 with loss 2.592132806777954
# Epoch 16: Iteration 40 with loss 2.237848997116089
# Epoch 16: Iteration 60 with loss 2.097391366958618
# Epoch 16: Iteration 80 with loss 1.6244207620620728
# Epoch 16: Iteration 100 with loss 2.586106538772583
# Epoch 16: Iteration 120 with loss 2.735490322113037
# Epoch 16: Iteration 140 with loss 1.9744288921356201
# Epoch 16 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.33833947880847
# Starting Training
# Epoch 17: Iteration 20 with loss 1.6771364212036133
# Epoch 17: Iteration 40 with loss 1.71763277053833
# Epoch 17: Iteration 60 with loss 1.4949071407318115
# Epoch 17: Iteration 80 with loss 2.0486013889312744
# Epoch 17: Iteration 100 with loss 1.4998730421066284
# Epoch 17: Iteration 120 with loss 1.2262922525405884
# Epoch 17: Iteration 140 with loss 1.9236146211624146
# Epoch 17 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.458694121058954
# Starting Training
# Epoch 18: Iteration 20 with loss 1.6965088844299316
# Epoch 18: Iteration 40 with loss 1.6690917015075684
# Epoch 18: Iteration 60 with loss 1.9857478141784668
# Epoch 18: Iteration 80 with loss 1.876647710800171
# Epoch 18: Iteration 100 with loss 1.331659197807312
# Epoch 18: Iteration 120 with loss 2.6681509017944336
# Epoch 18: Iteration 140 with loss 1.179355263710022
# Epoch 18 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.56813191365953
# Starting Training
# Epoch 19: Iteration 20 with loss 1.5873695611953735
# Epoch 19: Iteration 40 with loss 1.8511950969696045
# Epoch 19: Iteration 60 with loss 2.148184299468994
# Epoch 19: Iteration 80 with loss 1.0774610042572021
# Epoch 19: Iteration 100 with loss 1.5737868547439575
# Epoch 19: Iteration 120 with loss 1.7424668073654175
# Epoch 19: Iteration 140 with loss 2.839433431625366
# Epoch 19 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.22076065791109
# Starting Training
# Epoch 20: Iteration 20 with loss 1.4158821105957031
# Epoch 20: Iteration 40 with loss 1.4103708267211914
# Epoch 20: Iteration 60 with loss 1.0842082500457764
# Epoch 20: Iteration 80 with loss 1.5012731552124023
# Epoch 20: Iteration 100 with loss 2.081692695617676
# Epoch 20: Iteration 120 with loss 1.450069785118103
# Epoch 20: Iteration 140 with loss 1.3115260601043701
# Epoch 20 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.60564693209595
# Starting Training
# Epoch 21: Iteration 20 with loss 1.3935050964355469
# Epoch 21: Iteration 40 with loss 1.2445646524429321
# Epoch 21: Iteration 60 with loss 1.4711486101150513
# Epoch 21: Iteration 80 with loss 1.502368450164795
# Epoch 21: Iteration 100 with loss 1.2378126382827759
# Epoch 21: Iteration 120 with loss 1.0269815921783447
# Epoch 21: Iteration 140 with loss 1.4452112913131714
# Epoch 21 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.3433110991424
# Starting Training
# Epoch 22: Iteration 20 with loss 1.3525409698486328
# Epoch 22: Iteration 40 with loss 1.4629364013671875
# Epoch 22: Iteration 60 with loss 1.9268511533737183
# Epoch 22: Iteration 80 with loss 1.0800139904022217
# Epoch 22: Iteration 100 with loss 1.5364766120910645
# Epoch 22: Iteration 120 with loss 1.3308473825454712
# Epoch 22: Iteration 140 with loss 1.2208000421524048
# Epoch 22 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.01692422422008
# Starting Training
# Epoch 23: Iteration 20 with loss 1.6892136335372925
# Epoch 23: Iteration 40 with loss 1.2357386350631714
# Epoch 23: Iteration 60 with loss 1.022666096687317
# Epoch 23: Iteration 80 with loss 1.2615251541137695
# Epoch 23: Iteration 100 with loss 1.0241613388061523
# Epoch 23: Iteration 120 with loss 1.1001094579696655
# Epoch 23: Iteration 140 with loss 0.9939321875572205
# Epoch 23 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.75438124041927
# Starting Training
# Epoch 24: Iteration 20 with loss 0.9461202025413513
# Epoch 24: Iteration 40 with loss 1.1696133613586426
# Epoch 24: Iteration 60 with loss 1.6142628192901611
# Epoch 24: Iteration 80 with loss 0.974307656288147
# Epoch 24: Iteration 100 with loss 0.9249770045280457
# Epoch 24: Iteration 120 with loss 1.5022746324539185
# Epoch 24: Iteration 140 with loss 0.6528204679489136
# Epoch 24 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.575320048059
# Starting Training
# Epoch 25: Iteration 20 with loss 0.8824958205223083
# Epoch 25: Iteration 40 with loss 0.6345525979995728
# Epoch 25: Iteration 60 with loss 1.664060354232788
# Epoch 25: Iteration 80 with loss 0.5485174059867859
# Epoch 25: Iteration 100 with loss 1.3927550315856934
# Epoch 25: Iteration 120 with loss 0.8577152490615845
# Epoch 25: Iteration 140 with loss 0.5688470602035522
# Epoch 25 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.9301280192236
# Starting Training
# Epoch 26: Iteration 20 with loss 0.9496349096298218
# Epoch 26: Iteration 40 with loss 0.7508226037025452
# Epoch 26: Iteration 60 with loss 1.0337164402008057
# Epoch 26: Iteration 80 with loss 0.5902389287948608
# Epoch 26: Iteration 100 with loss 1.165775179862976
# Epoch 26: Iteration 120 with loss 0.6731207966804504
# Epoch 26: Iteration 140 with loss 1.054388403892517
# Epoch 26 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.059576583668225
# Starting Training
# Epoch 27: Iteration 20 with loss 0.6050320863723755
# Epoch 27: Iteration 40 with loss 1.3993663787841797
# Epoch 27: Iteration 60 with loss 0.7076195478439331
# Epoch 27: Iteration 80 with loss 1.0797392129898071
# Epoch 27: Iteration 100 with loss 0.9405800104141235
# Epoch 27: Iteration 120 with loss 1.3399748802185059
# Epoch 27: Iteration 140 with loss 1.1017130613327026
# Epoch 27 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.21920702655674
# Starting Training
# Epoch 28: Iteration 20 with loss 0.974526584148407
# Epoch 28: Iteration 40 with loss 0.7955849766731262
# Epoch 28: Iteration 60 with loss 0.9365829229354858
# Epoch 28: Iteration 80 with loss 0.9419938325881958
# Epoch 28: Iteration 100 with loss 1.1632823944091797
# Epoch 28: Iteration 120 with loss 0.7998412847518921
# Epoch 28: Iteration 140 with loss 1.1015208959579468
# Epoch 28 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.52661888387124
# Starting Training
# Epoch 29: Iteration 20 with loss 0.9530512094497681
# Epoch 29: Iteration 40 with loss 0.643673837184906
# Epoch 29: Iteration 60 with loss 1.1033034324645996
# Epoch 29: Iteration 80 with loss 1.117059350013733
# Epoch 29: Iteration 100 with loss 1.7052438259124756
# Epoch 29: Iteration 120 with loss 1.1045852899551392
# Epoch 29: Iteration 140 with loss 0.9318145513534546
# Epoch 29 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.33512864067614
# Starting Training
# Epoch 30: Iteration 20 with loss 0.9223629236221313
# Epoch 30: Iteration 40 with loss 0.9043604135513306
# Epoch 30: Iteration 60 with loss 2.501882791519165
# Epoch 30: Iteration 80 with loss 2.14521861076355
# Epoch 30: Iteration 100 with loss 2.340513229370117
# Epoch 30: Iteration 120 with loss 2.315702438354492
# Epoch 30: Iteration 140 with loss 1.916425108909607
# Epoch 30 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.06044661722667
# Starting Training
# Epoch 31: Iteration 20 with loss 1.2414439916610718
# Epoch 31: Iteration 40 with loss 2.264525890350342
# Epoch 31: Iteration 60 with loss 1.649397850036621
# Epoch 31: Iteration 80 with loss 1.679396629333496
# Epoch 31: Iteration 100 with loss 0.7458034753799438
# Epoch 31: Iteration 120 with loss 1.4660444259643555
# Epoch 31: Iteration 140 with loss 1.847639560699463
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.5 minutes
# iter 30 of Expectation completed in a total of  9.6 minutes
# iter 40 of Expectation completed in a total of  13.2 minutes
# iter 50 of Expectation completed in a total of  16.1 minutes
# iter 60 of Expectation completed in a total of  18.9 minutes
# Expectation step finished, posterior frame-wise accuracy  76.88%, boundary mse  0.00
# Epoch 31 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.54942619215313
# Starting Training
# Epoch 32: Iteration 20 with loss 1.727198839187622
# Epoch 32: Iteration 40 with loss 1.8904316425323486
# Epoch 32: Iteration 60 with loss 3.2885475158691406
# Epoch 32: Iteration 80 with loss 2.247351884841919
# Epoch 32: Iteration 100 with loss 4.442919731140137
# Epoch 32: Iteration 120 with loss 3.9945900440216064
# Epoch 32: Iteration 140 with loss 1.839294195175171
# Epoch 32 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.10842275344906
# Starting Training
# Epoch 33: Iteration 20 with loss 1.6138983964920044
# Epoch 33: Iteration 40 with loss 2.5847675800323486
# Epoch 33: Iteration 60 with loss 1.5630688667297363
# Epoch 33: Iteration 80 with loss 1.8574954271316528
# Epoch 33: Iteration 100 with loss 2.026162624359131
# Epoch 33: Iteration 120 with loss 1.4830632209777832
# Epoch 33: Iteration 140 with loss 3.321716785430908
# Epoch 33 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.7182541326594
# Starting Training
# Epoch 34: Iteration 20 with loss 1.9916963577270508
# Epoch 34: Iteration 40 with loss 0.9225572347640991
# Epoch 34: Iteration 60 with loss 1.3483723402023315
# Epoch 34: Iteration 80 with loss 2.7614753246307373
# Epoch 34: Iteration 100 with loss 1.9565813541412354
# Epoch 34: Iteration 120 with loss 2.5303375720977783
# Epoch 34: Iteration 140 with loss 1.7888987064361572
# Epoch 34 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.0255002692961
# Starting Training
# Epoch 35: Iteration 20 with loss 2.1777000427246094
# Epoch 35: Iteration 40 with loss 1.501232385635376
# Epoch 35: Iteration 60 with loss 1.092557430267334
# Epoch 35: Iteration 80 with loss 4.300575256347656
# Epoch 35: Iteration 100 with loss 1.6177661418914795
# Epoch 35: Iteration 120 with loss 2.5839617252349854
# Epoch 35: Iteration 140 with loss 1.208945631980896
# Epoch 35 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.53457347640552
# Starting Training
# Epoch 36: Iteration 20 with loss 2.183220148086548
# Epoch 36: Iteration 40 with loss 1.6281242370605469
# Epoch 36: Iteration 60 with loss 2.0227396488189697
# Epoch 36: Iteration 80 with loss 1.0633410215377808
# Epoch 36: Iteration 100 with loss 1.7286128997802734
# Epoch 36: Iteration 120 with loss 1.7667267322540283
# Epoch 36: Iteration 140 with loss 1.089959979057312
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.0 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  8.8 minutes
# iter 40 of Expectation completed in a total of  12.1 minutes
# iter 50 of Expectation completed in a total of  15.3 minutes
# iter 60 of Expectation completed in a total of  18.0 minutes
# Expectation step finished, posterior frame-wise accuracy  77.69%, boundary mse  0.00
# Epoch 36 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.15076438662634
# Starting Training
# Epoch 37: Iteration 20 with loss 3.038327217102051
# Epoch 37: Iteration 40 with loss 0.6301558613777161
# Epoch 37: Iteration 60 with loss 1.7432501316070557
# Epoch 37: Iteration 80 with loss 2.383396625518799
# Epoch 37: Iteration 100 with loss 1.1558456420898438
# Epoch 37: Iteration 120 with loss 1.084052324295044
# Epoch 37: Iteration 140 with loss 2.0273075103759766
# Epoch 37 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.01213903964867
# Starting Training
# Epoch 38: Iteration 20 with loss 1.548570156097412
# Epoch 38: Iteration 40 with loss 1.7572062015533447
# Epoch 38: Iteration 60 with loss 2.8520874977111816
# Epoch 38: Iteration 80 with loss 2.6286513805389404
# Epoch 38: Iteration 100 with loss 3.537219524383545
# Epoch 38: Iteration 120 with loss 1.8644964694976807
# Epoch 38: Iteration 140 with loss 2.436674118041992
# Epoch 38 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.60564693209595
# Starting Training
# Epoch 39: Iteration 20 with loss 2.189321279525757
# Epoch 39: Iteration 40 with loss 1.9260470867156982
# Epoch 39: Iteration 60 with loss 1.9956297874450684
# Epoch 39: Iteration 80 with loss 1.2107740640640259
# Epoch 39: Iteration 100 with loss 2.017615795135498
# Epoch 39: Iteration 120 with loss 1.1736102104187012
# Epoch 39: Iteration 140 with loss 2.421689510345459
# Epoch 39 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.964556490036045
# Starting Training
# Epoch 40: Iteration 20 with loss 1.251826524734497
# Epoch 40: Iteration 40 with loss 1.9993336200714111
# Epoch 40: Iteration 60 with loss 1.5063807964324951
# Epoch 40: Iteration 80 with loss 1.488509178161621
# Epoch 40: Iteration 100 with loss 1.5526669025421143
# Epoch 40: Iteration 120 with loss 1.468289852142334
# Epoch 40: Iteration 140 with loss 0.828052282333374
# Epoch 40 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.39224012926213
# Starting Training
# Epoch 41: Iteration 20 with loss 0.9462094306945801
# Epoch 41: Iteration 40 with loss 1.169384241104126
# Epoch 41: Iteration 60 with loss 1.0111439228057861
# Epoch 41: Iteration 80 with loss 0.6252208352088928
# Epoch 41: Iteration 100 with loss 0.8972969651222229
# Epoch 41: Iteration 120 with loss 1.0244687795639038
# Epoch 41: Iteration 140 with loss 0.8541457653045654
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.8 minutes
# iter 20 of Expectation completed in a total of  5.5 minutes
# iter 30 of Expectation completed in a total of  8.7 minutes
# iter 40 of Expectation completed in a total of  11.8 minutes
# iter 50 of Expectation completed in a total of  14.6 minutes
# iter 60 of Expectation completed in a total of  18.3 minutes
# Expectation step finished, posterior frame-wise accuracy  77.84%, boundary mse  0.00
# Epoch 41 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 60.3620996809877
# Starting Training
# Epoch 42: Iteration 20 with loss 0.49222466349601746
# Epoch 42: Iteration 40 with loss 0.5321922898292542
# Epoch 42: Iteration 60 with loss 0.6465282440185547
# Epoch 42: Iteration 80 with loss 1.4730219841003418
# Epoch 42: Iteration 100 with loss 3.6241893768310547
# Epoch 42: Iteration 120 with loss 0.9988148212432861
# Epoch 42: Iteration 140 with loss 1.1207640171051025
# Epoch 42 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.10842275344906
# Starting Training
# Epoch 43: Iteration 20 with loss 1.2623847723007202
# Epoch 43: Iteration 40 with loss 0.46646249294281006
# Epoch 43: Iteration 60 with loss 1.5133172273635864
# Epoch 43: Iteration 80 with loss 3.716670274734497
# Epoch 43: Iteration 100 with loss 1.1223574876785278
# Epoch 43: Iteration 120 with loss 1.4553141593933105
# Epoch 43: Iteration 140 with loss 1.1646082401275635
# Epoch 43 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 62.225110825703275
# Starting Training
# Epoch 44: Iteration 20 with loss 0.8621527552604675
# Epoch 44: Iteration 40 with loss 1.028294324874878
# Epoch 44: Iteration 60 with loss 1.1649538278579712
# Epoch 44: Iteration 80 with loss 1.153809666633606
# Epoch 44: Iteration 100 with loss 1.171435832977295
# Epoch 44: Iteration 120 with loss 1.1354674100875854
# Epoch 44: Iteration 140 with loss 1.4792323112487793
# Epoch 44 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 61.48723950780958
# Starting Training
# Epoch 45: Iteration 20 with loss 1.5836830139160156
# Epoch 45: Iteration 40 with loss 0.7332838177680969
# Epoch 45: Iteration 60 with loss 0.7342656254768372
# Epoch 45: Iteration 80 with loss 0.5016993880271912
# Epoch 45: Iteration 100 with loss 3.47835636138916
# Epoch 45: Iteration 120 with loss 2.7790181636810303
# Epoch 45: Iteration 140 with loss 1.8018678426742554
# Epoch 45 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 59.6193603181837
# Starting Training
# Epoch 46: Iteration 20 with loss 0.6492503881454468
# Epoch 46: Iteration 40 with loss 0.7282557487487793
# Epoch 46: Iteration 60 with loss 3.330726146697998
# Epoch 46: Iteration 80 with loss 0.7898324131965637
# Epoch 46: Iteration 100 with loss 0.7431051135063171
# Epoch 46: Iteration 120 with loss 0.774428129196167
# Epoch 46: Iteration 140 with loss 1.531643033027649
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.3 minutes
# iter 20 of Expectation completed in a total of  6.0 minutes
# iter 30 of Expectation completed in a total of  8.9 minutes
# iter 40 of Expectation completed in a total of  12.2 minutes
# iter 50 of Expectation completed in a total of  15.1 minutes
# iter 60 of Expectation completed in a total of  17.6 minutes
# Expectation step finished, posterior frame-wise accuracy  73.06%, boundary mse  0.00
# Epoch 46 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.62926212868211
# Starting Training
# Epoch 47: Iteration 20 with loss 1.3619372844696045
# Epoch 47: Iteration 40 with loss 1.3193466663360596
# Epoch 47: Iteration 60 with loss 2.5483040809631348
# Epoch 47: Iteration 80 with loss 1.6076732873916626
# Epoch 47: Iteration 100 with loss 1.021312952041626
# Epoch 47: Iteration 120 with loss 1.3569409847259521
# Epoch 47: Iteration 140 with loss 1.7039756774902344
# Epoch 47 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.714919004018725
# Starting Training
# Epoch 48: Iteration 20 with loss 1.0979461669921875
# Epoch 48: Iteration 40 with loss 1.6145895719528198
# Epoch 48: Iteration 60 with loss 1.7089827060699463
# Epoch 48: Iteration 80 with loss 2.5678517818450928
# Epoch 48: Iteration 100 with loss 1.3065260648727417
# Epoch 48: Iteration 120 with loss 1.3525556325912476
# Epoch 48: Iteration 140 with loss 1.1709589958190918
# Epoch 48 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.44266064548204
# Starting Training
# Epoch 49: Iteration 20 with loss 1.1130316257476807
# Epoch 49: Iteration 40 with loss 1.1894783973693848
# Epoch 49: Iteration 60 with loss 1.7013604640960693
# Epoch 49: Iteration 80 with loss 0.8031182289123535
# Epoch 49: Iteration 100 with loss 0.8956904411315918
# Epoch 49: Iteration 120 with loss 0.9752627611160278
# Epoch 49: Iteration 140 with loss 1.206457257270813
# Epoch 49 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.575195757550645
# Starting Training
# Epoch 50: Iteration 20 with loss 1.224167823791504
# Epoch 50: Iteration 40 with loss 1.6053016185760498
# Epoch 50: Iteration 60 with loss 0.9669131636619568
# Epoch 50: Iteration 80 with loss 0.8155723810195923
# Epoch 50: Iteration 100 with loss 0.8226178884506226
# Epoch 50: Iteration 120 with loss 1.7732930183410645
# Epoch 50: Iteration 140 with loss 1.5010038614273071
# Epoch 50 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.12168040767287
# Starting Training
# Epoch 51: Iteration 20 with loss 1.3678511381149292
# Epoch 51: Iteration 40 with loss 0.9218198657035828
# Epoch 51: Iteration 60 with loss 1.4382647275924683
# Epoch 51: Iteration 80 with loss 1.0260616540908813
# Epoch 51: Iteration 100 with loss 1.0725305080413818
# Epoch 51: Iteration 120 with loss 1.0774450302124023
# Epoch 51: Iteration 140 with loss 1.199817419052124
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.4 minutes
# iter 20 of Expectation completed in a total of  5.2 minutes
# iter 30 of Expectation completed in a total of  8.3 minutes
# iter 40 of Expectation completed in a total of  10.9 minutes
# iter 50 of Expectation completed in a total of  13.7 minutes
# iter 60 of Expectation completed in a total of  17.5 minutes
# Expectation step finished, posterior frame-wise accuracy  73.41%, boundary mse  0.00
# Epoch 51 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.14283050917678
# Starting Training
# Epoch 52: Iteration 20 with loss 0.6590552926063538
# Epoch 52: Iteration 40 with loss 0.6794342994689941
# Epoch 52: Iteration 60 with loss 0.6296558976173401
# Epoch 52: Iteration 80 with loss 0.7212855815887451
# Epoch 52: Iteration 100 with loss 0.701481282711029
# Epoch 52: Iteration 120 with loss 0.39668959379196167
# Epoch 52: Iteration 140 with loss 0.7845126986503601
# Epoch 52 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.34832414964577
# Starting Training
# Epoch 53: Iteration 20 with loss 0.6476103067398071
# Epoch 53: Iteration 40 with loss 0.7950783371925354
# Epoch 53: Iteration 60 with loss 0.4766230583190918
# Epoch 53: Iteration 80 with loss 0.6515058279037476
# Epoch 53: Iteration 100 with loss 0.5163090825080872
# Epoch 53: Iteration 120 with loss 0.9472947120666504
# Epoch 53: Iteration 140 with loss 1.0374077558517456
# Epoch 53 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.24311223432904
# Starting Training
# Epoch 54: Iteration 20 with loss 0.779961884021759
# Epoch 54: Iteration 40 with loss 0.7437817454338074
# Epoch 54: Iteration 60 with loss 0.6818479895591736
# Epoch 54: Iteration 80 with loss 0.838665246963501
# Epoch 54: Iteration 100 with loss 0.8532578945159912
# Epoch 54: Iteration 120 with loss 0.8203200101852417
# Epoch 54: Iteration 140 with loss 0.9414975643157959
# Epoch 54 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.42536354973692
# Starting Training
# Epoch 55: Iteration 20 with loss 0.4614694118499756
# Epoch 55: Iteration 40 with loss 1.2373313903808594
# Epoch 55: Iteration 60 with loss 1.1419570446014404
# Epoch 55: Iteration 80 with loss 0.5387671589851379
# Epoch 55: Iteration 100 with loss 0.7817255258560181
# Epoch 55: Iteration 120 with loss 0.7351974248886108
# Epoch 55: Iteration 140 with loss 0.5181665420532227
# Epoch 55 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.14363839748105
# Starting Training
# Epoch 56: Iteration 20 with loss 0.7064276933670044
# Epoch 56: Iteration 40 with loss 0.7589483857154846
# Epoch 56: Iteration 60 with loss 1.6050491333007812
# Epoch 56: Iteration 80 with loss 0.7686917781829834
# Epoch 56: Iteration 100 with loss 0.5390369892120361
# Epoch 56: Iteration 120 with loss 0.8732107281684875
# Epoch 56: Iteration 140 with loss 0.9522044658660889
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  7.0 minutes
# iter 30 of Expectation completed in a total of  9.9 minutes
# iter 40 of Expectation completed in a total of  12.6 minutes
# iter 50 of Expectation completed in a total of  15.3 minutes
# iter 60 of Expectation completed in a total of  18.3 minutes
# Expectation step finished, posterior frame-wise accuracy  73.07%, boundary mse  0.00
# Epoch 56 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.367920619795335
# Starting Training
# Epoch 57: Iteration 20 with loss 0.7712486386299133
# Epoch 57: Iteration 40 with loss 0.8911498785018921
# Epoch 57: Iteration 60 with loss 0.65248703956604
# Epoch 57: Iteration 80 with loss 1.0341917276382446
# Epoch 57: Iteration 100 with loss 1.5803258419036865
# Epoch 57: Iteration 120 with loss 2.172682285308838
# Epoch 57: Iteration 140 with loss 2.0396106243133545
# Epoch 57 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.53658283962381
# Starting Training
# Epoch 58: Iteration 20 with loss 0.5645633339881897
# Epoch 58: Iteration 40 with loss 0.5814310312271118
# Epoch 58: Iteration 60 with loss 1.3720170259475708
# Epoch 58: Iteration 80 with loss 1.0375224351882935
# Epoch 58: Iteration 100 with loss 0.5588977932929993
# Epoch 58: Iteration 120 with loss 0.7700273990631104
# Epoch 58: Iteration 140 with loss 0.966497004032135
# Epoch 58 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 46.73219538467912
# Starting Training
# Epoch 59: Iteration 20 with loss 0.6572452783584595
# Epoch 59: Iteration 40 with loss 0.7663103342056274
# Epoch 59: Iteration 60 with loss 0.75545334815979
# Epoch 59: Iteration 80 with loss 0.6776482462882996
# Epoch 59: Iteration 100 with loss 0.5465924739837646
# Epoch 59: Iteration 120 with loss 0.8369387984275818
# Epoch 59: Iteration 140 with loss 1.0883338451385498
# Epoch 59 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.26747317396528
# Starting Training
# Epoch 60: Iteration 20 with loss 0.5882146954536438
# Epoch 60: Iteration 40 with loss 0.7892126441001892
# Epoch 60: Iteration 60 with loss 0.9750595688819885
# Epoch 60: Iteration 80 with loss 0.7889172434806824
# Epoch 60: Iteration 100 with loss 0.5280615091323853
# Epoch 60: Iteration 120 with loss 1.6467318534851074
# Epoch 60: Iteration 140 with loss 0.8306847810745239
# Epoch 60 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.43454033226996
# Starting Training
# Epoch 61: Iteration 20 with loss 0.38645362854003906
# Epoch 61: Iteration 40 with loss 0.6827555894851685
# Epoch 61: Iteration 60 with loss 0.40905147790908813
# Epoch 61: Iteration 80 with loss 0.31214651465415955
# Epoch 61: Iteration 100 with loss 0.7366787791252136
# Epoch 61: Iteration 120 with loss 0.7801073789596558
# Epoch 61: Iteration 140 with loss 0.5558005571365356
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.5 minutes
# iter 20 of Expectation completed in a total of  6.1 minutes
# iter 30 of Expectation completed in a total of  8.9 minutes
# iter 40 of Expectation completed in a total of  12.6 minutes
# iter 50 of Expectation completed in a total of  15.7 minutes
# iter 60 of Expectation completed in a total of  18.9 minutes
# Expectation step finished, posterior frame-wise accuracy  72.90%, boundary mse  0.00
# Epoch 61 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.888469983842235
# Starting Training
# Epoch 62: Iteration 20 with loss 0.5107024312019348
# Epoch 62: Iteration 40 with loss 0.47529998421669006
# Epoch 62: Iteration 60 with loss 0.4327189326286316
# Epoch 62: Iteration 80 with loss 0.48478055000305176
# Epoch 62: Iteration 100 with loss 0.5809355974197388
# Epoch 62: Iteration 120 with loss 0.4854271411895752
# Epoch 62: Iteration 140 with loss 0.5345415472984314
# Epoch 62 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.14523345900485
# Starting Training
# Epoch 63: Iteration 20 with loss 0.583279013633728
# Epoch 63: Iteration 40 with loss 0.43246641755104065
# Epoch 63: Iteration 60 with loss 0.7179685235023499
# Epoch 63: Iteration 80 with loss 0.5206897854804993
# Epoch 63: Iteration 100 with loss 0.5174821615219116
# Epoch 63: Iteration 120 with loss 0.7803701162338257
# Epoch 63: Iteration 140 with loss 1.4388257265090942
# Epoch 63 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.83376144508431
# Starting Training
# Epoch 64: Iteration 20 with loss 0.705284595489502
# Epoch 64: Iteration 40 with loss 0.5520967841148376
# Epoch 64: Iteration 60 with loss 0.4617636203765869
# Epoch 64: Iteration 80 with loss 0.3790675103664398
# Epoch 64: Iteration 100 with loss 0.9775370359420776
# Epoch 64: Iteration 120 with loss 0.5323115587234497
# Epoch 64: Iteration 140 with loss 0.4261057674884796
# Epoch 64 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.066847578406595
# Starting Training
# Epoch 65: Iteration 20 with loss 0.3496713936328888
# Epoch 65: Iteration 40 with loss 0.6757774353027344
# Epoch 65: Iteration 60 with loss 0.6160039901733398
# Epoch 65: Iteration 80 with loss 0.3673822581768036
# Epoch 65: Iteration 100 with loss 0.4171198308467865
# Epoch 65: Iteration 120 with loss 0.5233151316642761
# Epoch 65: Iteration 140 with loss 0.4381808638572693
# Epoch 65 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.70733728300949
# Starting Training
# Epoch 66: Iteration 20 with loss 0.48511627316474915
# Epoch 66: Iteration 40 with loss 0.2778840959072113
# Epoch 66: Iteration 60 with loss 0.5211747288703918
# Epoch 66: Iteration 80 with loss 0.5101892948150635
# Epoch 66: Iteration 100 with loss 0.29157519340515137
# Epoch 66: Iteration 120 with loss 0.3691043555736542
# Epoch 66: Iteration 140 with loss 0.3202500641345978
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  7.1 minutes
# iter 30 of Expectation completed in a total of  9.9 minutes
# iter 40 of Expectation completed in a total of  13.4 minutes
# iter 50 of Expectation completed in a total of  15.8 minutes
# iter 60 of Expectation completed in a total of  19.1 minutes
# Expectation step finished, posterior frame-wise accuracy  73.69%, boundary mse  0.00
# Epoch 66 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.386460620623936
# Starting Training
# Epoch 67: Iteration 20 with loss 0.3439316749572754
# Epoch 67: Iteration 40 with loss 0.3425644636154175
# Epoch 67: Iteration 60 with loss 0.735434889793396
# Epoch 67: Iteration 80 with loss 0.39221033453941345
# Epoch 67: Iteration 100 with loss 0.48881247639656067
# Epoch 67: Iteration 120 with loss 0.6868077516555786
# Epoch 67: Iteration 140 with loss 0.7855616807937622
# Epoch 67 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.11393296598583
# Starting Training
# Epoch 68: Iteration 20 with loss 0.34595823287963867
# Epoch 68: Iteration 40 with loss 0.4163126051425934
# Epoch 68: Iteration 60 with loss 0.9410266876220703
# Epoch 68: Iteration 80 with loss 0.9315261840820312
# Epoch 68: Iteration 100 with loss 0.9220254421234131
# Epoch 68: Iteration 120 with loss 1.0920127630233765
# Epoch 68: Iteration 140 with loss 1.0361143350601196
# Epoch 68 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.35041637320297
# Starting Training
# Epoch 69: Iteration 20 with loss 0.784482479095459
# Epoch 69: Iteration 40 with loss 0.4047728180885315
# Epoch 69: Iteration 60 with loss 1.1678699254989624
# Epoch 69: Iteration 80 with loss 0.7965495586395264
# Epoch 69: Iteration 100 with loss 0.888631284236908
# Epoch 69: Iteration 120 with loss 0.766474723815918
# Epoch 69: Iteration 140 with loss 0.9281158447265625
# Epoch 69 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.085387579235196
# Starting Training
# Epoch 70: Iteration 20 with loss 0.9664854407310486
# Epoch 70: Iteration 40 with loss 0.8814901113510132
# Epoch 70: Iteration 60 with loss 0.49979856610298157
# Epoch 70: Iteration 80 with loss 0.6091384291648865
# Epoch 70: Iteration 100 with loss 0.6799140572547913
# Epoch 70: Iteration 120 with loss 0.9411465525627136
# Epoch 70: Iteration 140 with loss 1.1008347272872925
# Epoch 70 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.70132990843933
# Starting Training
# Epoch 71: Iteration 20 with loss 0.4379488229751587
# Epoch 71: Iteration 40 with loss 0.4111579656600952
# Epoch 71: Iteration 60 with loss 1.5621134042739868
# Epoch 71: Iteration 80 with loss 0.6698702573776245
# Epoch 71: Iteration 100 with loss 0.7821588516235352
# Epoch 71: Iteration 120 with loss 0.5639892816543579
# Epoch 71: Iteration 140 with loss 0.7331406474113464
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  6.8 minutes
# iter 30 of Expectation completed in a total of  10.2 minutes
# iter 40 of Expectation completed in a total of  13.4 minutes
# iter 50 of Expectation completed in a total of  16.1 minutes
# iter 60 of Expectation completed in a total of  18.9 minutes
# Expectation step finished, posterior frame-wise accuracy  73.56%, boundary mse  0.00
# Epoch 71 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.70928450097361
# Starting Training
# Epoch 72: Iteration 20 with loss 0.4648573696613312
# Epoch 72: Iteration 40 with loss 0.267112135887146
# Epoch 72: Iteration 60 with loss 0.4650193452835083
# Epoch 72: Iteration 80 with loss 0.3303426504135132
# Epoch 72: Iteration 100 with loss 0.8577175140380859
# Epoch 72: Iteration 120 with loss 0.25542914867401123
# Epoch 72: Iteration 140 with loss 0.4255073666572571
# Epoch 72 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.099660272610514
# Starting Training
# Epoch 73: Iteration 20 with loss 0.646269679069519
# Epoch 73: Iteration 40 with loss 0.3658551573753357
# Epoch 73: Iteration 60 with loss 0.46629053354263306
# Epoch 73: Iteration 80 with loss 0.3129909038543701
# Epoch 73: Iteration 100 with loss 0.3111251890659332
# Epoch 73: Iteration 120 with loss 0.6291857957839966
# Epoch 73: Iteration 140 with loss 0.35186395049095154
# Epoch 73 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.709160210465264
# Starting Training
# Epoch 74: Iteration 20 with loss 0.48850762844085693
# Epoch 74: Iteration 40 with loss 0.45126861333847046
# Epoch 74: Iteration 60 with loss 0.34163302183151245
# Epoch 74: Iteration 80 with loss 0.2767082154750824
# Epoch 74: Iteration 100 with loss 0.39568567276000977
# Epoch 74: Iteration 120 with loss 0.4132095277309418
# Epoch 74: Iteration 140 with loss 0.8178709149360657
# Epoch 74 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 58.65766250983967
# Starting Training
# Epoch 75: Iteration 20 with loss 0.6728135347366333
# Epoch 75: Iteration 40 with loss 0.5204980969429016
# Epoch 75: Iteration 60 with loss 0.3780021071434021
# Epoch 75: Iteration 80 with loss 0.6889743804931641
# Epoch 75: Iteration 100 with loss 0.35528355836868286
# Epoch 75: Iteration 120 with loss 0.4451174736022949
# Epoch 75: Iteration 140 with loss 0.4696993827819824
# Epoch 75 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.424804242449355
# Starting Training
# Epoch 76: Iteration 20 with loss 1.2089985609054565
# Epoch 76: Iteration 40 with loss 0.5588563680648804
# Epoch 76: Iteration 60 with loss 0.4794316589832306
# Epoch 76: Iteration 80 with loss 0.44342488050460815
# Epoch 76: Iteration 100 with loss 0.43485337495803833
# Epoch 76: Iteration 120 with loss 0.36526602506637573
# Epoch 76: Iteration 140 with loss 0.5915926694869995
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.7 minutes
# iter 30 of Expectation completed in a total of  9.9 minutes
# iter 40 of Expectation completed in a total of  12.7 minutes
# iter 50 of Expectation completed in a total of  15.2 minutes
# iter 60 of Expectation completed in a total of  19.1 minutes
# Expectation step finished, posterior frame-wise accuracy  73.63%, boundary mse  0.00
# Epoch 76 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.814869287815384
# Starting Training
# Epoch 77: Iteration 20 with loss 0.27269816398620605
# Epoch 77: Iteration 40 with loss 0.26648035645484924
# Epoch 77: Iteration 60 with loss 0.37387940287590027
# Epoch 77: Iteration 80 with loss 0.40018269419670105
# Epoch 77: Iteration 100 with loss 0.3750965893268585
# Epoch 77: Iteration 120 with loss 0.4607238471508026
# Epoch 77: Iteration 140 with loss 0.4770488142967224
# Epoch 77 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.55385922028421
# Starting Training
# Epoch 78: Iteration 20 with loss 0.4462277889251709
# Epoch 78: Iteration 40 with loss 0.40533071756362915
# Epoch 78: Iteration 60 with loss 0.33054548501968384
# Epoch 78: Iteration 80 with loss 0.6671832799911499
# Epoch 78: Iteration 100 with loss 0.31372693181037903
# Epoch 78: Iteration 120 with loss 0.23092646896839142
# Epoch 78: Iteration 140 with loss 0.44849300384521484
# Epoch 78 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.198056925052825
# Starting Training
# Epoch 79: Iteration 20 with loss 0.4582841396331787
# Epoch 79: Iteration 40 with loss 0.24694792926311493
# Epoch 79: Iteration 60 with loss 0.23571127653121948
# Epoch 79: Iteration 80 with loss 0.25290608406066895
# Epoch 79: Iteration 100 with loss 0.3393405079841614
# Epoch 79: Iteration 120 with loss 0.28463026881217957
# Epoch 79: Iteration 140 with loss 0.34120526909828186
# Epoch 79 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.67357169490823
# Starting Training
# Epoch 80: Iteration 20 with loss 0.227838397026062
# Epoch 80: Iteration 40 with loss 0.34620946645736694
# Epoch 80: Iteration 60 with loss 0.2617872953414917
# Epoch 80: Iteration 80 with loss 0.3110983073711395
# Epoch 80: Iteration 100 with loss 0.34241825342178345
# Epoch 80: Iteration 120 with loss 0.33357349038124084
# Epoch 80: Iteration 140 with loss 0.36156630516052246
# Epoch 80 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 57.501553631354355
# Starting Training
# Epoch 81: Iteration 20 with loss 0.2431669682264328
# Epoch 81: Iteration 40 with loss 0.1867704689502716
# Epoch 81: Iteration 60 with loss 0.6907351016998291
# Epoch 81: Iteration 80 with loss 0.22627303004264832
# Epoch 81: Iteration 100 with loss 0.20877580344676971
# Epoch 81: Iteration 120 with loss 0.39102840423583984
# Epoch 81: Iteration 140 with loss 0.2838428318500519
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.2 minutes
# iter 20 of Expectation completed in a total of  6.6 minutes
# iter 30 of Expectation completed in a total of  9.4 minutes
# iter 40 of Expectation completed in a total of  12.3 minutes
# iter 50 of Expectation completed in a total of  15.2 minutes
# iter 60 of Expectation completed in a total of  18.4 minutes
# Expectation step finished, posterior frame-wise accuracy  73.65%, boundary mse  0.00
# Epoch 81 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.92215271160459
# Starting Training
# Epoch 82: Iteration 20 with loss 0.219410240650177
# Epoch 82: Iteration 40 with loss 0.23980167508125305
# Epoch 82: Iteration 60 with loss 0.4587838351726532
# Epoch 82: Iteration 80 with loss 0.19454200565814972
# Epoch 82: Iteration 100 with loss 0.4632301926612854
# Epoch 82: Iteration 120 with loss 0.8348609805107117
# Epoch 82: Iteration 140 with loss 1.3498424291610718
# Epoch 82 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.21189460164892
# Starting Training
# Epoch 83: Iteration 20 with loss 0.38173454999923706
# Epoch 83: Iteration 40 with loss 1.669724941253662
# Epoch 83: Iteration 60 with loss 3.415438175201416
# Epoch 83: Iteration 80 with loss 1.5824518203735352
# Epoch 83: Iteration 100 with loss 0.8771418333053589
# Epoch 83: Iteration 120 with loss 1.0794873237609863
# Epoch 83: Iteration 140 with loss 1.544095516204834
# Epoch 83 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 49.04441314164975
# Starting Training
# Epoch 84: Iteration 20 with loss 1.1431282758712769
# Epoch 84: Iteration 40 with loss 1.1664183139801025
# Epoch 84: Iteration 60 with loss 1.3226677179336548
# Epoch 84: Iteration 80 with loss 0.8864900469779968
# Epoch 84: Iteration 100 with loss 3.667287588119507
# Epoch 84: Iteration 120 with loss 0.7761451005935669
# Epoch 84: Iteration 140 with loss 1.2412786483764648
# ...
# Starting Training
# Epoch 125: Iteration 20 with loss 0.18431861698627472
# Epoch 125: Iteration 40 with loss 0.16300322115421295
# Epoch 125: Iteration 60 with loss 0.4756867289543152
# Epoch 125: Iteration 80 with loss 0.23432712256908417
# Epoch 125: Iteration 100 with loss 0.415675550699234
# Epoch 125: Iteration 120 with loss 0.12346512824296951
# Epoch 125: Iteration 140 with loss 0.14732861518859863
# Epoch 125 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.82818908729337
# Starting Training
# Epoch 126: Iteration 20 with loss 0.5118721127510071
# Epoch 126: Iteration 40 with loss 0.2236965447664261
# Epoch 126: Iteration 60 with loss 0.20161135494709015
# Epoch 126: Iteration 80 with loss 0.1375836431980133
# Epoch 126: Iteration 100 with loss 0.18751713633537292
# Epoch 126: Iteration 120 with loss 0.23067660629749298
# Epoch 126: Iteration 140 with loss 0.16504135727882385
# Calculating expectation
# iter 10 of Expectation completed in a total of  2.9 minutes
# iter 20 of Expectation completed in a total of  6.1 minutes
# iter 30 of Expectation completed in a total of  9.4 minutes
# iter 40 of Expectation completed in a total of  11.7 minutes
# iter 50 of Expectation completed in a total of  15.3 minutes
# iter 60 of Expectation completed in a total of  18.2 minutes
# Expectation step finished, posterior frame-wise accuracy  73.10%, boundary mse  0.00
# Epoch 126 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.68825868997804
# Starting Training
# Epoch 127: Iteration 20 with loss 0.15550968050956726
# Epoch 127: Iteration 40 with loss 0.1490630805492401
# Epoch 127: Iteration 60 with loss 0.2094798982143402
# Epoch 127: Iteration 80 with loss 0.16969308257102966
# Epoch 127: Iteration 100 with loss 0.17086276412010193
# Epoch 127: Iteration 120 with loss 0.1477227360010147
# Epoch 127: Iteration 140 with loss 0.23215879499912262
# Epoch 127 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.16561710237395
# Starting Training
# Epoch 128: Iteration 20 with loss 0.20595237612724304
# Epoch 128: Iteration 40 with loss 0.16595865786075592
# Epoch 128: Iteration 60 with loss 0.2740504741668701
# Epoch 128: Iteration 80 with loss 0.15992029011249542
# Epoch 128: Iteration 100 with loss 0.26493024826049805
# Epoch 128: Iteration 120 with loss 0.1659800261259079
# Epoch 128: Iteration 140 with loss 0.15202252566814423
# Epoch 128 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.517669967270166
# Starting Training
# Epoch 129: Iteration 20 with loss 0.1793026328086853
# Epoch 129: Iteration 40 with loss 0.20296934247016907
# Epoch 129: Iteration 60 with loss 0.11569331586360931
# Epoch 129: Iteration 80 with loss 0.1671012043952942
# Epoch 129: Iteration 100 with loss 0.14126469194889069
# Epoch 129: Iteration 120 with loss 0.3623291850090027
# Epoch 129: Iteration 140 with loss 0.1862080842256546
# Epoch 129 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.612938641919044
# Starting Training
# Epoch 130: Iteration 20 with loss 0.30787762999534607
# Epoch 130: Iteration 40 with loss 0.13230791687965393
# Epoch 130: Iteration 60 with loss 0.1896815299987793
# Epoch 130: Iteration 80 with loss 0.16233594715595245
# Epoch 130: Iteration 100 with loss 0.2031908929347992
# Epoch 130: Iteration 120 with loss 0.19542941451072693
# Epoch 130: Iteration 140 with loss 0.1805424988269806
# Epoch 130 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.55205700791316
# Starting Training
# Epoch 131: Iteration 20 with loss 0.8316128253936768
# Epoch 131: Iteration 40 with loss 4.860395431518555
# Epoch 131: Iteration 60 with loss 3.7268009185791016
# Epoch 131: Iteration 80 with loss 2.4665579795837402
# Epoch 131: Iteration 100 with loss 1.875765323638916
# Epoch 131: Iteration 120 with loss 0.5946303606033325
# Epoch 131: Iteration 140 with loss 0.4807926118373871
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.0 minutes
# iter 20 of Expectation completed in a total of  6.0 minutes
# iter 30 of Expectation completed in a total of  9.1 minutes
# iter 40 of Expectation completed in a total of  11.5 minutes
# iter 50 of Expectation completed in a total of  15.0 minutes
# iter 60 of Expectation completed in a total of  18.0 minutes
# Expectation step finished, posterior frame-wise accuracy  71.36%, boundary mse  0.00
# Epoch 131 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.086216182624185
# Starting Training
# Epoch 132: Iteration 20 with loss 0.23266908526420593
# Epoch 132: Iteration 40 with loss 0.34419333934783936
# Epoch 132: Iteration 60 with loss 1.3489139080047607
# Epoch 132: Iteration 80 with loss 1.1983120441436768
# Epoch 132: Iteration 100 with loss 1.0917593240737915
# Epoch 132: Iteration 120 with loss 0.6406376361846924
# Epoch 132: Iteration 140 with loss 0.9976986050605774
# Epoch 132 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.340928864399054
# Starting Training
# Epoch 133: Iteration 20 with loss 0.7676159143447876
# Epoch 133: Iteration 40 with loss 0.5120365619659424
# Epoch 133: Iteration 60 with loss 0.3015488386154175
# Epoch 133: Iteration 80 with loss 0.28834623098373413
# Epoch 133: Iteration 100 with loss 0.5081132054328918
# Epoch 133: Iteration 120 with loss 0.7569728493690491
# Epoch 133: Iteration 140 with loss 0.5438284277915955
# Epoch 133 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.348697021170814
# Starting Training
# Epoch 134: Iteration 20 with loss 0.7792002558708191
# Epoch 134: Iteration 40 with loss 0.5937663316726685
# Epoch 134: Iteration 60 with loss 0.34382668137550354
# Epoch 134: Iteration 80 with loss 0.644589364528656
# Epoch 134: Iteration 100 with loss 0.37923741340637207
# Epoch 134: Iteration 120 with loss 0.4007282257080078
# Epoch 134: Iteration 140 with loss 0.3356172740459442
# Epoch 134 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 56.141919045448894
# Starting Training
# Epoch 135: Iteration 20 with loss 0.31939682364463806
# Epoch 135: Iteration 40 with loss 0.3360147178173065
# Epoch 135: Iteration 60 with loss 0.389828622341156
# Epoch 135: Iteration 80 with loss 0.20274798572063446
# Epoch 135: Iteration 100 with loss 0.2844405174255371
# Epoch 135: Iteration 120 with loss 0.4505186975002289
# Epoch 135: Iteration 140 with loss 0.23070859909057617
# Epoch 135 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.16168123627626
# Starting Training
# Epoch 136: Iteration 20 with loss 0.27081534266471863
# Epoch 136: Iteration 40 with loss 0.4036976993083954
# Epoch 136: Iteration 60 with loss 0.6301885843276978
# Epoch 136: Iteration 80 with loss 0.2336367815732956
# Epoch 136: Iteration 100 with loss 0.2170817255973816
# Epoch 136: Iteration 120 with loss 0.36875486373901367
# Epoch 136: Iteration 140 with loss 0.3622373938560486
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  6.2 minutes
# iter 30 of Expectation completed in a total of  8.7 minutes
# iter 40 of Expectation completed in a total of  11.6 minutes
# iter 50 of Expectation completed in a total of  14.7 minutes
# iter 60 of Expectation completed in a total of  17.1 minutes
# Expectation step finished, posterior frame-wise accuracy  71.52%, boundary mse  0.00
# Epoch 136 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.45900484732982
# Starting Training
# Epoch 137: Iteration 20 with loss 0.19706562161445618
# Epoch 137: Iteration 40 with loss 0.2895757555961609
# Epoch 137: Iteration 60 with loss 0.23778679966926575
# Epoch 137: Iteration 80 with loss 0.312898188829422
# Epoch 137: Iteration 100 with loss 0.5844261646270752
# Epoch 137: Iteration 120 with loss 0.6529443264007568
# Epoch 137: Iteration 140 with loss 0.46431902050971985
# Epoch 137 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.31754153374487
# Starting Training
# Epoch 138: Iteration 20 with loss 0.23658305406570435
# Epoch 138: Iteration 40 with loss 0.2789265811443329
# Epoch 138: Iteration 60 with loss 0.2629849910736084
# Epoch 138: Iteration 80 with loss 0.5005245804786682
# Epoch 138: Iteration 100 with loss 0.4441867470741272
# Epoch 138: Iteration 120 with loss 0.23377496004104614
# Epoch 138: Iteration 140 with loss 0.31146177649497986
# Epoch 138 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 50.67127232050379
# Starting Training
# Epoch 139: Iteration 20 with loss 0.24646469950675964
# Epoch 139: Iteration 40 with loss 0.6402969360351562
# Epoch 139: Iteration 60 with loss 0.37641647458076477
# Epoch 139: Iteration 80 with loss 0.3066617250442505
# Epoch 139: Iteration 100 with loss 0.38749590516090393
# Epoch 139: Iteration 120 with loss 0.32578355073928833
# Epoch 139: Iteration 140 with loss 0.19859173893928528
# Epoch 139 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.760202179226916
# Starting Training
# Epoch 140: Iteration 20 with loss 0.25224369764328003
# Epoch 140: Iteration 40 with loss 0.2725629210472107
# Epoch 140: Iteration 60 with loss 0.21974313259124756
# Epoch 140: Iteration 80 with loss 0.18082743883132935
# Epoch 140: Iteration 100 with loss 0.221665158867836
# Epoch 140: Iteration 120 with loss 0.16936245560646057
# Epoch 140: Iteration 140 with loss 0.47913098335266113
# Epoch 140 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.644612006463106
# Starting Training
# Epoch 141: Iteration 20 with loss 0.4058660566806793
# Epoch 141: Iteration 40 with loss 0.24043534696102142
# Epoch 141: Iteration 60 with loss 0.1603398621082306
# Epoch 141: Iteration 80 with loss 0.17944422364234924
# Epoch 141: Iteration 100 with loss 0.20911510288715363
# Epoch 141: Iteration 120 with loss 0.25060492753982544
# Epoch 141: Iteration 140 with loss 0.3621751666069031
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.0 minutes
# iter 20 of Expectation completed in a total of  5.7 minutes
# iter 30 of Expectation completed in a total of  8.9 minutes
# iter 40 of Expectation completed in a total of  12.1 minutes
# iter 50 of Expectation completed in a total of  14.8 minutes
# iter 60 of Expectation completed in a total of  17.7 minutes
# Expectation step finished, posterior frame-wise accuracy  71.42%, boundary mse  0.00
# Epoch 141 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 52.8074118573145
# Starting Training
# Epoch 142: Iteration 20 with loss 1.0841822624206543
# Epoch 142: Iteration 40 with loss 1.0511720180511475
# Epoch 142: Iteration 60 with loss 3.5707168579101562
# Epoch 142: Iteration 80 with loss 0.3374600112438202
# Epoch 142: Iteration 100 with loss 0.304198294878006
# Epoch 142: Iteration 120 with loss 1.5623254776000977
# Epoch 142: Iteration 140 with loss 0.3955152630805969
# Epoch 142 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 47.94806728259518
# Starting Training
# Epoch 143: Iteration 20 with loss 0.3417871594429016
# Epoch 143: Iteration 40 with loss 0.5957478284835815
# Epoch 143: Iteration 60 with loss 0.7239932417869568
# Epoch 143: Iteration 80 with loss 0.3215213716030121
# Epoch 143: Iteration 100 with loss 1.0308390855789185
# Epoch 143: Iteration 120 with loss 0.6570152044296265
# Epoch 143: Iteration 140 with loss 0.3588399291038513
# Epoch 143 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 53.300845175456764
# Starting Training
# Epoch 144: Iteration 20 with loss 0.2998413145542145
# Epoch 144: Iteration 40 with loss 0.5323089957237244
# Epoch 144: Iteration 60 with loss 0.3298690617084503
# Epoch 144: Iteration 80 with loss 0.2540099322795868
# Epoch 144: Iteration 100 with loss 0.42602720856666565
# Epoch 144: Iteration 120 with loss 0.7540956735610962
# Epoch 144: Iteration 140 with loss 0.30502474308013916
# Epoch 144 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.745308033309854
# Starting Training
# Epoch 145: Iteration 20 with loss 0.3469212055206299
# Epoch 145: Iteration 40 with loss 0.3518870174884796
# Epoch 145: Iteration 60 with loss 0.2242226004600525
# Epoch 145: Iteration 80 with loss 0.21302975714206696
# Epoch 145: Iteration 100 with loss 0.4819328486919403
# Epoch 145: Iteration 120 with loss 0.24307771027088165
# Epoch 145: Iteration 140 with loss 0.33754533529281616
# Epoch 145 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.095496540580854
# Starting Training
# Epoch 146: Iteration 20 with loss 1.3371660709381104
# Epoch 146: Iteration 40 with loss 0.2707693576812744
# Epoch 146: Iteration 60 with loss 0.8439446091651917
# Epoch 146: Iteration 80 with loss 0.2589189410209656
# Epoch 146: Iteration 100 with loss 0.3385900557041168
# Epoch 146: Iteration 120 with loss 0.2113022357225418
# Epoch 146: Iteration 140 with loss 0.16706016659736633
# Calculating expectation
# iter 10 of Expectation completed in a total of  3.4 minutes
# iter 20 of Expectation completed in a total of  6.4 minutes
# iter 30 of Expectation completed in a total of  9.5 minutes
# iter 40 of Expectation completed in a total of  12.9 minutes
# iter 50 of Expectation completed in a total of  15.2 minutes
# iter 60 of Expectation completed in a total of  18.4 minutes
# Expectation step finished, posterior frame-wise accuracy  71.66%, boundary mse  0.00
# Epoch 146 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.23727058043667
# Starting Training
# Epoch 147: Iteration 20 with loss 0.22782176733016968
# Epoch 147: Iteration 40 with loss 0.2603277266025543
# Epoch 147: Iteration 60 with loss 0.48704642057418823
# Epoch 147: Iteration 80 with loss 0.18803223967552185
# Epoch 147: Iteration 100 with loss 0.2961501479148865
# Epoch 147: Iteration 120 with loss 0.31639376282691956
# Epoch 147: Iteration 140 with loss 0.465196430683136
# Epoch 147 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 54.618220988523845
# Starting Training
# Epoch 148: Iteration 20 with loss 0.21369068324565887
# Epoch 148: Iteration 40 with loss 0.157078355550766
# Epoch 148: Iteration 60 with loss 0.20016951858997345
# Epoch 148: Iteration 80 with loss 0.3309101462364197
# Epoch 148: Iteration 100 with loss 3.4021971225738525
# Epoch 148: Iteration 120 with loss 0.34833645820617676
# Epoch 148: Iteration 140 with loss 0.4748780429363251
# Epoch 148 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.6550109789949
# Starting Training
# Epoch 149: Iteration 20 with loss 0.24548470973968506
# Epoch 149: Iteration 40 with loss 0.3236778676509857
# Epoch 149: Iteration 60 with loss 1.8286694288253784
# Epoch 149: Iteration 80 with loss 0.7717179656028748
# Epoch 149: Iteration 100 with loss 0.7282086610794067
# Epoch 149: Iteration 120 with loss 0.5477709770202637
# Epoch 149: Iteration 140 with loss 0.2936718463897705
# Epoch 149 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 51.81826656171024
# Starting Training
# Epoch 150: Iteration 20 with loss 0.625447154045105
# Epoch 150: Iteration 40 with loss 0.9380451440811157
# Epoch 150: Iteration 60 with loss 0.4477209448814392
# Epoch 150: Iteration 80 with loss 0.4433017671108246
# Epoch 150: Iteration 100 with loss 0.38061243295669556
# Epoch 150: Iteration 120 with loss 0.4466938376426697
# Epoch 150: Iteration 140 with loss 0.31911635398864746
# Epoch 150 finished, starting validation
# Calculating Validation Data Accuracy
# Validation:: Probability Accuracy 55.15764179475494

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {val_acc}")
# Out:
# Validation:: Epoch 105, Probability Accuracy 61.02425300046298

# %%
print(f"Validation:: Epoch {epoch}, Probability Accuracy {best_val_acc}")
# Out:
# Validation:: Epoch 149, Probability Accuracy 62.225110825703275

# %%
torch.save(model.state_dict(),
"/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-speed/final-em-maximized.wt")

# %%
config.output_dir
# Out:
# '/mnt/ssd/all_users/dipika/ms_tcn/data/breakfast//results/em-maximize-mstcn-split1/'

# %%
model.load_state_dict(torch.load(config.output_dir + "ms-tcn-emmax-best-model.wt"))
# model.load_state_dict(torch.load(config.output_dir + "ms-tcn-initial-15-epochs.wt"))
# Out:
# <All keys matched successfully>
